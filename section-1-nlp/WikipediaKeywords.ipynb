# %%
import wikipedia

# %%
ny = wikipedia.page("New York City")

# %%
ny.content[:1000] # limit output just for jupyter's sake
# Out:
# "The City of New York, often called New York City or simply New York, is the most populous city in the United States. With an estimated 2016 population of 8,537,673 distributed over a land area of about 302.6 square miles (784 km2), New York City is also the most densely populated major city in the United States. Located at the southern tip of the state of New York, the city is the center of the New York metropolitan area, one of the most populous urban agglomerations in the world with an estimated 23.7 million residents as of 2016. A global power city, New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, and sports. The city's fast pace defines the term New York minute. Home to the headquarters of the United Nations, New York is an important center for international diplomacy.\nSituated on one of the world's largest natural harbors, New York Ci"

# %%
import spacy

# %%
nlp = spacy.load('en')

# %%
nynlp = nlp(ny.content[:10000])

# %%
for chunk in nynlp.noun_chunks:
    print(chunk.text, "/", chunk.root.text, "/", chunk.root.dep_, "/", chunk.root.head.text)
# Out:
# The City / City / nsubj / is
# New York / York / pobj / of
# the most populous city / city / attr / is
# the United States / States / pobj / in
# an estimated 2016 population / population / pobj / With
# a land area / area / pobj / over
# about 302.6 square miles / miles / pobj / of
# 784 km2 / km2 / appos / miles
# New York City / City / nsubj / is
# the most densely populated major city / city / attr / is
# the United States / States / pobj / in
# the southern tip / tip / pobj / at
# the state / state / pobj / of
# New York / York / pobj / of
# the city / city / nsubj / is
# the center / center / attr / is
# the New York metropolitan area / area / pobj / of
# the most populous urban agglomerations / agglomerations / pobj / of
# the world / world / pobj / in
# an estimated 23.7 million residents / residents / pobj / with
# A global power city / city / nsubjpass / described
# New York City / City / appos / city
# the cultural, financial, and media capital / capital / pobj / as
# the world / world / pobj / of
# a significant impact / impact / dobj / exerts
# commerce / commerce / pobj / upon
# entertainment / entertainment / conj / commerce
# research / research / conj / entertainment
# technology / technology / conj / research
# education / education / conj / technology
# politics / politics / conj / education
# sports / sports / conj / politics
# The city's fast pace / pace / nsubj / defines
# the term / term / dobj / defines
# the headquarters / headquarters / pobj / to
# the United Nations / Nations / pobj / of
# New York / York / nsubj / is
# an important center / center / attr / is
# international diplomacy / diplomacy / pobj / for
# the world's largest natural harbors / harbors / pobj / of
# New York City / City / nsubj / consists
# five boroughs / boroughs / pobj / of
# a separate county / county / attr / is
# New York State / State / pobj / of
# The five boroughs / boroughs / nsubjpass / consolidated
# Brooklyn / Brooklyn / appos / boroughs
# Queens / Queens / conj / Brooklyn
# Manhattan / Manhattan / conj / Queens
# The Bronx / Bronx / conj / Manhattan
# Staten Island / Island / conj / Bronx
# a single city / city / pobj / into
# The city / city / nsubj / constitute
# its metropolitan area / area / conj / city
# the premier gateway / gateway / dobj / constitute
# legal immigration / immigration / pobj / for
# the United States / States / pobj / to
# as many as 800 languages / languages / nsubjpass / spoken
# New York / York / pobj / in
# it / it / nsubj / city
# the world / world / pobj / in
# New York City / City / nsubj / is
# more than 3.2 million residents / residents / pobj / to
# the United States / States / pobj / outside
# the largest foreign-born population / population / appos / States
# any city / city / pobj / of
# the world / world / pobj / in
# the tri-state New York Metropolitan Statistical Area / Area / nsubj / produced
# MSA / MSA / appos / Area
# a gross metropolitan product / product / dobj / produced
# GMP / GMP / appos / product
# greater New York City / City / nsubj / were
# a country / country / attr / were
# it / it / nsubj / have
# the 12th highest GDP / GDP / dobj / have
# the world / world / pobj / in
# New York City / City / nsubj / traces
# its origins / origins / dobj / traces
# a trading post / post / pobj / to
# colonists / colonists / pobj / by
# the Dutch Republic / Republic / pobj / from
# Lower Manhattan / Manhattan / pobj / on
# the post / post / nsubjpass / named
# The city / city / nsubj / came
# its surroundings / surroundings / conj / city
# English control / control / pobj / under
# King Charles II / II / nsubj / granted
# England / England / pobj / of
# the lands / lands / dobj / granted
# his brother / brother / pobj / to
# the Duke / Duke / appos / brother
# York / York / pobj / of
# New York / York / nsubj / served
# the capital / capital / pobj / as
# the United States / States / pobj / of
# It / It / nsubj / been
# the country's largest city / city / attr / been
# The Statue / Statue / nsubj / greeted
# Liberty / Liberty / pobj / of
# millions / millions / dobj / greeted
# immigrants / immigrants / pobj / of
# they / they / nsubj / came
# the Americas / Americas / pobj / to
# ship / ship / pobj / by
# the late 19th and early 20th centuries / centuries / pobj / in
# a world symbol / symbol / attr / is
# the United States / States / pobj / of
# its ideals / ideals / conj / symbol
# liberty / liberty / pobj / of
# peace / peace / conj / liberty
# the 21st century / century / pobj / In
# New York / York / nsubj / emerged
# a global node / node / pobj / as
# creativity / creativity / pobj / of
# entrepreneurship / entrepreneurship / conj / creativity
# social tolerance / tolerance / conj / creativity
# environmental sustainability / sustainability / conj / tolerance
# a symbol / symbol / pobj / as
# freedom / freedom / pobj / of
# cultural diversity / diversity / conj / freedom
# Many districts / districts / nsubj / are
# landmarks / landmarks / conj / districts
# New York City / City / pobj / in
# the city / city / nsubj / received
# a record 61 million tourists / tourists / dobj / received
# the world / world / pobj / of
# most visited tourist attractions / attractions / dobj / hosting
# Several sources / sources / nsubj / ranked
# New York / York / dobj / ranked
# the most photographed city / city / dobj / ranked
# the world / world / pobj / in
# Times Square / Square / nsubj / is
# the world's "heart / heart / pobj / as
# its "Crossroads / Crossroads / conj / iconic
# the brightly illuminated hub / hub / attr / is
# the Broadway Theater District / District / pobj / of
# the world's busiest pedestrian intersections / intersections / pobj / of
# a major center / center / conj / hub
# the world's entertainment industry / industry / pobj / of
# The names / names / nsubjpass / known
# the city's bridges / bridges / pobj / of
# skyscrapers / skyscrapers / conj / bridges
# parks / parks / conj / skyscrapers
# the world / world / pobj / around
# Wall Street / Street / pobj / by
# the Financial District / District / pobj / in
# Lower Manhattan / Manhattan / pobj / of
# New York City / City / nsubjpass / called
# the world / world / pobj / of
# the city / city / nsubj / is
# the world's two largest stock exchanges / exchanges / pobj / to
# total market capitalization / capitalization / pobj / by
# the New York Stock Exchange / Exchange / conj / is
# NASDAQ / NASDAQ / conj / Exchange
# Manhattan's real estate market / market / nsubj / is
# the world / world / pobj / in
# Manhattan's Chinatown / Chinatown / nsubj / incorporates
# the highest concentration / concentration / dobj / incorporates
# Chinese people / people / pobj / of
# the Western Hemisphere / Hemisphere / pobj / in
# multiple signature / signature / pobj / with
# Chinatowns / Chinatowns / nsubj / developing
# the city / city / pobj / across
# continuous 24/7 service / service / dobj / Providing
# the New York City Subway / Subway / nsubj / is
# the most extensive metro systems / systems / pobj / of
# 472 stations / stations / pobj / with
# operation / operation / pobj / in
# 120 colleges / colleges / pobj / Over
# universities / universities / nsubjpass / located
# New York City / City / pobj / in
# Columbia University / University / pobj / including
# New York University / University / conj / University
# Rockefeller University / University / conj / University
# the top universities / universities / pobj / among
# the world / world / pobj / in
# = History / History / appos / located
# ==
#
#
# === Etymology / Etymology / appos / History
# the city / city / nsubjpass / named
# Duke / Duke / pobj / after
# York / York / pobj / of
# England James II / II / pobj / of
# Charles II / II / nsubj / named
# King / King / appos / II
# England / England / pobj / of
# James's older brother / brother / appos / II
# him / him / dative / named
# the former territory / territory / pobj / of
# New Netherlands / Netherlands / pobj / of
# its main city / city / conj / territory
# New Amsterdam / Amsterdam / pobj / of
# the Dutch / Dutch / pobj / from
# the Wisconsinan glaciation / glaciation / pobj / During
# the New York City region / region / nsubjpass / situated
# the edge / edge / pobj / at
# a large ice sheet / sheet / pobj / of
# over 1,000 feet / feet / appos / sheet
# 300 m / m / appos / feet
# depth / depth / pobj / in
# The ice sheet / sheet / nsubj / scraped
# large amounts / amounts / dobj / scraped
# regolith / regolith / pobj / of
# the bedrock / bedrock / dobj / leaving
# the geologic foundation / foundation / pobj / as
# New York City / City / pobj / of
# movement / movement / nsubj / contribute
# the ice sheet / sheet / pobj / of
# the separation / separation / pobj / to
# what / what / nsubj / are
# Long Island / Island / attr / are
# Staten Island / Island / conj / Island
# the precolonial era / era / pobj / In
# the area / area / nsubjpass / inhabited
# present-day New York City / City / pobj / of
# Algonquian Native Americans / Americans / pobj / by
# the Lenape / Lenape / pobj / including
# whose homeland / homeland / nsubj / included
# Lenapehoking / Lenapehoking / pobj / as
# Staten Island / Island / dobj / included
# the western portion / portion / appos / Island
# Long Island / Island / pobj / of
# the area / area / pobj / including
# Brooklyn / Brooklyn / attr / become
# Queens / Queens / conj / Brooklyn
# Manhattan / Manhattan / conj / Brooklyn
# the Bronx / Bronx / conj / Manhattan
# the Lower Hudson Valley / Valley / conj / Bronx
# The first documented visit / visit / nsubj / was
# New York Harbor / Harbor / pobj / into
# a European / European / pobj / by
# Giovanni da Verrazzano / Verrazzano / pobj / by
# a Florentine explorer / explorer / appos / Verrazzano
# the service / service / pobj / in
# the French crown / crown / pobj / of
# He / He / nsubj / claimed
# the area / area / dobj / claimed
# France / France / pobj / for
# it / it / dobj / named
# New Angoulême / Angoulême / appos / Angoulême
# A Spanish expedition / expedition / nsubj / arrived
# captain Estêvão Gomes / Gomes / pobj / by
# a Portuguese sailing / sailing / appos / Gomes
# Emperor Charles V / V / pobj / for
# New York Harbor / Harbor / pobj / in
# January / January / pobj / in
# the mouth / mouth / dobj / charted
# the Hudson River / River / pobj / of
# he / he / nsubj / named
# The Padrón Real / Real / nsubjpass / informed
# the first scientific map / map / appos / Real
# North America's east coast / coast / dobj / show
# Gomes' expedition / expedition / pobj / by
# the Northeastern U.S. / U.S. / dobj / labeled
# Tierra de Esteban Gómez / Gómez / pobj / as
# his honor / honor / pobj / in
# the English explorer Henry Hudson / Hudson / nsubj / rediscovered
# the New York Harbor / Harbor / dobj / rediscovered
# the Northwest Passage / Passage / pobj / for
# the Orient / Orient / pobj / to
# the Dutch East India Company / Company / pobj / for
# He / He / nsubj / proceeded
# what / what / dobj / name
# the Dutch / Dutch / nsubj / name
# the North River / River / dobj / name
# now the Hudson River / River / appos / River
# Hudson / Hudson / pobj / by
# the Mauritius / Mauritius / pobj / as
# Maurice / Maurice / pobj / after
# Prince / Prince / conj / Mauritius
# Orange / Orange / pobj / of
# Hudson's first mate / mate / nsubj / described
# the harbor / harbor / dobj / described
# a very good Harbour / Harbour / pobj / as
# all windes / windes / pobj / for
# the river / river / conj / Harbour
# fish / fish / pobj / of
# Hudson / Hudson / nsubj / sailed
# the site / site / pobj / past
# present-day Albany / Albany / pobj / of
# the belief / belief / pobj / in
# it / it / nsubj / be
# an oceanic tributary / tributary / attr / be
# the river / river / nsubj / became
# He / He / nsubj / made
# a ten-day exploration / exploration / dobj / made
# the area / area / pobj / of
# the region / region / dobj / claimed
# the Dutch East India Company / Company / pobj / for
# the area / area / nsubjpass / claimed
# Cape Cod / Cod / pobj / between
# Delaware Bay / Bay / conj / Cod
# the Netherlands / Netherlands / pobj / by
# New Netherland / Netherland / appos / Nederland
# The first non-Native American inhabitant / inhabitant / nsubj / was
# what / what / nsubj / become
# New York City / City / attr / become
# Juan Rodriguez / Rodriguez / attr / was
# Dutch / Dutch / pobj / to
# Jan Rodrigues / Rodrigues / pobj / as
# a merchant / merchant / appos / transliterated
# Santo Domingo / Domingo / pobj / from
# Santo Domingo / Domingo / pobj / in
# Portuguese and African descent / descent / pobj / of
# he / he / nsubj / arrived
# Manhattan / Manhattan / pobj / in
# the winter / winter / pobj / during
# pelts / pelts / pobj / for
# trading / trading / conj / pelts
# the local population / population / pobj / with
# a representative / representative / pobj / as
# the Dutch / Dutch / pobj / of
# Broadway / Broadway / nsubjpass / named
# 159th Street / Street / pobj / from
# 218th Street / Street / pobj / to
# Upper Manhattan / Manhattan / pobj / in
# his honor / honor / pobj / in
# === Dutch rule / rule / nsubj / began
# A permanent European presence / presence / nsubj / began
# New Netherland / Netherland / pobj / in
# New York / York / dobj / making
# European-established settlement / settlement / dobj / occupied
# the continental United States / States / pobj / in
# the founding / founding / pobj / with
# a Dutch fur trading settlement / settlement / pobj / of
# Governors Island / Island / pobj / on
# construction / construction / nsubjpass / started
# a citadel / citadel / pobj / on
# Fort Amsterdam / Amsterdam / conj / citadel
# Manhattan Island / Island / pobj / on
# New Amsterdam / Amsterdam / appos / Amsterdam
# The colony / colony / nsubjpass / centered
# New Amsterdam / Amsterdam / pobj / of
# the site / site / pobj / at
# Lower Manhattan / Manhattan / attr / become
# the Dutch colonial Director-General / General / nsubj / purchased
# Peter Minuit / Minuit / appos / General
# the Dutch West India Company / Company / pobj / by
# the island / island / dobj / purchased
# Manhattan / Manhattan / pobj / of
# the Canarsie / Canarsie / pobj / from
# a small Lenape band / band / appos / Canarsie
# 60 guilders / guilders / pobj / for
# A disproved legend / legend / nsubj / claims
# Manhattan / Manhattan / nsubjpass / purchased
# glass beads / beads / pobj / of
# the purchase / purchase / pobj / Following
# New Amsterdam / Amsterdam / nsubj / grew
# settlers / settlers / dobj / attract
# the Dutch / Dutch / nsubj / instituted
# the patroon system / system / dobj / instituted
# wealthy Dutchmen / Dutchmen / nsubjpass / awarded
# "patroons / patroons / appos / Dutchmen
# patrons / patrons / conj / patroons
# who / who / nsubj / brought
# 50 colonists / colonists / dobj / brought
# New Netherland / Netherland / pobj / to
# swathes / swathes / dobj / awarded
# land / land / pobj / of
# local political autonomy / autonomy / pobj / with
# rights / rights / conj / autonomy
# the lucrative fur trade / trade / pobj / in
# This program / program / nsubj / had
# little success / success / dobj / had
# the Dutch West India Company / Company / nsubj / operated
# a monopoly / monopoly / pobj / as
# New Netherland / Netherland / pobj / in
# authority / authority / pobj / on
# the Dutch States General / General / pobj / by
# an effort / effort / pobj / in
# economic growth / growth / dobj / bolster
# the Dutch West India Company / Company / nsubj / relinquished
# its monopoly / monopoly / dobj / relinquished
# the fur trade / trade / pobj / over
# growth / growth / pobj / to
# the production / production / pobj / in
# trade / trade / conj / production
# food / food / pobj / of
# timber / timber / conj / food
# tobacco / tobacco / conj / timber
# slaves / slaves / conj / tobacco
# the Dutch West Indies / Indies / pobj / with
# Peter Stuyvesant / Stuyvesant / nsubj / began
# his tenure / tenure / dobj / began
# the last Director-General / General / pobj / as
# New Netherland / Netherland / pobj / of
# his tenure / tenure / pobj / During
# the population / population / nsubj / grew
# New Netherland / Netherland / pobj / of
# Stuyvesant / Stuyvesant / nsubjpass / credited
# law / law / dobj / improving
# order / order / conj / law
# the colony / colony / pobj / in
# he / he / nsubj / earned
# a reputation / reputation / dobj / earned
# a despotic leader / leader / pobj / as
# He / He / nsubj / instituted
# regulations / regulations / dobj / instituted
# liquor sales / sales / pobj / on
# control / control / dobj / assert
# the Dutch Reformed Church / Church / pobj / over
# other religious groups / groups / dobj / blocked
# Quakers / Quakers / pobj / including
# Jews / Jews / conj / Quakers
# Lutherans / Lutherans / conj / Jews
# houses / houses / dobj / establishing
# worship / worship / pobj / of
# The Dutch West India Company / Company / nsubj / attempt
# tensions / tensions / dobj / ease
# Stuyvesant / Stuyvesant / pobj / between
# residents / residents / conj / Stuyvesant
# New Amsterdam / Amsterdam / pobj / of
# == English rule / rule / appos / attempt
# any significant resistance / resistance / dobj / summon
# Stuyvesant / Stuyvesant / nsubj / surrendered
# New Amsterdam / Amsterdam / dobj / surrendered
# English troops / troops / pobj / to
# Colonel Richard Nicolls / Nicolls / pobj / by
# bloodshed / bloodshed / pobj / without
# The terms / terms / nsubj / permitted
# the surrender / surrender / pobj / of
# Dutch residents / residents / dobj / permitted
# the colony / colony / pobj / in
# religious freedom / freedom / pobj / for
# The English / English / nsubj / renamed
# the fledgling city / city / dobj / renamed
# New York / York / appos / city
# the Duke / Duke / pobj / after
# York / York / pobj / of
# the future King James II / II / appos / Duke
# England / England / pobj / of

# %%
for ent in nynlp.ents:
    print(ent.text, "/", ent.start_char, "/", ent.end_char, "/", ent.label_)
# Out:
# The City of New York / 0 / 20 / GPE
# New York City / 35 / 48 / GPE
# New York / 59 / 67 / GPE
# the United States / 98 / 115 / GPE
# 2016 / 135 / 139 / DATE
# 8,537,673 / 154 / 163 / CARDINAL
# about 302.6 square miles / 196 / 220 / QUANTITY
# 784 / 222 / 225 / CARDINAL
# New York City / 232 / 245 / GPE
# the United States / 295 / 312 / GPE
# New York / 358 / 366 / GPE
# New York / 398 / 406 / GPE
# one / 426 / 429 / CARDINAL
# an estimated 23.7 million / 490 / 515 / CARDINAL
# 2016 / 532 / 536 / DATE
# New York City / 559 / 572 / GPE
# New York / 807 / 815 / GPE
# the United Nations / 852 / 870 / ORG
# New York / 872 / 880 / GPE
#
#  / 932 / 933 / GPE
# one / 945 / 948 / CARDINAL
# New York City / 989 / 1002 / GPE
# five / 1015 / 1019 / CARDINAL
# New York State / 1068 / 1082 / GPE
# five / 1088 / 1092 / CARDINAL
# Brooklyn / 1104 / 1112 / GPE
# Queens / 1114 / 1120 / GPE
# Manhattan / 1122 / 1131 / GPE
# Bronx / 1137 / 1142 / GPE
# Staten Island – were / 1148 / 1168 / PERSON
# 1898 / 1204 / 1208 / DATE
# the United States / 1301 / 1318 / GPE
# as many as 800 / 1324 / 1338 / CARDINAL
# New York / 1363 / 1371 / GPE
# New York City / 1434 / 1447 / GPE
# more than 3.2 million / 1459 / 1480 / CARDINAL
# the United States / 1504 / 1521 / GPE
# 2013 / 1588 / 1592 / DATE
# New York Metropolitan Statistical Area / 1608 / 1646 / ORG
# GMP / 1692 / 1695 / ORG
# nearly US$1.4 trillion / 1700 / 1722 / MONEY
# New York City / 1735 / 1748 / GPE
# 12th / 1783 / 1787 / ORDINAL
#
#  / 1813 / 1814 / GPE
# New York City / 1814 / 1827 / GPE
# the Dutch Republic / 1891 / 1909 / GPE
# 1624 / 1913 / 1917 / DATE
# Lower Manhattan / 1921 / 1936 / LOC
# New Amsterdam / 1957 / 1970 / GPE
# 1626 / 1974 / 1978 / DATE
# English / 2021 / 2028 / LANGUAGE
# 1664 / 2040 / 2044 / DATE
# New York / 2062 / 2070 / GPE
# Charles II / 2082 / 2092 / PERSON
# England / 2096 / 2103 / GPE
# York / 2150 / 2154 / PERSON
# New York / 2156 / 2164 / GPE
# the United States / 2190 / 2207 / GPE
# 1785 / 2213 / 2217 / DATE
# 1790 / 2224 / 2228 / DATE
# 1790 / 2275 / 2279 / DATE
# The Statue of Liberty / 2281 / 2302 / WORK_OF_ART
# millions / 2311 / 2319 / CARDINAL
# Americas / 2354 / 2362 / LOC
# the late 19th and early 20th centuries / 2374 / 2412 / DATE
# the United States / 2438 / 2455 / GPE
# the 21st century / 2496 / 2512 / DATE
# New York / 2514 / 2522 / GPE
#
#  / 2690 / 2691 / GPE
# New York City / 2723 / 2736 / GPE
# 61 million / 2784 / 2794 / CARDINAL
# 2016 / 2807 / 2811 / DATE
# three / 2821 / 2826 / CARDINAL
# ten / 2842 / 2845 / CARDINAL
# 2013 / 2882 / 2886 / DATE
# New York / 2916 / 2924 / GPE
# Times Square / 2966 / 2978 / FAC
# the Broadway Theater District / 3067 / 3096 / FAC
# the Financial District of Lower Manhattan / 3328 / 3369 / LOC
# New York City / 3371 / 3384 / GPE
# two / 3525 / 3528 / CARDINAL
# the New York Stock Exchange / 3585 / 3612 / ORG
# NASDAQ / 3617 / 3623 / ORG
# Manhattan / 3625 / 3634 / GPE
# Manhattan / 3698 / 3707 / GPE
# Chinese / 3762 / 3769 / NORP
# the Western Hemisphere / 3780 / 3802 / LOC
# 24/7 / 3888 / 3892 / CARDINAL
# the New York City Subway / 3902 / 3926 / ORG
# one / 3930 / 3933 / CARDINAL
# 472 / 3986 / 3989 / CARDINAL
# 120 / 4018 / 4021 / CARDINAL
# New York City / 4063 / 4076 / GPE
# Columbia University / 4088 / 4107 / ORG
# New York University / 4109 / 4128 / ORG
# Rockefeller University / 4134 / 4156 / ORG
#
#  / 4257 / 4258 / GPE
# 1664 / 4261 / 4265 / DATE
# York / 4305 / 4309 / ORG
# Charles II / 4348 / 4358 / PERSON
# King of England / 4360 / 4375 / ORG
# James / 4377 / 4382 / PERSON
# New Netherlands / 4452 / 4467 / GPE
# New Amsterdam / 4489 / 4502 / GPE
# Dutch / 4544 / 4549 / NORP
#
#
#
#  / 4550 / 4553 / PERSON
#
#  / 4574 / 4575 / GPE
# Wisconsinan / 4586 / 4597 / PERSON
# New York City / 4614 / 4627 / GPE
# over 1,000 feet / 4681 / 4696 / QUANTITY
# 300 m / 4698 / 4703 / QUANTITY
# New York City / 4840 / 4853 / GPE
# today / 4854 / 4859 / DATE
# Long Island / 4948 / 4959 / GPE
# Staten Island / 4964 / 4977 / LOC
#
#  / 4978 / 4979 / GPE
# the precolonial era / 4982 / 5001 / DATE
# present-day / 5015 / 5026 / DATE
# New York City / 5027 / 5040 / GPE
# Algonquian / 5058 / 5068 / NORP
# Native Americans / 5069 / 5085 / NORP
# Lenape / 5101 / 5107 / GPE
# Lenapehoking / 5134 / 5146 / ORG
# Staten Island / 5157 / 5170 / PERSON
# Long Island / 5195 / 5206 / LOC
# Brooklyn / 5245 / 5253 / GPE
# Queens / 5258 / 5264 / GPE
# Manhattan / 5266 / 5275 / GPE
# Bronx / 5281 / 5286 / GPE
# the Lower Hudson Valley / 5292 / 5315 / LOC
#
#  / 5316 / 5317 / GPE
# first / 5321 / 5326 / ORDINAL
# New York Harbor / 5349 / 5364 / LOC
# European / 5370 / 5378 / NORP
# 1524 / 5386 / 5390 / DATE
# Giovanni da Verrazzano / 5394 / 5416 / PERSON
# Florentine / 5420 / 5430 / ORG
# French / 5462 / 5468 / NORP
# France / 5500 / 5506 / GPE
# Nouvelle Angoulême / 5520 / 5538 / PERSON
# New Angoulême / 5540 / 5553 / PERSON
# Spanish / 5559 / 5566 / NORP
# Estêvão Gomes / 5593 / 5606 / PERSON
# Portuguese / 5610 / 5620 / NORP
# Charles V / 5641 / 5650 / PERSON
# New York Harbor / 5663 / 5678 / GPE
# January 1525 / 5682 / 5694 / DATE
# the Hudson River / 5716 / 5732 / LOC
# Río de San Antonio / 5749 / 5767 / PERSON
# Saint Anthony's / 5769 / 5784 / GPE
# The Padrón Real of 1527 / 5793 / 5816 / LAW
# North America's / 5851 / 5866 / LOC
# Gomes / 5908 / 5913 / PERSON
# the Northeastern U.S. / 5938 / 5959 / LOC
# Tierra de Esteban Gómez / 5963 / 5986 / PERSON
#
#  / 6000 / 6001 / GPE
# 1609 / 6004 / 6008 / DATE
# English / 6014 / 6021 / LANGUAGE
# Henry Hudson / 6031 / 6043 / PERSON
# New York Harbor / 6061 / 6076 / LOC
# the Northwest Passage / 6097 / 6118 / GPE
# Orient / 6126 / 6132 / LOC
# the Dutch East India Company / 6137 / 6165 / ORG
# Dutch / 6200 / 6205 / NORP
# the North River / 6217 / 6232 / LOC
# the Hudson River / 6238 / 6254 / LOC
# first / 6263 / 6268 / ORDINAL
# Hudson / 6272 / 6278 / LOC
# Mauritius / 6286 / 6295 / PERSON
# Maurice / 6302 / 6309 / PERSON
# Hudson / 6329 / 6335 / PERSON
# first / 6338 / 6343 / ORDINAL
# Harbour / 6386 / 6393 / LOC
# Hudson / 6462 / 6468 / PERSON
# roughly 150 miles / 6476 / 6493 / QUANTITY
# present-day / 6518 / 6529 / DATE
# Albany / 6530 / 6536 / GPE
# ten-day / 6649 / 6656 / DATE
# the Dutch East India Company / 6708 / 6736 / ORG
# 1614 / 6741 / 6745 / DATE
# Cape Cod / 6764 / 6772 / LOC
# Delaware Bay / 6777 / 6789 / LOC
# Netherlands / 6814 / 6825 / GPE
# Nieuw-Nederland / 6837 / 6852 / GPE
# New Netherland / 6854 / 6868 / GPE
#
#  / 6870 / 6871 / GPE
# first / 6875 / 6880 / ORDINAL
# Native American / 6885 / 6900 / NORP
# New York City / 6944 / 6957 / GPE
# Juan Rodriguez / 6962 / 6976 / PERSON
# Dutch / 6996 / 7001 / NORP
# Santo Domingo / 7037 / 7050 / PRODUCT
# Santo Domingo / 7060 / 7073 / PERSON
# Portuguese / 7077 / 7087 / NORP
# African / 7092 / 7099 / NORP
# Manhattan / 7123 / 7132 / GPE
# winter / 7144 / 7150 / DATE
# Dutch / 7249 / 7254 / NORP
# Broadway / 7256 / 7264 / FAC
# 159th Street / 7271 / 7283 / FAC
# 218th Street / 7287 / 7299 / FAC
# Upper Manhattan / 7303 / 7318 / GPE
# Juan Rodriguez Way / 7329 / 7347 / PERSON
# Dutch / 7368 / 7373 / NORP
#
#  / 7382 / 7383 / GPE
# European / 7395 / 7403 / NORP
# New Netherland / 7416 / 7430 / GPE
# 1624 / 7440 / 7444 / DATE
# New York / 7454 / 7462 / GPE
# 12th / 7467 / 7471 / ORDINAL
# European / 7501 / 7509 / NORP
# United States / 7552 / 7565 / GPE
# Dutch / 7591 / 7596 / NORP
# Governors Island / 7623 / 7639 / LOC
# 1625 / 7644 / 7648 / DATE
# Fort Amsterdam / 7692 / 7706 / GPE
# Manhattan Island / 7710 / 7726 / LOC
# Nieuw Amsterdam / 7741 / 7756 / PERSON
# New Amsterdam / 7758 / 7771 / GPE
# New Amsterdam / 7788 / 7801 / GPE
# Lower Manhattan / 7857 / 7872 / LOC
# 1626 / 7877 / 7881 / DATE
# Dutch / 7887 / 7892 / NORP
# Peter Minuit / 7919 / 7931 / PERSON
# the Dutch West India Company / 7954 / 7982 / ORG
# Manhattan / 8008 / 8017 / GPE
# Canarsie / 8027 / 8035 / PERSON
# Lenape / 8045 / 8051 / ORG
# 60 guilders / 8062 / 8073 / MONEY
# about $1,000 / 8075 / 8087 / MONEY
# 2006 / 8091 / 8095 / DATE
# Manhattan / 8129 / 8138 / GPE
# 24 / 8158 / 8160 / MONEY
#
#  / 8182 / 8183 / GPE
# New Amsterdam / 8207 / 8220 / GPE
# Dutch / 8259 / 8264 / NORP
# 1628 / 8298 / 8302 / DATE
# Dutchmen / 8320 / 8328 / GPE
# 50 / 8366 / 8368 / CARDINAL
# New Netherland / 8382 / 8396 / GPE
#
#  / 8553 / 8554 / GPE
# 1621 / 8560 / 8564 / DATE
# the Dutch West India Company / 8566 / 8594 / ORG
# New Netherland / 8625 / 8639 / GPE
# the Dutch States General / 8665 / 8689 / ORG
# 1639–1640 / 8694 / 8703 / DATE
# the Dutch West India Company / 8746 / 8774 / ORG
# the Dutch West Indies / 8923 / 8944 / ORG
#
#  / 8946 / 8947 / GPE
# 1647 / 8950 / 8954 / DATE
# Peter Stuyvesant / 8956 / 8972 / PERSON
# New Netherland / 9022 / 9036 / GPE
# New Netherland / 9075 / 9089 / GPE
# 2,000 to 8,000 / 9100 / 9114 / CARDINAL
# the Dutch Reformed Church / 9324 / 9349 / ORG
# Quakers / 9397 / 9404 / PERSON
# Jews / 9406 / 9410 / NORP
# Lutherans / 9416 / 9425 / NORP
# The Dutch West India Company / 9464 / 9492 / ORG
# Stuyvesant / 9543 / 9553 / GPE
# New Amsterdam / 9571 / 9584 / GPE
# English / 9592 / 9599 / NORP
#
#  / 9608 / 9609 / GPE
# 1664 / 9612 / 9616 / DATE
# New Amsterdam / 9686 / 9699 / GPE
# English / 9703 / 9710 / NORP
# Richard Nicolls / 9733 / 9748 / PERSON
# Dutch / 9805 / 9810 / NORP
# English / 9884 / 9891 / NORP
# New York / 9929 / 9937 / GPE
# York / 9957 / 9961 / PERSON
# James II / 9979 / 9987 / PERSON
# England / 9991 / 9998 / GPE

# %%
for token in nlp(u'The Statue of Liberty greeted millions of immigrants who came to the Americas by ship in the late 19th and early 20th centuries and is a world symbol of the United States and its ideals of liberty and peace.'):
    print(token.text, "/", token.pos_, "/", token.tag_, "/", token.is_alpha, "/", token.is_stop)
# Out:
# The / DET / DT / True / False
# Statue / PROPN / NNP / True / False
# of / ADP / IN / True / True
# Liberty / PROPN / NNP / True / False
# greeted / VERB / VBD / True / False
# millions / NOUN / NNS / True / False
# of / ADP / IN / True / True
# immigrants / NOUN / NNS / True / False
# who / NOUN / WP / True / True
# came / VERB / VBD / True / False
# to / ADP / IN / True / True
# the / DET / DT / True / True
# Americas / PROPN / NNPS / True / False
# by / ADP / IN / True / True
# ship / NOUN / NN / True / False
# in / ADP / IN / True / True
# the / DET / DT / True / True
# late / ADJ / JJ / True / False
# 19th / ADJ / JJ / False / False
# and / CCONJ / CC / True / True
# early / ADJ / JJ / True / False
# 20th / ADJ / JJ / False / False
# centuries / NOUN / NNS / True / False
# and / CCONJ / CC / True / True
# is / VERB / VBZ / True / True
# a / DET / DT / True / True
# world / NOUN / NN / True / False
# symbol / NOUN / NN / True / False
# of / ADP / IN / True / True
# the / DET / DT / True / True
# United / PROPN / NNP / True / False
# States / PROPN / NNP / True / False
# and / CCONJ / CC / True / True
# its / ADJ / PRP$ / True / True
# ideals / NOUN / NNS / True / False
# of / ADP / IN / True / True
# liberty / NOUN / NN / True / False
# and / CCONJ / CC / True / True
# peace / NOUN / NN / True / False
# . / PUNCT / . / False / False

# %%
from spacy.matcher import Matcher

# %%
from spacy import displacy

# %%
matcher = Matcher(nlp.vocab)
matched_sents = [] # collect data of matched sentences to be visualized
matched_phrases = [] # just the matched phrases without the sentence

def collect_sents(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = doc[start : end] # matched span
    sent = span.sent # sentence containing matched span
    # append mock entity for match in displaCy style to matched_sents
    # get the match span by ofsetting the start and end of the span with the
    # start and end of the sentence in the doc
    match_ents = [{'start': span.start_char - sent.start_char, 
                   'end': span.end_char - sent.start_char,
                   'label': 'MATCH'}]
    matched_sents.append({'text': sent.text, 'ents': match_ents})
    matched_phrases.append(span.text)

# %%
pattern = [{'POS': 'NOUN'}, {'POS': 'NOUN'}]

# %%
matcher.add('nounphrase', collect_sents, pattern) # add pattern

# %%
matches = matcher(nynlp)

# %%
matches
# Out:
# [(8429085606845659861, 36, 38),
#  (8429085606845659861, 110, 112),
#  (8429085606845659861, 126, 128),
#  (8429085606845659861, 371, 373),
#  (8429085606845659861, 482, 484),
#  (8429085606845659861, 565, 567),
#  (8429085606845659861, 618, 620),
#  (8429085606845659861, 629, 631),
#  (8429085606845659861, 696, 698),
#  (8429085606845659861, 700, 702),
#  (8429085606845659861, 714, 716),
#  (8429085606845659861, 742, 744),
#  (8429085606845659861, 765, 767),
#  (8429085606845659861, 915, 917),
#  (8429085606845659861, 928, 930),
#  (8429085606845659861, 944, 946),
#  (8429085606845659861, 960, 962),
#  (8429085606845659861, 1152, 1154),
#  (8429085606845659861, 1313, 1315),
#  (8429085606845659861, 1492, 1494),
#  (8429085606845659861, 1493, 1495),
#  (8429085606845659861, 1601, 1603),
#  (8429085606845659861, 1622, 1624),
#  (8429085606845659861, 1664, 1666),
#  (8429085606845659861, 1721, 1723),
#  (8429085606845659861, 1813, 1815),
#  (8429085606845659861, 1924, 1926)]

# %%
matched_sents
# Out:
# [{'ents': [{'end': 75, 'label': 'MATCH', 'start': 66}],
#   'text': 'With an estimated 2016 population of 8,537,673 distributed over a land area of about 302.6 square miles (784 km2), New York City is also the most densely populated major city in the United States.'},
#  {'ents': [{'end': 19, 'label': 'MATCH', 'start': 9}],
#   'text': 'A global power city, New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, and sports.'},
#  {'ents': [{'end': 99, 'label': 'MATCH', 'start': 86}],
#   'text': 'A global power city, New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, and sports.'},
#  {'ents': [{'end': 50, 'label': 'MATCH', 'start': 38}],
#   'text': 'New York City traces its origins to a trading post founded by colonists from the Dutch Republic in 1624 on Lower Manhattan; the post was named New Amsterdam in 1626.'},
#  {'ents': [{'end': 153, 'label': 'MATCH', 'start': 141}],
#   'text': 'The Statue of Liberty greeted millions of immigrants as they came to the Americas by ship in the late 19th and early 20th centuries and is a world symbol of the United States and its ideals of liberty and peace.'},
#  {'ents': [{'end': 187, 'label': 'MATCH', 'start': 168}],
#   'text': "Many districts and landmarks in New York City are well known, and the city received a record 61 million tourists in 2016, hosting three of the world's ten most visited tourist attractions in 2013."},
#  {'ents': [{'end': 183, 'label': 'MATCH', 'start': 159}],
#   'text': 'Times Square, iconic as the world\'s "heart" and its "Crossroads", is the brightly illuminated hub of the Broadway Theater District, one of the world\'s busiest pedestrian intersections, and a major center of the world\'s entertainment industry.'},
#  {'ents': [{'end': 241, 'label': 'MATCH', 'start': 219}],
#   'text': 'Times Square, iconic as the world\'s "heart" and its "Crossroads", is the brightly illuminated hub of the Broadway Theater District, one of the world\'s busiest pedestrian intersections, and a major center of the world\'s entertainment industry.'},
#  {'ents': [{'end': 251, 'label': 'MATCH', 'start': 236}],
#   'text': "Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the most economically powerful city and the leading financial center of the world, and the city is home to the world's two largest stock exchanges by total market capitalization, the New York Stock Exchange and NASDAQ."},
#  {'ents': [{'end': 282, 'label': 'MATCH', 'start': 261}],
#   'text': "Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the most economically powerful city and the leading financial center of the world, and the city is home to the world's two largest stock exchanges by total market capitalization, the New York Stock Exchange and NASDAQ."},
#  {'ents': [{'end': 30, 'label': 'MATCH', 'start': 17}],
#   'text': "Manhattan's real estate market is among the most expensive in the world."},
#  {'ents': [{'end': 140, 'label': 'MATCH', 'start': 120}],
#   'text': "Manhattan's Chinatown incorporates the highest concentration of Chinese people in the Western Hemisphere, with multiple signature Chinatowns developing across the city."},
#  {'ents': [{'end': 102, 'label': 'MATCH', 'start': 89}],
#   'text': 'Providing continuous 24/7 service, the New York City Subway is one of the most extensive metro systems worldwide, with 472 stations in operation.'},
#  {'ents': [{'end': 105, 'label': 'MATCH', 'start': 96}],
#   'text': 'During the Wisconsinan glaciation, the New York City region was situated at the edge of a large ice sheet over 1,000 feet (300 m) in depth.'},
#  {'ents': [{'end': 13, 'label': 'MATCH', 'start': 4}],
#   'text': 'The ice sheet scraped away large amounts of regolith, leaving the bedrock that serves as the geologic foundation for much of New York City today.'},
#  {'ents': [{'end': 112, 'label': 'MATCH', 'start': 93}],
#   'text': 'The ice sheet scraped away large amounts of regolith, leaving the bedrock that serves as the geologic foundation for much of New York City today.'},
#  {'ents': [{'end': 35, 'label': 'MATCH', 'start': 26}],
#   'text': 'Later on, movement of the ice sheet would contribute to the separation of what are now Long Island and Staten Island.\n'},
#  {'ents': [{'end': 84, 'label': 'MATCH', 'start': 74}],
#   'text': "The Padrón Real of 1527, the first scientific map to show North America's east coast continuously, was informed by Gomes' expedition and labeled the Northeastern U.S. as Tierra de Esteban Gómez in his honor.\n"},
#  {'ents': [{'end': 29, 'label': 'MATCH', 'start': 14}],
#   'text': 'He made a ten-day exploration of the area and claimed the region for the Dutch East India Company.'},
#  {'ents': [{'end': 145, 'label': 'MATCH', 'start': 134}],
#   'text': 'the 12th oldest continuously occupied European-established settlement in the continental United States – with the founding of a Dutch fur trading settlement on Governors Island.'},
#  {'ents': [{'end': 156, 'label': 'MATCH', 'start': 138}],
#   'text': 'the 12th oldest continuously occupied European-established settlement in the continental United States – with the founding of a Dutch fur trading settlement on Governors Island.'},
#  {'ents': [{'end': 83, 'label': 'MATCH', 'start': 72}],
#   'text': 'A disproved legend claims that Manhattan was purchased for $24 worth of glass beads.\n'},
#  {'ents': [{'end': 60, 'label': 'MATCH', 'start': 46}],
#   'text': 'To attract settlers, the Dutch instituted the patroon system in 1628, whereby wealthy Dutchmen ("patroons", or patrons) who brought 50 colonists to New Netherland would be awarded swathes of land, along with local political autonomy and rights to participate in the lucrative fur trade.'},
#  {'ents': [{'end': 285, 'label': 'MATCH', 'start': 276}],
#   'text': 'To attract settlers, the Dutch instituted the patroon system in 1628, whereby wealthy Dutchmen ("patroons", or patrons) who brought 50 colonists to New Netherland would be awarded swathes of land, along with local political autonomy and rights to participate in the lucrative fur trade.'},
#  {'ents': [{'end': 128, 'label': 'MATCH', 'start': 119}],
#   'text': 'In 1639–1640, in an effort to bolster economic growth, the Dutch West India Company relinquished its monopoly over the fur trade, leading to growth in the production and trade of food, timber, tobacco, and slaves (particularly with the Dutch West Indies).\n'},
#  {'ents': [{'end': 41, 'label': 'MATCH', 'start': 29}],
#   'text': 'He instituted regulations on liquor sales, attempted to assert control over the Dutch Reformed Church, and blocked other religious groups (including Quakers, Jews, and Lutherans) from establishing houses of worship.'},
#  {'ents': [{'end': 47, 'label': 'MATCH', 'start': 33}],
#   'text': 'The English promptly renamed the fledgling city "New York" after the Duke of York (the future King James II of England).'}]

# %%
displacy.render(matched_sents, style='ent', manual=True, jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5">With an estimated 2016 population of 8,537,673 distributed over a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     land area
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of about 302.6 square miles (784 km2), New York City is also the most densely populated major city in the United States.</div>
#
# <div class="entities" style="line-height: 2.5">A global
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     power city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# , New York City has been described as the cultural, financial, and media capital of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, and sports.</div>
#
# <div class="entities" style="line-height: 2.5">A global power city, New York City has been described as the cultural, financial, and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     media capital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of the world, and exerts a significant impact upon commerce, entertainment, research, technology, education, politics, and sports.</div>
#
# <div class="entities" style="line-height: 2.5">New York City traces its origins to a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     trading post
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  founded by colonists from the Dutch Republic in 1624 on Lower Manhattan; the post was named New Amsterdam in 1626.</div>
#
# <div class="entities" style="line-height: 2.5">The Statue of Liberty greeted millions of immigrants as they came to the Americas by ship in the late 19th and early 20th centuries and is a
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     world symbol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  of the United States and its ideals of liberty and peace.</div>
#
# <div class="entities" style="line-height: 2.5">Many districts and landmarks in New York City are well known, and the city received a record 61 million tourists in 2016, hosting three of the world's ten most visited
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     tourist attractions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  in 2013.</div>
#
# <div class="entities" style="line-height: 2.5">Times Square, iconic as the world's "heart" and its "Crossroads", is the brightly illuminated hub of the Broadway Theater District, one of the world's busiest
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     pedestrian intersections
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# , and a major center of the world's entertainment industry.</div>
#
# <div class="entities" style="line-height: 2.5">Times Square, iconic as the world's "heart" and its "Crossroads", is the brightly illuminated hub of the Broadway Theater District, one of the world's busiest pedestrian intersections, and a major center of the world's
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     entertainment industry
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# .</div>
#
# <div class="entities" style="line-height: 2.5">Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the most economically powerful city and the leading financial center of the world, and the city is home to the world's two largest
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     stock exchanges
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  by total market capitalization, the New York Stock Exchange and NASDAQ.</div>
#
# <div class="entities" style="line-height: 2.5">Anchored by Wall Street in the Financial District of Lower Manhattan, New York City has been called both the most economically powerful city and the leading financial center of the world, and the city is home to the world's two largest stock exchanges by total
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     market capitalization
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
# , the New York Stock Exchange and NASDAQ.</div>
#
# <div class="entities" style="line-height: 2.5">Manhattan's real
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     estate market
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  is among the most expensive in the world.</div>
#
# <div class="entities" style="line-height: 2.5">Manhattan's Chinatown incorporates the highest concentration of Chinese people in the Western Hemisphere, with multiple
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     signature Chinatowns
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MATCH</span>
# </mark>
#  developing across the city.</div>
#
# <div class="entities" style="line-height: 2.5">Providing continuous 24/7 service, the New York City Subway is one of the m

# %%
#patterns = [[{'POS': 'ADJ', 'IS_ALPHA': True, 'IS_STOP': False, 'OP': '*'},
#             {'POS': 'NOUN', 'IS_ALPHA': True, 'IS_STOP': False, 'OP': '+'}],
#            [{'POS': 'NOUN', 'IS_ALPHA': True, 'IS_STOP': False},
#             {'POS': 'ADP', 'IS_ALPHA': True},
#             {'POS': 'NOUN', 'IS_ALPHA': True, 'IS_STOP': False, 'OP': '+'}]
#           ]
patterns = [[{'POS': 'NOUN', 'IS_ALPHA': True, 'IS_STOP': False, 'OP': '+'}]]
matcher = Matcher(nlp.vocab)
matched_sents = []
matched_phrases = []
for pattern in patterns:
    matcher.add('keyword', collect_sents, pattern)

# %%
matches = matcher(nynlp)

# %%
sorted(matched_phrases)
# Out:
# ['Chinatowns',
#  'Crossroads',
#  'Etymology',
#  'GDP',
#  'Gomes',
#  'Harbour',
#  'History',
#  'Home',
#  'Street',
#  'agglomerations',
#  'amounts',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'area',
#  'attractions',
#  'authority',
#  'autonomy',
#  'band',
#  'beads',
#  'bedrock',
#  'belief',
#  'bloodshed',
#  'boroughs',
#  'boroughs',
#  'bridges',
#  'brother',
#  'brother',
#  'capital',
#  'capital',
#  'capitalization',
#  'captain',
#  'center',
#  'center',
#  'center',
#  'center',
#  'centuries',
#  'century',
#  'citadel',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'city',
#  'coast',
#  'colleges',
#  'colonial',
#  'colonists',
#  'colonists',
#  'colony',
#  'colony',
#  'colony',
#  'commerce',
#  'concentration',
#  'construction',
#  'control',
#  'control',
#  'country',
#  'country',
#  'county',
#  'creativity',
#  'crown',
#  'day',
#  'day',
#  'day exploration',
#  'depth',
#  'descent',
#  'diplomacy',
#  'districts',
#  'diversity',
#  'east coast',
#  'edge',
#  'education',
#  'effort',
#  'entertainment',
#  'entertainment industry',
#  'entrepreneurship',
#  'era',
#  'estate market',
#  'exchanges',
#  'expedition',
#  'expedition',
#  'exploration',
#  'explorer',
#  'explorer',
#  'feet',
#  'fish',
#  'fledgling city',
#  'food',
#  'foreign',
#  'foundation',
#  'founding',
#  'freedom',
#  'freedom',
#  'fur trade',
#  'fur trade',
#  'fur trading',
#  'gateway',
#  'geologic foundation',
#  'glaciation',
#  'glass beads',
#  'groups',
#  'growth',
#  'growth',
#  'guilders',
#  'harbor',
#  'harbors',
#  'headquarters',
#  'heart',
#  'history',
#  'home',
#  'home',
#  'homeland',
#  'honor',
#  'honor',
#  'houses',
#  'hub',
#  'ice sheet',
#  'ice sheet',
#  'ice sheet',
#  'ideals',
#  'immigrants',
#  'immigration',
#  'impact',
#  'industry',
#  'inhabitant',
#  'intersections',
#  'island',
#  'land',
#  'land area',
#  'landmarks',
#  'lands',
#  'languages',
#  'law',
#  'leader',
#  'legend',
#  'liberty',
#  'liquor sales',
#  'm',
#  'map',
#  'market',
#  'market capitalization',
#  'mate',
#  'media capital',
#  'merchant',
#  'metro systems',
#  'mile',
#  'miles',
#  'miles',
#  'millions',
#  'minute',
#  'monopoly',
#  'monopoly',
#  'mouth',
#  'movement',
#  'names',
#  'node',
#  'operation',
#  'order',
#  'origins',
#  'pace',
#  'parks',
#  'patrons',
#  'patroon system',
#  'patroons',
#  'peace',
#  'pedestrian intersections',
#  'pelts',
#  'people',
#  'politics',
#  'population',
#  'population',
#  'population',
#  'population',
#  'portion',
#  'post',
#  'post',
#  'power city',
#  'presence',
#  'product',
#  'production',
#  'program',
#  'proprietor',
#  'purchase',
#  'region',
#  'region',
#  'regolith',
#  'regulations',
#  'representative',
#  'reputation',
#  'research',
#  'residents',
#  'residents',
#  'residents',
#  'residents',
#  'resistance',
#  'rights',
#  'river',
#  'river',
#  'rule',
#  'rule',
#  'sailing',
#  'sales',
#  'separation',
#  'service',
#  'service',
#  'settlement',
#  'settlement',
#  'settlers',
#  'sheet',
#  'sheet',
#  'sheet',
#  'ship',
#  'signature Chinatowns',
#  'site',
#  'site',
#  'skyscrapers',
#  'slaves',
#  'sources',
#  'sports',
#  'state',
#  'state',
#  'stations',
#  'stock exchanges',
#  'success',
#  'surrender',
#  'surroundings',
#  'sustainability',
#  'swathes',
#  'symbol',
#  'symbol',
#  'system',
#  'systems',
#  'technology',
#  'tensions',
#  'tenure',
#  'tenure',
#  'term',
#  'terms',
#  'territory',
#  'timber',
#  'tip',
#  'tobacco',
#  'today',
#  'tolerance',
#  'tourist attractions',
#  'tourists',
#  'trade',
#  'trade',
#  'trade',
#  'trading',
#  'trading post',
#  'trading settlement',
#  'tri',
#  'tributary',
#  'troops',
#  'universities',
#  'universities',
#  'visit',
#  'windes',
#  'winter',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world',
#  'world symbol',
#  'worship',
#  'worth']

# %%
from collections import Counter
keywords = dict(Counter(matched_phrases))

# %%
keywords
# Out:
# {'Chinatowns': 1,
#  'Crossroads': 1,
#  'Etymology': 1,
#  'GDP': 1,
#  'Gomes': 1,
#  'Harbour': 1,
#  'History': 1,
#  'Home': 1,
#  'Street': 1,
#  'agglomerations': 1,
#  'amounts': 1,
#  'area': 8,
#  'attractions': 1,
#  'authority': 1,
#  'autonomy': 1,
#  'band': 1,
#  'beads': 1,
#  'bedrock': 1,
#  'belief': 1,
#  'bloodshed': 1,
#  'boroughs': 2,
#  'bridges': 1,
#  'brother': 2,
#  'capital': 2,
#  'capitalization': 1,
#  'captain': 1,
#  'center': 4,
#  'centuries': 1,
#  'century': 1,
#  'citadel': 1,
#  'city': 20,
#  'coast': 1,
#  'colleges': 1,
#  'colonial': 1,
#  'colonists': 2,
#  'colony': 3,
#  'commerce': 1,
#  'concentration': 1,
#  'construction': 1,
#  'control': 2,
#  'country': 2,
#  'county': 1,
#  'creativity': 1,
#  'crown': 1,
#  'day': 2,
#  'day exploration': 1,
#  'depth': 1,
#  'descent': 1,
#  'diplomacy': 1,
#  'districts': 1,
#  'diversity': 1,
#  'east coast': 1,
#  'edge': 1,
#  'education': 1,
#  'effort': 1,
#  'entertainment': 1,
#  'entertainment industry': 1,
#  'entrepreneurship': 1,
#  'era': 1,
#  'estate market': 1,
#  'exchanges': 1,
#  'expedition': 2,
#  'exploration': 1,
#  'explorer': 2,
#  'feet': 1,
#  'fish': 1,
#  'fledgling city': 1,
#  'food': 1,
#  'foreign': 1,
#  'foundation': 1,
#  'founding': 1,
#  'freedom': 2,
#  'fur trade': 2,
#  'fur trading': 1,
#  'gateway': 1,
#  'geologic foundation': 1,
#  'glaciation': 1,
#  'glass beads': 1,
#  'groups': 1,
#  'growth': 2,
#  'guilders': 1,
#  'harbor': 1,
#  'harbors': 1,
#  'headquarters': 1,
#  'heart': 1,
#  'history': 1,
#  'home': 2,
#  'homeland': 1,
#  'honor': 2,
#  'houses': 1,
#  'hub': 1,
#  'ice sheet': 3,
#  'ideals': 1,
#  'immigrants': 1,
#  'immigration': 1,
#  'impact': 1,
#  'industry': 1,
#  'inhabitant': 1,
#  'intersections': 1,
#  'island': 1,
#  'land': 1,
#  'land area': 1,
#  'landmarks': 1,
#  'lands': 1,
#  'languages': 1,
#  'law': 1,
#  'leader': 1,
#  'legend': 1,
#  'liberty': 1,
#  'liquor sales': 1,
#  'm': 1,
#  'map': 1,
#  'market': 1,
#  'market capitalization': 1,
#  'mate': 1,
#  'media capital': 1,
#  'merchant': 1,
#  'metro systems': 1,
#  'mile': 1,
#  'miles': 2,
#  'millions': 1,
#  'minute': 1,
#  'monopoly': 2,
#  'mouth': 1,
#  'movement': 1,
#  'names': 1,
#  'node': 1,
#  'operation': 1,
#  'order': 1,
#  'origins': 1,
#  'pace': 1,
#  'parks': 1,
#  'patrons': 1,
#  'patroon system': 1,
#  'patroons': 1,
#  'peace': 1,
#  'pedestrian intersections': 1,
#  'pelts': 1,
#  'people': 1,
#  'politics': 1,
#  'population': 4,
#  'portion': 1,
#  'post': 2,
#  'power city': 1,
#  'presence': 1,
#  'product': 1,
#  'production': 1,
#  'program': 1,
#  'proprietor': 1,
#  'purchase': 1,
#  'region': 2,
#  'regolith': 1,
#  'regulations': 1,
#  'representative': 1,
#  'reputation': 1,
#  'research': 1,
#  'residents': 4,
#  'resistance': 1,
#  'rights': 1,
#  'river': 2,
#  'rule': 2,
#  'sailing': 1,
#  'sales': 1,
#  'separation': 1,
#  'service': 2,
#  'settlement': 2,
#  'settlers': 1,
#  'sheet': 3,
#  'ship': 1,
#  'signature Chinatowns': 1,
#  'site': 2,
#  'skyscrapers': 1,
#  'slaves': 1,
#  'sources': 1,
#  'sports': 1,
#  'state': 2,
#  'stations': 1,
#  'stock exchanges': 1,
#  'success': 1,
#  'surrender': 1,
#  'surroundings': 1,
#  'sustainability': 1,
#  'swathes': 1,
#  'symbol': 2,
#  'system': 1,
#  'systems': 1,
#  'technology': 1,
#  'tensions': 1,
#  'tenure': 2,
#  'term': 1,
#  'terms': 1,
#  'territory': 1,
#  'timber': 1,
#  'tip': 1,
#  'tobacco': 1,
#  'today': 1,
#  'tolerance': 1,
#  'tourist attractions': 1,
#  'tourists': 1,
#  'trade': 3,
#  'trading': 1,
#  'trading post': 1,
#  'trading settlement': 1,
#  'tri': 1,
#  'tributary': 1,
#  'troops': 1,
#  'universities': 2,
#  'visit': 1,
#  'windes': 1,
#  'winter': 1,
#  'world': 16,
#  'world symbol': 1,
#  'worship': 1,
#  'worth': 1}

# %%
import math
import re
keywords_cvalues = {}
for keyword in sorted(keywords.keys()):
    parent_terms = list(filter(lambda t: t != keyword and re.match('\\b%s\\b' % keyword, t), keywords.keys()))
    keywords_cvalues[keyword] = keywords[keyword]
    print("TERM:", keyword, "PARENT TERMS:", parent_terms)
    for pt in parent_terms:
        keywords_cvalues[keyword] -= float(keywords[pt])/float(len(parent_terms))
    keywords_cvalues[keyword] *= math.log(len(keyword.split()), 2)
# Out:
# TERM: Chinatowns PARENT TERMS: []
# TERM: Crossroads PARENT TERMS: []
# TERM: Etymology PARENT TERMS: []
# TERM: GDP PARENT TERMS: []
# TERM: Gomes PARENT TERMS: []
# TERM: Harbour PARENT TERMS: []
# TERM: History PARENT TERMS: []
# TERM: Home PARENT TERMS: []
# TERM: Street PARENT TERMS: []
# TERM: agglomerations PARENT TERMS: []
# TERM: amounts PARENT TERMS: []
# TERM: area PARENT TERMS: []
# TERM: attractions PARENT TERMS: []
# TERM: authority PARENT TERMS: []
# TERM: autonomy PARENT TERMS: []
# TERM: band PARENT TERMS: []
# TERM: beads PARENT TERMS: []
# TERM: bedrock PARENT TERMS: []
# TERM: belief PARENT TERMS: []
# TERM: bloodshed PARENT TERMS: []
# TERM: boroughs PARENT TERMS: []
# TERM: bridges PARENT TERMS: []
# TERM: brother PARENT TERMS: []
# TERM: capital PARENT TERMS: []
# TERM: capitalization PARENT TERMS: []
# TERM: captain PARENT TERMS: []
# TERM: center PARENT TERMS: []
# TERM: centuries PARENT TERMS: []
# TERM: century PARENT TERMS: []
# TERM: citadel PARENT TERMS: []
# TERM: city PARENT TERMS: []
# TERM: coast PARENT TERMS: []
# TERM: colleges PARENT TERMS: []
# TERM: colonial PARENT TERMS: []
# TERM: colonists PARENT TERMS: []
# TERM: colony PARENT TERMS: []
# TERM: commerce PARENT TERMS: []
# TERM: concentration PARENT TERMS: []
# TERM: construction PARENT TERMS: []
# TERM: control PARENT TERMS: []
# TERM: country PARENT TERMS: []
# TERM: county PARENT TERMS: []
# TERM: creativity PARENT TERMS: []
# TERM: crown PARENT TERMS: []
# TERM: day PARENT TERMS: ['day exploration']
# TERM: day exploration PARENT TERMS: []
# TERM: depth PARENT TERMS: []
# TERM: descent PARENT TERMS: []
# TERM: diplomacy PARENT TERMS: []
# TERM: districts PARENT TERMS: []
# TERM: diversity PARENT TERMS: []
# TERM: east coast PARENT TERMS: []
# TERM: edge PARENT TERMS: []
# TERM: education PARENT TERMS: []
# TERM: effort PARENT TERMS: []
# TERM: entertainment PARENT TERMS: ['entertainment industry']
# TERM: entertainment industry PARENT TERMS: []
# TERM: entrepreneurship PARENT TERMS: []
# TERM: era PARENT TERMS: []
# TERM: estate market PARENT TERMS: []
# TERM: exchanges PARENT TERMS: []
# TERM: expedition PARENT TERMS: []
# TERM: exploration PARENT TERMS: []
# TERM: explorer PARENT TERMS: []
# TERM: feet PARENT TERMS: []
# TERM: fish PARENT TERMS: []
# TERM: fledgling city PARENT TERMS: []
# TERM: food PARENT TERMS: []
# TERM: foreign PARENT TERMS: []
# TERM: foundation PARENT TERMS: []
# TERM: founding PARENT TERMS: []
# TERM: freedom PARENT TERMS: []
# TERM: fur trade PARENT TERMS: []
# TERM: fur trading PARENT TERMS: []
# TERM: gateway PARENT TERMS: []
# TERM: geologic foundation PARENT TERMS: []
# TERM: glaciation PARENT TERMS: []
# TERM: glass beads PARENT TERMS: []
# TERM: groups PARENT TERMS: []
# TERM: growth PARENT TERMS: []
# TERM: guilders PARENT TERMS: []
# TERM: harbor PARENT TERMS: []
# TERM: harbors PARENT TERMS: []
# TERM: headquarters PARENT TERMS: []
# TERM: heart PARENT TERMS: []
# TERM: history PARENT TERMS: []
# TERM: home PARENT TERMS: []
# TERM: homeland PARENT TERMS: []
# TERM: honor PARENT TERMS: []
# TERM: houses PARENT TERMS: []
# TERM: hub PARENT TERMS: []
# TERM: ice sheet PARENT TERMS: []
# TERM: ideals PARENT TERMS: []
# TERM: immigrants PARENT TERMS: []
# TERM: immigration PARENT TERMS: []
# TERM: impact PARENT TERMS: []
# TERM: industry PARENT TERMS: []
# TERM: inhabitant PARENT TERMS: []
# TERM: intersections PARENT TERMS: []
# TERM: island PARENT TERMS: []
# TERM: land PARENT TERMS: ['land area']
# TERM: land area PARENT TERMS: []
# TERM: landmarks PARENT TERMS: []
# TERM: lands PARENT TERMS: []
# TERM: languages PARENT TERMS: []
# TERM: law PARENT TERMS: []
# TERM: leader PARENT TERMS: []
# TERM: legend PARENT TERMS: []
# TERM: liberty PARENT TERMS: []
# TERM: liquor sales PARENT TERMS: []
# TERM: m PARENT TERMS: []
# TERM: map PARENT TERMS: []
# TERM: market PARENT TERMS: ['market capitalization']
# TERM: market capitalization PARENT TERMS: []
# TERM: mate PARENT TERMS: []
# TERM: media capital PARENT TERMS: []
# TERM: merchant PARENT TERMS: []
# TERM: metro systems PARENT TERMS: []
# TERM: mile PARENT TERMS: []
# TERM: miles PARENT TERMS: []
# TERM: millions PARENT TERMS: []
# TERM: minute PARENT TERMS: []
# TERM: monopoly PARENT TERMS: []
# TERM: mouth PARENT TERMS: []
# TERM: movement PARENT TERMS: []
# TERM: names PARENT TERMS: []
# TERM: node PARENT TERMS: []
# TERM: operation PARENT TERMS: []
# TERM: order PARENT TERMS: []
# TERM: origins PARENT TERMS: []
# TERM: pace PARENT TERMS: []
# TERM: parks PARENT TERMS: []
# TERM: patrons PARENT TERMS: []
# TERM: patroon system PARENT TERMS: []
# TERM: patroons PARENT TERMS: []
# TERM: peace PARENT TERMS: []
# TERM: pedestrian intersections PARENT TERMS: []
# TERM: pelts PARENT TERMS: []
# TERM: people PARENT TERMS: []
# TERM: politics PARENT TERMS: []
# TERM: population PARENT TERMS: []
# TERM: portion PARENT TERMS: []
# TERM: post PARENT TERMS: []
# TERM: power city PARENT TERMS: []
# TERM: presence PARENT TERMS: []
# TERM: product PARENT TERMS: []
# TERM: production PARENT TERMS: []
# TERM: program PARENT TERMS: []
# TERM: proprietor PARENT TERMS: []
# TERM: purchase PARENT TERMS: []
# TERM: region PARENT TERMS: []
# TERM: regolith PARENT TERMS: []
# TERM: regulations PARENT TERMS: []
# TERM: representative PARENT TERMS: []
# TERM: reputation PARENT TERMS: []
# TERM: research PARENT TERMS: []
# TERM: residents PARENT TERMS: []
# TERM: resistance PARENT TERMS: []
# TERM: rights PARENT TERMS: []
# TERM: river PARENT TERMS: []
# TERM: rule PARENT TERMS: []
# TERM: sailing PARENT TERMS: []
# TERM: sales PARENT TERMS: []
# TERM: separation PARENT TERMS: []
# TERM: service PARENT TERMS: []
# TERM: settlement PARENT TERMS: []
# TERM: settlers PARENT TERMS: []
# TERM: sheet PARENT TERMS: []
# TERM: ship PARENT TERMS: []
# TERM: signature Chinatowns PARENT TERMS: []
# TERM: site PARENT TERMS: []
# TERM: skyscrapers PARENT TERMS: []
# TERM: slaves PARENT TERMS: []
# TERM: sources PARENT TERMS: []
# TERM: sports PARENT TERMS: []
# TERM: state PARENT TERMS: []
# TERM: stations PARENT TERMS: []
# TERM: stock exchanges PARENT TERMS: []
# TERM: success PARENT TERMS: []
# TERM: surrender PARENT TERMS: []
# TERM: surroundings PARENT TERMS: []
# TERM: sustainability PARENT TERMS: []
# TERM: swathes PARENT TERMS: []
# TERM: symbol PARENT TERMS: []
# TERM: system PARENT TERMS: []
# TERM: systems PARENT TERMS: []
# TERM: technology PARENT TERMS: []
# TERM: tensions PARENT TERMS: []
# TERM: tenure PARENT TERMS: []
# TERM: term PARENT TERMS: []
# TERM: terms PARENT TERMS: []
# TERM: territory PARENT TERMS: []
# TERM: timber PARENT TERMS: []
# TERM: tip PARENT TERMS: []
# TERM: tobacco PARENT TERMS: []
# TERM: today PARENT TERMS: []
# TERM: tolerance PARENT TERMS: []
# TERM: tourist attractions PARENT TERMS: []
# TERM: tourists PARENT TERMS: []
# TERM: trade PARENT TERMS: []
# TERM: trading PARENT TERMS: ['trading post', 'trading settlement']
# TERM: trading post PARENT TERMS: []
# TERM: trading settlement PARENT TERMS: []
# TERM: tri PARENT TERMS: []
# TERM: tributary PARENT TERMS: []
# TERM: troops PARENT TERMS: []
# TERM: universities PARENT TERMS: []
# TERM: visit PARENT TERMS: []
# TERM: windes PARENT TERMS: []
# TERM: winter PARENT TERMS: []
# TERM: world PARENT TERMS: ['world symbol']
# TERM: world symbol PARENT TERMS: []
# TERM: worship PARENT TERMS: []
# TERM: worth PARENT TERMS: []

# %%
keywords_cvalues
# Out:
# {'Chinatowns': 0.0,
#  'Crossroads': 0.0,
#  'Etymology': 0.0,
#  'GDP': 0.0,
#  'Gomes': 0.0,
#  'Harbour': 0.0,
#  'History': 0.0,
#  'Home': 0.0,
#  'Street': 0.0,
#  'agglomerations': 0.0,
#  'amounts': 0.0,
#  'area': 0.0,
#  'attractions': 0.0,
#  'authority': 0.0,
#  'autonomy': 0.0,
#  'band': 0.0,
#  'beads': 0.0,
#  'bedrock': 0.0,
#  'belief': 0.0,
#  'bloodshed': 0.0,
#  'boroughs': 0.0,
#  'bridges': 0.0,
#  'brother': 0.0,
#  'capital': 0.0,
#  'capitalization': 0.0,
#  'captain': 0.0,
#  'center': 0.0,
#  'centuries': 0.0,
#  'century': 0.0,
#  'citadel': 0.0,
#  'city': 0.0,
#  'coast': 0.0,
#  'colleges': 0.0,
#  'colonial': 0.0,
#  'colonists': 0.0,
#  'colony': 0.0,
#  'commerce': 0.0,
#  'concentration': 0.0,
#  'construction': 0.0,
#  'control': 0.0,
#  'country': 0.0,
#  'county': 0.0,
#  'creativity': 0.0,
#  'crown': 0.0,
#  'day': 0.0,
#  'day exploration': 1.0,
#  'depth': 0.0,
#  'descent': 0.0,
#  'diplomacy': 0.0,
#  'districts': 0.0,
#  'diversity': 0.0,
#  'east coast': 1.0,
#  'edge': 0.0,
#  'education': 0.0,
#  'effort': 0.0,
#  'entertainment': 0.0,
#  'entertainment industry': 1.0,
#  'entrepreneurship': 0.0,
#  'era': 0.0,
#  'estate market': 1.0,
#  'exchanges': 0.0,
#  'expedition': 0.0,
#  'exploration': 0.0,
#  'explorer': 0.0,
#  'feet': 0.0,
#  'fish': 0.0,
#  'fledgling city': 1.0,
#  'food': 0.0,
#  'foreign': 0.0,
#  'foundation': 0.0,
#  'founding': 0.0,
#  'freedom': 0.0,
#  'fur trade': 2.0,
#  'fur trading': 1.0,
#  'gateway': 0.0,
#  'geologic foundation': 1.0,
#  'glaciation': 0.0,
#  'glass beads': 1.0,
#  'groups': 0.0,
#  'growth': 0.0,
#  'guilders': 0.0,
#  'harbor': 0.0,
#  'harbors': 0.0,
#  'headquarters': 0.0,
#  'heart': 0.0,
#  'history': 0.0,
#  'home': 0.0,
#  'homeland': 0.0,
#  'honor': 0.0,
#  'houses': 0.0,
#  'hub': 0.0,
#  'ice sheet': 3.0,
#  'ideals': 0.0,
#  'immigrants': 0.0,
#  'immigration': 0.0,
#  'impact': 0.0,
#  'industry': 0.0,
#  'inhabitant': 0.0,
#  'intersections': 0.0,
#  'island': 0.0,
#  'land': 0.0,
#  'land area': 1.0,
#  'landmarks': 0.0,
#  'lands': 0.0,
#  'languages': 0.0,
#  'law': 0.0,
#  'leader': 0.0,
#  'legend': 0.0,
#  'liberty': 0.0,
#  'liquor sales': 1.0,
#  'm': 0.0,
#  'map': 0.0,
#  'market': 0.0,
#  'market capitalization': 1.0,
#  'mate': 0.0,
#  'media capital': 1.0,
#  'merchant': 0.0,
#  'metro systems': 1.0,
#  'mile': 0.0,
#  'miles': 0.0,
#  'millions': 0.0,
#  'minute': 0.0,
#  'monopoly': 0.0,
#  'mouth': 0.0,
#  'movement': 0.0,
#  'names': 0.0,
#  'node': 0.0,
#  'operation': 0.0,
#  'order': 0.0,
#  'origins': 0.0,
#  'pace': 0.0,
#  'parks': 0.0,
#  'patrons': 0.0,
#  'patroon system': 1.0,
#  'patroons': 0.0,
#  'peace': 0.0,
#  'pedestrian intersections': 1.0,
#  'pelts': 0.0,
#  'people': 0.0,
#  'politics': 0.0,
#  'population': 0.0,
#  'portion': 0.0,
#  'post': 0.0,
#  'power city': 1.0,
#  'presence': 0.0,
#  'product': 0.0,
#  'production': 0.0,
#  'program': 0.0,
#  'proprietor': 0.0,
#  'purchase': 0.0,
#  'region': 0.0,
#  'regolith': 0.0,
#  'regulations': 0.0,
#  'representative': 0.0,
#  'reputation': 0.0,
#  'research': 0.0,
#  'residents': 0.0,
#  'resistance': 0.0,
#  'rights': 0.0,
#  'river': 0.0,
#  'rule': 0.0,
#  'sailing': 0.0,
#  'sales': 0.0,
#  'separation': 0.0,
#  'service': 0.0,
#  'settlement': 0.0,
#  'settlers': 0.0,
#  'sheet': 0.0,
#  'ship': 0.0,
#  'signature Chinatowns': 1.0,
#  'site': 0.0,
#  'skyscrapers': 0.0,
#  'slaves': 0.0,
#  'sources': 0.0,
#  'sports': 0.0,
#  'state': 0.0,
#  'stations': 0.0,
#  'stock exchanges': 1.0,
#  'success': 0.0,
#  'surrender': 0.0,
#  'surroundings': 0.0,
#  'sustainability': 0.0,
#  'swathes': 0.0,
#  'symbol': 0.0,
#  'system': 0.0,
#  'systems': 0.0,
#  'technology': 0.0,
#  'tensions': 0.0,
#  'tenure': 0.0,
#  'term': 0.0,
#  'terms': 0.0,
#  'territory': 0.0,
#  'timber': 0.0,
#  'tip': 0.0,
#  'tobacco': 0.0,
#  'today': 0.0,
#  'tolerance': 0.0,
#  'tourist attractions': 1.0,
#  'tourists': 0.0,
#  'trade': 0.0,
#  'trading': 0.0,
#  'trading post': 1.0,
#  'trading settlement': 1.0,
#  'tri': 0.0,
#  'tributary': 0.0,
#  'troops': 0.0,
#  'universities': 0.0,
#  'visit': 0.0,
#  'windes': 0.0,
#  'winter': 0.0,
#  'world': 0.0,
#  'world symbol': 1.0,
#  'worship': 0.0,
#  'worth': 0.0}

# %%
best_keywords = []
for keyword in sorted(keywords_cvalues, key=keywords_cvalues.get, reverse=True)[:10]:
    best_keywords.append([keyword, keywords_cvalues[keyword]])

# %%
best_keywords
# Out:
# [['ice sheet', 3.0],
#  ['fur trade', 2.0],
#  ['day exploration', 1.0],
#  ['east coast', 1.0],
#  ['entertainment industry', 1.0],
#  ['estate market', 1.0],
#  ['fledgling city', 1.0],
#  ['fur trading', 1.0],
#  ['geologic foundation', 1.0],
#  ['glass beads', 1.0]]

# %%
import wikipedia
import spacy
from spacy.matcher import Matcher
import math
import re
from collections import Counter

nlp = spacy.load('en', disable=['parser', 'ner', 'textcat'])

matched_phrases = []
def collect_sents(matcher, doc, i, matches):
    match_id, start, end = matches[i]
    span = doc[start : end]
    matched_phrases.append(span.lemma_)
    
patterns = [[{'POS': 'NOUN', 'IS_ALPHA': True, 'IS_STOP': False, 'OP': '+'}]]
matcher = Matcher(nlp.vocab)
for pattern in patterns:
    matcher.add('keyword', collect_sents, pattern)

def extract_keywords_wikipedia(pagename, num_keywords):
    global matched_phrases
    page = wikipedia.page(pagename)
    pagenlp = nlp(page.content)
    matched_phrases = []
    matches = matcher(pagenlp)
    keywords = dict(Counter(matched_phrases).most_common(100))
    keywords_cvalues = {}
    for keyword in sorted(keywords.keys()):
        parent_terms = list(filter(lambda t: t != keyword and re.match('\\b%s\\b' % keyword, t), keywords.keys()))
        keywords_cvalues[keyword] = keywords[keyword]
        for pt in parent_terms:
            keywords_cvalues[keyword] -= float(keywords[pt])/float(len(parent_terms))
        keywords_cvalues[keyword] *= 1 + math.log(len(keyword.split()), 2)
    best_keywords = []
    for keyword in sorted(keywords_cvalues, key=keywords_cvalues.get, reverse=True)[:num_keywords]:
        best_keywords.append([keyword, keywords_cvalues[keyword]])
    return best_keywords

# %%
extract_keywords_wikipedia("New York City", 10)
# Out:
# [['city', 209.0],
#  ['world', 69.0],
#  ['area', 49.0],
#  ['population', 46.0],
#  ['borough', 40.0],
#  ['system', 40.0],
#  ['center', 23.0],
#  ['year', 22.0],
#  ['park', 21.0],
#  ['home', 19.0]]

# %%
extract_keywords_wikipedia("Python (programming language)", 10)
# Out:
# [['language', 58.0],
#  ['statement', 27.0],
#  ['expression', 26.0],
#  ['programming language', 26.0],
#  ['object', 23.0],
#  ['type', 18.0],
#  ['code', 17.0],
#  ['implementation', 17.0],
#  ['division', 16.0],
#  ['operator', 16.0]]

# %%
extract_keywords_wikipedia("Artificial intelligence", 10)
# Out:
# [['intelligence', 103.0],
#  ['problem', 67.0],
#  ['machine', 52.0],
#  ['network', 42.0],
#  ['system', 39.0],
#  ['research', 38.0],
#  ['agent', 34.0],
#  ['researcher', 29.0],
#  ['ai', 28.0],
#  ['learning', 28.0]]

# %%
extract_keywords_wikipedia("Computer science", 10)
# Out:
# [['computer science', 106.0],
#  ['science', 47.0],
#  ['computation', 26.0],
#  ['system', 24.0],
#  ['computer', 20.166666666666664],
#  ['field', 20.0],
#  ['study', 20.0],
#  ['theory', 20.0],
#  ['discipline', 18.0],
#  ['software engineering', 18.0]]
