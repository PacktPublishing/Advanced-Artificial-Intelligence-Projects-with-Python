# %%
import mailbox

# %%
mbox = mailbox.mbox('enron.mbox')
msgs = mbox.keys()

# %%
for msg_key in msgs[10:20]:
    message = mbox.get(msg_key)
    print(msg_key, "/", message['Subject'], "/", message['From'], "/", message['Date'])
    print("======================")
    print(message.get_payload())
    print("**********************")
    print("**********************")
# Out:
# 10 / RE: / eric.bass@enron.com / Mon, 22 Oct 2001 08:28:52 -0700 (PDT)
# ======================
# new orleans was fun.  the wedding was nice and it was good to get away for the weekend.  how was your weekend?
# as far as enron, i think long term it is a buy, but wall street has no confidence in managament and there is definately a negative sentiment.  i think in the short term we will definately see the teens.
# -e
#
#
#
# -----Original Message-----
# From: Larry Bass [mailto:lwbthemarine@alltel.net]
# Sent: Monday, October 22, 2001 10:21 AM
# To: Bass, Eric
# Subject: Re:
#
#
# How was your trip? Unless it is discovered that Enron has done something illegal or committed shareholder fraud (each of which I find highly unlikely), I think the market has overreacted to the Enron partnership info. I like the price @ 22-23. Dad
#
#
#
#
#
# ----- Original Message -----
# From: Bass, Eric <mailto:Eric.Bass@ENRON.com>
# To: Larry Bass <mailto:lwbthemarine@alltel.net>
# Sent: Monday, October 22, 2001 8:43 AM
# Subject: RE:
#
# sorry i am so late in returning the e-mail, but have been on vacation since last wednesday.  as far as enron, it looks like another down day today on the open.  i hate to tell you to sell now, but i wouldn't want to own enron right now.  i could see enron moving down to the teens much easier than moving up to the thirties.  i might just sell now and look to buy backl ower.
#
# let me know what you think
#
# -e
#
# -----Original Message-----
# From: Larry Bass [mailto:lwbthemarine@alltel.net]
# Sent: Thursday, October 18, 2001 11:29 AM
# To: Bass, Eric
# Subject:
#
#
# Good morning. Do you have any advice about whether I should unload ENE? Seems it cannot take a forward step without then taking 3 steps back. I have never seen a company so effectively shoot itself in the foot. What do you think?-L
#
#
#
# **********************************************************************
# This e-mail is the property of Enron Corp. and/or its relevant affiliate and may contain confidential and privileged material for the sole use of the intended recipient (s). Any review, use, distribution or disclosure by others is strictly prohibited. If you are not the intended recipient (or authorized to receive for the recipient), please contact the sender or reply to Enron Corp. at enron.messaging.administration@enron.com and delete all copies of the message. This e-mail (and any attachments hereto) are not intended to be an offer (or an acceptance) and do not create or evidence a binding and enforceable contract between Enron Corp. (or any of its affiliates) and the intended recipient or any other party, and may not be relied on by anyone as the basis of a contract by estoppel or otherwise. Thank you.
# **********************************************************************
#
#
# **********************
# **********************
# 11 / T+1 / eric.bass@enron.com / Tue, 13 Nov 2001 07:24:03 -0800 (PST)
# ======================
# what's up?  things are pretty hectic here.  you lucked out by getting out of dodge.
#
#
# are you still coming to see the 2001-2002 nat'l champs on T+1?
#
# -eric
#
# **********************
# **********************
# 12 / RE: / eric.bass@enron.com / Mon, 26 Nov 2001 12:01:47 -0800 (PST)
# ======================
# hey. long time no hear. how is everything going with you? how is the family doing?
#
# Eric
#
#  -----Original Message-----
# From: 	"Danielle Samson" <deesamson@hotmail.com>@ENRON COMMUNICATIONS
# Sent:	Monday, November 26, 2001 12:33 PM
# To:	Eric_Bass@enron.net
# Subject:
#
# Hello there.  I'm not sure if you will get this or not, but I have been
# trying to get in touch with you.  Nothing too important, but if you do
# receive this and have the chance, would you please write me back. I hope
# everyone is doing well and that you had a wonderful Thanksgiving!
#
# Danielle
#
# _________________________________________________________________
# Get your FREE download of MSN Explorer at http://explorer.msn.com/intl.asp
#
# **********************
# **********************
# 13 / RE: Application Forms / eric.bass@enron.com / Tue, 22 Jan 2002 07:59:55 -0800 (PST)
# ======================
# Is this the old enron building or the new one?
#
# Eric Bass
#
# -----Original Message-----
# From: Buckley, Karen
# Sent: Monday, January 21, 2002 5:24 PM
# Subject: Application Forms
#
#
# Please come by 5C2 at your convenience tomorrow as UBS require you to complete missing information on your application form.
#
# Kind regards,
#
#
#
# Karen Buckley
#
# Human Resources
#
# Tel: 713 345 4667
#
#
#
#
#
# **********************
# **********************
# 14 / RE: / eric.bass@enron.com / Mon, 22 Oct 2001 06:43:10 -0700 (PDT)
# ======================
# sorry i am so late in returning the e-mail, but have been on vacation since last wednesday.  as far as enron, it looks like another down day today on the open.  i hate to tell you to sell now, but i wouldn't want to own enron right now.  i could see enron moving down to the teens much easier than moving up to the thirties.  i might just sell now and look to buy back lower.
#
# let me know what you think
#
# -e
#
# -----Original Message-----
# From: Larry Bass [mailto:lwbthemarine@alltel.net]
# Sent: Thursday, October 18, 2001 11:29 AM
# To: Bass, Eric
# Subject:
#
#
# Good morning. Do you have any advice about whether I should unload ENE? Seems it cannot take a forward step without then taking 3 steps back. I have never seen a company so effectively shoot itself in the foot. What do you think?-L
#
# **********************
# **********************
# 15 / FW: Bet / eric.bass@enron.com / Tue, 27 Nov 2001 07:36:34 -0800 (PST)
# ======================
# surprising . . .
#
#  -----Original Message-----
# From: 	Bass, Eric
# Sent:	Tuesday, November 27, 2001 9:36 AM
# To:	Hatten, Micah
# Subject:	RE: Bet
#
# that sounds good 9 it is.  we will go for beers regardless
#
#  -----Original Message-----
# From: 	Hatten, Micah
# Sent:	Tuesday, November 27, 2001 9:28 AM
# To:	Bass, Eric
# Subject:	RE: Bet
#
# Alright,  I'll take the bet.  I'll have to scrounge around to find 40 buck though!  You know you're stealing money from my severance!  I may need that to eat on by the end of the week.  If you say the line is 9, that works for me.  CU is on a role....it's time for Simms to go down!
#
# If you steal my money, you'll have to buy me a beer.
#  -----Original Message-----
# From: 	Bass, Eric
# Sent:	Tuesday, November 27, 2001 9:24 AM
# To:	Hatten, Micah
# Subject:	Bet
#
# Since you never gave me the $20 for the last time we bet on CU/Texas, I figured I would give you the chance to go double or nothing on the second round.  I think the line is Texas -9.  Let me know.
#
# **********************
# **********************
# 16 / RE: Super Bowl / eric.bass@enron.com / Thu, 31 Jan 2002 08:10:17 -0800 (PST)
# ======================
# he told me that he wasn't sure if he would be in town.  i guess there is no need to have two. so i won't have one then
#
#  -----Original Message-----
# From: 	Blanchard, Timothy
# Sent:	Thursday, January 31, 2002 9:48 AM
# To:	Bass, Eric
# Subject:	RE: Super Bowl
#
# looks like we need to have a co-ordinated effort because i think val may be having people over too.  i am indifferent as to where the party is held, but would like a consensus.  you guys should probably talk about it.
#
#  -----Original Message-----
# From: 	Bass, Eric
# Sent:	Wednesday, January 30, 2002 1:37 PM
# To:	Blanchard, Timothy
# Subject:	RE: Super Bowl
#
# right now i guess we have 6 - i have not heard back from boone.  val said he would stop by if they were back in town by then.  i didn't have mitch's e-mail so you may want to forward to him and i will talk to hull.
#
# i guess we could have about 10 people.
#
# what do you think?
#
#
#  -----Original Message-----
# From: 	Blanchard, Timothy
# Sent:	Wednesday, January 30, 2002 10:54 AM
# To:	Bass, Eric
# Subject:	Super Bowl
#
# What's the plan?
#
# **********************
# **********************
# 17 / RE: Free Agents / eric.bass@enron.com / Thu, 4 Oct 2001 10:19:29 -0700 (PDT)
# ======================
# it goes by record then points
#
#  -----Original Message-----
# From: 	Ames, Chuck
# Sent:	Thursday, October 04, 2001 12:19 PM
# To:	Bass, Eric
# Subject:	Free Agents
#
# Eric,
#
# Remind me again at how the free agent pool works for pick-ups.  Thanks
#
# Chuck
#
# **********************
# **********************
# 18 / RE: Cologne / eric.bass@enron.com / Thu, 6 Dec 2001 10:50:46 -0800 (PST)
# ======================
# I like issey miyake and acqua di gio.
#
# -e
#
# -----Original Message-----
# From: K. Bass [mailto:daphneco64@alltel.net]
# Sent: Tuesday, December 04, 2001 2:35 PM
# To: Bass, Eric; Jason Bass
# Subject: Cologne
#
#
# What kind do you like and what kind do you absolutely dislike??  LU-M
#
# **********************
# **********************
# 19 / FW: Fw: Illusion :-) / eric.bass@enron.com / Tue, 16 Oct 2001 15:01:43 -0700 (PDT)
# ======================
#
#
#  -----Original Message-----
# From: 	Love, Phillip M.
# Sent:	Tuesday, October 16, 2001 4:43 PM
# To:	Hull, Bryan; Bass, Eric; Baumbach, David; Bosse, Kevin; Simien, Jimmy; Lilly, Kyle R.; Winfree, O'Neal D.; Ryder, Patrick; "Scott <wax (E-mail); Ashley Love (E-mail); Everett" "Smith (E-mail); Gregory "Sonntag (E-mail); James Love (E-mail); Kathy nuernberg (E-mail); Mike <mjillard (E-mail); rachel bonilla-kragel (E-mail); ROCK (E-mail); Toni" "D'Agostina (E-mail); Giron, Darron C.; Crowell, Scott
# Subject:	FW: Fw: Illusion :-)
#
#
#
#  -----Original Message-----
# From: 	"Jason Dobbs" <jmjaked@mindspring.com>@ENRON
# Sent:	Tuesday, October 16, 2001 4:29 PM
# To:	phil love; jim wood; dobbswn; dana sanders; chris chambless; chance wood; caleb dobbs; boo boo dobbs; ashley himber
# Subject:	Fw: Fw: Illusion :-)
#
#
# ----- Original Message -----
# From: Michael Mobley <leemobley@excite.com>
# To: <darmy4@sonet.net>; <therealflame@yahoo.com>; <DClay@championhomes.net>;
# <jmjaked@mindspring.com>; <jameyestes@yahoo.com>; <rhowell@sonet.net>;
# <StevenHull@msn.com>; <cindy.kaelin@maxwell.af.mil>;
# <dkeeton@continentalconveyor.com>; <teresatapl@excite.com>;
# <mlewis@sonet.net>; <barrysmc@sonet.net>
# Sent: Monday, October 15, 2001 9:28 PM
# Subject: Fwd: Fw: Illusion :-)
#
#
# >
# >
# >
# >
# >
# >
# > _______________________________________________________
# > Send a cool gift with your E-Card
# > http://www.bluemountain.com/giftcenter/
# >
# >
#
# Return-Path: <kclark@sonet.net>
# Received: from neptune2.sonet.net ([207.230.88.9]) by hopper.excite.com          (InterMail vM.4.01.03.23 201-229-121-123-20010418) with ESMTP          id <20011016004722.YODH15631.hopper.excite.com@neptune2.sonet.net>;          Mon, 15 Oct 2001 17:47:22 -0700
# Received: from Default (hamtc4-ppp-210.sonet.net [63.170.208.210])	by neptune2.sonet.net (8.9.3/8.9.3) with SMTP id TAA23739;	Mon, 15 Oct 2001 19:33:41 -0500
# Message-ID: <003401c155db$8eabb120$d2d0aa3f@Default>
# From: "kerry s clark" <kclark@sonet.net>
# To: "Wendy Cannon" <windless_95@yahoo.com>,        "Trent Doss" <trentdoss@excite.com>,        "Shanna Mitchell" <smitchell@cisfn.com>,        "Shae Umfress" <SUmfress@Monroe.k12.ms.us>,        "S Sharp" <groovy_girl_799@yahoo.com>,        "Ray Lyons" <trlyons@hotmail.com>, "Lee Mobley" <leemobley@excite.com>,        "Lajune Davidson" <lajunedavidson@hotmail.com>,        "Kimmy Burleson" <Kabtherapy@yahoo.com>,        "Jane Riner" <jarino@sonet.net>,        "Doug Wharton" <dougwharton@webtv.net>,        "Craig Hull" <chull@continentalconveyor.com>,        "Bev Garrison" <Bdgarrison@aol.com>,        "Annette Rea" <area@bevillst.cc.al.us>
# Subject: Fw: Illusion :-)
# Date: Mon, 15 Oct 2001 19:43:19 -0500
# MIME-Version: 1.0
# Content-Type: multipart/mixed;	boundary="----=_NextPart_000_0031_01C155B1.A44BFBE0"
# X-Priority: 3
# X-MSMail-Priority: Normal
# X-Mailer: Microsoft Outlook Express 6.00.2600.0000
# X-MimeOLE: Produced By Microsoft MimeOLE V6.00.2600.0000
#
#
# ----- Original Message -----
# From: "Holley, Pam" <pholley@buccaneerhomes.com>
# To: "White, Jeff" <JWhite@buccaneerhomes.com>
# Cc: <kclark@sonet.net>
# Sent: Monday, October 15, 2001 4:46 PM
# Subject: FW: Illusion :-)
#
#
# >
# >
# > -----Original Message-----
# > From: Rector, Carla
# > Sent: Monday, October 15, 2001 1:03 PM
# > To: Nix, Billie Jean; Armstrong, Kim; Tittle, Stephanie; Holley, Pam;
# > Holley, Shana; Childers, Sue
# > Subject: FW: Illusion :-)
# >
# >
# >
# >
# > -----Original Message-----
# > From: Sims, Melissa
# > Sent: Monday, October 15, 2001 12:02 PM
# > To: Rector, Carla
# > Subject: FW: Illusion :-)
# >
# >
# >
# >
# > -----Original Message-----
# > From: Plyler, Shelley
# > Sent: Monday, October 15, 2001 11:56 AM
# > To: Franks, Marlana; Sims, Melissa; Robertson, Misty
# > Subject: FW: Illusion :-)
# >
# >
# >
# >
# > -----Original Message-----
# > From: Hammontree, Kelly
# > Sent: Monday, October 15, 2001 11:54 AM
# > To: Avery, Dianne; Plyler, Shelley; Hammontree, Charlotte; Allen,
# > Teresa; Crowe, Candi
# > Subject: FW: Illusion :-)
# >
# >
# >
# >
# > KELLY HAMMONTREE
# >
# >
# > -----Original Message-----
# > From: Phillip Lucius [mailto:pwlucius@icc.cc.ms.us]
# > Sent: Monday, October 15, 2001 10:01 AM
# > To: jlucius@sonet.net
# > Subject: FW: Illusion :-)
# >
# >
# >
# >
# > -----Original Message-----
# > From: Robbins, Danny [mailto:drrobbins@icc.cc.ms.us]
# > Sent: Monday, October 15, 2001 8:33 AM
# > To: Tice, Tony; Brady, Ronald; Emison, Barry; Kitchens, Terry; Stephens,
# > Ronnie; Lucius, Phillip; Ray Orr (E-mail)
# > Subject: FW: Illusion :-)
# >
# >
# >
# >
#
#  - Illusion d'optique.pps
#
# **********************
# **********************

# %%
# try to remove "original message," quotes, and signatures
import re
def cleanup_email(msgbody):
    regex_replies = re.compile('(\-+Original Message|\-\-+|~~+).*', re.DOTALL) # find 'Original Message...' and variants
    msgbody = re.sub(regex_replies, '', msgbody)
    msgbody = re.sub(r'=\d\d', ' ', msgbody) # remove funny email formatting issues
    msgbody = re.sub(r'\s*>.*', '', msgbody) # remove quotes
    msgbody = re.sub(r'https?://.*?\s', '', msgbody) # remove links
    bigspace = re.compile(r'\n\n\n\n\n+.*', re.DOTALL) # find large gaps
    msgbody = re.sub(bigspace, '', msgbody)
    bigindent = re.compile(r'(\t| {4,}).*', re.DOTALL) # find big indentations (i.e., a quoted document)
    msgbody = re.sub(bigindent, '', msgbody)
    emailpaste = re.compile(r'(From|Subject|To): .*', re.DOTALL) # find pasted emails
    msgbody = re.sub(emailpaste, '', msgbody)
    msgbody = re.sub(r'=(\s*)\n', '\1', msgbody) # fix broken newlines
    msgbody = re.sub(r' ,([stm])', '\'\1', msgbody) # fix funny apostrophe 's and 't and 'm
    msgbody = re.sub(r'([\?\.])\?', '\1', msgbody) # fix funny extra question marks
    msgbody = re.sub(r'\x01', ' ', msgbody) # fix odd spaces
    return msgbody.strip()

# %%
for msg_key in msgs[326:500]:
    message = mbox.get(msg_key)
    msgbody = cleanup_email(message.get_payload())
    print(msg_key, "/", message['Subject'], "/", message['From'], "/", message['To'], "/", message['Date'])
    print("======================")
    print(msgbody)
    print("**********************")
    print("**********************")
# Out:
# 326 / Fw: [caninesolutions] Digest Number 144 / eric.bass@enron.com / brian.hoskins@enron.com, hector.campos@enron.com,
#  lenine.jeganathan@enron.com, brettlawler@hotmail.com / Fri, 15 Sep 2000 07:49:00 -0700 (PDT)
# ======================
# his
# the
# dies
# his
# know
# cold
# shivering
# a
# so?
# deserves
# where
# Clinton
# that
# house,
#
# Content-transfer-encoding: 7BIT
# Return-path: sentto-1293958-144-968674576-mjb5778=aol.com@returns.onelist.com
# Received: from  rly-yd04.mx.aol.com (rly-yd04.mail.aol.com [172.18.150.4]) by
# air-yd02.mail.aol.com (v75_b3.11) with ESMTP; Mon, 11 Sep 2000 08:17:18 -0400
# Received: from  hp.egroups.com (hp.egroups.com [208.50.99.201]) by
# rly-yd04.mx.aol.com (v75_b3.9) with ESMTP; Mon, 11 Sep 2000 08:17:01 -0400
# Received: from [10.1.10.143] by hp.egroups.com with NNFMP; Mon, 11 Sep 2000
# 12:16:19 +0000
# Date: Mon, 11 Sep 2000 12:16:16 +0000
# **********************
# **********************
# 327 / Check it out! / eric.bass@enron.com / shanna.husser@enron.com / Tue, 7 Nov 2000 01:49:00 -0800 (PST)
# ======================
# -
# **********************
# **********************
# 328 / Tonight's Gathering - National Championship / eric.bass@enron.com / david.baumbach@enron.com, brian.hoskins@enron.com, hector.campos@enron.com,
#  lenine.jeganathan@enron.com / Tue, 4 Jan 2000 07:39:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 329 / Inside UT Football: November 30, 2000 / newsletters@newsletters.dallasnews.com / insideutfootball@newsletters.dallasnews.com / Wed, 29 Nov 2000 16:15:00 -0800 (PST)
# ======================
# [IMAGE]
# **********************
# **********************
# 330 / A&A brown bag / tom.wilbeck@enron.com / craig.hall@enron.com, ryan.hinze@enron.com, jennifer.martinez@enron.com,
#  james.whitehead@enron.com, darren.maloney@enron.com,
#  crystal.hyde@enron.com, benjamin.markey@enron.com,
#  george.thomas@enron.com, catherine.clark@enron.com,
#  zaib.iqtidar@enron.com, chad.landry@enron.com, chad.landry@enron.com,
#  mo.bawa@enron.com, john.massey@enron.com, jonathon.pielop@enron.com,
#  brent.dornier@enron.com, christa.winfrey@enron.com,
#  akasha.redrick@enron.com, reza.rezaeian@enron.com,
#  eric.scott@enron.com, kate.lucas@enron.com, erin.willis@enron.com,
#  farzad.farhangnia@enron.com, sarah.mulholland@enron.com,
#  matthew.lenhart@enron.com, kenneth.shulklapper@enron.com,
#  kevin.ruscitti@enron.com, hector.campos@enron.com,
#  karla.compean@enron.com, zal.masani@enron.com,
#  leonard.tham@enron.com, claire.broido@enron.com,
#  yvan.chaxel@enron.com, pearce.hammond@enron.com,
#  elizabeth.howley@enron.com, usman.shaukat@enron.com,
#  misti.day@enron.com, simone.rose@enron.com, michelle.zhang@enron.com,
#  shilpa.chunchu@enron.com, daniel.graham@enron.com,
#  molly.hellerman@enron.com, david.hunker@enron.com,
#  alberto.jimenez@enron.com, jebong.lee@enron.com,
#  chetan.paipanandiker@enron.com, eva.rainer@enron.com,
#  carlos.ruiz@enron.com, stephanie.segura@enron.com,
#  rahul.seksaria@enron.com, michael.simmons@enron.com,
#  imad.tareen@enron.com, todd.roten@enron.com, chu.wang@enron.com,
#  chad.gronvold@enron.com, alton.jackson@enron.com,
#  gerardo.benitez@enron.com, ibrahim.qureishi@enron.com,
#  bret.scholtes@enron.com, marc.sabine@enron.com,
#  jason.seigal@enron.com, valter.stoiani@enron.com,
#  jennifer.reside@enron.com, michael.garberding@enron.com,
#  chris.herron@enron.com, ed.wood@enron.com, petual.jeanmard@enron.com,
#  john.scarborough@enron.com, jean-sebastien.fontaine@enron.com,
#  jason.althaus@enron.com, leonardo.pacheco@enron.com,
#  mario.cardoso@enron.com, jin.guo@enron.com,
#  selena.gonzalez@enron.com, matthew.jachimiak@enron.com,
#  kelly.mccoy@enron.com, michael.kolman@enron.com, binh.pham@enron.com,
#  peter.bennett@enron.com, angie.zeman@enron.com,
#  victor.guggenheim@enron.com, alicia.perkins@enron.com,
#  chris.walker@enron.com, raimund.grube@enron.com,
#  stephen.plauche@enron.com, adnan.patel@enron.com,
#  ross.prevatt@enron.com, israel.estrada@enron.com,
#  gaurav.babbar@enron.com, banu.ozcan@enron.com,
#  milind.pasad@enron.com, claudio.ribeiro@enron.com,
#  travis.winfrey@enron.com, gray.calvert@enron.com,
#  stephen.thome@enron.com, laura.wente@enron.com,
#  yvette.parker@enron.com, victor.browner@enron.com,
#  winston.cheng@enron.com, vicky.ha@enron.com, nick.hiemstra@enron.com,
#  john.howton@enron.com, josephine.lin@enron.com,
#  tyrell.harrison@enron.com, todd.hattenbach@enron.com,
#  charles.varnell@enron.com, lisa.gillette@enron.com,
#  jay.epstein@enron.com, jody.crook@enron.com,
#  michael.benien@enron.com, daniel.falcone@enron.com,
#  jennifer.bagwell@enron.com, gabriel.monroy@enron.com,
#  robin.rodrigue@enron.com, michelle.waldhauser@enron.com,
#  purvi.patel@enron.com, sscott5@enron.com, greg.martin@enron.com,
#  john.weakly@enron.com, sheetal.patel@enron.com,
#  brando.hayden@enron.com, seth.hurwitz@enron.com,
#  bryan.hull@enron.com, angelique.woods@enron.com,
#  ryan.deane@enron.com, zeina.el-azzi@enron.com,
#  michael.flanigan@enron.com, marsha.francis@enron.com,
#  joe.gordon@enron.com, paul.gregory@enron.com, amber.hamby@enron.com,
#  jonathan.hoff@enron.com, sean.keenan@enron.com,
#  dayem.khandker@enron.com, john.king@enron.com,
#  kelli.little@enron.com, stanton.ray@enron.com, shahid.shah@enron.com,
#  ying.soong@enron.com, ryan.synnott@enron.com,
#  benjamin.thomason@enron.com, justyn.thompson@enron.com,
#  miguel.vasquez@enron.com, jason.wiesepape@enron.com,
#  virawan.yawapongsiri@enron.com, michael.driscoll@enron.com,
#  chris.mallory@enron.com, cooper.richey@enron.com,
#  geir.solberg@enron.com, jennifer.newbrough@enron.com,
#  heather.alon@enron.com, eric.bass@enron.com, erica.bess@enron.com,
#  evan.betzer@enron.com, harry.bucalo@enron.com, hang.bui@enron.com,
#  mark.castiglione@enron.com, monika.causholli@enron.com,
#  brandon.cavazos@enron.com, andy.chen@enron.com,
#  christopher.chenoweth@enron.com, teresa.dyar@enron.com,
#  daniel.ferrell@enron.com, steve.gim@enron.com, john.gordon@enron.com,
#  scott.griffin@enron.com, christian.hackett@enron.com,
#  brian.hoskins@enron.com, avinash.jain@enron.com,
#  jolly.jose@enron.com, william.keeney@enron.com,
#  joshua.koenig@enron.com, clement.lau@enron.com,
#  fatimata.liamidi@enron.com, homer.lin@enron.com,
#  atticus.lyon@enron.com, kelley.mcintyre@enron.com,
#  ravi.mujumdar@enron.com, kourtney.nelson@enron.com,
#  iris.ng@enron.com, sanjay.patel@enron.com, shiraz.rehman@enron.com,
#  justin.rostant@enron.com, anthony.sexton@enron.com,
#  elizabeth.shim@enron.com, joseph.short@enron.com,
#  gauri.khokha@enron.com, carrie.southard@enron.com,
#  sarah.taylor@enron.com, maria.tefel@enron.com, brandon.wax@enron.com,
#  lewis.worthy@enron.com, allan.wu@enron.com, george.zivic@enron.com,
#  ted.noble@enron.com, brogers2@enron.com, gautam.gupta@enron.com,
#  russell.dyk@enron.com, wjennin@enron.com, doug.sewell@enron.com,
#  lisa.connolly@enron.com, tara.piazze@enron.com, chuck.ames@enron.com,
#  nate.blackburn@enron.com, sachin.gandhi@enron.com, mog.heu@enron.com,
#  sabina.rank@enron.com, elizabeth.shim@enron.com,
#  massimo.marolo@enron.com, vladi.pimenov@enron.com,
#  damon.harvey@enron.com, hector.alviar@enron.com,
#  joana.ryan.bekerman@enron.com / Mon, 4 Dec 2000 07:09:00 -0800 (PST)
# ======================
# Thank you to those who have already RSVP'd for this informative brown bag
# session.  This is one of the last opportunities you'll have to gain more
# insight into our business.  Please RSVP ASAP, Okay?
#
# Jen Fraser, Director of Origination in EGM - December 5 from 12 to 1 in 30C1
# **********************
# **********************
# 331 / Fw: Golf / lwbthemarine@bigplanet.com / daphneco64@bigplanet.com, daphneco64@yahoo.com, jason.bass2@compaq.com,
#  eric.bass@enron.com / Fri, 1 Dec 2000 01:43:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 332 / Sorry, I keep getting these things. / matthew.lenhart@enron.com / chad.landry@enron.com, timothy.blanchard@enron.com, bryan.hull@enron.com,
#  eric.bass@enron.com, phillip.love@enron.com,
#  kenneth.shulklapper@enron.com, jay.reitmeyer@enron.com,
#  tori.kuykendall@enron.com, lisa.gillette@enron.com,
#  christa.winfrey@enron.com / Tue, 14 Nov 2000 06:59:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 333 / Pick ups / patrick.ryder@enron.com / jason.bass2@compaq.com, phillip.love@enron.com, bryan.hull@enron.com,
#  david.baumbach@enron.com, lqcolombo@aol.com,
#  michael.walters@enron.com, matthew.lenhart@enron.com,
#  harry.bucalo@enron.com, gary.lamphier@enron.com,
#  o'neal.winfree@enron.com, eric.bass@enron.com, steve.venturatos@enron.com / Fri, 17 Nov 2000 04:34:00 -0800 (PST)
# ======================
# Gary  Pollard 6
#  Morton 6
#  Allen 1
#  Ferotte 6
# **********************
# **********************
# 334 / WE HAVE THE TICKETS!!!!!!!!! / michael.simmons@enron.com / stephen.schwarzbach@enron.com, eric.bass@enron.com, luis.mena@enron.com,
#  paul.broderick@enron.com, sarah.goodpastor@enron.com,
#  christopher.chenoweth@enron.com / Mon, 13 Nov 2000 02:17:00 -0800 (PST)
# ======================
# Major breakthrough, we have 16 tickets.  Now we need to win 'em.  After the
# f'''aggies near victory vs. ou, these tickets are now priceless.  Therefore,
# we must win at all cost THIS Saturday, the 18th.
#
# The team to date is as follows:
#
# Stephen
# Eric
# Luis
# Paul
# Sarah
# Myself
# Christopher Chenoweth - new addition (recruited away from Webb Jennings' team
# at no small cost)
#
# One other unnamed guy (Luis, I need this name).
#
# == To do:
#
# 1.   I need all of you to confirm (by voice or email) that you will be able
# to play on Saturday.  If I don't hear from you, I will have to replace you.
# If you think there is a chance that you won't make, please contact me ASAP.
#
# 2.   We need to deliver $2,000 in donations.  If you haven't started bringing
# in donations, please do so immediately.  I have the donation envelopes,
# contact me and I'll have one sent to you.
#
# 3.  We will have a scrimmage this Wed. or Thurs.  so mark your calender.  I
# encourage you all to take whatever steps necessary to see to your physical
# preparation for this game.
#
# My extension is 37842.   Home phone is 713-864-6229.
# **********************
# **********************
# 335 / Your Basketball League is Back! / eric.bass@enron.com / david.baumbach@enron.com, phillip.love@enron.com, bryan.hull@enron.com,
#  chris.walker@enron.com, michael.walters@enron.com,
#  o'neal.winfree@enron.com, harry.bucalo@enron.com / Mon, 16 Oct 2000 06:30:00 -0700 (PDT)
# ======================
#
# **********************
# **********************
# 336 / 'Tis the Season / laura.harder@enron.com / elsa.villarreal@enron.com, edward.gottlob@enron.com, lauri.allen@enron.com,
#  carey.metz@enron.com, eric.bass@enron.com, danny.conner@enron.com / Thu, 9 Nov 2000 05:06:00 -0800 (PST)
# ======================
# If you would like for me to send cards to your customers, please provide me
# with a list of their names and addresses by next Friday, 11/17.  I will get
# the amount of cards as per however many customer names I am given.  I will
# then have everyone sign one card so that I can send it out to get the
# signatures lasered on the customer's cards.  I've already spoken with the
# others on the desk, and they either aren't interested or they've gotten their
# primary assistants to take care of it.
#
# Elsa, as we've previously discussed, I can use the list that we just recently
# updated.  Please let me know if you are going to select people from that
# list, or if you are just going to send a card to everybody on it.
#
# Thanks guys,
# Laura
# **********************
# **********************
# 337 / Rebook Items / eric.bass@enron.com / chance.rabon@enron.com / Fri, 16 Mar 2001 01:27:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 338 /  / shanna.husser@enron.com / eric.bass@enron.com, scrilla364@aol.com / Mon, 6 Nov 2000 00:38:00 -0800 (PST)
# ======================
# Thought you both would appreciate this one- with both of your "women drivers"
# comments all the time.
# **********************
# **********************
# 339 / Turret Phone - Page 6 / laura.harder@enron.com / thomas.martin@enron.com, jim.schwieger@enron.com, james.mckay@enron.com,
#  greg.mcclendon@enron.com, elsa.villarreal@enron.com,
#  daren.farmer@enron.com, liz.bellamy@enron.com,
#  stacey.neuweiler@enron.com, carey.metz@enron.com,
#  lauri.allen@enron.com, edward.gottlob@enron.com, eric.bass@enron.com,
#  gary.lamphier@enron.com, danny.conner@enron.com, janet.wallis@enron.com / Mon, 6 Nov 2000 03:54:00 -0800 (PST)
# ======================
# I am trying to organize everybody's turret so that we have all of the Texas
# Desk people on one page.  This will be especially beneficial for when we have
# people out.  The phone guys are going to completely wipe out what you
# curretnly have on Page 6, so if there is anything other than Texas Desk
# employees, let me know so that they don't get deleted.
#
# I would also like to reserve some space on Page7 for the rollover lines, so
# ditto with Page 7 as with Page 6.
#
# Let's put a deadline of December 1st for this .... that should be enough time
# for you busy people to let me know if there's a problem.  I'd like to have
# this done on December 4th.
#
# Thanks,
# Laura
# **********************
# **********************
# 340 / Commissioner.COM E-Reports for The Perfect League 11/30/00 / noreply@ccomad3.uu.commissioner.com / None / Thu, 30 Nov 2000 07:37:00 -0800 (PST)
# ======================
# [IMAGE]
#
#
# Fantasy Basketball is here...and it's FREE! Join a league or create your own.
# It's a slam dunk!
# Run your Fantasy Basketball league for FREE with our fully-customizable
# league management service!
#
# The tab for SportsLine's FREE Fantasy Football is being picked up by Miller
# Lite, our favorite beer around here. Check them out offline at your local bar
# or online with us. Grab a Miller Lite. It's Miller Time!
#
# Half Time is the perfect time to visit Half.com. Half.com offers Music,
# Books, Movies & Games at HALF the price.
#
# Win The Fantasy Football Trip Of A Lifetime! Love to surf the
# cbs.sportsline.com site? You could win a 4-day/3-night weekend in Florida to
# attend Cris Carter's FAST Program in Florida! Click here to get started now!
#
#
#
# Brought to you by
#
#
#
# Sponsorship Bar
# You are receiving these e-reports because you have signed up for CBS
# SportsLine Fantasy Football.  To customize, reschedule, or turn off these
# reports please  click here
#
#
#
#  Player Updates?NFL Reports?
#  Latest NFL Player News
#
#  Steve McNair , QB TEN - FDIC Updated 11/30/00
#  Although McNair is listed as questionable on the Titans' injury report for
# Sunday's game in Philadelphia, he is expected to get the start. His thumb is
# still sore and he's been icing it regularly, but it's not expected to keep
# him from playing. Still, the Eagles have a solid defense and the Titans'
# passing game has struggled of late, so you might want to consider starting
# someone else this week.
#
#  Eddie George , RB TEN - Fear Updated 11/30/00
#  George did not practice yesterday in order to rest his injured right big
# toe, although he and Coach Jeff Fisher said he could have participated.
# Fisher wants George to be able to fully participate in today's session, and
# expects he will be able to. Considering George has held up this well through
# a variety of injuries in recent weeks, there's little reason to expect he
# won't start Sunday in his return to Philadelphia and post solid Fantasy
# numbers.
#
#  Hines Ward , WR PIT - Thrill Kill Cult Updated 11/30/00
#  Ward is listed as probable on the Steelers' injury report for Sunday's game
# against Oakland. With Pittsburgh's receivers hurting, expect him to play and
# be the focus of the passing game. He's still marginal as a Fantasy producer,
# though.
#
#  Plaxico Burress , WR PIT - The Lie Downs Updated 11/30/00
#  The Steelers will be without Burress likely for the remainder of the season
# after learning he has a torn ligament and two broken bones in his right
# wrist. He said he originally sustained the injury during the season opener,
# but played the next 11 games despite constant pain in the wrist. Burress had
# it X-rayed and placed in a cast after practice yesterday, and it will require
# surgery. With him out, Courtney Hawkins will continue to start in his place
# for the next four games.
#
#  Jamel White , RB CLE - Free Agent Updated 11/30/00
#  The Browns have listed White as questionable with a shoulder injury for
# Sunday's game against Jacksonville. He has performed fairly well spelling
# fellow rookie Travis Prentice in recent weeks, and may earn himself
# consideration in the Browns' RB plans for 2001. He won't provide you with
# much this season, though.
#
#  Jaguars , DT JAC - The Snake Pit Updated 11/30/00
#  The Jaguars will be without linebackers Hardy Nickerson, who has a knee
# injury, and Erik Storz, who has a broken thumb, as well as safety Erik Olson,
# who has an ankle injury, for Sunday's game against the Browns. Fortunately,
# linebackers Lonnie Marts, listed as probable after missing four games with a
# groin injury, and Kevin Hardy, probable with an ankle injury, are both
# expected to play. Despite all the injuries, keep in mind that this might be
# the best week to start the Jacksonville defense, as it faces a Cleveland
# offense that has been decimated by injuries.
#
#  Wayne Chrebet , WR NYJ - FDIC Updated 11/30/00
#  "The Green Lantern" had his light burned out last week against the Bears,
# catching only one pass for eight yards in the entire game. After four solid
# weeks, Chrebet has caught only four passes for 41 yards over his last two
# games. He faces off against a Colts' secondary that he burned for eight
# catches and 140 yards receiving in Week Ten, so a productive day is certainly
# not out of the question. Although he hasn't been overly consistent, Chrebet
# will likely find his way onto many starting lineups as the playoffs begin.
# **********************
# **********************
# 341 / Telluride is OPEN! / eric.bass@enron.com / shanna.husser@enron.com, dfranklin@hanovermeasurement.com,
#  jason.bass2@compaq.com, daphneco64@bigplanet.com,
#  lwbthemarine@bigplanet.com / Tue, 21 Nov 2000 03:50:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 342 / Re: 318923 / eric.bass@enron.com / chance.rabon@enron.com / Tue, 27 Feb 2001 03:01:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 343 / Re: Plays and other information / michael.simmons@enron.com / eric.bass@enron.com / Tue, 14 Nov 2000 08:22:00 -0800 (PST)
# ======================
# the scrimmage is still up in the air...
#
#
# webb said that they didnt want to scrimmage...
#
# the aggies  are scrimmaging each other... (the aggie teams practiced on
# Sunday)
#
# when I called the aggie captains to see if we could use their field.... they
# said that it was tooo smalll for us to use...
#
#
# sounds like bullshit to me... but what can we do....
#
#
# anyway... we will have to do another practice Wed. night....
# **********************
# **********************
# 344 / Re: check it out / daphneco64@bigplanet.com / eric.bass@enron.com / Tue, 14 Nov 2000 07:25:00 -0800 (PST)
# ======================
# I'm ready, are you?  Did you get my message about Dad?  I don't want you to
# worry but he will have to be in bed with his leg elevated for a week.  Send
# him a nice note, o.k?
# **********************
# **********************
# 345 / SFX Music / Houston Concert Update! / announce-list@sfx.com / ebass@enron.com / Fri, 10 Nov 2000 02:50:00 -0800 (PST)
# ======================
# [IMAGE]
#
# SFX Music / Houston Concert Update
# 3DTrans-Siberian
#
#
# 3DJust
#
#
# Trans-Siberian Orchestra
#
# December 20, 2000
# Aerial Theater at Bayou Place
# On-Sale Saturday, November 11 at 10am!=A0=A0
# 3DBuy
#
#
# Pantera
#
# with Soulfly and second opener TBD
# - Due to band injury, the De= cember 8th show has been rescheduled for March
# 25
# Astro Arena
# On sale now!=A0=A0
# 3DBuy
# Original tickets will be honored= !!!
#
#
#
#
# 3DJust Steve Earle
#
# with Matthew Ryan
# Monday, November 13
# Aerial Theater at Bayo= u Palace
# On sale now!=A0=A0
# 3DBuy
#
#
# Gregg Allman and Friends
#
# Tuesday, November 14
# Aerial Theater at Bayou Palace
# On sale now!=A0=A0
# 3DBuy
#
#
# Merle Haggard
#
# with Cory Morrow
# Wednesday, November 15
# Aerial Theater at Ba= you Palace
# On sale now!=A0=A0
# 3DBuy
#
#
# Judy Tenuta presents Funny Gay Men
#
# Brian Bradley / Bob Smith / Jason Stuart
# Saturday, November 18Aerial Theater at Bayou Palace
# On sale now!=A0=A0
# 3DBuy
#
#
# Macy Gray
#
# with Common and Black Eyed Peas
# Sunday, November 19
# Aerial T= heater at Bayou Palace
# On sale now!=A0=A0
# 3DBuy
#
#
# Jerry Jeff Walker
#
# with Ray Wylie Hubbard
# Friday, November 24, 2000
# Aerial Thea= ter at Bayou Palace
# On sale now!=A0=A0
# 3DBuy
#
#
# Mark Farner of Grand Funk Railroad
#
# with Edgar Winter
# Saturday, November 25, 2000
# Aerial Theater= at Bayou Palace
# On sale now!=A0=A0
# 3DBuy
#
#
# The Anger Management Tour with Limp Bizkit
# Godsmack / DMX / Sinisstar
# Wednesday, November 29, 2000
# Comp= aq Center
# On sale now!!=A0=A0
# 3DBuy
#
#
#
#
# All dates, act= s, and ticket prices are subject to change without notice. A
# service charge is added to each ticket price.  All events are rai= n or shine.
#
#
#
#
# For the Aerial Theater's complete show schedule visit www.aerialtheater.com.
#
#
# 3DSFX.com
# **********************
# **********************
# 346 / GAME WEDNEDSDAY @ 7:00 / eric.bass@enron.com / brian.hoskins@enron.com, matthew.lenhart@enron.com,
#  timothy.blanchard@enron.com, jeffrey.gossett@enron.com,
#  kenneth.shulklapper@enron.com, nick.hiemstra@enron.com,
#  luis.mena@enron.com, amir.ahanchian@enron.com / Mon, 18 Sep 2000 07:04:00 -0700 (PDT)
# ======================
# We have a game this Wednesday @ 7:00.  Pleas let me know whether or not you
# will attend.
#
# Thanks,
#
#
# Eric
# **********************
# **********************
# 347 / taylor / eric.bass@enron.com / jason.bass2@compaq.com / Tue, 26 Sep 2000 06:08:00 -0700 (PDT)
# ======================
# your choice of anderson or watters   and  taylor
# **********************
# **********************
# 348 / Re: Statistical Database / eric.bass@enron.com / david.baumbach@enron.com / Tue, 22 Feb 2000 02:30:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 349 / Re: / eric.bass@enron.com / jason.bass2@compaq.com / Thu, 16 Nov 2000 23:57:00 -0800 (PST)
# ======================
# I can do the tv but I am busy all weekend so, if I can do it next week let me
# know.  I might be able to squeeze it in on Saturday b/c I will be out that
# way.
#
#
# On another note, do you know of any hotels in the cotton bowl area in Dallas?
# **********************
# **********************
# 350 /  / eric.bass@enron.com / steve.venturatos@enron.com / Wed, 1 Nov 2000 02:19:00 -0800 (PST)
# ======================
# Mcnabb, Toomer, and Autry for Warner.
#
# This at least gives you a chance for the rest of the year
# **********************
# **********************
# 351 / Re: FYI / eric.bass@enron.com / timothy.blanchard@enron.com / Mon, 4 Dec 2000 06:26:00 -0800 (PST)
# ======================
# and none of them are good :-)
# **********************
# **********************
# 352 /  / eric.bass@enron.com / lwbthemarine@bigplanet.com / Wed, 6 Dec 2000 06:03:00 -0800 (PST)
# ======================
# did you buy any enron in the 60s?
# **********************
# **********************
# 353 / RE: My new work email / eric.bass@enron.com / shanna.husser@enron.com / Wed, 21 Feb 2001 04:03:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 354 /  / eric.bass@enron.com / phillip.love@enron.com / Tue, 7 Nov 2000 00:16:00 -0800 (PST)
# ======================
# just wanted to let you know that lsu is still projected to go to the sharpie
# bowl!
# **********************
# **********************
# 355 / Deal # QM4771 / eric.bass@enron.com / denver.plachy@enron.com / Mon, 29 Jan 2001 08:14:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 356 / Inside UT Football: September 21, 2000 / eric.bass@enron.com / luis.mena@enron.com, mballases@hotmail.com, ami.chokshi@enron.com,
#  denver.plachy@enron.com, victor.guggenheim@enron.com,
#  jackson.logan@enron.com, darron.giron@enron.com / Thu, 21 Sep 2000 01:17:00 -0700 (PDT)
# ======================
#
# **********************
# **********************
# 357 / eSource presents eSearch / enron.announcements@enron.com / all.worldwide@enron.com / Sun, 10 Dec 2000 22:07:00 -0800 (PST)
# ======================
# eSource Launches eSearch Site Bringing Research to Your Desktop
#
#
# eSource, Enron's premier research group, launched their new product, eSearch,
# on December 8, 2000.
#
# eSource's team of specialized researchers have created a web site to bring
# information and research to every employee's desktop.  The eSearch web site
# offers many links to information resources, access to research databases,
# specialized searches, sites to purchase books, articles, and reports, and
# training.  Employees can use the web site to conduct their own research or as
# a vehicle to submit research requests.  eSource's researchers and industry
# specialists are available to all Enron business units to provide timely and
# cost efficient research, to work with individuals or groups to fulfill one
# time research requests, or to design ongoing, customized monitoring projects
# or news updates.
#
#
# The preferred browser is Internet Explorer
#
# Join us for a demonstration and training session on Friday, December 15th at
# 1:00-1:30 and 2:00-2:30 in room EB5C2.
#
#
#
# Discover a Wealth of Information at Your Desktop
# **********************
# **********************
# 358 / Paintball Tomorrow / eric.bass@enron.com / bryan.hull@enron.com, timothy.blanchard@enron.com,
#  matthew.lenhart@enron.com, luis.mena@enron.com, jason.bass2@compaq.com / Fri, 26 Jan 2001 02:12:00 -0800 (PST)
# ======================
# We are getting a group together to play paintaball tomorrow at around 10 am.
# We will be playing at Adventure Village (just north of Intercontinental
# Airport on FM 1960).  Their website is www.adventurevillage.com.  The total
# cost should be somewhere between $30-$40 per person ( about $15 for a gun and
# $6 per 100 paintballs).  Let me know if you can make it.
#
#
# -Eric
# **********************
# **********************
# 359 / Re: Keneally's / matthew.lenhart@enron.com / eric.bass@enron.com / Fri, 17 Nov 2000 02:51:00 -0800 (PST)
# ======================
# i am in
# **********************
# **********************
# 360 / [cheatsheets] Breaking News - Terrell Davis Out Indefinitely / bryant@cheatsheets.net / cheatsheets@egroups.com / Tue, 28 Nov 2000 12:41:00 -0800 (PST)
# ======================
# My friend Catherine Miller, local Denver resident  and Broncos fanatic told
# me tonight that the Channel 9 News in Denver is  reporting that Terrell Davis
# is out indefinitely  They've found  inflammation in his shin bone and are
# now immobilizing his leg with a  cast  They're not yet saying he's out the
# for the season but it definitely  does not look good at this point  More as
# I hear it  Thanks  Cat!
# ?
# Joe
# ?
# ?
#
# To unsubscribe from this group, send an email to:
# cheatsheets-unsubscribe@egroups.com
# **********************
# **********************
# 361 / Re: Fw: Check it out! / daphneco64@yahoo.com / eric.bass@enron.com / Tue, 7 Nov 2000 23:32:00 -0800 (PST)
# ======================
# Fabulous picture.  Thanks.  Your Sleep Deprived Mother
# **********************
# **********************
# 362 / Beware of this file!!! / mfe252@airmail.net / claude2020@yahoo.com, angelwgsx2@aol.com, jason.bass2@compaq.com,
#  alaska_turtles@yahoo.com, vettel22@flash.net, blazic@infosky.net,
#  blazic18@yahoo.co.uk, blondi46@aol.com, bpdhlbrg@aol.com,
#  ccoffee@anpower.com, cassiecorcoran@hotmail.com, freesqr2@aol.com,
#  charityp@flash.net, moonriter1@aol.com, ckendal@comp.uark.edu,
#  cyn05@yahoo.com, prince_foxi@yahoo.com, prhf@glade.net,
#  delena38@home.com, delena1212@icqmail.com, deniesed@hotmail.com,
#  deni_dabei@yahoo.de, dndlitch@btigate.com, donna_42@hotmail.com,
#  eric.bass@enron.com, marstersco@earthlink.net,
#  farah_nado@hotmail.com, farfeched@aol.com, whmfgm@yahoo.com,
#  my2truheart@aol.com, starlit_gazer@yahoo.com, ggstops@aol.com,
#  greenup@airmail.net, hmcgill-satx@worldnet.att.net, jmcmurr1@txu.com,
#  jimmycheer@yahoo.com, janet.corcoran@verizon.com,
#  strait_line@yahoo.com, wxranch@airmail.net, jayjayjarv@yahoo.com,
#  jwheeler45@home.com, jordan_14jb@hotmail.com, jsshives14@aol.com,
#  vaclavik@airmail.net, junebug@ezmailbox.net, euvarova@izvestia.ru,
#  catherine1204@mail.ru, bush56@flash.net, teapot2k@yahoo.com,
#  lj_dipsy@yahoo.com, lindsaym@earthlink.net, slott@esc12.net,
#  lvassil@comp.uark.edu, lucretia@airlinedata.com, lynnrd@tyler.net,
#  maca@glade.net, mblox@flash.net, lmarsters@fortbend.k12.tx.us,
#  dmcdonald@anpower.com, meg51379@aol.com, mfe252@airmail.net,
#  mfergus1@txu.com, fyr_chief@hotmail.com, mdburns@ezmailbox.net,
#  mgriff@glade.net, tmiller1@txu.com, achin2th@aol.com,
#  pkjday@yahoo.com, racox@ev1.net, turbosbabe96@yahoo.com,
#  rcgreentx@hotmail.com, raaron2@txu.com, erpickens@aol.com,
#  uspsa@airmail.net, kalar@airmail.net, sandra_bloxom@hotmail.com,
#  canary@flash.net, steltow@yahoo.com, savinakd@yahoo.com,
#  ladyeagles98_04@yahoo.com, sherrywine2000@yahoo.com,
#  esjames@earthlink.net, spayton@flash.net, sunnygirl730@aol.com,
#  surfworm@flash.net, tammy7129@aol.com, tgdavis1@airmail.net,
#  timbob@flash.net, tlmiller@pflash.com, lvthomas@airmail.net,
#  wmjock@mail.com, wlgreen@airmail.net, zoge2@hotmail.com / Mon, 4 Dec 2000 01:40:00 -0800 (PST)
# ======================
# Beware of this file... it contains a virus that my Norton AntiVirus
# picked up!!!
# Delete it as soon as you see it! DO NOT OPEN IT!!!!
#
# "sexy virgin.scr"
# **********************
# **********************
# 363 / SFX Music / Houston Concert Update / announce-list@sfx.com / ebass@enron.com / Sun, 3 Dec 2000 21:46:00 -0800 (PST)
# ======================
# [IMAGE]
#
# SFX Music / Houston Concert Update
# 3DSammy
#
#
# 3DJust
#
#
# Sammy Hagar
#
# January 24, 2001
# Aerial Theater at Bayou Place
# On sale Saturday, December 9 at 10am=A0=A0
# 3DBuy
# **********************
# **********************
# 364 / Good house / eric.bass@enron.com / daphneco64@bigplanet.com / Wed, 17 Jan 2001 02:54:00 -0800 (PST)
# ======================
# MLS # 534605
#
#
# check it out - maybe a little too expensive though
# **********************
# **********************
# 365 / Re: Good Morning / eric.bass@enron.com / daphneco64@bigplanet.com / Fri, 17 Nov 2000 07:09:00 -0800 (PST)
# ======================
# I just talked to Dad about it.  That is fine.  I should be able to get the $
# to you this weekend.
#
# Love,
#
# E
# **********************
# **********************
# 366 / Moss / eric.bass@enron.com / david.baumbach@enron.com / Mon, 21 Aug 2000 02:53:00 -0700 (PDT)
# ======================
# What do you want for Randy Moss?
# **********************
# **********************
# 367 / FW: snowman / eric.bass@enron.com / bryan.hull@enron.com, david.baumbach@enron.com, michael.walters@enron.com,
#  o'neal.winfree@enron.com, phillip.love@enron.com,
#  matthew.lenhart@enron.com, chad.landry@enron.com,
#  b.lawler@mail.utexas.edu, shelleyzee@mail.utexas.edu / Mon, 13 Dec 1999 06:32:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 368 / Fwd: And We Wonder Why He Was Popular / bthoskins@hotmail.com / mpstan0@hotmail.com, roberto.martinez@enron.com, hcampos@enron.com,
#  leninej@hotmail.com, ebass@enron.com / Thu, 16 Nov 2000 07:30:00 -0800 (PST)
# ======================
# _________________________________________________________________________
# Get Your Private, Free E-mail from MSN Hotmail at
# Share information about yourself, create your own public profile at
# **********************
# **********************
# 369 / Telluride E-Ride Newsletter / eric.bass@enron.com / daphneco64@bigplanet.com, lwbthemarine@bigplanet.com,
#  jason.bass2@compaq.com, shanna.husser@enron.com / Wed, 8 Nov 2000 08:33:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 370 / FYI -New Product on EOL / eric.bass@enron.com / edward.gottlob@enron.com / Tue, 28 Mar 2000 23:38:00 -0800 (PST)
# ======================
# FYI
# **********************
# **********************
# 371 / The Palm Beach Pokey / brian.hoskins@enron.com / eric.bass@enron.com / Wed, 15 Nov 2000 01:32:00 -0800 (PST)
# ======================
# Brian T. Hoskins
# Enron Broadband Services
# 713-853-0380 (office)
# 713-412-3667 (mobile)
# 713-646-5745 (fax)
# Brian_Hoskins@enron.net
# **********************
# **********************
# 372 / Volunteers needed - Houston Boys Club Weekend / eric.bass@enron.com / timothy.blanchard@enron.com / Fri, 30 Jun 2000 04:44:00 -0700 (PDT)
# ======================
# i think this is a call for help.  maybe you should provide with some service
# tonight?
# **********************
# **********************
# 373 / MATT DRUDGE -- DRUDGE REPORT 2000c / eric.bass@enron.com / shanna.husser@enron.com, brian.hoskins@enron.com, hector.campos@enron.com,
#  bryan.hull@enron.com, timothy.blanchard@enron.com,
#  matthew.lenhart@enron.com / Wed, 24 Jan 2001 23:59:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 374 / Bush News Update: 11/28/00 / bushnews@georgewbush.com / ebass@enron.com / Tue, 28 Nov 2000 17:48:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 375 / FANTASY FOOTBALL 2000 / eric.bass@enron.com / matthew.lenhart@enron.com, timothy.blanchard@enron.com,
#  chad.landry@enron.com, brian.hoskins@enron.com,
#  jason.bass2@compaq.com, michael.walters@enron.com,
#  phillip.love@enron.com, david.baumbach@enron.com,
#  o'neal.winfree@enron.com, bryan.hull@enron.com,
#  hector.campos@enron.com, dasparado@aol.com, mballases@hotmail.com,
#  jody.crook@enron.com, harry.bucalo@enron.com / Wed, 28 Jun 2000 01:23:00 -0700 (PDT)
# ======================
# It is coming up on that time again.  The most glorious time of year.  The
# time of the year when life begins anew.  No, not spring, FOOTBALL SEASON!
#
# That being said, it is time to start thinking about fantasy football again.
#
# I need to know who of you is interested in playing again, and any suggestions
# on rule changes (i.e. scoring, fees, etc.). I was thinking about having the
# draft in late August.
#
# Let me know if you have any friends that you think might want to play.
#
#
# -Eric
# **********************
# **********************
# 376 / Fwd: The new Democratic Seal / brettlawler@hotmail.com / lhoff@owenhealth.com, chris_a_regnier@yahoo.com, chmargau@aol.com,
#  blawler875@aol.com, m.montano@mail.utexas.edu, cll@prodigy.net,
#  srhea@acm.org, ebass@ect.enron.com / Wed, 29 Nov 2000 08:08:00 -0800 (PST)
# ======================
# The Democrats just keep giving and giving to the honor and prestige of the
# office of the President of the United States.
#
#
# ______________________________________________________________________________
# _______
# Get more from the Web.  FREE MSN Explorer download :
#  - Democratic Seal.jpg
# **********************
# **********************
# 377 / Amazon.com Order Revision (#107-7339612-5270104) / orders@amazon.com / ebass@enron.com / Tue, 5 Dec 2000 00:03:00 -0800 (PST)
# ======================
# Greetings from Amazon.com.  Thanks for updating the shipping
# address for your order #107-7339612-5270104 to:
# **********************
# **********************
# 378 / URGENT: Help Preserve the Bush Victory / bushnews@georgewbush.com / ebass@enron.com / Mon, 13 Nov 2000 12:56:00 -0800 (PST)
# ======================
# Emergency funds needed:
# On Election Night, George W. Bush won the most votes in Florida.
# Not surprisingly, Al Gore's campaign did not like the result.  They
# immediately dispatched lawyers to Florida and had a Washington
# lobbyist raise $3 million in one day to fund Gore's Florida operation.
#
# Unfortunately, the Gore camp refuses to accept the Election Night
# count or the 2nd computer count or even, in some instances, a 3rd
# computer count.  Now they want a hand count, even though computer
# counts are more precise and objective.  On top of that, they have only
# asked for hand counts in counties that are overwhelmingly Democratic.
#
# We have the high ground.  We're poised to win.  But we need your help
# to defend the integrity of the Florida election.
#
# CLICK BELOW TO MAKE A SECURE ONLINE CONTRIBUTION TO THE BUSH CHENEY
# RECOUNT FUND NOW:
#
#
# PLEASE SEND THIS TO AS MANY CONCERNED AMERICANS AS YOU KNOW.
#
# Unlike the Gore Campaign, which is accepting donations from
# contributors whose name and contributions they are refusing to
# disclose, the Bush Cheney Recount Fund will limit contributions to
# $5,000 and disclose its donors on our Website.
#
# Thank you for all you've done to help elect Governor Bush and
# Secretary Cheney.  Your continued commitment and generosity during
# this important time in the life of our country is greatly appreciated.
#
#
# AOL users: <a href=Recount Fund</a
#
# _____________________________________________________________
#
# Contributions to Bush Cheney Recount Fund are not tax deductible
# for federal income tax purposes.  Corporate and foreign national
# contributions are not permitted under federal law.  Only
# personal funds are permitted.
#
# Paid for by Bush Cheney Recount Fund
# **********************
# **********************
# 379 / Delta Ad / brian.hoskins@enron.com / roberto.martinez@enron.com, hector.campos@enron.com, eric.bass@enron.com,
#  luis.mena@enron.com, barry.steinhart@enron.com, dick.jenkins@enron.com / Mon, 26 Jun 2000 09:10:00 -0700 (PDT)
# ======================
# For old times' sake...
#
#
#  - DELTA.WAV
# **********************
# **********************
# 380 / Robinson / eric.bass@enron.com / o'neal.winfree@enron.com / Tue, 22 Aug 2000 08:01:00 -0700 (PDT)
# ======================
# What is your offer on marcus robinson?
# **********************
# **********************
# 381 / RE: New Gore Campaign Sign / jason.bass2@compaq.com / eric.bass@enron.com / Tue, 21 Nov 2000 00:14:00 -0800 (PST)
# ======================
# I saw you called last night.  What was up?  I tried to call a few times.  Is
# there any way wew can meet today or tomorrow for the TV?  It is due and I
# would rather pay you some money instead another wasted payment with them.
# BTW, how much is the payout for most points in the league?  How much for
# second?
# **********************
# **********************
# 382 / The US military gets mightier / eric.bass@enron.com / lwbthemarine@bigplanet.com, brettlawler@hotmail.com / Fri, 12 Jan 2001 01:53:00 -0800 (PST)
# ======================
# Interesting read . . .
# **********************
# **********************
# 383 / OpinionJournal - Extra / daphneco64@bigplanet.com / lwbthemarine@bigplanet.com, jason.bass2@compaq.com, eric.bass@enron.com / Wed, 6 Dec 2000 01:59:00 -0800 (PST)
# ======================
# ?
#
# ?000738
#  - OpinionJournal - Extra.url
# **********************
# **********************
# 384 / Got questions for Chip Brown? / newsletters@newsletters.dallasnews.com / insideutfootball@newsletters.dallasnews.com / Mon, 6 Nov 2000 10:05:00 -0800 (PST)
# ======================
# Dear Inside UT Football newsletter subscriber:
#
# There's still plenty of football to be played, and we're sure you
# have lots of questions about the Longhorns. Remember, Chip Brown's
# Inside UT Football newsletter is based on your questions. Send yours
# to Chip here: mailto:chipbrown@dallasnews.com
#
# And don't forget to tell a friend about this free service. New
# subscribers may sign up here:
# Enjoy the rest of the season!
# **********************
# **********************
# 385 / Renaissance Austin Hotel / eric.bass@enron.com / shanna.husser@enron.com / Thu, 31 Aug 2000 05:43:00 -0700 (PDT)
# ======================
# here is where we are staying in austin
# **********************
# **********************
# 386 / Dave Kopel on NRO / daphneco64@bigplanet.com / lwbthemarine@bigplanet.com, jason.bass2@compaq.com, eric.bass@enron.com / Thu, 9 Nov 2000 01:19:00 -0800 (PST)
# ======================
# ?
#
# ? - Dave Kopel on NRO.url
# **********************
# **********************
# 387 / computer / eric.bass@enron.com / jason.bass2@compaq.com / Wed, 17 Jan 2001 01:08:00 -0800 (PST)
# ======================
# option 1 is an extra $600
#
# option 2 is an extra $1300
# **********************
# **********************
# 388 / RE: Trade / eric.bass@enron.com / jason.bass2@compaq.com / Fri, 3 Nov 2000 00:37:00 -0800 (PST)
# ======================
# if you get a good deal - i will throw in toomer
# **********************
# **********************
# 389 / brown bags / stacey.dempsey@enron.com / craig.hall@enron.com, ryan.hinze@enron.com, jennifer.martinez@enron.com,
#  james.whitehead@enron.com, darren.maloney@enron.com,
#  crystal.hyde@enron.com, benjamin.markey@enron.com,
#  george.thomas@enron.com, catherine.clark@enron.com,
#  zaib.iqtidar@enron.com, chad.landry@enron.com, chad.landry@enron.com,
#  mo.bawa@enron.com, john.massey@enron.com, jonathon.pielop@enron.com,
#  brent.dornier@enron.com, christa.winfrey@enron.com,
#  akasha.redrick@enron.com, reza.rezaeian@enron.com,
#  eric.scott@enron.com, kate.lucas@enron.com, erin.willis@enron.com,
#  farzad.farhangnia@enron.com, sarah.mulholland@enron.com,
#  matthew.lenhart@enron.com, kenneth.shulklapper@enron.com,
#  kevin.ruscitti@enron.com, hector.campos@enron.com,
#  karla.compean@enron.com, zal.masani@enron.com,
#  leonard.tham@enron.com, claire.broido@enron.com,
#  yvan.chaxel@enron.com, pearce.hammond@enron.com,
#  elizabeth.howley@enron.com, usman.shaukat@enron.com,
#  misti.day@enron.com, simone.rose@enron.com, michelle.zhang@enron.com,
#  shilpa.chunchu@enron.com, daniel.graham@enron.com,
#  molly.hellerman@enron.com, david.hunker@enron.com,
#  alberto.jimenez@enron.com, jebong.lee@enron.com,
#  chetan.paipanandiker@enron.com, eva.rainer@enron.com,
#  carlos.ruiz@enron.com, stephanie.segura@enron.com,
#  rahul.seksaria@enron.com, michael.simmons@enron.com,
#  imad.tareen@enron.com, todd.roten@enron.com, chu.wang@enron.com,
#  chad.gronvold@enron.com, alton.jackson@enron.com,
#  gerardo.benitez@enron.com, ibrahim.qureishi@enron.com,
#  bret.scholtes@enron.com, marc.sabine@enron.com,
#  jason.seigal@enron.com, valter.stoiani@enron.com,
#  jennifer.reside@enron.com, michael.garberding@enron.com,
#  chris.herron@enron.com, ed.wood@enron.com, petual.jeanmard@enron.com,
#  john.scarborough@enron.com, jean-sebastien.fontaine@enron.com,
#  jason.althaus@enron.com, leonardo.pacheco@enron.com,
#  mario.cardoso@enron.com, jin.guo@enron.com,
#  selena.gonzalez@enron.com, matthew.jachimiak@enron.com,
#  kelly.mccoy@enron.com, michael.kolman@enron.com, binh.pham@enron.com,
#  peter.bennett@enron.com, angie.zeman@enron.com,
#  victor.guggenheim@enron.com, alicia.perkins@enron.com,
#  chris.walker@enron.com, raimund.grube@enron.com,
#  stephen.plauche@enron.com, adnan.patel@enron.com,
#  ross.prevatt@enron.com, israel.estrada@enron.com,
#  gaurav.babbar@enron.com, banu.ozcan@enron.com,
#  milind.pasad@enron.com, claudio.ribeiro@enron.com,
#  travis.winfrey@enron.com, gray.calvert@enron.com,
#  stephen.thome@enron.com, laura.wente@enron.com,
#  yvette.parker@enron.com, victor.browner@enron.com,
#  winston.cheng@enron.com, vicky.ha@enron.com, nick.hiemstra@enron.com,
#  john.howton@enron.com, josephine.lin@enron.com,
#  tyrell.harrison@enron.com, todd.hattenbach@enron.com,
#  charles.varnell@enron.com, lisa.gillette@enron.com,
#  jay.epstein@enron.com, jody.crook@enron.com,
#  michael.benien@enron.com, daniel.falcone@enron.com,
#  jennifer.bagwell@enron.com, gabriel.monroy@enron.com,
#  robin.rodrigue@enron.com, michelle.waldhauser@enron.com,
#  purvi.patel@enron.com, sscott5@enron.com, greg.martin@enron.com,
#  john.weakly@enron.com, sheetal.patel@enron.com,
#  brando.hayden@enron.com, seth.hurwitz@enron.com,
#  bryan.hull@enron.com, angelique.woods@enron.com,
#  ryan.deane@enron.com, zeina.el-azzi@enron.com,
#  michael.flanigan@enron.com, marsha.francis@enron.com,
#  joe.gordon@enron.com, paul.gregory@enron.com, amber.hamby@enron.com,
#  jonathan.hoff@enron.com, sean.keenan@enron.com,
#  dayem.khandker@enron.com, john.king@enron.com,
#  kelli.little@enron.com, stanton.ray@enron.com, shahid.shah@enron.com,
#  ying.soong@enron.com, ryan.synnott@enron.com,
#  benjamin.thomason@enron.com, justyn.thompson@enron.com,
#  miguel.vasquez@enron.com, jason.wiesepape@enron.com,
#  virawan.yawapongsiri@enron.com, michael.driscoll@enron.com,
#  chris.mallory@enron.com, cooper.richey@enron.com,
#  geir.solberg@enron.com, jennifer.newbrough@enron.com,
#  heather.alon@enron.com, eric.bass@enron.com, erica.bess@enron.com,
#  evan.betzer@enron.com, harry.bucalo@enron.com, hang.bui@enron.com,
#  mark.castiglione@enron.com, monika.causholli@enron.com,
#  brandon.cavazos@enron.com, andy.chen@enron.com,
#  christopher.chenoweth@enron.com, teresa.dyar@enron.com,
#  daniel.ferrell@enron.com, steve.gim@enron.com, john.gordon@enron.com,
#  scott.griffin@enron.com, christian.hackett@enron.com,
#  brian.hoskins@enron.com, avinash.jain@enron.com,
#  jolly.jose@enron.com, william.keeney@enron.com,
#  joshua.koenig@enron.com, clement.lau@enron.com,
#  fatimata.liamidi@enron.com, homer.lin@enron.com,
#  atticus.lyon@enron.com, kelley.mcintyre@enron.com,
#  ravi.mujumdar@enron.com, kourtney.nelson@enron.com,
#  iris.ng@enron.com, sanjay.patel@enron.com, shiraz.rehman@enron.com,
#  justin.rostant@enron.com, anthony.sexton@enron.com,
#  elizabeth.shim@enron.com, joseph.short@enron.com,
#  gauri.khokha@enron.com, carrie.southard@enron.com,
#  sarah.taylor@enron.com, maria.tefel@enron.com, brandon.wax@enron.com,
#  lewis.worthy@enron.com, allan.wu@enron.com, george.zivic@enron.com,
#  ted.noble@enron.com, brogers2@enron.com, gautam.gupta@enron.com,
#  russell.dyk@enron.com, wjennin@enron.com, doug.sewell@enron.com,
#  lisa.connolly@enron.com, tara.piazze@enron.com, chuck.ames@enron.com,
#  nate.blackburn@enron.com, sachin.gandhi@enron.com, mog.heu@enron.com,
#  sabina.rank@enron.com, elizabeth.shim@enron.com,
#  massimo.marolo@enron.com, vladi.pimenov@enron.com, damon.harvey@enron.com / Mon, 13 Nov 2000 00:22:00 -0800 (PST)
# ======================
# Have you signed up?
#
# Jen Fraser, a Director with Enron Global Markets, November 14 from 12 to 1 in
# EB 30C
#
#
# Call or email Stacey Dempsey.
# **********************
# **********************
# 390 / Historical flows / eric.bass@enron.com / howard.camp@enron.com / Wed, 23 Feb 2000 03:44:00 -0800 (PST)
# ======================
# Howard,
#
# Per our conversation, these are the meters that I need historical flow
# information on.  Info for 2 years back would be helpful.
#
#
# #1008
# #1007
# #1358
# #1009
# #1175
#
#
# Thanks,
#
#
# Eric
# x3-0977
# **********************
# **********************
# 391 / Gonzalez / eric.bass@enron.com / o'neal.winfree@enron.com / Mon, 21 Aug 2000 01:57:00 -0700 (PDT)
# ======================
# What do you want for tony gonzalez?
# **********************
# **********************
# 392 / [Fwd: Coping With Job Stress] / eric.bass@enron.com / bryan.hull@enron.com, michael.walters@enron.com, phillip.love@enron.com,
#  david.baumbach@enron.com, ami.chokshi@enron.com,
#  yvette.connevey@enron.com, o'neal.winfree@enron.com,
#  timothy.blanchard@enron.com, brian.hoskins@enron.com,
#  chad.landry@enron.com, matthew.lenhart@enron.com / Wed, 12 Jan 2000 01:35:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 393 / New Team / eric.bass@enron.com / jason.bass2@compaq.com, phillip.love@enron.com, bryan.hull@enron.com,
#  david.baumbach@enron.com, lqcolombo@aol.com,
#  michael.walters@enron.com, matthew.lenhart@enron.com,
#  harry.bucalo@enron.com, gary.lamphier@enron.com,
#  o'neal.winfree@enron.com, steve.venturatos@enron.com / Fri, 11 Aug 2000 07:26:00 -0700 (PDT)
# ======================
# Brian, Hector, and Lenny have dropped out (what a shocker).  Steve Venturatos
# has graciously offered to take their place.
#
# Thanks Steve.
# **********************
# **********************
# 394 / [cheatsheets] Week 14 Upgrades - Downgrades (11-27-00) / bryant@cheatsheets.net / cheatsheets@egroups.com / Mon, 27 Nov 2000 16:46:00 -0800 (PST)
# ======================
# ?
#
# Hi  Folks,
#
# I gotta say  before I get started that Monday Night Football'   &Pack"  and
# "Cats 8 in the  scoring box was one of the more annoying moves they ,ve  made
# this season   &Cats 8  That'  so  lame.
#
# Enough of that,  let's jump right into our Upgraded and Downgraded  Players
# ...
#
# If you have not picked up your Showdown T-shirt, please come to EB737 to get
# one.  Thanks!
# **********************
# **********************
# 488 /  / brian.hoskins@enron.com / lenine.jeganathan@enron.com, eric.bass@enron.com, hector.campos@enron.com / Mon, 27 Nov 2000 09:55:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 489 / Game tonight @ 7:00 / eric.bass@enron.com / matthew.lenhart@enron.com, timothy.blanchard@enron.com,
#  jeffrey.gossett@enron.com, kenneth.shulklapper@enron.com,
#  nick.hiemstra@enron.com, luis.mena@enron.com,
#  amir.ahanchian@enron.com, brian.hoskins@enron.com / Wed, 27 Sep 2000 01:25:00 -0700 (PDT)
# ======================
# Our game tonight is at 7:00.  Please try to make it by 6:30.
#
# As of now we have eight people.
#
# Tim - can you see if Micah can play again?
# **********************
# **********************
# 490 / Re: College Bowl Pool / shanna.husser@enron.com / eric.bass@enron.com / Mon, 4 Dec 2000 04:44:00 -0800 (PST)
# ======================
# Only if we play together.
#
#
#
# Eric Bass@ECT
# 12/04/2000 12:43 PM
# **********************
# **********************
# 491 / Two-Rows for MNF / eric.bass@enron.com / timothy.blanchard@enron.com, bryan.hull@enron.com,
#  matthew.lenhart@enron.com, harry.bucalo@enron.com / Mon, 25 Sep 2000 03:10:00 -0700 (PDT)
# ======================
# Anyone up for half price pizza tonight, say around 7:45?  And yes, I am a fat
# ass!
#
# Let me know.
# **********************
# **********************
# 492 / [cheatsheets] #150 Week 15 Upgrades - Downgrades (12-4-00) / bryant@cheatsheets.net / cheatsheets@egroups.com / Mon, 4 Dec 2000 14:52:00 -0800 (PST)
# ======================
# Hi  Folks
#
# It's crunch time so  let's jump right into our  Upgraded and Downgraded
# Players  As we head down the home  stretch, identifying those players movi ng
# up or down can be the difference  between?dominating the playoffs or watchi ng
# from the sidelines  As we head into our 15th week  of listing these player s,
# it'  inevitable that some guys will have made both the  upgrade or downg rade
# list  Make  sure you understand, what we ,re talking about is players th at
# are moving  In other words, a player like TE Ricky  Dudley could appear on the downgrade list and still be good enough to be a  starter in your league
# It just  means I'  concerned about the way he seems to be heading  Like wise,
# a player like WR Willie  Jackson may make the upgrade list even though he '
# still fairly far down the  list of WRs  It'  all about which  direction players are moving   Keeping an eye on these trends as they can very often make all the  difference.
#
# Joe
#
# ?
#
# Upgrades and  Downgrades  Some of these  players are obvious moves up or down and some aren't as clear  Here's my  list of guys I see moving this week.
#
# QBs Moving  Up?
#
# QB Aaron Brooks  (NO)? We keep hyping the kid and he keeps delivering
# Another outstanding game Sunday where he rolled up 441 yards and 2 TDs as h e
# went 30 for 48  The Saints rushing game is clearly struggling so it  appea rs
# Brooks will continue to air the ball out  Yes, he'll make some  young QB mistakes and I'd be surprised if he didn't throw as many interceptions  as  he
# does TDs  I expect him to throw a lot of both  I almost  started him over Peyton Manning in my local league but didn't pull the  trigger  Manning wa s
# solid but Brooks was better.
#
# QB Kordell Stewart  (Pit)? Kordell made our upgrade list last week and here he sits  again  It took a few years, but he's showing folks that maybe 199 7
# was no  fluke  He showed guts coming back in the game after being knocked out with  a bad knee or calf (depending on whether you listen to coach Bill Cowher or  Stewart)? The TD rush was highlight material  His problem all along  seems to have been confidence and he's surely brimming with it now  Kent  Graham was so bad I won't even mention him in the downgrades but he p ut
# on a  horrid display when he was in the game  He's  awful.
#
# QB Jay Fiedler  (Mia)? Dan Fouts said on Monday Night Football a few weeks ago  that a nice pass just thrown by Fiedler "was as pretty as anything Dan Marino  ever threw"  Fiedler has those moments and he was having them fair ly
# often  against the supposedly tough Bills where they were supposedly going  to
# have an  advantage in their cold weather  Didn't play out that way
# Fiedler  looks pretty darn good.
#
# QB Jeff Garcia  (SF)? We had him high in week 14 like we have all year and he  didn't disappoint  WR Terrell Owens was a huge help and apparently
# Jerry  Rice's wife?harping on the radio had some sort of positive effect   The Chargers had been very tough against the pass and Garcia shredded  them .
#
# QB Brett Favre  (GB)? I have a hard time putting a finger on it but this gu y
# just  does what it takes to get the job done  He'd be much better off if W R
# Antonio Freeman earned 10% of his paycheck but in the meantime, Bill
# Schroeder's  doing a great job
#
# QB Jeff George  (Was)? Lil Danny Snyder removed the primary obstacle to
# keeping  his QB Jeff George off the field by firing Norv Turner Monday
# George  looks to start this week and possibly for the rest of the year
# Although  tying Snyder to anything past the next series is a stretch  I'm  a
# Jeff  George fan though and he does give the team a big arm  We'll see how it  goes but at least it looks as if he'll get his shot.
#
# ?
#
# RBs Moving  Up
#
# RB Mike Anderson  (Den)? Like you need me to tell you this  The fact that he  ran buck wild on a tough New Orleans defense made the effort all the
# more  impressive  He bruised a knee but seemed to bounce back and looks to be  good for Sunday  Clearly, the Denver OL is the star on this team so if you  own Anderson, it's probably not a bad idea to grab KaRon Coleman for t he
# stretch  run
#
# RB Fred Taylor  (Jac)? For all the early?ripping I've done to Taylor, he's  performed just as we predicted he would lately - like a madman  You don't  need me to tell you he's been awesome.
#
# RB Warrick Dunn  (TB)? Can the little guy take up the slack for Mike
# Alstott   I've got a couple hundred reasons that says "yes"  Ok, rushing for 200+  against Dallas is nothing special (it's happened in 23% of the
# Cowboys games  this year) but you have to admit Dunn looked great  Sunday
#
# RB Corey Dillon  (Cin)? One can only salivate about what he might do if he played  for a team like Denver  The fact he can continue to roll up huge yardage  on this team is amazing  New QB Scott Mitchell is a huge boost as he looks  like Peyton Manning back there compared to Akili  Smith...
#
# RB Ahman Green  (GB)? Green's a guy that's finally living up to his
# potential  You always knew he had the physical skills but now he seems to  be catching up mentally as well  He showed a nice nose for the endzone
# Sunday with the 2 TDs.
#
# RB Lamar Smith  (Mia)? So much for the cold weather hamstring worries
# Smith  carried the load Sunday in frigid Buffalo and looked great  It look s
# to me  like he's picking up right where he left off.
#
# RB Terrell Fletcher  (SD)? It's not exactly the same as earning the startin g
# RB job in  Tennessee or Indianapolis, but Fletcher does seem to have nailed down the #1 RB  slot in San Diego  And that's worth something  You have t o
# decide  how much...
#
# RB Fred Beasley  (SF)? We loved Beasley early in the season as he racked up TDs  He got back in the mix Sunday with 5 carries and a TD  The FB  for S an
# Francisco has always been a valuable FF slot and Beasley might be worth  th e
# roll of the dice if you're thin at RB.
#
# RB Shawn Bryson  (Buf)? Finally, Bryson does something besides make me look bad for  hyping him  He rolled up 88 yards on just 12 attempts Sunday and looks to  take advantage of Sammy Morris' ankle troubles
#
# RB Terry Allen  (NO)? Allen made an appearance Sunday and with Jerald Moore and  Chad Morton failing to astound anyone, Allen could get more looks
# Whether  he's got anything left in the tank remains to be seen.
#
# ?
#
# WRs Moving  Up
#
# WR David Boston  (Ari)  Boston turned in a huge game Sunday and has to be  considered an upgrade  He's a streaky guy but with Frank Sanders a total  non factor, Boston is getting most of QB Jake Plummer's attention these
# days  And with Arizona almost certain to be playing from behind, he could  do some damage.
#
# WR Darrell Jackson  (Sea)? Jackson was red hot several weeks ago but had
# cooled of  late  He warmed up again Sunday with Jon Kitna under center  It's  tough to depend on the Seahawk passing game but Jackson could be wort h
# a  shot.
#
# WR Curtis Conway  (SD)? Conway has benefited the most from the Ryan Leaf  resurgence  He caught 7 passes Sunday and should benefit as Leaf continues to improve.
#
# WR Willie Jackson  (NO)? Jackson's officially moved past the "flash in the pan" stage  with another solid day  Aaron Brooks continues to look good at QB   Jackson may suffer a bit when Jake Reed gets healthy but for right no w,
# he's  looking good.
#
# WR Joe Horn  (NO)? Again, QB Aaron Brooks delivers and Horn is the prime  recipient  Joe Horn is one of the better stories of 2000 and he should
# continue to shine especially if the rushing game doesn't get  untracked.
#
# WR Bobby Shaw  (Pit)? Shaw may still be available in your league as the
# starting  WR opposite Hines Ward  He found the endzone again and continues to make  some noise with Kordell Stewart quarterbacking.
#
# WR Terrell Owens  (SF)? The best news for Jeff Garcia owners had to be a
# solid day  from Terrell Owens  He's a huge boost to the offense when he ca n
# go and it  looked like he'd made progress with the toe  Keep an eye out fo r
# how he  responds after the game but I liked what I saw.
#
# WR Shockmain Davis  (NE)? Ok, I'll be honest  I'm pretty much just includi ng
# him  here because he's the owner of the coolest name in the  league...
#
# ?
#
# TEs Moving  Up
#
# TE Dwayne Carswell  (Den)? Carswell's finally starting to emerge as the TE  of
# choice  in Denver  His 62 yards Sunday were second only to San Diego's
# Freddie  Jones  You have to worry about Desmond Clark stealing time but I' d
# have no  trouble starting Carswell each week.
#
# TE Reggie Kelly  (Atl)? One of the few bright spots for Atlanta has been th e
# play  of Kelly  He caught 4 passes for 44 yards Sunday with a TD  New QB  Doug Johnson may lean on him as he settles in.
#
# TE Mark Bruener  (Pit)? Bruener makes the list not only for having another solid  game but for making one of the best TD runs after the catch Sunday a s
# he piggy  backed a defender into the endzone after refusing to go down at t he
# 5 yard  line.
#
# TE Andrew Glover  (NO)? Obviously, the play of Aaron Brooks raises the leve l
# of play  for all the Saints receivers  Glover made a couple of nice plays Sunday  including a good looking TD catch.
#
# ?
#
# Players Moving  Down
#
# QBs Moving  Down
#
# QB Shane Matthews  (Chi)? Take a seat Shane  Cade McNown likely makes his  return  Folks can hardly wait...
#
# QB Troy Aikman  (Dal)? Emmitt Smith owners had to love it but did it seem strange  to anyone else that the Cowboys felt the best way to come back fro m
# a huge  deficit against Tampa was to feed the ball to Emmitt  Clearly, the team  has zero faith in Aikman's ability to throw the ball.
#
# QB Shaun King  (TB)? I know he's had trouble with the back but 65 passing  yards  That's a joke  He'll be better but I've seen  enough.
#
# QB Brad Johnson  (Was)? It's the Jeff George show  At least until?George  looks bad for a few series...
#
# QB Rob Johnson  (Buf)? In leagues that penalize for interceptions, you'd ha ve
# been  better off starting yourself this weekend than you would've Rob
# Johnson   Once again, he starts the game but finishes holding a  clipboard .
#
# ?
#
# RBs?Moving  Down
#
# RB Jamal Anderson  (Atl)? Anderson's not playing too badly but the team is in  shambles  After QB Chris Chandler was benched, Anderson vented some  frustrations saying for all he knew, "he might be punting this week"  I  don't think we'll see that but I also don't think we'll see the days of him seriously rushing the ball for the rest of the year.
#
# RB Shaun Alexander  (Sea)  RB Ricky Watters has proven to be less than an ideal  playmate refusing to share the ball  Actually, he's played so well that  Mike Holmgren has been reluctant to do anything to disrupt the flow o f
# his  star  When the team is struggling as badly as it is, you don't mess with  the one thing that's working.
#
# Philadelphia  RBs? Forget about them  This team will live and die by
# Donovan McNabb.
#
# RB Jermaine Fazande  (SD)? Evidently, Fazande is the 2nd choice behind
# Terrell Fletcher  now  That's gotta hurt...
#
# ?
#
# WRs Moving  Down
#
# WR Joe Jurevicius  (NYG)? This has nothing to do with the play of Jureviciu s
# as he's  been very solid but you have to think Ike Hilliard will be a facto r
# when he  returns  He's no lock to go this week but he may be  close.
#
# WR Terrance Mathis  (Atl)? Mathis continues to struggle on a team that's in a  tailspin  New QB Doug Johnson seemed to like throwing to Shawn Jefferso n
# which could spell more bad things for Mathis.
#
# WRs Torrance Small /  Charles Johnson (Phi)? Forget about it  Donovan McNa bb
# can  be a solid QB without WRs.
#
# WRs James McKnight / Wayne  McGarity (Dal)? These guys just aren't very
# McGood  QB Troy  Aikman is a mere shadow of his former self.
#
# WR Marcus Robinson  (Chi)? Robinson's back troubles were apparently more
# serious than  many had expected  It was announced Monday that he'll likely miss the rest  of the season with a bulging disk in his back  It appears h e
# can get by  without surgery but he's certainly not looking good.
#
# ?
#
# TEs Moving  Down
#
# TEs Marcus Pollard / Ken  Dilger (Ind)? Neither of these guys did much
# Sunday  This  offense clearly isn't in the same groove it was earlier this year
#
# TEs Jackie Harris / David  LaFleur (Dal)? More bad news associated with Tro y
# Aikman   Neither of these guys were much value Sunday and I don't see that changing very  quickly.
#
# TE Pete Mitchell  (NYG)? One of the bigger disappointments at TE this seaso n,
# he  just can't get untracked.
#
# ?
#
# ?
#
# ?
#
# ?
#
#
#  To unsubscribe from this group, send an email to:
# cheatsheets-unsubscribe@egroups.com
# **********************
# **********************
# 493 /  / eric.bass@enron.com / jason.bass2@compaq.com / Wed, 20 Sep 2000 05:05:00 -0700 (PDT)
# ======================
# what do you want for taylor?
# **********************
# **********************
# 494 / Re: / lwbthemarine@bigplanet.com / eric.bass@enron.com / Wed, 6 Dec 2000 11:32:00 -0800 (PST)
# ======================
# yes,@68. Your inheritance is @ risk.
# **********************
# **********************
# 495 / Re: FW: FW: Aggies Demand a Recount / todd.migliore@enron.com / stephen.schwarzbach@enron.com / Wed, 15 Nov 2000 00:53:00 -0800 (PST)
# ======================
# Good one.  Let's hope they lose the next one too, and someone will write
# another funny parody.
# **********************
# **********************
# 496 / Re: Wellhead Accrual Income / eric.bass@enron.com / brenda.herod@enron.com / Mon, 17 Apr 2000 08:09:00 -0700 (PDT)
# ======================
# Hear is the info.  Let me know if you have any further questions.
# **********************
# **********************
# 497 / Fw: Word Merchants at their best... / lwbthemarine@bigplanet.com / daphneco64@bigplanet.com, daphneco64@yahoo.com, jason.bass2@compaq.com,
#  eric.bass@enron.com / Fri, 8 Dec 2000 04:39:00 -0800 (PST)
# ======================
#
# **********************
# **********************
# 498 /  / lwbthemarine@bigplanet.com / eric.bass@enron.com / Fri, 10 Nov 2000 01:45:00 -0800 (PST)
# ======================
# Hi Son. Mother found another box of ski clothes  including her white ski
# outfit and a couple of others.  Next time you are here,  have Shana look. See
# you this p.m.-Dad
# **********************
# **********************
# 499 / Generation / eric.bass@enron.com / leonard.tham@enron.com / Mon, 26 Jun 2000 05:02:00 -0700 (PDT)
# ======================
# Let me know if you can pull this info together.
#
# Thanks,
#
# Eric
# **********************
# **********************

# %%
# filter out announcement and mailing list emails, and emails to large numbers of people
def check_good_tofrom(msg):
    return (re.match(r'.*(admin|newsletter|list|announce|all[\._]|everyone[\.\_]).*', msg['From'], re.IGNORECASE) is None and
            msg['To'] is not None and
            re.match(r'.*(admin|newsletter|list|announce|all[\._]|everyone[\.\_]).*', msg['To'], re.IGNORECASE) is None and
            re.match(r'.*@enron\.com', msg['From'], re.IGNORECASE) and
            len(msg['To'].split()) <= 3)

# %%
for msg_key in msgs[15000:15500]:
    message = mbox.get(msg_key)
    if check_good_tofrom(message):
        msgbody = cleanup_email(message.get_payload())
        if len(msgbody) > 0:
            print(msg_key, "/", message['Subject'], "/", message['From'], "/", message['To'], "/", message['Date'])
            print("======================")
            print(msgbody)
            print("**********************")
            print("**********************")
# Out:
# 15000 / EOL Outage Saturday, January 20th / steve.hotte@enron.com / bob.martinez@enron.com / Fri, 19 Jan 2001 01:41:00 -0800 (PST)
# ======================
# Please add Michelle Lokay (TW) to the EOL distributions.
#
# Thank you.
# **********************
# **********************
# 15003 / Internet Report Access / hottap@enron.com / michelle.lokay@enron.com / Fri, 23 Jun 2000 01:48:00 -0700 (PDT)
# ======================
# You have been added as an internal user to be able to access flowing gas
# reports and invoices on the internet at  Your
# user id is "mlokay" and your password is "FLOWGAS56".
# **********************
# **********************
# 15008 / Re: download basis differential for TW (rms_basis table) / meiling.chen@enron.com / gary.kenagy@enron.com / Mon, 4 Dec 2000 06:46:00 -0800 (PST)
# ======================
# Gary,
# Changes related to TW basis differential for TW Deal Analysis is completed.
# Michelle Lokay has reviewed the new index price using the new tables and
# logic.
# The migration does not  impact other applications.  Please approve it and
# forward
# it to Margaret Waters mail box.
# **********************
# **********************
# 15009 / MUST READ: ISC.ENRON.COM / sap.hotline@enron.com / enron.users@enron.com / Fri, 1 Dec 2000 07:02:00 -0800 (PST)
# ======================
# With the completion of the Enron SAP implementation known as "Apollo &
# Beyond" in August 2000, a new organization, the Integrated Solutions Center
# (ISC), was formed. The ISC is a support organization for Enron-wide back
# office information systems which, of course, includes SAP users and the SAP
# system.
#
# The web is an integral form of support for our customers and as you may know,
# the ISC recently launched a new website in order to better serve its
# customers and to reflect the widening scope of services the ISC has to
# offer.
# preparation for the final closure of the "old" website on Tuesday 5th
# December 2000.
#
# All due diligence was taken when verifying and validating documents that were
# migrated from the old to the new site.  In order to assist you in navigating
# around isc.enron.com, please note the following navigation tips:
#
# - Online forms reside at isc.enron.com
#
# - Non-online forms (formerly at sap.enron.com
# the Document Library at  isc.enron.com
#
# - Documentation (ie User Procedures, quick ref cards, step-by-steps) reside
# in the Document Library at isc.enron.com under Get Help
#
# Please take a moment today to visit and familiarize
# yourself with the new site if you haven't already been able to do so.
#
# Questions & Comments
#
# Website only:  Call the ISC Call Center at 713-345-4SAP, or send an e-mail
# from the site to the ISC Webmaster.
#
# Site or Documentation Content: Call the ISC Call Center
#
# Thank you.
# **********************
# **********************
# 15010 / Palm Pilot Request / audrey.robertson@enron.com / jmcfarl@enron.com / Wed, 14 Jun 2000 02:34:00 -0700 (PDT)
# ======================
# Jean, would your group have the responsibility now of purchasing and
# installing the needed software for a Palm Pilot for our new staff member,
# Michelle Lokay?
#
# Please forward the necessary forms for this purchase.
#
# Thanks in advance,
#
# adr
# **********************
# **********************
# 15011 / WinInstall Will Run on Friday / ets.center@enron.com / ets.center@enron.com / Thu, 11 Jan 2001 05:08:00 -0800 (PST)
# ======================
# WinInstall Will Run on Friday
#
# A WinInstall screen will appear during your login on Friday, January 12,
# 2001.
#
# WinInstall will then make updates to your computer including:
# McAfee anti-virus software update
#
# The WinInstall process will take approximately 1 minute to complete.  A bar
# showing percentage of completion is displayed during the process.  Please
# note that during the update, you should not disturb the machine.  Doing so
# will only slow the update.
#
# If you have any questions, please call the GPG Solution Center
# **********************
# **********************
# 15013 / Re: migration request / meiling.chen@enron.com / kim.kouri@enron.com, michelle.lokay@enron.com / Tue, 7 Nov 2000 01:49:00 -0800 (PST)
# ======================
# I have replace the old basis differential with Michelle's new numbers and
# migrated the program to
# production.  So TW Deal Analysis is using the new basis differential now.
#
# Mei-Ling
# **********************
# **********************
# 15022 / Hot Line Request / audrey.robertson@enron.com / joe.witherspoon@enron.com / Thu, 4 Jan 2001 08:07:00 -0800 (PST)
# ======================
# Joe, we would like to make an urgent request to have one of our staff persons
# added to our hotline number 18000.  We have discussed this request on
# numerous occasions, but have not been successful in any attempt.
#
# Would you please, at this time, please arrange to have Michelle Lokay's
# extension, 57932, roll over to the hotline number, 18000.
#
# When we spoke, you assured me that this would be handled.  Please call me on
# ext. 35849 if you have any questions regarding this request.
#
# Again, we will need this handled today.
#
# Thanks in advance for your assistance,
#
# adr
# **********************
# **********************
# 15030 / WinInstall Will Run on Today -Tuesday After 2:00 p.m. / ets.center@enron.com / ets.center@enron.com / Tue, 13 Feb 2001 05:12:00 -0800 (PST)
# ======================
# WinInstall Will Run on Today
#
# A McAfee update is set to run after 2:00 p.m. Today Tuesday February 13,
# 2001.
# Please be advised that the McAfee Winstall will only run if you reboot your
# pc after 2:00 p.m. today. We would like to advise you to REBOOT your PC after
# 2:00 p.m. IF you DONOT reboot after 2:00 p.m. Please Power Down your computer
# so that Winstall will run at your next Login.
#
# McAfee update is run as a Precaution for some Suspected Valentine Viruses.
#
# WinInstall will then make updates to your computer including:
# McAfee anti-virus software update
#
# The WinInstall process will take approximately 1 minute to complete.  A bar
# showing percentage of completion is displayed during the process.  Please
# note that during the update, you should not disturb the machine.  Doing so
# will only slow the update.
#
# If you have any questions, please call the GPG Solution Center
# **********************
# **********************
# 15032 / RE: Distribution list / tara.rosenbohm@enron.com / michelle.lokay@enron.com, julie.armstrong@enron.com / Wed, 20 Feb 2002 08:01:24 -0800 (PST)
# ======================
# Getting added to global distribution lists is now an eRequest under Applications -
# **********************
# **********************
# 15035 / Michelle Lokay Name Problem / jean.mcfarland@enron.com / michelle.lokay@enron.com / Thu, 22 Jun 2000 13:19:00 -0700 (PDT)
# ======================
# Michelle
# **********************
# **********************
# 15039 / Re: 30-Year Service Award Reception for Mike McGowan Today! / jean.mcfarland@enron.com / julie.mccoy@enron.com / Thu, 15 Jun 2000 07:41:00 -0700 (PDT)
# ======================
# Julie
# **********************
# **********************
# 15042 / Year End 2000 Performance Feedback / perfmgmt@enron.com / michelle.lokay@enron.com / Mon, 30 Oct 2000 15:05:00 -0800 (PST)
# ======================
# NOTE:  YOU WILL RECEIVE THIS MESSAGE EACH TIME YOU ARE SELECTED AS A REVIEWER.
#
# You have been selected to participate in the Year End 2000 Performance
# Management process by providing meaningful feedback on specific employee(s).
# Your feedback plays an important role in the process, and your participation
# is critical to the success of Enron's Performance Management goals.
#
# To complete requests for feedback, access PEP at
# and select Perform Review under Performance Review Services.  You may begin
# providing feedback immediately and are requested to have all feedback forms
# completed by Friday, November 17, 2000.
#
# If you have any questions regarding PEP or your responsibility in the
# process, please contact the PEP Help Desk at:
#
# Houston: 1.713.853.4777, Option 4
# London:  44.207.783.4040, Option 4
# Email: perfmgmt@enron.com
#
# Thank you for your participation in this important process.
#
# The following is a CUMULATIVE list of employee feedback requests with a
# status of "OPEN."   Once you have submitted or declined an employee's request
# for feedback, their name will no longer appear on this list.
# **********************
# **********************
# 15049 / Netscape / kevin.hyatt@enron.com / jean.mcfarland@enron.com / Fri, 4 Aug 2000 04:10:00 -0700 (PDT)
# ======================
# Jean, per our conversation today, please add Netscape to the following users
# PC's.  The application is required to run the "Deal Analysis" program
# recently completed by Dave Foti.  This program was written to help the
# marketing team analyze the profitability of new transport deals and the fuel
# consumed on the proposed pipeline path.  I understand we will lose the
# Netscape capability in approx. 3 months with the advent of Windows 2000.
#
# thanks for the help
#
# Team Members
# Kevin Hyatt
# Jeff Fawcett
# TK Lohman
# Lorraine Lindberg
# Christine Stokes
# Michelle Lokay
# Steve Harris - VP
# **********************
# **********************
# 15050 / RE: TW Unsubscribed Capacity / jeff.huo@enron.com / jeff.huo@enron.com, michelle.lokay@enron.com, perry.frazier@enron.com / Mon, 11 Feb 2002 20:27:13 -0800 (PST)
# ======================
# I migrated the new web pages to www.hottap.enron.com <Please let me know if you have any questions.
#
# Thanks
# Jeff
# **********************
# **********************
# 15051 / DP Question / david.foti@enron.com / jeffery.fawcett@enron.com / Wed, 28 Jun 2000 10:57:00 -0700 (PDT)
# ======================
# Jeff:
#
# You asked how your Gross Margin % could be higher in 2000 but your overall
# Gross Margin be lower.
#
# You appear to have lower invoiced volumes in Jan-April 2000.
#
# January and Feb. -for example:
# **********************
# **********************
# 15053 / Re: TW Security Access Request / maggie.matheson@enron.com / kevin.hyatt@enron.com, michelle.lokay@enron.com / Mon, 8 Jan 2001 08:34:00 -0800 (PST)
# ======================
# Your access request has been completed, please let me know if your have any
# problems.
#
# Maggie
# **********************
# **********************
# 15062 / Nymex info on desktop PC's / kevin.hyatt@enron.com / sharris1@enron.com / Mon, 19 Jun 2000 09:17:00 -0700 (PDT)
# ======================
# One of the deliverables of Revenue Management is the Marketing Dashboard
# which, among a veritable cornucopia of features, will include live Nymex and
# Enron OnLine data pricing feeds.  The rollout of the Dashboard for NNG and TW
# is in the next 2 weeks.  However, the Nymex data feed won't happen till
# August due to technology limitations.
#
# In the meantime, via our desktops, we all have access to Enron OnLine which
# provides live market data that is as good or better than Nymex.  This should
# suffice in the interim till the Dashboard is fully functional.  Let me know
# if you have questions.
#
# thanks
# KH
# **********************
# **********************
# 15063 / Enron Year End 2000 Performance Management Process / perfmgmt@enron.com / michelle.lokay@enron.com / Mon, 30 Oct 2000 11:17:00 -0800 (PST)
# ======================
# Reminder, Enron's Year-End 2000 Performance Management Process has begun!
#
# During the feedback phase you will need to access PEP at
# to suggest reviewers who can provide feedback on
# your performance.  You may also be requested to provide feedback on fellow
# employees, but the system will only be open for feedback until November 17th!
#
# HelpDesk representatives will be available to answer questions throughout the
# process.  You may contact the HelpDesk at:
#
# Houston:  1-713-853-4777, Option 4
# London:  44-207-783-4040, Option 4
# E-mail:  perfmgmt@enron.com
#
# Your User ID & Password for PEP at are:
#
# User ID: 90125268
#
# Password: WELCOME
# **********************
# **********************
# 15064 / Performance Management Process - New Password / perfmgmt@enron.com / michelle.lokay@enron.com / Tue, 31 Oct 2000 11:02:00 -0800 (PST)
# ======================
# According to our system records, you have not yet logged into the Enron
# Performance Management system (PEP).   As a result your temporary password
# for the PEP system has expired.  Your  User Id and new password are provided
# below.
#
# During the feedback phase you will need to access PEP at
# to suggest reviewers who can provide feedback on
# your performance.  You may also be requested to provide feedback on fellow
# employees, but the system will only be open for feedback until November 17th!
#
# HelpDesk representatives will be available to answer questions throughout the
# process.  You may contact the HelpDesk at:
#
# Houston:  1-713-853-4777, Option 4
# London:  44-207-783-4040, Option 4
# E-mail:  perfmgmt@enron.com
#
# Your  User Id and new PEP password are:
#
# User ID: 90125268
#
# Password: IGSQVDYG
# **********************
# **********************
# 15065 / ET&S intranet access / richard.abramowicz@enron.com / michelle.lokay@enron.com / Wed, 16 Aug 2000 02:33:00 -0700 (PDT)
# ======================
# I have set up your user id and password on the ET&S intranet.  It will allow
# you to see the marketing reports, TW Marketing, and ET&S updates.  Your user
# id and password are both "mlokay".  Please change your password by going to
# and pressing the "Change User Info" link on the
# navigation bar.
# **********************
# **********************
# 15076 / RE: TW Deal Profitability / kimberly.carter@enron.com / michelle.lokay@enron.com / Thu, 14 Feb 2002 06:41:14 -0800 (PST)
# ======================
# The programs will still be available to be resurrected but it would not be instantaneous.
#
# Thank you,
# Kimberly
# **********************
# **********************
# 15079 / eRequest Password / erequest@enron.com / michelle.lokay@enron.com / Thu, 18 Jan 2001 03:21:00 -0800 (PST)
# ======================
# Your eRequest's password is 6136
# To use this password, go to the eRequest website and click on non-Corp logon.
# Put in your email address and the password above and click Log In, and you
# will log into eRequest.
# **********************
# **********************
# 15080 / Burlington OBA name change / michelle.lokay@enron.com / dennis.lee@enron.com / Tue, 19 Mar 2002 06:51:52 -0800 (PST)
# ======================
# Burlington has agreed to execute this outstanding OBA if the name on the contract is changed.  Can we update the name from BURLINGTON RESOURCES TRADING, INC.  to BURLINGTON RESOURCES Gathering, INC.
# **********************
# **********************
# 15083 / FW: FROM CINDY OLSON, COMMUNITY RELATIONS:  Discount Tickets to The
#  Nutcracker / michelle.lokay@enron.com / jimboman@bigfoot.com / Thu, 20 Dec 2001 05:38:33 -0800 (PST)
# ======================
# Do you want to go?
# **********************
# **********************
# 15084 / RE: TW CAS Hands -on Training / michelle.lokay@enron.com / ramona.betancourt@enron.com / Tue, 19 Mar 2002 12:56:22 -0800 (PST)
# ======================
# 30 minutes...is that all we need?  Let's schedule all the marketers:  me, Lorraine, TK, Paul, Mark, and Kim.  Thanks.
# **********************
# **********************
# 15085 / FW: Contract #27496 / michelle.lokay@enron.com / dennis.lee@enron.com / Mon, 31 Dec 2001 06:21:38 -0800 (PST)
# ======================
# This is the San Juan to San Juan contract, with alternates out of the path.  Same as December.
# **********************
# **********************
# 15086 / RE: Call when you receive this (no rush) / michelle.lokay@enron.com / 548@britishparts.com / Tue, 19 Mar 2002 08:34:56 -0800 (PST)
# ======================
# HI
# **********************
# **********************
# 15089 / RE: Dinner Invitation / michelle.lokay@enron.com / mark.mcconnell@enron.com / Wed, 30 Jan 2002 09:32:12 -0800 (PST)
# ======================
# Thanks for the invite...either night works!
# **********************
# **********************
# 15090 / RE: Mojave Imbalance with Transwestern / michelle.lokay@enron.com / 'mayher@enron.com, susan.mayher@elpaso.com / Mon, 11 Feb 2002 12:03:37 -0800 (PST)
# ======================
# Great!  Based on your reconciling, I will run additional reports on our side for 09/00 and 11/00.  Please call me, 713-345-7932.
# **********************
# **********************
# 15091 / RE: Time Reports Are Due!!! / michelle.lokay@enron.com / audrey.robertson@enron.com / Thu, 13 Dec 2001 09:25:34 -0800 (PST)
# ======================
# I don't know if I am taking 1/2 day of vacation yet...or if we can just leave a little early to prepare and travel for tomorrow night.  What do you think?
# **********************
# **********************
# 15093 / RE: Mojave Imbalance with Transwestern / michelle.lokay@enron.com / michelle.lokay@enron.com / Mon, 11 Feb 2002 12:21:47 -0800 (PST)
# ======================
# I would like to receive your daily volume statements...my fax is 713-646-4095.  Thanks again.
# **********************
# **********************
# 15095 / FW: What's Wrong With This Picture? / michelle.lokay@enron.com / lokay@bigfoot.com / Fri, 1 Mar 2002 13:34:11 -0800 (PST)
# ======================
# Can you spot what's wrong with this picture? Look closely. It may take you a minute.
# **********************
# **********************
# 15096 / RE: Baker Fied Project / michelle.lokay@enron.com / ron.matthews@enron.com, mansoor.abdmoulaie@enron.com / Fri, 1 Mar 2002 12:48:39 -0800 (PST)
# ======================
# Of course...Tuesday it is!
# **********************
# **********************
# 15099 / RE: Transportation / michelle.lokay@enron.com / tdickers@westerngas.com / Mon, 17 Dec 2001 07:27:27 -0800 (PST)
# ======================
# Approved.  The contract number will remain the same, #27785.
#
# Dennis,
# Per conversation, same contract, volume, and rate for 1 additional day.  Thanks.
# **********************
# **********************
# 15100 / FW: I/B Link Capacity for 12/11 / michelle.lokay@enron.com / dennis.lee@enron.com / Mon, 10 Dec 2001 14:20:19 -0800 (PST)
# ======================
# Approved.
# **********************
# **********************
# 15103 / eBay item 701625455 (Ends Mar-24-02 125035 PST ) - 100% AUTH. LOUIS
#  VUITTON CLA / michelle.lokay@enron.com / lokay@bigfoot.com / Tue, 12 Mar 2002 11:27:48 -0800 (PST)
# ======================
# 1625455
# **********************
# **********************
# 15105 / RE: Time Reports Due Tomorrow / michelle.lokay@enron.com / audrey.robertson@enron.com / Thu, 14 Mar 2002 11:07:12 -0800 (PST)
# ======================
# I took 1/2 day of vacation last Friday, 03/08.  Thanks.
# **********************
# **********************
# 15106 / FW: Transwestern Capacity Release - ENA/Burlington / michelle.lokay@enron.com / paul.y'barbo@enron.com / Wed, 30 Jan 2002 13:05:16 -0800 (PST)
# ======================
# FYI.
# **********************
# **********************
# 15107 / SprintEnron / michelle.lokay@enron.com / 'hitschel@enron.com, bhitschel@tesoropetroleum.com, jimboman@bigfoot.com / Thu, 14 Feb 2002 06:24:13 -0800 (PST)
# ======================
# C:\Documents and Settings\mlokay\Local Settings\Temporary Internet Files\OLK118\SprintEnron.jpg
# **********************
# **********************
# 15108 / RE: TW Imbalances at Topock and Tumbleweed / michelle.lokay@enron.com / 'mayher@enron.com, susan.mayher@elpaso.com / Thu, 14 Feb 2002 08:39:31 -0800 (PST)
# ======================
# About CIG...yes, please send statements to support the volume difference for 07/01 and 03/00.  The reconciliation seems to be going very well.  We had originally sent Mike Clark the CIG data back to 06/93...do you have those?  Thanks.
# **********************
# **********************
# 15109 / RE: FW: Williams Field Services OBA / michelle.lokay@enron.com / steven.harris@enron.com, shelley.corman@enron.com / Wed, 12 Dec 2001 09:15:21 -0800 (PST)
# ======================
# Final approval received!  I have an executed document signed by Williams and Danny McCarty.  Cash in amount of $268,702 is forthcoming.
# **********************
# **********************
# 15110 / AVAILABLE FIRM CAPACITY ON TRANSWESTERN / michelle.lokay@enron.com / tdickers@westerngas.com / Tue, 22 Jan 2002 07:08:34 -0800 (PST)
# ======================
# Due today at 5:00...hope you guys bid!
# **********************
# **********************
# 15111 / Disney link / michelle.lokay@enron.com / jimboman@bigfoot.com / Fri, 4 Jan 2002 12:53:30 -0800 (PST)
# ======================
# Michelle Lokay
# Account Director
# Transwestern Commercial Group
# 713-345-7932
# **********************
# **********************
# 15113 / TW - available capacity / michelle.lokay@enron.com / rvhamman@aep.com / Tue, 22 Jan 2002 07:45:50 -0800 (PST)
# ======================
# Bids are due today at 5:00...hope you guys bid!
# **********************
# **********************
# 15115 / Gas Sales Confirmation.xls / michelle.lokay@enron.com / paul.cherry@enron.com / Mon, 4 Feb 2002 11:22:03 -0800 (PST)
# ======================
# Paul,
# I am not sure how this info gets to you; but, attached is the sales confirm I executed this morning.  TW is selling "operational gas" to Western, effective April 1,2002.
# **********************
# **********************
# 15116 / RE: Time Reports Are Due!!! / michelle.lokay@enron.com / audrey.robertson@enron.com / Thu, 13 Dec 2001 09:28:28 -0800 (PST)
# ======================
# Thank you.
# **********************
# **********************
# 15123 / Let's go here...Grand Wailea in Maui! / michelle.lokay@enron.com / jimboman@bigfoot.com / Mon, 7 Jan 2002 09:03:07 -0800 (PST)
# ======================
# Grand Romance Package
#
# It's the ultimate in romance, starting at $1827* for four nights! Ideal for honeymooners or couples on a romantic getaway, this package includes:
# Accommodations in a Terrace room**
# Welcome amenity upon arrival
# Two full 50-minute massage or facial sessions at the award winning Spa Grande
# One romantic lanai breakfast (ordered from Room Service)
# Keepsake memento
# *Packages available in all room categories. Prices are based on double occupancy and are subject to availability. Rates are subject to change. Tax and gratuities not included. Package contents may vary.
# **Room category upgrade on stays of 7 nights or longer (excluding Deluxe Ocean, Napua Club rooms, and suites).
# 50-minute treatments available with this package are: Reflexology Massage, Hawaiian Lomi Lomi Massage, Jin Shin Acupressure Massage, Massage Sampler, Reiki Massage, Shiatsu Massage, Sports Massage, Swedish Massage, Detoxifying Seaweed Body Masque, European Deep Cleansing Facial, Men's Facial, Teen's Facial.
#
#
# Michelle Lokay
# Account Director
# Transwestern Commercial Group
# 713-345-7932
# **********************
# **********************
# 15124 / Enron's New Voice Mail System / michelle.lokay@enron.com / jimboman@bigfoot.com, 'hitschel@enron.com, bhitschel@tesoropetroleum.com / Thu, 14 Feb 2002 07:03:13 -0800 (PST)
# ======================
# - WitCity The Enron Voice Mail System 2002.htm
# **********************
# **********************
# 15125 / RE: Transwestern Capacity Release - ENA/Burlington / michelle.lokay@enron.com / richard.hanagriff@enron.com, elizabeth.brown@enron.com,
#  amy.mulligan@enron.com / Thu, 17 Jan 2002 06:29:14 -0800 (PST)
# ======================
# Let's discuss this prior to billing.  I agree that ENA owes us money, but there were certain conditions agreed to before we could get this capacity back!...
# **********************
# **********************
# 15126 / RE: books / michelle.lokay@enron.com / jlokay@yahoo.com / Wed, 30 Jan 2002 09:33:17 -0800 (PST)
# ======================
# Thanks...let's pick up "one" tonight!
# **********************
# **********************
# 15129 / Accomplishments 2001.xls / michelle.lokay@enron.com / kimberly.watson@enron.com / Fri, 14 Dec 2001 13:09:08 -0800 (PST)
# ======================
# Kim, I updated additional accomplishments...hope it's not too late!  Thanks.
# **********************
# **********************
# 15130 / mojaveimb2001.xls / michelle.lokay@enron.com / michael.clark@elpaso.com / Thu, 31 Jan 2002 08:27:28 -0800 (PST)
# ======================
# Mike,
# Here are the historical measured versus scheduled volumes for the Mojave OBA imbalances.  Hope this helps!
# **********************
# **********************
# 15131 / eBay item 1079301268 (Ends Mar-08-02 110435 PST ) - ENRON DENIM
#  SHIRT BRAND NEW / michelle.lokay@enron.com / lokay@bigfoot.com / Fri, 8 Mar 2002 05:59:14 -0800 (PST)
# ======================
# 79301268
# **********************
# **********************
# 15132 / RE: NWP System Notice - System Operations / michelle.lokay@enron.com / tdickers@westerngas.com / Fri, 15 Mar 2002 11:37:22 -0800 (PST)
# ======================
# More information.  The Questar (Southern Trails) tie-in is for one day only, 04/02.  The Ignacio to Blanco line, from La Plata, will be down over 700 million (which is pretty much the whole lateral) from 04/02-04/05.  Talk soon, Michelle.
# **********************
# **********************
# 15133 / Car jokes / michelle.lokay@enron.com / bhitschel@tesoropetroleum.com / Fri, 15 Mar 2002 06:23:44 -0800 (PST)
# ======================
# What's Worse Than A Pyromaniac In A Blazer?
#
# A barber in a Seville
#
# A seamstress in a Dart
#
# An insurance adjuster in an Acclaim
#
# A construction worker in a Bobcat
#
# A creature in a black Laguna
#
# A theater manager in a Marquis
#
# An astronomer in an Eclipse
#
# An exterminator in a Beetle
#
# A call-girl in an Escort
#
# A spiritualist in an Aurora
#
# A proctologist in a Probe
#
# A proctologist in a Ram
#
# An orator in a Civic
#
# A country singer in a Neon
#
# A reporter in a S'Coupe
#
# A Good Humor man in a S'Coupe
#
# An orchestra conductor in a Prelude
#
# A classical musician in a Sonata
#
# A customs inspector in a Passport
#
# A dog trainer in a Rover
#
# A jeweler in a Topaz
#
# A band leader in a Tempo
#
# A gentleman in a Gallant
#
# A Bullfighter in a Matador
#
# A mother-in-law in a Barracuda
#
# An electrician in a Charger
#
# A snake handler in a Viper
#
# A second-story man in a Prowler
#
# A car thief in a Jimmy
#
# A lepidopterist in a Monarch
#
# Barbie in a Malibu
#
# Sgt. Preston in a Yukon
#
# Queen Elizabeth in a Regal
#
# Prince Rainier in a Monaco
#
# Princess Stephanie in a Riviera
#
# Prince Charles in a Regency
#
# Joan Collins in a Dynasty
#
# (Hillary Clinton in a Park Avenue?)
#
# Jim Garner in a Maverick
#
# Kato in a green Hornet
#
# Nixon in a Checker
#
# Kissinger in a Diplomat
#
# Speedy Gonzales in a Fiesta
#
# Wile E. Coyote in a Road Runner
#
# Elmer Fudd in a Wabbit
#
# Miss Muffet in a Spyder
#
# Charles Lindberg in an Intrepid
#
# Christopher Columbus in a Voyager
#
# Blackbeard in a Corsair
#
# Russell Means in a Dakota
#
# Tonto in a Cherokee
#
# Dorothy in a Syclone
#
# Benjamin Franklin in a Lightning
#
# Carl Sagan in a Nova
#
# Bruce Lee in a Sidekick
#
# Oscar De la Hoya in a Challenger
#
# John Mellencamp in a Cougar
#
# Wonder Woman in a gold Lariat
#
# Edmund Halley in a Comet
#
# Public-TV yoga instructor Lillias in a Lotus
#
# Rosie O'Donnel and Charlton Heston in a Colt
#
# Yassir Arafat and Menahim Begin in an Accord
#
# Nostradamus and Jeanne Dixon in a Futura
# **********************
# **********************
# 15134 / FW: New TW Contract/Capacity Release System Demo / michelle.lokay@enron.com / alma.carrillo@enron.com / Mon, 4 Mar 2002 13:15:54 -0800 (PST)
# ======================
# Is there still room in the 03/21 class?  Thanks.
# **********************
# **********************
# 15135 / RE: February -1 Capacity Analysis System ( CAS) meeting / michelle.lokay@enron.com / mansoor.abdmoulaie@enron.com / Wed, 30 Jan 2002 12:56:43 -0800 (PST)
# ======================
# Sounds good, but TW has a weekly gas control meeting every Friday at 3:00.  Can your meeting be finished by 3:00, or should we start earlier?
# **********************
# **********************
# 15136 / Enron New Voice Mail System / michelle.lokay@enron.com / 'ott@enron.com, shana.ott@elpaso.com / Thu, 14 Feb 2002 07:01:13 -0800 (PST)
# ======================
# Try this...does it work on your computer system?
#
#
#  - WitCity The Enron Voice Mail System 2002.htm
# **********************
# **********************
# 15137 / TW - available capacity / michelle.lokay@enron.com / pabercrombie@txu.com / Tue, 22 Jan 2002 07:29:55 -0800 (PST)
# ======================
# Due today at 5:00...hope you guys bid!
# **********************
# **********************
# 15138 / eBay item 704532436 (Ends Mar-12-02 111446 PST ) - WOW~NEW 100%
#  AUTH LOUIS VUIT / michelle.lokay@enron.com / lokay@bigfoot.com / Tue, 12 Mar 2002 11:22:26 -0800 (PST)
# ======================
# 4532436
# **********************
# **********************
# 15139 / RE: PPL EnergyPlus Amendments / michelle.lokay@enron.com / dennis.lee@enron.com / Wed, 23 Jan 2002 12:32:16 -0800 (PST)
# ======================
# Thanks.
# **********************
# **********************
# 15141 / RE: cash in / michelle.lokay@enron.com / laura.giambrone@enron.com / Thu, 20 Dec 2001 11:13:04 -0800 (PST)
# ======================
# Yes.  Kim Richards with Williams confirmed this morning.
# **********************
# **********************
# 15142 / FW: I/B Link Space / michelle.lokay@enron.com / michael.bodnar@enron.com / Thu, 13 Dec 2001 13:00:36 -0800 (PST)
# ======================
# FYI.
# **********************
# **********************
# 15143 / FW: Williams Field Services OBA / michelle.lokay@enron.com / steven.harris@enron.com, shelley.corman@enron.com / Wed, 12 Dec 2001 07:16:12 -0800 (PST)
# ======================
# Williams will probably cash out the old OBA imbalance...$269,000!
# **********************
# **********************
# 15146 / RE: Club Memberships / michelle.lokay@enron.com / jan.moore@enron.com / Thu, 21 Feb 2002 07:11:15 -0800 (PST)
# ======================
# None for me.
# **********************
# **********************
# 15147 / FW: cash in / michelle.lokay@enron.com / tracy.geaccone@enron.com, paul.cherry@enron.com / Fri, 21 Dec 2001 08:47:50 -0800 (PST)
# ======================
# This is the wire transfer that I have been looking for since last week.
# **********************
# **********************
# 15149 / Western Gas Sales Confirmation / michelle.lokay@enron.com / bert.hernandez@enron.com / Thu, 7 Feb 2002 08:40:25 -0800 (PST)
# ======================
# Copy of confirmation of gas sales.
# **********************
# **********************
# 15150 / Lousi Vuitton bag / michelle.lokay@enron.com / lokay@bigfoot.com / Wed, 13 Mar 2002 12:54:49 -0800 (PST)
# ======================
# 6170040
# **********************
# **********************
# 15151 / RE: Scope: PG&E lateral to Bakersfield, California / michelle.lokay@enron.com / a..howard@enron.com / Thu, 14 Feb 2002 05:41:08 -0800 (PST)
# ======================
# Attached is the spreadsheet from Facility Planning showing our costs.  James Centilli is running additional economics.  Will forward those as soon as I receive them.  I can also meet with you to discuss all.  Thanks.
# **********************
# **********************
# 15152 / RE: Please forward time reports!! / michelle.lokay@enron.com / arobertson@houston.rr.com / Thu, 3 Jan 2002 08:57:51 -0800 (PST)
# ======================
# Hope you are feeling better!  I took my last day of vacation on Wednesday, Dec 26.  I was even here and on call for New Year's!
# **********************
# **********************
# 15153 / FW: ROFR Capacity / michelle.lokay@enron.com / kimberly.watson@enron.com / Fri, 28 Dec 2001 07:21:03 -0800 (PST)
# ======================
# FYI.  Section 13(h) does state 3 months prior to expiration and 07/31/02 is 3 months before 10/31/02.
# **********************
# **********************
# 15154 / FW: TW transport / michelle.lokay@enron.com / dennis.lee@enron.com / Mon, 31 Dec 2001 06:40:50 -0800 (PST)
# ======================
# Approved.  Amendment to increase TQ by 10,000 for 2 days.
# **********************
# **********************
# 15156 / FW: I/B Link Space / michelle.lokay@enron.com / dennis.lee@enron.com / Tue, 11 Dec 2001 14:12:38 -0800 (PST)
# ======================
# Approved. Additional 15,000 on top of the 10,000 that is there all month.
# **********************
# **********************
# 15157 / Brief of Amsterdam Weather Conference / michelle.lokay@enron.com / mark.mcconnell@enron.com / Thu, 7 Mar 2002 06:43:47 -0800 (PST)
# ======================
# Weather Trading
# Energy and weather are so inextricably tied to one another that it is sometimes hard to separate the two. The demand for power is directly related to temperature going up in summer and going down in winter. If, therefore, you have an unusually cool summer, the demand for power will be much lesser than anticipated, and the same in case of an unusually warm winter. Several electricity utilities enter into power purchase agreements based on anticipated demand, and would face serious financial losses in such cases.
# Weather derivatives provide such companies an option to hedge against risk of weather fluctuations. It is no surprise, then, that one of the conferences more lively discussions centered on the presentation by Tom Fletcher, head of weather trading for Mirant <In describing weather trading, Fletcher reported the market has grown exponentially since it was first formed in 1997. Fletcher highlighted how successful trading requires purchasing the right product. He went on to describe some of the sophisticated products being launched and how Mirant is integrating weather risk into their overall profile and what that means for the traders on the floor.
# With presentations from other market leaders such as Centrica, I-Wex, Spectron, Aquila, LIFFE, Mirant, Bewag, Aon and Entergy-Koch, Weather Trading Europe <The conference touched on key issues surrounding the sector including liquidity in the weather market-where is it and how to access it; data issues-the state of play in European weather data and how you can best utilize the information you've got and a host of other topics designed to help attendees leverage their skills.
# As weather trading takes its place in the online world, there is a pressing need to develop greater use of weather derivatives from corporations to avoid the market becoming a predominantly speculative industry.
#
#
# Michelle Lokay
# Account Director
# Transwestern Commercial Group
# 713-345-7932
# **********************
# **********************
# 15158 / RE: Conference Call with PG&E to Discuss the Gas Portion of Its
#  Proposed Plan of Reorganization that It Will File w/FERC Toward End of
#  November / michelle.lokay@enron.com / jeff.dasovich@enron.com / Mon, 7 Jan 2002 08:05:24 -0800 (PST)
# ======================
# Good morning!
#
# Are we still on tomorrow?  What are the calling instructions?  Thanks.
# **********************
# **********************
# 15159 / Mojave Imbalances / michelle.lokay@enron.com / michael.clark@elpaso.com / Thu, 24 Jan 2002 13:11:51 -0800 (PST)
# ======================
# Mike,
# Here is a spreadsheet that will hopefully help with reconciling the Mojave interconnect.  Let's talk soon.
# **********************
# **********************
# 15160 / Shopping Bag / michelle.lokay@enron.com / jimboman@bigfoot.com / Mon, 31 Dec 2001 09:11:58 -0800 (PST)
# ======================
# 06030&wpid 3028
# **********************
# **********************
# 15161 / FW: Enron Benefit Phone Numbers / michelle.lokay@enron.com / jimboman@bigfoot.com / Wed, 12 Dec 2001 09:08:09 -0800 (PST)
# ======================
# 1-800-332-7979 Benefit Service Center
# Health and Group Plans, Option 1
# Cash Balance Plan, Option 2
# Saving and Employee Stock Ownership Plan, Option 3
# Employee Stock Options, Option 4
# 1-800-251-0669 Cigna Healthcare (Group #0024647)
# 1-800-433-0153 United Healthcare (Group #175910)
# 1-800-457-1020 MerckMedco RX (Group #EnronRx)
# 1-800-492-8588 MetLife Dental (Group #39742 or 38866)
# 1-800-345-1391 Innovative Resource Group (Enron EAP and Mental Health Claims)
# 1-800-877-7195 Vision Service (Group 46303)
#
#
# Michelle Lokay
# Account Director
# Transwestern Commercial Group
# 713-345-7932
# **********************
# **********************
# 15162 / Burlington OBA paragraph change / michelle.lokay@enron.com / bill.rapp@enron.com / Wed, 6 Mar 2002 14:17:19 -0800 (PST)
# ======================
# Notwithstanding anything herein that may be interpreted to the contrary, the aggregate Operational Imbalance for all Interconnect Points in any month will be within a 10% tolerance level (i.e., neither exceeds 110% of the quantities scheduled, or is less than 90% of the quantities scheduled).
#
#
# Bill,
# Here is how I currently have paragraph 6 (tolerance level) in the OBA.  Should we insert another sentence reemphasizing that "all imbalances" will be "cashed out"?
#
#
# Michelle Lokay
# Account Director
# Transwestern Commercial Group
# 713-345-7932
# **********************
# **********************
# 15163 / RE: United Way / michelle.lokay@enron.com / fran.fagan@enron.com / Fri, 14 Dec 2001 11:30:23 -0800 (PST)
# ======================
# Thank you.
# **********************
# **********************
# 15168 / RE: Baker Fied Project / michelle.lokay@enron.com / mansoor.abdmoulaie@enron.com, ron.matthews@enron.com / Fri, 1 Mar 2002 11:54:24 -0800 (PST)
# ======================
# Either...you pick the day!
# **********************
# **********************
# 15169 / The San Antonio discount and luxury hotel reservations & visitors
#  guide. / michelle.lokay@enron.com / jlokay@4quest.com / Fri, 22 Feb 2002 12:43:47 -0800 (PST)
# ======================
# 67&histoindex_left=neighborhoods&sorted=rank-desc&context=hotels_visitors&histo_name=Riverwalk/Downtown&cslink=cs_filter1
# **********************
# **********************
# 15170 / FW: Mojave index / michelle.lokay@enron.com / richard.hanagriff@enron.com / Mon, 4 Mar 2002 13:18:22 -0800 (PST)
# ======================
# The February 2002 El Paso Topock point price was $1.8600.
# **********************
# **********************
# 15173 / United Way / michelle.lokay@enron.com / fran.fagan@enron.com / Fri, 14 Dec 2001 08:06:52 -0800 (PST)
# ======================
# How can I discontinue my United Way contributions effective Jan 1?  These are being deducted through payroll deductions.  Thanks.
#
# Michelle Lokay
# Account Director
# Transwestern Commercial Group
# 713-345-7932
# **********************
# **********************
# 15175 / RE: Time Reports Are Due!!! / michelle.lokay@enron.com / audrey.robertson@enron.com / Thu, 13 Dec 2001 09:23:47 -0800 (PST)
# ======================
# I took 1/2 day vacation Friday, December 7.  Thanks.
# **********************
# **********************
# 15177 / RE: Time Reports Due Thursday / michelle.lokay@enron.com / audrey.robertson@enron.com / Thu, 14 Feb 2002 05:36:18 -0800 (PST)
# ======================
# I was out sick yesterday afternoon, 02/13, and will be taking vacation tomorrow, 02/15.  Thanks.
# **********************
# **********************
# 15178 / RE: Bullets / michelle.lokay@enron.com / kimberly.watson@enron.com / Fri, 8 Mar 2002 08:20:48 -0800 (PST)
# ======================
# No bullets....ongoing with TXU, Burlington, Mojave.
# **********************
# **********************
# 15179 / FW: Burlington OBA name change / michelle.lokay@enron.com / jreames@br-inc.com / Tue, 19 Mar 2002 06:56:54 -0800 (PST)
# ======================
# Julie,
# Contract Administration needs you to email them officially requesting a name change.  Thanks.
# **********************
# **********************
# 15182 / FW: I/B Link Capacity / michelle.lokay@enron.com / michael.bodnar@enron.com / Thu, 13 Dec 2001 12:57:49 -0800 (PST)
# ======================
# Approved.
# **********************
# **********************
# 15183 / FW: I/B LINK CAPACITY / michelle.lokay@enron.com / dennis.lee@enron.com / Mon, 10 Dec 2001 07:13:04 -0800 (PST)
# ======================
# Approved.
#
# Please increase the Total Quantity from 10000 to 23115 for TODAY.  Points remain the same.  Thanks.
# **********************
# **********************
# 15184 / RE: Marketing / michelle.lokay@enron.com / tdickers@westerngas.com / Mon, 25 Mar 2002 12:20:45 -0800 (PST)
# ======================
# Got it!  Will send you documentation this evening.  Thanks for speaking with Johnny.
# **********************
# **********************
# 15185 / RE: THANKS / michelle.lokay@enron.com / rjuenke@br-inc.com / Fri, 8 Mar 2002 08:23:04 -0800 (PST)
# ======================
# You are definitely welcome.  Are you coming in for systems training next week (or it that Spring Break)?
# **********************
# **********************
# 15186 / RE: FW: Williams Field Services OBA / michelle.lokay@enron.com / shelley.corman@enron.com / Wed, 12 Dec 2001 08:16:10 -0800 (PST)
# ======================
# Yes, I will keep you posted.  They have another level of approval left.  If that happens, we will receive either check or wire.
# **********************
# **********************
# 15187 / Error message TW Unsubscribed Capacity / michelle.lokay@enron.com / perry.frazier@enron.com / Thu, 7 Feb 2002 08:28:54 -0800 (PST)
# ======================
# error '80004005'
# Unspecified error
# /infopostings/tw/asp/et_unsub_capacity_form.asp, line 2
# **********************
# **********************
# 15188 / Bid on this one? / michelle.lokay@enron.com / lokay@bigfoot.com / Tue, 12 Mar 2002 11:32:59 -0800 (PST)
# ======================
# I think I want to bid on this...how about up to $150?!?
#
#  5566445
# **********************
# **********************
# 15189 / AVAILABLE FIRM CAPACITY ON TRANSWESTERN / michelle.lokay@enron.com / bill.rapp@enron.com, teb.lokey@enron.com, robert.kilmer@enron.com / Fri, 18 Jan 2002 14:12:36 -0800 (PST)
# ======================
# Can you guys review this posting prior to Tuesday morning?  Thanks.
# **********************
# **********************
# 15190 / RE: SPRINT Ad   ;-) / michelle.lokay@enron.com / 'ott@enron.com, shana.ott@elpaso.com / Thu, 14 Feb 2002 06:39:35 -0800 (PST)
# ======================
# Wow...is that what really happened?!?!  I am so glad it's all clarified.  Since we're suing everyone (the accountants, the lawyers, etc.), we might as well sue our long distance carrier.  Talk soon!
# **********************
# **********************
# 15191 / Enron Auction Details / michelle.lokay@enron.com / danny.mccarty@enron.com / Wed, 27 Feb 2002 07:36:50 -0800 (PST)
# ======================
# 82
# **********************
# **********************
# 15192 / RE: set up / michelle.lokay@enron.com / tdickers@westerngas.com / Mon, 7 Jan 2002 14:46:15 -0800 (PST)
# ======================
# Sounds like too much fun....you're the best!
# **********************
# **********************
# 15193 / RE: Time Reports are Due!! / michelle.lokay@enron.com / audrey.robertson@enron.com / Thu, 28 Feb 2002 06:35:44 -0800 (PST)
# ======================
# I have been here except last Tuesday..traveling for work!
# **********************
# **********************
# 15195 / RE: TW Deal Profitability / michelle.lokay@enron.com / kimberly.carter@enron.com / Thu, 14 Feb 2002 06:27:16 -0800 (PST)
# ======================
# Sorry, I was out of the office yesterday.  We are currently not utilizing these systems.  Are you actually deleting them and can we resurrect if needed?
# **********************
# **********************
# 15196 / FW: Mojave Imbalance with Transwestern / michelle.lokay@enron.com / susan.mayher@elpaso.com / Mon, 11 Feb 2002 12:23:18 -0800 (PST)
# ======================
# I would also like to receive your daily volume statements for 09/00 and 11/00...my fax is 713-646-4095.  Thanks again.
# **********************
# **********************
# 15198 / Enron government / michelle.lokay@enron.com / jimboman@bigfoot.com / Thu, 21 Feb 2002 07:59:13 -0800 (PST)
# ======================
# Feudalism
# You have two cows.
# Your lord takes some of the milk.
# Fascism
# You have two cows.
# The government takes both, hires you to take care of them and sells you the  milk.
# Communism
# You have two cows.
# You must take care of them, but the government takes all the milk.
# Capitalism
# You have two cows.
# You sell one and buy a bull.
# Your herd multiplies, and the economy grows.
# You sell them and retire on the income.
# Enron
# You have two cows.  You borrow 80% of the forward value of the two cows fro m your bank, then buy another cow with 5% down and the rest financed by the  seller on a note callable if your market cap goes below $20B at a rate 2 t imes prime. You now sell three cows to your publicly listed company, using  letters of credit opened by your brother-in-law at a 2nd bank, then execute  a debt/equity swap with an associated general offer so that you get four c ows back, with a tax exemption for five cows. The milk rights of six cows a re transferred via an intermediary to a Cayman Island company secretly owne d by the majority shareholder who sells the rights to seven cows back to yo ur listed company. The annual report says the company owns eight cows, with  an option on one more and this transaction process is upheld by your indep endent auditor and no Balance Sheet provided with the press release that an nounces that Enron as a major owner of cows will begin trading cows via the  Internet site COW (cows on web). I am sure you now fully understand what h appened.
# **********************
# **********************
# 15200 / RE: TW Unsubscribed Capacity / michelle.lokay@enron.com / jeff.huo@enron.com, perry.frazier@enron.com / Fri, 8 Feb 2002 11:41:09 -0800 (PST)
# ======================
# This looks good from the Commercial side.  I am assuming that when a customer uses the "View Printable Page," that printout header cannot be frozen.  Otherwise, this is what we are looking for as far as viewing this spreadsheet on line.  When the formatting issues are resolved, I recommend we move this to production.  Thanks.
# **********************
# **********************
# 15202 / RE: PPL EnergyPlus, LLC / michelle.lokay@enron.com / dennis.lee@enron.com / Wed, 20 Feb 2002 08:14:24 -0800 (PST)
# ======================
# Thanks.
# **********************
# **********************
# 15203 / AVAILABLE FIRM CAPACITY ON TRANSWESTERN / michelle.lokay@enron.com / dlsmith@pplweb.com / Tue, 22 Jan 2002 07:07:25 -0800 (PST)
# ======================
# Due today at 5:00 CST...hope you guys bid!
# **********************
# **********************
# 15204 / RE: Weather Trading Prize Draw / michelle.lokay@enron.com / arobertshaw@eyeforenergy.com / Wed, 30 Jan 2002 06:26:11 -0800 (PST)
# ======================
# I am sorry. but will not be able to attend.  Thanks.
# **********************
# **********************
# 15205 / Disney trip / michelle.lokay@enron.com / 'hitschel@enron.com, bhitschel@tesoropetroleum.com / Mon, 17 Dec 2001 08:52:04 -0800 (PST)
# ======================
# What do you think of this itinerary?  You guys would leave San Antonio and pick us up at Hobby for the same flight to Orlando.  On the return trip, we leave 1 1/2 hours before you, but you guys have a direct flight.  The trip is Friday through Saturday, for 8 nights.  The flights are getting more limited and have increased again!  Let's talk soon.
# **********************
# **********************
# 15207 / FW: Red Rock Receipts / michelle.lokay@enron.com / dennis.lee@enron.com / Wed, 28 Nov 2001 06:17:56 -0800 (PST)
# ======================
# Approved.
#
# This request had been preapproved by Facility Planning.  Please generate amendments for PPL's Red Rock expansion contract #27641.  The Administrative Contract will also need to be updated.  Thanks.
# **********************
# **********************
# 15208 / RE: Toner - Replaced / michelle.lokay@enron.com / audrey.robertson@enron.com / Tue, 5 Feb 2002 13:20:38 -0800 (PST)
# ======================
# Thanks!
# **********************
# **********************
# 15209 / TW On Call Schedule / michelle.lokay@enron.com / shelley.corman@enron.com / Mon, 25 Mar 2002 11:18:05 -0800 (PST)
# ======================
# Shelley, here is the current weekend on-call schedule for the TW marketers.
# **********************
# **********************
# 15210 / Burlington and Window Rock / michelle.lokay@enron.com / darrell.schoolcraft@enron.com, ron.matthews@enron.com / Thu, 7 Feb 2002 11:49:11 -0800 (PST)
# ======================
# Burlington is scheduling a conference call with TW and EL Paso for next Thursday, 02/14/02, at 3:00.  We will discuss pressure scenarios, pressure ranges, and potential facility modifications...
#
# Please put this on your calendars...I, of course, would like to get together prior to the call!
#
# Michelle Lokay
# Account Director
# Transwestern Commercial Group
# 713-345-7932
# **********************
# **********************
# 15211 / FW: Mojave index / michelle.lokay@enron.com / richard.hanagriff@enron.com / Tue, 5 Mar 2002 10:54:59 -0800 (PST)
# ======================
# February 2002 price $2.07
# March 2002 price $2.30
#
#
# February was revised and March is now posted.
# **********************
# **********************
# 15213 / PPL #27641 / michelle.lokay@enron.com / dennis.lee@enron.com / Thu, 3 Jan 2002 08:17:45 -0800 (PST)
# ======================
# ...
# ? Participation: This program will be available to active regular full-time and regular part-time employees of Enron and its wholly owned subsidiaries; however, employees of some Enron companies (Portland General Electric, EOTT ,
# Enron Facility Services) may not be able to participate due to legal,
# accounting, tax, labor or business reasons.  Eligibility includes being
# employed at the time of implementation.
# ? Timing: U.S. employee sign-up will begin in early 2001, with delivery of the equipment and Internet connection to follow shortly thereafter.  Delive ry
# of equipment to participating non-U.S. employees is targeted for late 2001.
#
# Details about this program are still being finalized.  To address some of your initial questions, we ,ve posted a question-and-answer document on  We will schedule an eSpeak session in the ne ar
# future where you will have an opportunity to ask questions. Or, you can
# submit your questions and comments to ClickAtHome@enron.com.
#
# We are excited to extend our investment in technology to you and your
# family.  We believe this program takes communication at Enron to a new leve l
# by creating endless possibilities for you to experience and participate in the broadband Internet revolution. It is just another reason why we believe Enron is a great place to work.
# **********************
# **********************
# 15414 / Meeting with Dan McCarty / michelle.lokay@enron.com / lorraine.lindberg@enron.com, jeffery.fawcett@enron.com,
#  lindy.donoho@enron.com / Wed, 15 Nov 2000 07:02:00 -0800 (PST)
# ======================
# FYI...since you guys weren't on the distribution list.
# **********************
# **********************
# 15418 / Transwestern IOS Posting / christine.stokes@enron.com / richard.abramowicz@enron.com / Fri, 4 Aug 2000 01:03:00 -0700 (PDT)
# ======================
# Rich - Please immediately post the attached information announcing
# Transwestern's IOS to be held on August 10th.  The posting can come down on
# the 10th.  Thanks.
# **********************
# **********************
# 15425 / Re: TW's Christmas Luncheon / michelle.lokay@enron.com / audrey.robertson@enron.com / Wed, 29 Nov 2000 05:47:00 -0800 (PST)
# ======================
# Count me in...
# **********************
# **********************
# 15426 / Trip Report / christine.stokes@enron.com / kevin.hyatt@enron.com / Thu, 17 Aug 2000 04:39:00 -0700 (PDT)
# ======================
# Summary of COGA conference follows.  FYI - at the time of the conference, the
# conference organizers indicated that all speakers presentations would be made
# available at the COGA.org websit after the conference.  However, COGA is
# currently experiencing difficulties in actually getting each speaker to
# provide this information.  I have requested a copy of the Interstate Pipeline
# (CIG/Questar/El Paso/Transcolorado/Western/NWPL) presentations to be mailed
# to me and will circulate them when I receive them.  They provide interesting
# summaries of pipeline expansion programs.
#
# Main conference themes which seem to be repeated among various speackers
# include the following points:
#
#   -  Annual U.S. domestic requirements are headed towards the 30 TCF point
# sooner than expected.  One attributable reason for the higher than expected
# growth rate was the impact of growing internet & cellular activity of the
# nation.  It was estimated that these combined markets have grown from
# representing 2% of total electrical requirements of the nation to
# approximately an 8-10% range which will be sustainable from this point
# forward.  In addition, overall healthy economic growth of the nation also
# contributes to the increase in domestic gas demand.
#   -   Power River Basin coalbed methane production has the highest potential
# growth opportunity for Rocky production.
#  -   Currently the companies most active in Rocky Mountain exploration &
# production are experiencing a shortage of geologists, engineers, and field
# personnel which they fear may impact the desired rate of field  developement
# - Rig counts in the Rockies are on the rise, but additional rig availability
# is also an issue which may impact rate of production.
# - The only pipelines which actively promoted access to Waha markets for Rocky
# production were El Paso and Transcolorado.
# - El Paso was already encouraging interest in the 1.2 BCF of capacity which
# El Paso Merchant Services currently has on their system which will expire
# October 01.
# - General conference discussion opinion is that the  Alliance in-service
# impact will be fairly neutral to market demand and gas prices for Rocky
# production.  They continue to be optimistic with their growth opportunities
# and price expectations.
#
#
# Customer Meetings:
#
# Western Gas Resources - met with Bill Koch (project developer), Chris O'Dell
# (Texas gas marketer), Andrew Carter and Andrew Richmond (western region gas
# marketers).  Western is in the process of purchasing some NNG lines which are
# in close proximity to the most southern part of Transwestern's West Texas
# lateral.   Western would eventually like to deliver treated gas into this
# line,  once Traswestern cleans the line and finalizes the Gomez to Puckett
# Tie-Over, in order to access our Waha markets.
# **********************
# **********************
# 15427 / Nymex info on desktop PC's / kevin.hyatt@enron.com / sharris1@enron.com / Mon, 19 Jun 2000 09:17:00 -0700 (PDT)
# ======================
# One of the deliverables of Revenue Management is the Marketing Dashboard
# which, among a veritable cornucopia of features, will include live Nymex and
# Enron OnLine data pricing feeds.  The rollout of the Dashboard for NNG and TW
# is in the next 2 weeks.  However, the Nymex data feed won't happen till
# August due to technology limitations.
#
# In the meantime, via our desktops, we all have access to Enron OnLine which
# provides live market data that is as good or better than Nymex.  This should
# suffice in the interim till the Dashboard is fully functional.  Let me know
# if you have questions.
#
# thanks
# KH
# **********************
# **********************
# 15434 / TW Bullets 9/29 / kevin.hyatt@enron.com / bullets@enron.com / Fri, 29 Sep 2000 02:37:00 -0700 (PDT)
# ======================
# Amoco - Amoco has changed its name to BP Energy.  Two deals with BP Energy
# were closed late last Friday:
#
# Ignacio to Blanco
# 18,000 MMBtu/d January, 2001
# 22,000 MMBtu/d Feb - Dec, 2001
# retains ROFR
# rate:  $0.07
#
# Red Cedar to Blanco
# 21,200 MMBtu/d
# Feb 1, 2001 - Dec 31, 2001
# $0.045
#
# Southwest Gas - Marketing and Market Services met with reps from SWG to
# discuss finalizing an OBA (we will use the currently effective OBA rather
# than the 637 filed OBA), nominations, scheduling and capacity release.  This
# is in preparation for their new firm transport agreement beginning November 1.
#
# El Paso Field Services -  We have finalized the terms with EPFS for a new
# receipt point in Eddy County, NM.  EPFS will pay $190,000 towards the total
# cost of the interconnect of $330,000 (these figures include tax gross-up).
# TW will construct, own, operate and maintain the new interconnect which will
# tie into the high pressure line of the West Texas lateral.  The estimated
# in-service date is Jan. 1, 2001.  EPFS has committed to flow incremental
# supplies of 12,500 MMBtu/d for a 2 year commitment through the new point.
#
# El Paso Blanco Mis-Measurement - EP made some minor adjustments to the
# language in our settlement letter; final versions were sent out for
# execution.  They have already begun delivering the gas back to TW at Window
# Rock.  If the flow remains high, the payback may be complete before EP goes
# down for maintenance at the end of October otherwise we will complete the
# transaction in early November.   We sold 15,000 MMBtu/d of the volume for
# October to USGT/Aquila at $5.20/MMBtu.
#
# Park 'n Ride - The new automated allocation procedures were implemented this
# week so customers can automatically nominate volume and the system will
# handle any necessary allocations.
# **********************
# **********************
# 15439 / Re: Throughput Forecast / michelle.lokay@enron.com / jim.wiltfong@enron.com / Mon, 7 Aug 2000 09:14:00 -0700 (PDT)
# ======================
# Good.
# **********************
# **********************
# 15447 / Re: TW FT Assignments / dennis.lee@enron.com / michelle.lokay@enron.com / Fri, 27 Oct 2000 00:43:00 -0700 (PDT)
# ======================
# The below mentioned contracts have been assigned to Amoco Energy Trading
# effective 11/01/00.   We are still working on the name change from Amoco to
# BP.
# **********************
# **********************
# 15451 / Re: Dashboard and Internet Explorer 5.01 upgrade. Houston / michelle.lokay@enron.com / dan.bunch@enron.com / Tue, 28 Nov 2000 02:00:00 -0800 (PST)
# ======================
# OK.  Mine is updated...FYI, I had to still use the U versus N drive!
# **********************
# **********************
# 15454 / Re: Park-n-ride and Deal Profitability / michelle.lokay@enron.com / kim.kouri@enron.com / Thu, 30 Nov 2000 04:40:00 -0800 (PST)
# ======================
# Sure, let's talk.
# **********************
# **********************
# 15456 / TW Bullets 12/1 / kevin.hyatt@enron.com / bullets@enron.com / Fri, 1 Dec 2000 03:19:00 -0800 (PST)
# ======================
# Pipeline Operations - As of December, 1 TW is back to scheduling over
# 1,054,000 MMBtu/d to the California border.  The preliminary indication on
# the corrosion dig-outs that occurred this week is the pipe appears to be OK
# but the final call will come from Max Brown's office shortly.
#
# Gas Inventory Sale - In preparation for the corrosion dig-outs this week, we
# assisted operations in relieving some line pressure by selling gas inventory
# at the Cal Border pool.  We sold 10,000 MMBtu for gas day 11/30 at
# $14.00/MMBtu.
#
# Expired ROFR's - Two contract ROFR notifications expired this week
# (11/30/2000).  Both of these contracts will terminate next year 11/30/2001.
# Burlington has  15,000 MMBtu/d from  Ignacio to Blanco and PG&E has 20,000
# MMBtu/d from Blanco to EOT.
#
# Park N Ride - Eprime signed a 50,000 MMBtu/d park and ride agreement
# effective 12/01/2000.  Current posted rates are at max of .3883.
# Invoices are going out next week.
# **********************
# **********************
# 15474 / Re: Info for Steve / michelle.lokay@enron.com / lindy.donoho@enron.com / Tue, 7 Nov 2000 06:28:00 -0800 (PST)
# ======================
# EOG interconnect is finishing this week and will be in service by this
# weekend.  It will initially flow 8-10000/day and will increase to over 15000.
# **********************
# **********************
# 15475 / California Gas Prices - Market Intelligence / kevin.hyatt@enron.com / sharris1@enron.com / Thu, 30 Nov 2000 05:54:00 -0800 (PST)
# ======================
# Below are some notes taken while conversing with several TW customers on the
# various reasons prices have risen so dramatically out West.
#
# El Paso line 1103 is still out of service from the August 2000 explosion.
# The remaining 2 lines are still operating at reduced flow levels taking
# 200-300,000/d capacity off the market.
#
# Storage levels in California were low to begin with.  With several coal and
# nuclear generation plants off-line (unplanned outages), the gas-burning
# generators have been running all out.
#
# Northwest Pipeline has instituted several OFO's this month requiring shippers
# not to overpull the pipeline.  Penalty gas was selling for $22.00/MMBtu.
#
# Beginning in November, SoCal Gas instituted its 5-day balancing requirement.
# This was not an unplanned event in the marketplace, however, it seems several
# entities were caught short early in the month and still haven't caught up.
#
# LDC's east of California have experienced some dramatic weather but not
# severe.  They have been impacted more by firm demand to California knocking
# off IT and Alternate Firm supply destined for points east of California.
# SouthWest Gas has several alternate supply contracts with these LDC's and is
# collecting 150% of the market price from these LDC's by using SWG's full
# requirements contract on El Paso.
#
# In addition, we now believe SoCal Gas is playing some storage games with the
# interstate pipes.  SoCal lowered their window on us for tomorrow to 580,000
# down from 750,000 due to "lower projected gas demand".  Sempra, Reliant,
# Dynegy, and Texaco are calling foul.  The thought is SoCal demand may be
# falling but instead of taking excess gas to replenish storage, SoCal is
# preventing higher-priced gas from reaching storage.
# **********************
# **********************
# 15477 / DP Question / david.foti@enron.com / jeffery.fawcett@enron.com / Wed, 28 Jun 2000 10:57:00 -0700 (PDT)
# ======================
# Jeff:
#
# You asked how your Gross Margin % could be higher in 2000 but your overall
# Gross Margin be lower.
#
# You appear to have lower invoiced volumes in Jan-April 2000.
#
# January and Feb. -for example:
# **********************
# **********************
# 15484 / Re: IOS Capacity Posting / toby.kuehl@enron.com / christine.stokes@enron.com / Tue, 1 Aug 2000 08:52:00 -0700 (PDT)
# ======================
# Posted 8/1/00
#
# Toby
# **********************
# **********************
# 15494 / Year End 2000 Performance Feedback / perfmgmt@enron.com / michelle.lokay@enron.com / Mon, 6 Nov 2000 14:47:00 -0800 (PST)
# ======================
# NOTE:  YOU WILL RECEIVE THIS MESSAGE EACH TIME YOU ARE SELECTED AS A REVIEWER.
#
# You have been selected to participate in the Year End 2000 Performance
# Management process by providing meaningful feedback on specific employee(s).
# Your feedback plays an important role in the process, and your participation
# is critical to the success of Enron's Performance Management goals.
#
# To complete requests for feedback, access PEP at
# and select Perform Review under Performance Review Services.  You may begin
# providing feedback immediately and are requested to have all feedback forms
# completed by Friday, November 17, 2000.
#
# If you have any questions regarding PEP or your responsibility in the
# process, please contact the PEP Help Desk at:
#
# Houston: 1.713.853.4777, Option 4
# London:  44.207.783.4040, Option 4
# Email: perfmgmt@enron.com
#
# Thank you for your participation in this important process.
#
# The following is a CUMULATIVE list of employee feedback requests with a
# status of "OPEN."   Once you have submitted or declined an employee's request
# for feedback, their name will no longer appear on this list.
# **********************
# **********************
# 15496 / base differential for TW deal analysis / meiling.chen@enron.com / michelle.lokay@enron.com / Wed, 29 Nov 2000 08:45:00 -0800 (PST)
# ======================
# Michelle,
#
# Our dba has loaded TW base differential to test database from revenue
# management data base
# after Vernon added TW to his regular update.
# The spreadsheet is the latest NYMEX and base differential for 4 areas of TW
# as of 11/28/00.
# Please take a look.  If no problem, I'll apply the same logic that I used to
# create this spreadsheet
# to TW deal analysis program.  I'll dynamically get the latest price from the
# table based on
# receipt point location.
# Please let me know.
# Thanks,
#
# Mei-Ling
# **********************
# **********************
# 15499 / Contract Options / lorraine.lindberg@enron.com / jeffery.fawcett@enron.com, michelle.lokay@enron.com,
#  christine.stokes@enron.com / Wed, 5 Jul 2000 08:38:00 -0700 (PDT)
# ======================
# As we discussed in staff meeting this morning, please provide me with a
# summary of any type of transport options imbedded in your assigned customer
# accounts' contracts (i.e., contract #, Shipper name, explanation of option,
# term of contract, term of option, how much advance notice to trigger the
# option, etc.).  I will incorporate these transport options into a capacity
# spreadsheet which will be forwarded to our group.
#
# Please try to forward this information to me at your earliest convenience.
# Thanks.
#
# Lorraine
# **********************
# **********************

# %%
import spacy
nlp = spacy.load('en')

# %%
for token in nlp(u'I want to buy stock.'):
    print(token.text, "/", token.lemma_, "/", token.pos_, "/", token.tag_, "/", token.is_alpha, "/", token.is_stop)
# Out:
# I / -PRON- / PRON / PRP / True / False
# want / want / VERB / VBP / True / False
# to / to / PART / TO / True / True
# buy / buy / VERB / VB / True / False
# stock / stock / NOUN / NN / True / False
# . / . / PUNCT / . / False / False

# %%
for token in nlp(u'Bob said he knows about the scam.'):
    print(token.text, "/", token.lemma_, "/", token.pos_, "/", token.tag_, "/", token.is_alpha, "/", token.is_stop)
# Out:
# Bob / bob / PROPN / NNP / True / False
# said / say / VERB / VBD / True / False
# he / -PRON- / PRON / PRP / True / True
# knows / know / VERB / VBZ / True / False
# about / about / ADP / IN / True / True
# the / the / DET / DT / True / True
# scam / scam / NOUN / NN / True / False
# . / . / PUNCT / . / False / False

# %%
from spacy import displacy

# %%
displacy.render(nlp(u'I want to buy stock.'), style='dep', jupyter=True)
# Out:
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="925" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">want</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">buy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">stock.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
# </svg>

# %%
displacy.render(nlp(u'Bob said he knows about the scam.'), style='dep', jupyter=True)
# Out:
# /usr/lib/python3.6/runpy.py:193: DeprecationWarning: Positional arguments to Doc.merge are deprecated. Instead, use the keyword arguments, for example tag=, lemma= or ent_type=.
#   "__main__", mod_spec)
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1275" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Bob</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">said</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">knows</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">scam.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M770,177.0 C770,2.0 1100.0,2.0 1100.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,179.0 L1108.0,167.0 1092.0,167.0" fill="currentColor"/>
# </g>
# </svg>

# %%
from spacy.symbols import nsubj, xcomp, dobj, pobj, prep, attr, VERB, PRON, NOUN, PROPN, PUNCT

def extract_relationships(doc):
    relationships = []
    for possible_subject in doc:
        if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
            subj = possible_subject
            verb = possible_subject.head
            print(subj, verb)
            for vr in verb.rights:
                if vr.dep == xcomp:
                    for vc in vr.children:
                        if vc.dep == dobj and vc.pos == NOUN:
                            relationships.append((subj, verb, vr, vc))
                if vr.dep == prep:
                    for vc in vr.children:
                        if vc.dep == pobj and vc.pos == NOUN:
                            relationships.append((subj, verb, vr, vc))
                if vr.dep == dobj and vr.pos == NOUN:
                    relationships.append((subj, verb, vr))
                print(vr, vr.dep_, vr.pos_)
    return relationships

# %%
extract_relationships(nlp('I want to buy stock.'))
# Out:
# I want
# buy xcomp VERB
# . punct PUNCT
# [(I, want, buy, stock)]

# %%
extract_relationships(nlp('Bob said he knows about the scam.'))
# Out:
# Bob said
# knows ccomp VERB
# . punct PUNCT
# he knows
# about prep ADP
# [(he, knows, about, scam)]

# %%
extract_relationships(nlp('I bought stock.'))
# Out:
# I bought
# stock dobj NOUN
# . punct PUNCT
# [(I, bought, stock)]

# %%
extract_relationships(nlp('Jane said Bob knows about the scam.'))
# Out:
# Jane said
# knows ccomp VERB
# . punct PUNCT
# Bob knows
# about prep ADP
# [(Bob, knows, about, scam)]

# %%
# simple method for anaphora resolution
def find_referent(doc, pronoun, msgfrom, msgto):
    # if pronoun is 'I' or 'myself' or 'me' or 'we', use msg from name
    if pronoun.text.lower() in ['i', 'myself', 'me', 'we']:
        return msgfrom
    # if pronoun is 'you' or 'your', use msg to name
    elif pronoun.text.lower() == 'you' or pronoun.text.lower() == 'your':
        return msgto
    # else, find root verb for pronoun, then find the subject
    else:
        w = pronoun
        while w.head != w: # walk up the tree to root
            w = w.head
        # now we have the root verb, find the nsubj if exists
        for c in w.children:
            if c.dep == nsubj:
                return c.text
        return None

# %%
doc = nlp('Bob said he knows about the scam.')
rels = extract_relationships(doc)
for rel in rels:
    for w in rel:
        if w.pos == PRON:
            print(find_referent(doc, w, 'me@example.com', 'you@example.com'))
# Out:
# Bob said
# knows ccomp VERB
# . punct PUNCT
# he knows
# about prep ADP
# Bob

# %%
def extract_relationships2(doc, msgfrom, msgto):
    #print(doc)
    relationships = []
    for possible_subject in doc:
        if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
            subj = possible_subject
            verb = possible_subject.head
            
            if subj.pos == PRON or subj.pos == PROPN:
                if subj.pos == PRON:
                    ref = find_referent(doc, subj, msgfrom, msgto)
                    if ref is not None:
                        subj = ref
                    else:
                        subj = subj.text
                else:
                    subj = subj.text
                
                # ignore worthless subjects
                if subj.lower() in ['they', 'it']:
                    continue
                    
                for vr in verb.rights:
                    if vr.dep == xcomp:
                        for vc in vr.children:
                            if vc.dep == dobj and vc.pos == NOUN:
                                if vr.idx < vc.idx:
                                    relationships.append((subj, verb.lemma_, vr.lemma_ + " " + vc.lemma_))
                                else:
                                    relationships.append((subj, verb.lemma_, vc.lemma_ + " " + vr.lemma_))
                    elif vr.dep == prep:
                        for vc in vr.children:
                            if vc.dep == pobj and vc.pos == NOUN:
                                relationships.append((subj, verb.lemma_, vc.lemma_))
                    elif vr.dep == dobj and (vr.pos == NOUN or vr.pos == PROPN):
                        has_compound = False
                        for vc in vr.children:
                            if vc.dep_ == 'compound' and vc.pos == NOUN:
                                has_compound = True
                                if vr.idx < vc.idx:
                                    relationships.append((subj, verb.lemma_, vr.lemma_ + " " + vc.lemma_))
                                else:
                                    relationships.append((subj, verb.lemma_, vc.lemma_ + " " + vr.lemma_))
                        if not has_compound:
                            relationships.append((subj, verb.lemma_, vr.lemma_))
                    elif vr.dep == attr:
                        relationships.append((subj, verb.lemma_, vr.lemma_))
    return relationships

# %%
[extract_relationships2(nlp('I want to buy stock.'), 'me@example.com', 'you@example.com'),
 extract_relationships2(nlp('Bob said he knows about the scam.'), 'me@example.com', 'you@example.com'),
 extract_relationships2(nlp('You bought stock.'), 'me@example.com', 'you@example.com'),
 extract_relationships2(nlp('Jane said Bob knows about the scam.'), 'me@example.com', 'you@example.com')]
# Out:
# [[('me@example.com', 'want', 'buy stock')],
#  [('Bob', 'know', 'scam')],
#  [('you@example.com', 'buy', 'stock')],
#  [('Bob', 'know', 'scam')]]

# %%
def extract_email_relationships(mbox, msg_key):
    message = mbox.get(msg_key)
    if message['From'] is not None and message['To'] is not None:
        try:
            msgnlp = nlp(cleanup_email(message.get_payload()))
            return extract_relationships2(msgnlp, message['From'], message['To'].split(', ')[0])
        except:
            return []
    else:
        return []

# %%
extract_email_relationships(mbox, 15426)
# Out:
# [('christine.stokes@enron.com', 'request', 'copy'),
#  ('Paso', 'encourage', 'interest'),
#  ('Services', 'have', 'system'),
#  ('Western', 'be', 'process'),
#  ('Western', 'like', 'deliver gas'),
#  ('Traswestern', 'clean', 'line')]

# %%
import rdflib
from rdflib import Graph, Literal, RDF
from rdflib.namespace import FOAF

# %%
g = Graph()

# %%
g.add((Literal('christine.stokes@enron.com'), RDF.type, FOAF.Person))
g.add((Literal('christine.stokes@enron.com'), Literal('requested'), Literal('copy')))

# %%
for s, p, o in g:
    print((s, p, o))
# Out:
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'), rdflib.term.URIRef('http://xmlns.com/foaf/0.1/Person'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('requested'), rdflib.term.Literal('copy'))

# %%
for person in g.subjects(RDF.type, FOAF.Person):
    print(person)
# Out:
# christine.stokes@enron.com

# %%
qres = g.query('SELECT ?s ?o WHERE { ?s ?p ?o . }', initBindings = {'p' : Literal('requested')})

for row in qres:
    print("%s -> %s" % row)
# Out:
# christine.stokes@enron.com -> copy

# %%
def create_graph_from_email_relationships(mbox):
    g = Graph()
    msg_key_idx = {}
    msg_key_idx_reverse = {}
    
    for msg_key in msgs[15000:15500]:
    
        # find relationships
        rels = extract_email_relationships(mbox, msg_key)
        
        # for each relationship
        for (s, p, o) in rels:
            
            r = (Literal(s), Literal(p), Literal(o))
            
            # add relationship to the graph
            g.add(r)
            
            # remember which message(s) had this relationship
            if r in msg_key_idx:
                msg_key_idx[r].append(msg_key)
            else:
                msg_key_idx[r] = [msg_key]
                
            # remember the relationships this message had
            if msg_key in msg_key_idx_reverse:
                msg_key_idx_reverse[msg_key].append(r)
            else:
                msg_key_idx_reverse[msg_key] = [r]
                
    return (g, msg_key_idx, msg_key_idx_reverse)

# %%
(g, msg_key_idx, msg_key_idx_reverse) = create_graph_from_email_relationships(mbox)

# %%
for s, p, o in g:
    print((s, p, o))
# Out:
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('bob.burleson@enron.com'), rdflib.term.Literal('spend'), rdflib.term.Literal('money'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('sell'), rdflib.term.Literal('mmbtu'))
# (rdflib.term.Literal('Services'), rdflib.term.Literal('chip'), rdflib.term.Literal('obstacle'))
# (rdflib.term.Literal('Walk'), rdflib.term.Literal('be'), rdflib.term.Literal('event'))
# (rdflib.term.Literal('enron.worldwide@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('approval'))
# (rdflib.term.Literal('River'), rdflib.term.Literal('cast'), rdflib.term.Literal('expansion'))
# (rdflib.term.Literal('Payables'), rdflib.term.Literal('input'), rdflib.term.Literal('invoice'))
# (rdflib.term.Literal('lindy.donoho@enron.com'), rdflib.term.Literal('mark'), rdflib.term.Literal('calendar'))
# (rdflib.term.Literal('GPG'), rdflib.term.Literal('begin'), rdflib.term.Literal('gather information'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('Volume'), rdflib.term.Literal('be'), rdflib.term.Literal('production'))
# (rdflib.term.Literal('andre.walters@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('store message'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('schedule'), rdflib.term.Literal('future'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('update'), rdflib.term.Literal('tw list'))
# (rdflib.term.Literal('Generators'), rdflib.term.Literal('post'), rdflib.term.Literal('am'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('turn'), rdflib.term.Literal('demand'))
# (rdflib.term.Literal('mlokay@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('Engbrock'), rdflib.term.Literal('have'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('Coral'), rdflib.term.Literal('participate'), rdflib.term.Literal('part'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('register'), rdflib.term.Literal('attendance'))
# (rdflib.term.Literal('michael.bodnar@enron.com'), rdflib.term.Literal('copy'), rdflib.term.Literal('h'))
# (rdflib.term.Literal('we'), rdflib.term.Literal('book'), rdflib.term.Literal('gain'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('welcome'), rdflib.term.Literal('effect'))
# (rdflib.term.Literal('Western'), rdflib.term.Literal('be'), rdflib.term.Literal('process'))
# (rdflib.term.Literal('Below'), rdflib.term.Literal('be'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('ID'), rdflib.term.Literal('be'), rdflib.term.Literal('id'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('opportunity'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('run'), rdflib.term.Literal('side'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('tomorrow'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('request form'))
# (rdflib.term.Literal('Paso'), rdflib.term.Literal('expect'), rdflib.term.Literal('manage risk'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('remove'), rdflib.term.Literal('category'))
# (rdflib.term.Literal('mark.mcconnell@enron.com'), rdflib.term.Literal('utilize'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('Price'), rdflib.term.Literal('join'), rdflib.term.Literal('markets'))
# (rdflib.term.Literal('ChevronTexaco'), rdflib.term.Literal('be'), rdflib.term.Literal('production'))
# (rdflib.term.Literal('Westcoast'), rdflib.term.Literal('have'), rdflib.term.Literal('% tolerance'))
# (rdflib.term.Literal('enron.operations@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('jot'), rdflib.term.Literal('note'))
# (rdflib.term.Literal('ken.skilling@enron.com'), rdflib.term.Literal('appreciate'), rdflib.term.Literal('effort'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('service'))
# (rdflib.term.Literal('he'), rdflib.term.Literal('be'), rdflib.term.Literal('force'))
# (rdflib.term.Literal('He'), rdflib.term.Literal('base'), rdflib.term.Literal('recommendation'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('see'), rdflib.term.Literal('drop off'))
# (rdflib.term.Literal('PG&E'), rdflib.term.Literal('purchase'), rdflib.term.Literal('property'))
# (rdflib.term.Literal('the.mailout@enron.com'), rdflib.term.Literal('remember'), rdflib.term.Literal('pulse'))
# (rdflib.term.Literal('Foundation'), rdflib.term.Literal('seek'), rdflib.term.Literal('walker'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('access'))
# (rdflib.term.Literal('Smith'), rdflib.term.Literal('accept'), rdflib.term.Literal('ed'))
# (rdflib.term.Literal('lindy.donoho@enron.com'), rdflib.term.Literal('save'), rdflib.term.Literal('reference'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('discount'))
# (rdflib.term.Literal('Mirant'), rdflib.term.Literal('integrate'), rdflib.term.Literal('profile'))
# (rdflib.term.Literal('Campaign'), rdflib.term.Literal('draw'), rdflib.term.Literal('close'))
# (rdflib.term.Literal('Measurement'), rdflib.term.Literal('analyze'), rdflib.term.Literal('model'))
# (rdflib.term.Literal('tk.lohman@enron.com'), rdflib.term.Literal('know'), rdflib.term.Literal('cost'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('test'), rdflib.term.Literal('curiosity'))
# (rdflib.term.Literal('ChevronTexaco'), rdflib.term.Literal('be'), rdflib.term.Literal('producer'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('sue'), rdflib.term.Literal('distance carrier'))
# (rdflib.term.Literal('Services'), rdflib.term.Literal('have'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('EP'), rdflib.term.Literal('make'), rdflib.term.Literal('language'))
# (rdflib.term.Literal('Coral'), rdflib.term.Literal('be'), rdflib.term.Literal('marketer'))
# (rdflib.term.Literal('legale.black@enron.com'), rdflib.term.Literal('post'), rdflib.term.Literal('notice'))
# (rdflib.term.Literal('mark.mcconnell@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('summer'))
# (rdflib.term.Literal('feedback@intcx.com'), rdflib.term.Literal('continue'), rdflib.term.Literal('investigate issue'))
# (rdflib.term.Literal('EP'), rdflib.term.Literal('go'), rdflib.term.Literal('end'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('sue'), rdflib.term.Literal('everyone'))
# (rdflib.term.Literal('shelley.corman@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('count'))
# (rdflib.term.Literal('Burlington'), rdflib.term.Literal('schedule'), rdflib.term.Literal('conference call'))
# (rdflib.term.Literal('Transwestern'), rdflib.term.Literal('attempt'), rdflib.term.Literal('answer question'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('donot'), rdflib.term.Literal('reboot'))
# (rdflib.term.Literal('Commission'), rdflib.term.Literal('authorize'), rdflib.term.Literal('gas'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('continue'), rdflib.term.Literal('increase return'))
# (rdflib.term.Literal('TW'), rdflib.term.Literal('open'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('manage'), rdflib.term.Literal('business'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('purchase'), rdflib.term.Literal('ticket package'))
# (rdflib.term.Literal('dennis.lee@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('email'))
# (rdflib.term.Literal('Allot'), rdflib.term.Literal('begin'), rdflib.term.Literal('feel effect'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('desktop'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('pressure scenario'))
# (rdflib.term.Literal('Clyde'), rdflib.term.Literal('conduct'), rdflib.term.Literal('session'))
# (rdflib.term.Literal('Commission'), rdflib.term.Literal('grant'), rdflib.term.Literal('determination'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('user'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('address'), rdflib.term.Literal('range'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('access'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('attention'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('visit'), rdflib.term.Literal('table'))
# (rdflib.term.Literal('SoCalGas'), rdflib.term.Literal('file'), rdflib.term.Literal('letter'))
# (rdflib.term.Literal('andre.walters@enron.com'), rdflib.term.Literal('access'), rdflib.term.Literal('outlook'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('experience'), rdflib.term.Literal('connection problem'))
# (rdflib.term.Literal('River'), rdflib.term.Literal('hold'), rdflib.term.Literal('season'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('discontinue'), rdflib.term.Literal('contribution'))
# (rdflib.term.Literal('Windows'), rdflib.term.Literal('be'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('hedge'), rdflib.term.Literal('mmbtu'))
# (rdflib.term.Literal('et&s.office@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('assistance'))
# (rdflib.term.Literal('Coop'), rdflib.term.Literal('owe'), rdflib.term.Literal('tw'))
# (rdflib.term.Literal('operators'), rdflib.term.Literal('operate'), rdflib.term.Literal('pipeline'))
# (rdflib.term.Literal('Paso'), rdflib.term.Literal('have'), rdflib.term.Literal('finalize agreement'))
# (rdflib.term.Literal('Jean'), rdflib.term.Literal('add'), rdflib.term.Literal('netscape'))
# (rdflib.term.Literal('Juan'), rdflib.term.Literal('hold'), rdflib.term.Literal('widening'))
# (rdflib.term.Literal('ruth.mann@enron.com'), rdflib.term.Literal('hold'), rdflib.term.Literal('basis'))
# (rdflib.term.Literal('gpg.announcement@enron.com'), rdflib.term.Literal('strive'), rdflib.term.Literal('%'))
# (rdflib.term.Literal('advantage'), rdflib.term.Literal('increase'), rdflib.term.Literal('capacity'))
# (rdflib.term.Literal('public.relations@enron.com'), rdflib.term.Literal('up'), rdflib.term.Literal('t'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('power'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('build'), rdflib.term.Literal('orientation'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('group'))
# (rdflib.term.Literal('Interruptions'), rdflib.term.Literal('modify'), rdflib.term.Literal('network setting'))
# (rdflib.term.Literal('audrey.robertson@enron.com'), rdflib.term.Literal('move'), rdflib.term.Literal('something'))
# (rdflib.term.Literal('et&s.office@enron.com'), rdflib.term.Literal('instal'), rdflib.term.Literal('desktop'))
# (rdflib.term.Literal('audrey.robertson@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('meeting discussion'))
# (rdflib.term.Literal('susan.scott@enron.com'), rdflib.term.Literal('know'), rdflib.term.Literal('thought'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('disapprove'), rdflib.term.Literal('t'))
# (rdflib.term.Literal('ruth.mann@enron.com'), rdflib.term.Literal('prepare'), rdflib.term.Literal('video example'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('problem'))
# (rdflib.term.Literal('enron.houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('role'), rdflib.term.Literal('identify'), rdflib.term.Literal('solution'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('go'), rdflib.term.Literal('begin phase'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('mention'), rdflib.term.Literal('meeting'))
# (rdflib.term.Literal('Gardens'), rdflib.term.Literal('be'), rdflib.term.Literal('community'))
# (rdflib.term.Literal('Alliance'), rdflib.term.Literal('have'), rdflib.term.Literal('delay date'))
# (rdflib.term.Literal('new.jun-sept@enron.com'), rdflib.term.Literal('join'), rdflib.term.Literal('growth'))
# (rdflib.term.Literal('Skinner'), rdflib.term.Literal('join'), rdflib.term.Literal('responsibility'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('create'), rdflib.term.Literal('link category'))
# (rdflib.term.Literal('market.team@enron.com'), rdflib.term.Literal('call'), rdflib.term.Literal('customer'))
# (rdflib.term.Literal('Customers'), rdflib.term.Literal('know'), rdflib.term.Literal('maximum'))
# (rdflib.term.Literal('EPFS'), rdflib.term.Literal('pay'), rdflib.term.Literal('cost'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('require'), rdflib.term.Literal('shipper'))
# (rdflib.term.Literal('PG&E'), rdflib.term.Literal('overcome'), rdflib.term.Literal('roadblock'))
# (rdflib.term.Literal('Children'), rdflib.term.Literal('develop'), rdflib.term.Literal('skill'))
# (rdflib.term.Literal('Leader'), rdflib.term.Literal('work'), rdflib.term.Literal('t'))
# (rdflib.term.Literal('ISC'), rdflib.term.Literal('launch'), rdflib.term.Literal('website'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('email system'))
# (rdflib.term.Literal('ets.announcement@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('volunteer'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('review'), rdflib.term.Literal('file'))
# (rdflib.term.Literal('donna.vaughn@enron.com'), rdflib.term.Literal('find'), rdflib.term.Literal('computer'))
# (rdflib.term.Literal('dynamics'), rdflib.term.Literal('do'), rdflib.term.Literal('regard'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('day'))
# (rdflib.term.Literal('legale.black@enron.com'), rdflib.term.Literal('post'), rdflib.term.Literal('capacity'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('disapprove'), rdflib.term.Literal('middle'))
# (rdflib.term.Literal('gpg.announcement@enron.com'), rdflib.term.Literal('strive'), rdflib.term.Literal('participation'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('continue'), rdflib.term.Literal('maintain view'))
# (rdflib.term.Literal('market.team@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('idea'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('introduce'), rdflib.term.Literal('t'))
# (rdflib.term.Literal('Select'), rdflib.term.Literal('be'), rdflib.term.Literal('contact'))
# (rdflib.term.Literal('Analysis'), rdflib.term.Literal('use'), rdflib.term.Literal('basis differential'))
# (rdflib.term.Literal('et&s.office@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('version'))
# (rdflib.term.Literal('lindy.donoho@enron.com'), rdflib.term.Literal('prepare'), rdflib.term.Literal('presentation'))
# (rdflib.term.Literal('all.downtown@enron.com'), rdflib.term.Literal('consider'), rdflib.term.Literal('fact'))
# (rdflib.term.Literal('lindy.donoho@enron.com'), rdflib.term.Literal('prepare'), rdflib.term.Literal('cheat sheet'))
# (rdflib.term.Literal('Jenkins'), rdflib.term.Literal('present'), rdflib.term.Literal('team'))
# (rdflib.term.Literal('mlokay@enron.com'), rdflib.term.Literal('buy'), rdflib.term.Literal('house'))
# (rdflib.term.Literal('Northwest'), rdflib.term.Literal('announce'), rdflib.term.Literal('revision'))
# (rdflib.term.Literal('Payable'), rdflib.term.Literal('provide'), rdflib.term.Literal('help desk'))
# (rdflib.term.Literal('new.may-june@enron.com'), rdflib.term.Literal('understand'), rdflib.term.Literal('breadth'))
# (rdflib.term.Literal('Pipeline'), rdflib.term.Literal('extend'), rdflib.term.Literal('delay'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('pass'))
# (rdflib.term.Literal('bob.burleson@enron.com'), rdflib.term.Literal('spend'), rdflib.term.Literal('put measurement'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('action plan'))
# (rdflib.term.Literal("'s"), rdflib.term.Literal('schedule'), rdflib.term.Literal('marketer'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('nomination form'))
# (rdflib.term.Literal('michael.bodnar@enron.com'), rdflib.term.Literal('call'), rdflib.term.Literal('helpdesk'))
# (rdflib.term.Literal('the.mailout@enron.com'), rdflib.term.Literal('fill'), rdflib.term.Literal('survey'))
# (rdflib.term.Literal('nancy.bastida@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('I'), rdflib.term.Literal('have'), rdflib.term.Literal('contribute fund'))
# (rdflib.term.Literal('ISC'), rdflib.term.Literal('launch'), rdflib.term.Literal('order'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('email'))
# (rdflib.term.Literal('Shelley'), rdflib.term.Literal('be'), rdflib.term.Literal('weekend'))
# (rdflib.term.Literal('ISC'), rdflib.term.Literal('be'), rdflib.term.Literal('organization'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('wish'), rdflib.term.Literal('approve increase'))
# (rdflib.term.Literal('Centrica'), rdflib.term.Literal('eye'), rdflib.term.Literal('candidate'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('communication'))
# (rdflib.term.Literal('NOVA'), rdflib.term.Literal('change'), rdflib.term.Literal('%'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('location'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('reach'), rdflib.term.Literal('%'))
# (rdflib.term.Literal('EPFS'), rdflib.term.Literal('commit'), rdflib.term.Literal('flow supply'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('experience'), rdflib.term.Literal('outage'))
# (rdflib.term.Literal('jean.mcfarland@enron.com'), rdflib.term.Literal('apologize'), rdflib.term.Literal('problem'))
# (rdflib.term.Literal('Brunch'), rdflib.term.Literal('start'), rdflib.term.Literal('10:30am'))
# (rdflib.term.Literal('dan.bunch@enron.com'), rdflib.term.Literal('look'), rdflib.term.Literal('have everyone'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('encounter'), rdflib.term.Literal('construction'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('approve'), rdflib.term.Literal('process'))
# (rdflib.term.Literal('the.mailout@enron.com'), rdflib.term.Literal('feel'), rdflib.term.Literal('job'))
# (rdflib.term.Literal('Coral'), rdflib.term.Literal('participate'), rdflib.term.Literal('business partner'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('log'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('richard.abramowicz@enron.com'), rdflib.term.Literal('set'), rdflib.term.Literal('user'))
# (rdflib.term.Literal('isc.groups@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('Gas'), rdflib.term.Literal('play'), rdflib.term.Literal('storage game'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('finalize'), rdflib.term.Literal('term'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('create'), rdflib.term.Literal('memo pad'))
# (rdflib.term.Literal('Office'), rdflib.term.Literal('have'), rdflib.term.Literal('what say'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('change'), rdflib.term.Literal('name'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('keep day'))
# (rdflib.term.Literal('Myers'), rdflib.term.Literal('join'), rdflib.term.Literal('management team'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('kick'), rdflib.term.Literal('campaign'))
# (rdflib.term.Literal('Marketing'), rdflib.term.Literal('approve'), rdflib.term.Literal('point'))
# (rdflib.term.Literal('Duke'), rdflib.term.Literal('move'), rdflib.term.Literal('mmbtu'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('operate'), rdflib.term.Literal('period'))
# (rdflib.term.Literal('julie.mccoy@enron.com'), rdflib.term.Literal('miss'), rdflib.term.Literal('conference call'))
# (rdflib.term.Literal('he'), rdflib.term.Literal('have'), rdflib.term.Literal('what say'))
# (rdflib.term.Literal('FERC'), rdflib.term.Literal('schedule'), rdflib.term.Literal('conference'))
# (rdflib.term.Literal('Steve'), rdflib.term.Literal('have'), rdflib.term.Literal('month'))
# (rdflib.term.Literal('Shell'), rdflib.term.Literal('form'), rdflib.term.Literal('intergen'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('notes'))
# (rdflib.term.Literal('Work'), rdflib.term.Literal('gear'), rdflib.term.Literal('session'))
# (rdflib.term.Literal('Western'), rdflib.term.Literal('like'), rdflib.term.Literal('deliver gas'))
# (rdflib.term.Literal('jimbomania@hotmail.com'), rdflib.term.Literal('attach'), rdflib.term.Literal('file version'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('track'), rdflib.term.Literal('contract'))
# (rdflib.term.Literal('Williams'), rdflib.term.Literal('plan'), rdflib.term.Literal('way'))
# (rdflib.term.Literal('julie.mccoy@enron.com'), rdflib.term.Literal('listen'), rdflib.term.Literal('replay'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('dth'))
# (rdflib.term.Literal('clickathome.mailout@enron.com'), rdflib.term.Literal('consider'), rdflib.term.Literal('purchase'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('be'), rdflib.term.Literal('process'))
# (rdflib.term.Literal('Varner'), rdflib.term.Literal('be'), rdflib.term.Literal('year'))
# (rdflib.term.Literal('Bus'), rdflib.term.Literal('depart'), rdflib.term.Literal('a.m.'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('capacity'))
# (rdflib.term.Literal('England'), rdflib.term.Literal('see'), rdflib.term.Literal('price'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('assist'), rdflib.term.Literal('operation'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('earn'), rdflib.term.Literal('idea'))
# (rdflib.term.Literal('tk.lohman@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('Apollo'), rdflib.term.Literal('conduct'), rdflib.term.Literal('implementation'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('welcome'), rdflib.term.Literal('proceeding'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('disturb'), rdflib.term.Literal('machine'))
# (rdflib.term.Literal('lorraine.lindberg@enron.com'), rdflib.term.Literal('maintain'), rdflib.term.Literal('spreadsheet'))
# (rdflib.term.Literal('Duke'), rdflib.term.Literal('move'), rdflib.term.Literal('rate'))
# (rdflib.term.Literal('Chairman'), rdflib.term.Literal('speak'), rdflib.term.Literal('lunch'))
# (rdflib.term.Literal('andre.walters@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('action'))
# (rdflib.term.Literal('Computers'), rdflib.term.Literal('be'), rdflib.term.Literal('property'))
# (rdflib.term.Literal('jean.mcfarland@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('email'))
# (rdflib.term.Literal('gpg.employees@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('chance'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('group'), rdflib.term.Literal('link'))
# (rdflib.term.Literal('dale.eldridge@enron.com'), rdflib.term.Literal('update'), rdflib.term.Literal('marketer'))
# (rdflib.term.Literal('analysis'), rdflib.term.Literal('hope'), rdflib.term.Literal('give answer'))
# (rdflib.term.Literal('enron.operations@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('Employees'), rdflib.term.Literal('pay'), rdflib.term.Literal('management'))
# (rdflib.term.Literal('He'), rdflib.term.Literal('inform'), rdflib.term.Literal('activity'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('platform'))
# (rdflib.term.Literal('Traswestern'), rdflib.term.Literal('clean'), rdflib.term.Literal('line'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('provide information'))
# (rdflib.term.Literal('October'), rdflib.term.Literal('be'), rdflib.term.Literal('chapter'))
# (rdflib.term.Literal('the.mailout@enron.com'), rdflib.term.Literal('feel'), rdflib.term.Literal('fear'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('support'), rdflib.term.Literal('socalgas'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('approve'), rdflib.term.Literal('portion'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('welcome'), rdflib.term.Literal('evidence'))
# (rdflib.term.Literal('Mike'), rdflib.term.Literal('be'), rdflib.term.Literal('measure'))
# (rdflib.term.Literal('tbrother@utilicorp.com'), rdflib.term.Literal('like'), rdflib.term.Literal('change point'))
# (rdflib.term.Literal('spokesperson'), rdflib.term.Literal('underscore'), rdflib.term.Literal('seriousness'))
# (rdflib.term.Literal("'s"), rdflib.term.Literal('do'), rdflib.term.Literal('show'))
# (rdflib.term.Literal('lorraine.lindberg@enron.com'), rdflib.term.Literal('meet'), rdflib.term.Literal('office'))
# (rdflib.term.Literal('jim.wiltfong@enron.com'), rdflib.term.Literal('reserve'), rdflib.term.Literal('meeting'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('approval'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('post'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('fund'))
# (rdflib.term.Literal('gpg.employees@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('meeting'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('do'), rdflib.term.Literal('holiday'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('retain'), rdflib.term.Literal('file'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('require'), rdflib.term.Literal('take capacity'))
# (rdflib.term.Literal('Alliance'), rdflib.term.Literal('flow'), rdflib.term.Literal('amount'))
# (rdflib.term.Literal('jimboman@bigfoot.com'), rdflib.term.Literal('sell'), rdflib.term.Literal('cow'))
# (rdflib.term.Literal('He'), rdflib.term.Literal('hold'), rdflib.term.Literal('bachelor'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('authorize'), rdflib.term.Literal('process claim'))
# (rdflib.term.Literal('Mirant'), rdflib.term.Literal('integrate'), rdflib.term.Literal('weather risk'))
# (rdflib.term.Literal('michael.bodnar@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('michael.bodnar@enron.com'), rdflib.term.Literal('keep'), rdflib.term.Literal('file'))
# (rdflib.term.Literal('Center'), rdflib.term.Literal('take'), rdflib.term.Literal('step'))
# (rdflib.term.Literal('WinInstall'), rdflib.term.Literal('make'), rdflib.term.Literal('update'))
# (rdflib.term.Literal('dennis.lee@enron.com'), rdflib.term.Literal('do'), rdflib.term.Literal('email'))
# (rdflib.term.Literal('lana.belnoske@nesanet.org'), rdflib.term.Literal('attach'), rdflib.term.Literal('registration form'))
# (rdflib.term.Literal('sharee.payne@compaq.com'), rdflib.term.Literal('have'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('America'), rdflib.term.Literal('offer'), rdflib.term.Literal('17th'))
# (rdflib.term.Literal('Vector'), rdflib.term.Literal('begin'), rdflib.term.Literal('service'))
# (rdflib.term.Literal('steven.harris@enron.com'), rdflib.term.Literal('join'), rdflib.term.Literal('adr'))
# (rdflib.term.Literal('Commission'), rdflib.term.Literal('launch'), rdflib.term.Literal('offensive'))
# (rdflib.term.Literal('enron.worldwide@enron.com'), rdflib.term.Literal('go'), rdflib.term.Literal('website'))
# (rdflib.term.Literal('i'), rdflib.term.Literal('be'), rdflib.term.Literal('initial'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('contact'), rdflib.term.Literal('helpdesk'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('have'), rdflib.term.Literal('day'))
# (rdflib.term.Literal('Ballet'), rdflib.term.Literal('be'), rdflib.term.Literal('need'))
# (rdflib.term.Literal('Mike'), rdflib.term.Literal('be'), rdflib.term.Literal('spreadsheet'))
# (rdflib.term.Literal('et&s.office@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('message'))
# (rdflib.term.Literal('Bus'), rdflib.term.Literal('depart'), rdflib.term.Literal('building'))
# (rdflib.term.Literal('Centrica'), rdflib.term.Literal('tell'), rdflib.term.Literal('newspaper'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('liberty'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('crank'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('identify'), rdflib.term.Literal('condition'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('answer'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('new.jun-sept@enron.com'), rdflib.term.Literal('understand'), rdflib.term.Literal('breadth'))
# (rdflib.term.Literal('Outlook'), rdflib.term.Literal('integrate'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('support'), rdflib.term.Literal('work environment'))
# (rdflib.term.Literal('Transwestern'), rdflib.term.Literal('hold'), rdflib.term.Literal('workshop'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('message'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('element'))
# (rdflib.term.Literal('Moore'), rdflib.term.Literal('join'), rdflib.term.Literal('team'))
# (rdflib.term.Literal('martha.janousek@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('survey'))
# (rdflib.term.Literal('Jenkins'), rdflib.term.Literal('present'), rdflib.term.Literal('check'))
# (rdflib.term.Literal('martha.janousek@enron.com'), rdflib.term.Literal('roll'), rdflib.term.Literal('release'))
# (rdflib.term.Literal('dennis.lee@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('document'))
# (rdflib.term.Literal('Duke'), rdflib.term.Literal('move'), rdflib.term.Literal('west'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('purchase'), rdflib.term.Literal('seat'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('push'), rdflib.term.Literal('envelope'))
# (rdflib.term.Literal('trader'), rdflib.term.Literal('know'), rdflib.term.Literal('own capacity'))
# (rdflib.term.Literal('all.states@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('Alliance'), rdflib.term.Literal('increase'), rdflib.term.Literal('gas'))
# (rdflib.term.Literal('new.may-june@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('forefront'))
# (rdflib.term.Literal('trader'), rdflib.term.Literal('have'), rdflib.term.Literal('suspicion'))
# (rdflib.term.Literal('Gary'), rdflib.term.Literal('have'), rdflib.term.Literal('year'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('answer question'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('experience'), rdflib.term.Literal('timeframe'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('earn'), rdflib.term.Literal('credit'))
# (rdflib.term.Literal('HealthCare'), rdflib.term.Literal('reach'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('Aquila'), rdflib.term.Literal('have'), rdflib.term.Literal('transport right'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('box'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('document'))
# (rdflib.term.Literal('Tickets'), rdflib.term.Literal('remain'), rdflib.term.Literal('sale'))
# (rdflib.term.Literal('Furniture'), rdflib.term.Literal('have'), rdflib.term.Literal('offer'))
# (rdflib.term.Literal('Systems'), rdflib.term.Literal('ask'), rdflib.term.Literal('%'))
# (rdflib.term.Literal('lorraine.lindberg@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('meeting'))
# (rdflib.term.Literal('jimboman@bigfoot.com'), rdflib.term.Literal('borrow'), rdflib.term.Literal('%'))
# (rdflib.term.Literal('Horton'), rdflib.term.Literal('open'), rdflib.term.Literal('remark'))
# (rdflib.term.Literal('Dynegy'), rdflib.term.Literal('echo'), rdflib.term.Literal('concern'))
# (rdflib.term.Literal('public.relations@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('entry'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('talk'), rdflib.term.Literal('account'))
# (rdflib.term.Literal('ENA'), rdflib.term.Literal('meet'), rdflib.term.Literal('owner'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('update'), rdflib.term.Literal('trading'))
# (rdflib.term.Literal('mlokay@enron.com'), rdflib.term.Literal('see'), rdflib.term.Literal('email'))
# (rdflib.term.Literal('jean.mcfarland@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('he'), rdflib.term.Literal('examine'), rdflib.term.Literal('technology'))
# (rdflib.term.Literal('II'), rdflib.term.Literal('add'), rdflib.term.Literal('dth'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('reset'), rdflib.term.Literal('hedge'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('participation'))
# (rdflib.term.Literal('Difference'), rdflib.term.Literal('mojave'), rdflib.term.Literal('tw'))
# (rdflib.term.Literal('Centilli'), rdflib.term.Literal('run'), rdflib.term.Literal('economic'))
# (rdflib.term.Literal('lorraine.lindberg@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('meeting'))
# (rdflib.term.Literal('lindy.donoho@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('people'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('look'), rdflib.term.Literal('what'))
# (rdflib.term.Literal('TW'), rdflib.term.Literal('open'), rdflib.term.Literal('floor'))
# (rdflib.term.Literal('Below'), rdflib.term.Literal('be'), rdflib.term.Literal('detail'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('tool'))
# (rdflib.term.Literal('jimboman@bigfoot.com'), rdflib.term.Literal('have'), rdflib.term.Literal('cow'))
# (rdflib.term.Literal('InterGen'), rdflib.term.Literal('receive'), rdflib.term.Literal('majority'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('apologize'), rdflib.term.Literal('inconvenience'))
# (rdflib.term.Literal('kent.miller@enron.com'), rdflib.term.Literal('click'), rdflib.term.Literal('category'))
# (rdflib.term.Literal('michael.bodnar@enron.com'), rdflib.term.Literal('delete'), rdflib.term.Literal('example'))
# (rdflib.term.Literal('Centrica'), rdflib.term.Literal('eye'), rdflib.term.Literal('energy'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('access'))
# (rdflib.term.Literal('WinInstall'), rdflib.term.Literal('make'), rdflib.term.Literal('computer'))
# (rdflib.term.Literal('Process'), rdflib.term.Literal('lose'), rdflib.term.Literal('mail message'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('leave'), rdflib.term.Literal('hour'))
# (rdflib.term.Literal('the.mailout@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('right'))
# (rdflib.term.Literal('Administration'), rdflib.term.Literal('project'), rdflib.term.Literal('gas price'))
# (rdflib.term.Literal('Chicago'), rdflib.term.Literal('be'), rdflib.term.Literal('market'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('communicate'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('Gala'), rdflib.term.Literal('need'), rdflib.term.Literal('volunteer'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('appreciate'), rdflib.term.Literal('participation'))
# (rdflib.term.Literal('SAP'), rdflib.term.Literal('bring'), rdflib.term.Literal('dynamic'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('process'))
# (rdflib.term.Literal('gpg.employees@enron.com'), rdflib.term.Literal('submit'), rdflib.term.Literal('answer'))
# (rdflib.term.Literal('Jan'), rdflib.term.Literal('be'), rdflib.term.Literal('position'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('sign'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('Pipeline'), rdflib.term.Literal('institute'), rdflib.term.Literal('ofo'))
# (rdflib.term.Literal('public.relations@enron.com'), rdflib.term.Literal('up'), rdflib.term.Literal('addition'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('understand'), rdflib.term.Literal('situation'))
# (rdflib.term.Literal('Joy'), rdflib.term.Literal('promote'), rdflib.term.Literal('need'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('respond'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('He'), rdflib.term.Literal('see'), rdflib.term.Literal('temperature'))
# (rdflib.term.Literal('Winter'), rdflib.term.Literal('bring'), rdflib.term.Literal('rockies'))
# (rdflib.term.Literal('isc.groups@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('user'))
# (rdflib.term.Literal('Merchants'), rdflib.term.Literal('showcase'), rdflib.term.Literal('row'))
# (rdflib.term.Literal('Transco'), rdflib.term.Literal('initiate'), rdflib.term.Literal('domain proceeding'))
# (rdflib.term.Literal('Bechtel'), rdflib.term.Literal('be'), rdflib.term.Literal('leader'))
# (rdflib.term.Literal('all.america@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('data ehronline'))
# (rdflib.term.Literal('Fitch'), rdflib.term.Literal('state'), rdflib.term.Literal('announcement'))
# (rdflib.term.Literal('TRAINING'), rdflib.term.Literal('go'), rdflib.term.Literal('page'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('prefer'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('NW'), rdflib.term.Literal('run'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('Option'), rdflib.term.Literal('call'), rdflib.term.Literal('capacity'))
# (rdflib.term.Literal('Team'), rdflib.term.Literal('work'), rdflib.term.Literal('vendor'))
# (rdflib.term.Literal('Lokay'), rdflib.term.Literal('have'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('Hermann'), rdflib.term.Literal('cancel'), rdflib.term.Literal('contract'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('expect'), rdflib.term.Literal('see basis'))
# (rdflib.term.Literal('nancy.bastida@enron.com'), rdflib.term.Literal('fax'), rdflib.term.Literal('envision'))
# (rdflib.term.Literal('audrey.robertson@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('reflect change'))
# (rdflib.term.Literal('Maintenance'), rdflib.term.Literal('perform'), rdflib.term.Literal('battery'))
# (rdflib.term.Literal('Dan'), rdflib.term.Literal('conduct'), rdflib.term.Literal('session'))
# (rdflib.term.Literal('new.may-june@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('day'))
# (rdflib.term.Literal('River'), rdflib.term.Literal('plan'), rdflib.term.Literal('expansion'))
# (rdflib.term.Literal('CPUC'), rdflib.term.Literal('tell'), rdflib.term.Literal('ferc'))
# (rdflib.term.Literal('pipeline'), rdflib.term.Literal('limit'), rdflib.term.Literal('volume'))
# (rdflib.term.Literal('Maintenance'), rdflib.term.Literal('perform'), rdflib.term.Literal('maintenance'))
# (rdflib.term.Literal('lorraine.lindberg@enron.com'), rdflib.term.Literal('incorporate'), rdflib.term.Literal('capacity'))
# (rdflib.term.Literal('mlokay@enron.com'), rdflib.term.Literal('find'), rdflib.term.Literal('name'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('direct'), rdflib.term.Literal('socalga'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('store'), rdflib.term.Literal('rate system'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('rate schedule'))
# (rdflib.term.Literal('Project'), rdflib.term.Literal('provide'), rdflib.term.Literal('capacity'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('look'), rdflib.term.Literal('effort'))
# (rdflib.term.Literal("'hitschel@enron.com"), rdflib.term.Literal('think'), rdflib.term.Literal('itinerary'))
# (rdflib.term.Literal('Explorer'), rdflib.term.Literal('join'), rdflib.term.Literal('session'))
# (rdflib.term.Literal('enron.customers@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('basis'))
# (rdflib.term.Literal('chris.smith@enron.com'), rdflib.term.Literal('approach'), rdflib.term.Literal('project'))
# (rdflib.term.Literal('rjuenke@br-inc.com'), rdflib.term.Literal('come'), rdflib.term.Literal('training'))
# (rdflib.term.Literal('jean.mcfarland@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('training'))
# (rdflib.term.Literal('Cookies'), rdflib.term.Literal('be'), rdflib.term.Literal('sale'))
# (rdflib.term.Literal('new.jun-sept@enron.com'), rdflib.term.Literal('join'), rdflib.term.Literal('company'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('brochure'))
# (rdflib.term.Literal('all.america@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('create'), rdflib.term.Literal('requirement document'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('keep'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('he'), rdflib.term.Literal('end'), rdflib.term.Literal('paragraph'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('win'), rdflib.term.Literal('award'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('gather'), rdflib.term.Literal('hardware'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('make'), rdflib.term.Literal('event'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('create'), rdflib.term.Literal('business'))
# (rdflib.term.Literal('Tickets'), rdflib.term.Literal('remain'), rdflib.term.Literal('p.m.'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('update'), rdflib.term.Literal('name'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('test'), rdflib.term.Literal('version'))
# (rdflib.term.Literal('meiling.chen@enron.com'), rdflib.term.Literal('replace'), rdflib.term.Literal('basis differential'))
# (rdflib.term.Literal('Gish'), rdflib.term.Literal('begin'), rdflib.term.Literal('service'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('support'), rdflib.term.Literal('messaging'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('communication'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('phase'), rdflib.term.Literal('reporti'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('oba'))
# (rdflib.term.Literal('Glassberg'), rdflib.term.Literal('discuss'), rdflib.term.Literal('butterfly'))
# (rdflib.term.Literal('Tennessee'), rdflib.term.Literal('have'), rdflib.term.Literal('quarter'))
# (rdflib.term.Literal('kim.kouri@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('what modify'))
# (rdflib.term.Literal('Bechtel'), rdflib.term.Literal('fold'), rdflib.term.Literal('intergen'))
# (rdflib.term.Literal('Marketing'), rdflib.term.Literal('approve'), rdflib.term.Literal('addition'))
# (rdflib.term.Literal('Transwestern'), rdflib.term.Literal('seek'), rdflib.term.Literal('assistance'))
# (rdflib.term.Literal('Dec'), rdflib.term.Literal('retain'), rdflib.term.Literal('rate'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('est'), rdflib.term.Literal('stamina'))
# (rdflib.term.Literal('dale.eldridge@enron.com'), rdflib.term.Literal('update'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('Proceeds'), rdflib.term.Literal('go'), rdflib.term.Literal('line'))
# (rdflib.term.Literal('Dynegy'), rdflib.term.Literal('reiterate'), rdflib.term.Literal('suggestion'))
# (rdflib.term.Literal('joe.witherspoon@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('approve'), rdflib.term.Literal('basis'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('forget'), rdflib.term.Literal('password'))
# (rdflib.term.Literal('Cedar'), rdflib.term.Literal('need'), rdflib.term.Literal('signature'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('check pulse'))
# (rdflib.term.Literal('December'), rdflib.term.Literal('see'), rdflib.term.Literal('retention cost'))
# (rdflib.term.Literal('Chairman'), rdflib.term.Literal('conduct'), rdflib.term.Literal('session'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('request'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('et&s.office@enron.com'), rdflib.term.Literal('run'), rdflib.term.Literal('winstall'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('owner'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('platform'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('print'), rdflib.term.Literal('newsletter'))
# (rdflib.term.Literal('chris.smith@enron.com'), rdflib.term.Literal('migrate'), rdflib.term.Literal('datum'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('schedule'))
# (rdflib.term.Literal('FERC'), rdflib.term.Literal('depart'), rdflib.term.Literal('policy'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('continue'), rdflib.term.Literal('evaluate potential'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('invite'), rdflib.term.Literal('attend day'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('post'), rdflib.term.Literal('result'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('start'), rdflib.term.Literal('commodity market'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('add'), rdflib.term.Literal('alias'))
# (rdflib.term.Literal('Needles'), rdflib.term.Literal('spread'), rdflib.term.Literal('spread'))
# ...
# (rdflib.term.Literal('gas.operations@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('continue'), rdflib.term.Literal('monitor usage'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('match'), rdflib.term.Literal('contribution dollar'))
# (rdflib.term.Literal('kevin.hyatt@enron.com'), rdflib.term.Literal('assemble'), rdflib.term.Literal('impact figure'))
# (rdflib.term.Literal('Things'), rdflib.term.Literal('be'), rdflib.term.Literal('debacle'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('see'), rdflib.term.Literal('marketing report'))
# (rdflib.term.Literal('she'), rdflib.term.Literal('facilitate'), rdflib.term.Literal('training'))
# (rdflib.term.Literal('Smith'), rdflib.term.Literal('accept'), rdflib.term.Literal('position'))
# (rdflib.term.Literal('Imbalance'), rdflib.term.Literal('be'), rdflib.term.Literal('level'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('finalize'), rdflib.term.Literal('rollout schedule'))
# (rdflib.term.Literal('Power'), rdflib.term.Literal('be'), rdflib.term.Literal('buy'))
# (rdflib.term.Literal('clickathome.mailout@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('opportunity'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('check'))
# (rdflib.term.Literal('Winter'), rdflib.term.Literal('arrive'), rdflib.term.Literal('earnest'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('store'), rdflib.term.Literal('level'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('move'), rdflib.term.Literal('message'))
# (rdflib.term.Literal('Shell'), rdflib.term.Literal('be'), rdflib.term.Literal('one'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('subsidize'), rdflib.term.Literal('half'))
# (rdflib.term.Literal('Bechtel'), rdflib.term.Literal('own'), rdflib.term.Literal('%'))
# (rdflib.term.Literal('new.jun-sept@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('day'))
# (rdflib.term.Literal('she'), rdflib.term.Literal('be'), rdflib.term.Literal('addition'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('subsidize'), rdflib.term.Literal('internet connection'))
# (rdflib.term.Literal('Virginia'), rdflib.term.Literal('continue'), rdflib.term.Literal('coordinate trip'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('be'), rdflib.term.Literal('place'))
# (rdflib.term.Literal('Fitch'), rdflib.term.Literal('cite'), rdflib.term.Literal('need'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('% participation'))
# (rdflib.term.Literal('Paso'), rdflib.term.Literal('be'), rdflib.term.Literal('player'))
# (rdflib.term.Literal('Company'), rdflib.term.Literal('object'), rdflib.term.Literal('provision'))
# (rdflib.term.Literal('MMBtu'), rdflib.term.Literal('compete'), rdflib.term.Literal('capacity'))
# (rdflib.term.Literal('jeff.huo@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('appreciate'), rdflib.term.Literal('work'))
# (rdflib.term.Literal('jeffery.fawcett@enron.com'), rdflib.term.Literal('appear'), rdflib.term.Literal('have volume'))
# (rdflib.term.Literal('et&s.office@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('Mexico'), rdflib.term.Literal('force'), rdflib.term.Literal('operations'))
# (rdflib.term.Literal('steven.harris@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('store'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('Coral'), rdflib.term.Literal('have'), rdflib.term.Literal('d'))
# (rdflib.term.Literal('Company'), rdflib.term.Literal('deliver'), rdflib.term.Literal('response'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('day vacation'))
# (rdflib.term.Literal('Transportation'), rdflib.term.Literal('sponsor'), rdflib.term.Literal('program'))
# (rdflib.term.Literal('InterGen'), rdflib.term.Literal('be'), rdflib.term.Literal('developer'))
# (rdflib.term.Literal('Cafe'), rdflib.term.Literal('be'), rdflib.term.Literal('grinch'))
# (rdflib.term.Literal('Coral'), rdflib.term.Literal('have'), rdflib.term.Literal('gas supply'))
# (rdflib.term.Literal('Lobby'), rdflib.term.Literal('have'), rdflib.term.Literal('audience'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('version'))
# (rdflib.term.Literal('ENA'), rdflib.term.Literal('owe'), rdflib.term.Literal('money'))
# (rdflib.term.Literal('ramona.betancourt@enron.com'), rdflib.term.Literal('implement'), rdflib.term.Literal('system requirement'))
# (rdflib.term.Literal('Club'), rdflib.term.Literal('collect'), rdflib.term.Literal('t shirt'))
# (rdflib.term.Literal('Lokay'), rdflib.term.Literal('review'), rdflib.term.Literal('index price'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('use'), rdflib.term.Literal('store document'))
# (rdflib.term.Literal("O'Neill"), rdflib.term.Literal('coordinate'), rdflib.term.Literal('plane schedule'))
# (rdflib.term.Literal('Chevron'), rdflib.term.Literal('retain'), rdflib.term.Literal('share'))
# (rdflib.term.Literal('Weather'), rdflib.term.Literal('permit'), rdflib.term.Literal('area'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('increase'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('He'), rdflib.term.Literal('s'), rdflib.term.Literal('value'))
# (rdflib.term.Literal('pcervin@br-inc.com'), rdflib.term.Literal('send'), rdflib.term.Literal('representative'))
# (rdflib.term.Literal('the.mailout@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('participation number'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('schedule'), rdflib.term.Literal('session'))
# (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'), rdflib.term.Literal('take'), rdflib.term.Literal('minute'))
# (rdflib.term.Literal('new.may-june@enron.com'), rdflib.term.Literal('join'), rdflib.term.Literal('time'))
# (rdflib.term.Literal('Products'), rdflib.term.Literal('have'), rdflib.term.Literal('addition'))
# (rdflib.term.Literal('Michelle'), rdflib.term.Literal('be'), rdflib.term.Literal('evaluate ride'))
# (rdflib.term.Literal('Williams'), rdflib.term.Literal('declare'), rdflib.term.Literal('force'))
# (rdflib.term.Literal('Transmission'), rdflib.term.Literal('plan'), rdflib.term.Literal('file application'))
# (rdflib.term.Literal('Jean'), rdflib.term.Literal('add'), rdflib.term.Literal('user'))
# (rdflib.term.Literal('Cliff'), rdflib.term.Literal('focus'), rdflib.term.Literal('repositioning'))
# (rdflib.term.Literal('ETS'), rdflib.term.Literal('have'), rdflib.term.Literal('duck'))
# (rdflib.term.Literal('Conduct'), rdflib.term.Literal('hold'), rdflib.term.Literal('employee'))
# (rdflib.term.Literal('audrey.robertson@enron.com'), rdflib.term.Literal('discuss'), rdflib.term.Literal('request'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('get'), rdflib.term.Literal('ticket'))
# (rdflib.term.Literal('Martin'), rdflib.term.Literal('become'), rdflib.term.Literal('president'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('contract level'))
# (rdflib.term.Literal('FERC'), rdflib.term.Literal('deny'), rdflib.term.Literal('request'))
# (rdflib.term.Literal('all.worldwide@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('intelligence'))
# (rdflib.term.Literal('all.downtown@enron.com'), rdflib.term.Literal('win'), rdflib.term.Literal('9th'))
# (rdflib.term.Literal('FERC'), rdflib.term.Literal('require'), rdflib.term.Literal('tw'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('utilize'), rdflib.term.Literal('system'))
# (rdflib.term.Literal('meiling.chen@enron.com'), rdflib.term.Literal('apply'), rdflib.term.Literal('logic'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('look'), rdflib.term.Literal('location'))
# (rdflib.term.Literal('River'), rdflib.term.Literal('cast'), rdflib.term.Literal('lot'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('apologize'), rdflib.term.Literal('miscommunication'))
# (rdflib.term.Literal('office.chairman@enron.com'), rdflib.term.Literal('hope'), rdflib.term.Literal('reach goal'))
# (rdflib.term.Literal('Legal'), rdflib.term.Literal('check'), rdflib.term.Literal('row'))
# (rdflib.term.Literal('Varner'), rdflib.term.Literal('lead'), rdflib.term.Literal('workshop'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('call'), rdflib.term.Literal('service number'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('begin'), rdflib.term.Literal('utilize service'))
# (rdflib.term.Literal('Engbrock'), rdflib.term.Literal('have'), rdflib.term.Literal('term'))
# (rdflib.term.Literal('Stephanie'), rdflib.term.Literal('be'), rdflib.term.Literal('office'))
# (rdflib.term.Literal('Winter'), rdflib.term.Literal('bring'), rdflib.term.Literal('price'))
# (rdflib.term.Literal('jean.mcfarland@enron.com'), rdflib.term.Literal('test'), rdflib.term.Literal('marketing application'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('look'), rdflib.term.Literal('edge'))
# (rdflib.term.Literal('the.mailout@enron.com'), rdflib.term.Literal('complete'), rdflib.term.Literal('surve'))
# (rdflib.term.Literal('toby.kuehl@enron.com'), rdflib.term.Literal('provide'), rdflib.term.Literal('code'))
# (rdflib.term.Literal('Central'), rdflib.term.Literal('provide'), rdflib.term.Literal('training session'))
# (rdflib.term.Literal('rockey.storie@enron.com'), rdflib.term.Literal('want'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('Husband'), rdflib.term.Literal('uninstall'), rdflib.term.Literal('program'))
# (rdflib.term.Literal('SoCal'), rdflib.term.Literal('lower'), rdflib.term.Literal('window'))
# (rdflib.term.Literal('bob.burleson@enron.com'), rdflib.term.Literal('ammend'), rdflib.term.Literal('agreement'))
# (rdflib.term.Literal('Oasis'), rdflib.term.Literal('complete'), rdflib.term.Literal('upgrade'))
# (rdflib.term.Literal('Williams'), rdflib.term.Literal('plan'), rdflib.term.Literal('upgrade station'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('comment'))
# (rdflib.term.Literal('clickathome.mailout@enron.com'), rdflib.term.Literal('submit'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('begin'), rdflib.term.Literal('provide feedback'))
# (rdflib.term.Literal('mlokay@enron.com'), rdflib.term.Literal('sign'), rdflib.term.Literal('16th'))
# (rdflib.term.Literal('michael.bodnar@enron.com'), rdflib.term.Literal('save'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('Gary'), rdflib.term.Literal('assume'), rdflib.term.Literal('resource responsibility'))
# (rdflib.term.Literal('all.america@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('business'))
# (rdflib.term.Literal('Bechtel'), rdflib.term.Literal('fold'), rdflib.term.Literal('business'))
# (rdflib.term.Literal('Energy'), rdflib.term.Literal('expect'), rdflib.term.Literal('close transaction'))
# (rdflib.term.Literal('christine.stokes@enron.com'), rdflib.term.Literal('mention'), rdflib.term.Literal('meeting'))
# (rdflib.term.Literal('Representatives'), rdflib.term.Literal('be'), rdflib.term.Literal('answer question'))
# (rdflib.term.Literal('Alliance'), rdflib.term.Literal('flow'), rdflib.term.Literal('market'))
# (rdflib.term.Literal('Interruptions'), rdflib.term.Literal('modify'), rdflib.term.Literal('hardware setting'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('enlist'), rdflib.term.Literal('cooperation'))
# (rdflib.term.Literal('Paso'), rdflib.term.Literal('declare'), rdflib.term.Literal('situation'))
# (rdflib.term.Literal('Gary'), rdflib.term.Literal('be'), rdflib.term.Literal('president'))
# (rdflib.term.Literal('ken.skilling@enron.com'), rdflib.term.Literal('send'), rdflib.term.Literal('copy'))
# (rdflib.term.Literal('richard.hanagriff@enron.com'), rdflib.term.Literal('print'), rdflib.term.Literal('lists'))
# (rdflib.term.Literal('david.badura@enron.com'), rdflib.term.Literal('edit'), rdflib.term.Literal('list'))
# (rdflib.term.Literal('Amoco'), rdflib.term.Literal('change'), rdflib.term.Literal('name'))
# (rdflib.term.Literal('Gas'), rdflib.term.Literal('institute'), rdflib.term.Literal('balancing requirement'))
# (rdflib.term.Literal('enron.mailout@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('question'))
# (rdflib.term.Literal('mlokay@enron.com'), rdflib.term.Literal('be'), rdflib.term.Literal('pleasure'))
# (rdflib.term.Literal('Enron'), rdflib.term.Literal('match'), rdflib.term.Literal('dollar'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('reach'), rdflib.term.Literal('year'))
# (rdflib.term.Literal('InterGen'), rdflib.term.Literal('take'), rdflib.term.Literal('% stake'))
# (rdflib.term.Literal('nancy.bastida@enron.com'), rdflib.term.Literal('fax'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('anticipate'), rdflib.term.Literal('service disruption'))
# (rdflib.term.Literal('Horton'), rdflib.term.Literal('open'), rdflib.term.Literal('class'))
# (rdflib.term.Literal('lorna.brennan@enron.com'), rdflib.term.Literal('look'), rdflib.term.Literal('pipe'))
# (rdflib.term.Literal('all.houston@enron.com'), rdflib.term.Literal('need'), rdflib.term.Literal('access'))
# (rdflib.term.Literal('M.L.'), rdflib.term.Literal('run'), rdflib.term.Literal('reserve'))
# (rdflib.term.Literal('Williams'), rdflib.term.Literal('offer'), rdflib.term.Literal('rate'))
# (rdflib.term.Literal('michelle.lokay@enron.com'), rdflib.term.Literal('have'), rdflib.term.Literal('use u'))
# (rdflib.term.Literal('audrey.robertson@enron.com'), rdflib.term.Literal('like'), rdflib.term.Literal('make request'))
# (rdflib.term.Literal('Vernon'), rdflib.term.Literal('add'), rdflib.term.Literal('tw'))
# (rdflib.term.Literal('Winters'), rdflib.term.Literal('initiate'), rdflib.term.Literal('coverage'))
# (rdflib.term.Literal('Sempra'), rdflib.term.Literal('be'), rdflib.term.Literal('candidate'))
# (rdflib.term.Literal('enron.everyone_et&s_field_offices@enron.com'), rdflib.term.Literal('find'), rdflib.term.Literal('information'))
# (rdflib.term.Literal('all.america@enron.com'), rdflib.term.Literal('update'), rdflib.term.Literal('datum'))
# (rdflib.term.Literal('Reports'), rdflib.term.Literal('accommodate'), rdflib.term.Literal('code'))
# (rdflib.term.Literal('ets.center@enron.com'), rdflib.term.Literal('encourage'), rdflib.term.Literal('review folder'))
# (rdflib.term.Literal('gpg.employees@enron.com'), rdflib.term.Literal('help'), rdflib.term.Literal('million'))
# (rdflib.term.Literal('kent.miller@enron.com'), rdflib.term.Literal('click'), rdflib.term.Literal('exit screen'))
# (rdflib.term.Literal('enron.announcements@enron.com'), rdflib.term.Literal('reorganize'), rdflib.term.Literal('business unit'))
# (rdflib.term.Literal('lindy.donoho@enron.com'), rdflib.term.Literal('propose'), rdflib.term.Literal('make assumption'))
# (rdflib.term.Literal('He'), rdflib.term.Literal('label'), rdflib.term.Literal('power'))
# (rdflib.term.Literal('Taylor'), rdflib.term.Literal('join'), rdflib.term.Literal('group'))
# (rdflib.term.Literal('PerkCard'), rdflib.term.Literal('offer'), rdflib.term.Literal('discount'))
# (rdflib.term.Literal('Burlington'), rdflib.term.Literal('have'), rdflib.term.Literal('mmbtu'))
# (rdflib.term.Literal('all.employees@enron.com'), rdflib.term.Literal('receive'), rdflib.term.Literal('letter'))
# (rdflib.term.Literal('Management'), rdflib.term.Literal('conduct'), rdflib.term.Literal('audits'))

# %%
predicates = set()
for s, p, o in g:
    predicates.add(p)

# %%
predicates
# Out:
# {rdflib.term.Literal('accept'),
#  rdflib.term.Literal('access'),
#  rdflib.term.Literal('accommodate'),
#  rdflib.term.Literal('accomplish'),
#  rdflib.term.Literal('acquire'),
#  rdflib.term.Literal('act'),
#  rdflib.term.Literal('add'),
#  rdflib.term.Literal('address'),
#  rdflib.term.Literal('adopt'),
#  rdflib.term.Literal('agree'),
#  rdflib.term.Literal('alleviate'),
#  rdflib.term.Literal('ammend'),
#  rdflib.term.Literal('analyze'),
#  rdflib.term.Literal('announce'),
#  rdflib.term.Literal('answer'),
#  rdflib.term.Literal('anticipate'),
#  rdflib.term.Literal('apologize'),
#  rdflib.term.Literal('appear'),
#  rdflib.term.Literal('apply'),
#  rdflib.term.Literal('appreciate'),
#  rdflib.term.Literal('approach'),
#  rdflib.term.Literal('approve'),
#  rdflib.term.Literal('arrive'),
#  rdflib.term.Literal('ask'),
#  rdflib.term.Literal('assemble'),
#  rdflib.term.Literal('assist'),
#  rdflib.term.Literal('assume'),
#  rdflib.term.Literal('attach'),
#  rdflib.term.Literal('attempt'),
#  rdflib.term.Literal('attend'),
#  rdflib.term.Literal('authorize'),
#  rdflib.term.Literal('base'),
#  rdflib.term.Literal('be'),
#  rdflib.term.Literal('become'),
#  rdflib.term.Literal('begin'),
#  rdflib.term.Literal('book'),
#  rdflib.term.Literal('borrow'),
#  rdflib.term.Literal('bring'),
#  rdflib.term.Literal('build'),
#  rdflib.term.Literal('buy'),
#  rdflib.term.Literal('call'),
#  rdflib.term.Literal('cancel'),
#  rdflib.term.Literal('cash'),
#  rdflib.term.Literal('cast'),
#  rdflib.term.Literal('change'),
#  rdflib.term.Literal('check'),
#  rdflib.term.Literal('chip'),
#  rdflib.term.Literal('cite'),
#  rdflib.term.Literal('clean'),
#  rdflib.term.Literal('click'),
#  rdflib.term.Literal('collect'),
#  rdflib.term.Literal('come'),
#  rdflib.term.Literal('commit'),
#  rdflib.term.Literal('communicate'),
#  rdflib.term.Literal('compete'),
#  rdflib.term.Literal('complete'),
#  rdflib.term.Literal('conduct'),
#  rdflib.term.Literal('consider'),
#  rdflib.term.Literal('contact'),
#  rdflib.term.Literal('continue'),
#  rdflib.term.Literal('coordinate'),
#  rdflib.term.Literal('copy'),
#  rdflib.term.Literal('crank'),
#  rdflib.term.Literal('create'),
#  rdflib.term.Literal('customize'),
#  rdflib.term.Literal('declare'),
#  rdflib.term.Literal('delete'),
#  rdflib.term.Literal('deliver'),
#  rdflib.term.Literal('deny'),
#  rdflib.term.Literal('depart'),
#  rdflib.term.Literal('develop'),
#  rdflib.term.Literal('direct'),
#  rdflib.term.Literal('disapprove'),
#  rdflib.term.Literal('discontinue'),
#  rdflib.term.Literal('discuss'),
#  rdflib.term.Literal('disturb'),
#  rdflib.term.Literal('do'),
#  rdflib.term.Literal('donate'),
#  rdflib.term.Literal('donot'),
#  rdflib.term.Literal('draw'),
#  rdflib.term.Literal('earn'),
#  rdflib.term.Literal('echo'),
#  rdflib.term.Literal('edit'),
#  rdflib.term.Literal('elect'),
#  rdflib.term.Literal('encounter'),
#  rdflib.term.Literal('encourage'),
#  rdflib.term.Literal('end'),
#  rdflib.term.Literal('enlist'),
#  rdflib.term.Literal('enter'),
#  rdflib.term.Literal('est'),
#  rdflib.term.Literal('examine'),
#  rdflib.term.Literal('expect'),
#  rdflib.term.Literal('experience'),
#  rdflib.term.Literal('extend'),
#  rdflib.term.Literal('eye'),
#  rdflib.term.Literal('facilitate'),
#  rdflib.term.Literal('familiarize'),
#  rdflib.term.Literal('fax'),
#  rdflib.term.Literal('feel'),
#  rdflib.term.Literal('file'),
#  rdflib.term.Literal('fill'),
#  rdflib.term.Literal('finalize'),
#  rdflib.term.Literal('find'),
#  rdflib.term.Literal('flow'),
#  rdflib.term.Literal('focus'),
#  rdflib.term.Literal('fold'),
#  rdflib.term.Literal('force'),
#  rdflib.term.Literal('forget'),
#  rdflib.term.Literal('form'),
#  rdflib.term.Literal('forward'),
#  rdflib.term.Literal('gather'),
#  rdflib.term.Literal('gear'),
#  rdflib.term.Literal('get'),
#  rdflib.term.Literal('go'),
#  rdflib.term.Literal('grant'),
#  rdflib.term.Literal('group'),
#  rdflib.term.Literal('have'),
#  rdflib.term.Literal('hear'),
#  rdflib.term.Literal('hedge'),
#  rdflib.term.Literal('help'),
#  rdflib.term.Literal('hold'),
#  rdflib.term.Literal('hope'),
#  rdflib.term.Literal('host'),
#  rdflib.term.Literal('identify'),
#  rdflib.term.Literal('implement'),
#  rdflib.term.Literal('include'),
#  rdflib.term.Literal('incorporate'),
#  rdflib.term.Literal('increase'),
#  rdflib.term.Literal('inform'),
#  rdflib.term.Literal('initiate'),
#  rdflib.term.Literal('input'),
#  rdflib.term.Literal('instal'),
#  rdflib.term.Literal('institute'),
#  rdflib.term.Literal('integrate'),
#  rdflib.term.Literal('introduce'),
#  rdflib.term.Literal('invite'),
#  rdflib.term.Literal('join'),
#  rdflib.term.Literal('jot'),
#  rdflib.term.Literal('keep'),
#  rdflib.term.Literal('kick'),
#  rdflib.term.Literal('know'),
#  rdflib.term.Literal('label'),
#  rdflib.term.Literal('launch'),
#  rdflib.term.Literal('lead'),
#  rdflib.term.Literal('leave'),
#  rdflib.term.Literal('like'),
#  rdflib.term.Literal('limit'),
#  rdflib.term.Literal('listen'),
#  rdflib.term.Literal('lock'),
#  rdflib.term.Literal('log'),
#  rdflib.term.Literal('look'),
#  rdflib.term.Literal('lose'),
#  rdflib.term.Literal('lower'),
#  rdflib.term.Literal('lp'),
#  rdflib.term.Literal('maintain'),
#  rdflib.term.Literal('make'),
#  rdflib.term.Literal('manage'),
#  rdflib.term.Literal('mark'),
#  rdflib.term.Literal('match'),
#  rdflib.term.Literal('meet'),
#  rdflib.term.Literal('mention'),
#  rdflib.term.Literal('migrate'),
#  rdflib.term.Literal('miss'),
#  rdflib.term.Literal('modify'),
#  rdflib.term.Literal('mojave'),
#  rdflib.term.Literal('move'),
#  rdflib.term.Literal('need'),
#  rdflib.term.Literal('notice'),
#  rdflib.term.Literal('object'),
#  rdflib.term.Literal('offer'),
#  rdflib.term.Literal('open'),
#  rdflib.term.Literal('operate'),
#  rdflib.term.Literal('overcome'),
#  rdflib.term.Literal('owe'),
#  rdflib.term.Literal('own'),
#  rdflib.term.Literal('participate'),
#  rdflib.term.Literal('pay'),
#  rdflib.term.Literal('perform'),
#  rdflib.term.Literal('permit'),
#  rdflib.term.Literal('phase'),
#  rdflib.term.Literal('pick'),
#  rdflib.term.Literal('plan'),
#  rdflib.term.Literal('play'),
#  rdflib.term.Literal('post'),
#  rdflib.term.Literal('prefer'),
#  rdflib.term.Literal('prepare'),
#  rdflib.term.Literal('present'),
#  rdflib.term.Literal('print'),
#  rdflib.term.Literal('prohibit'),
#  rdflib.term.Literal('project'),
#  rdflib.term.Literal('promote'),
#  rdflib.term.Literal('propose'),
#  rdflib.term.Literal('provide'),
#  rdflib.term.Literal('purchase'),
#  rdflib.term.Literal('push'),
#  rdflib.term.Literal('put'),
#  rdflib.term.Literal('rank'),
#  rdflib.term.Literal('reach'),
#  rdflib.term.Literal('reboot'),
#  rdflib.term.Literal('receive'),
#  rdflib.term.Literal('recommend'),
#  rdflib.term.Literal('recruit'),
#  rdflib.term.Literal('register'),
#  rdflib.term.Literal('reiterate'),
#  rdflib.term.Literal('remain'),
#  rdflib.term.Literal('remember'),
#  rdflib.term.Literal('remove'),
#  rdflib.term.Literal('reorganize'),
#  rdflib.term.Literal('replace'),
#  rdflib.term.Literal('request'),
#  rdflib.term.Literal('require'),
#  rdflib.term.Literal('rescue'),
#  rdflib.term.Literal('reserve'),
#  rdflib.term.Literal('reset'),
#  rdflib.term.Literal('respond'),
#  rdflib.term.Literal('retain'),
#  rdflib.term.Literal('review'),
#  rdflib.term.Literal('roll'),
#  rdflib.term.Literal('run'),
#  rdflib.term.Literal('s'),
#  rdflib.term.Literal('save'),
#  rdflib.term.Literal('say'),
#  rdflib.term.Literal('schedule'),
#  rdflib.term.Literal('secure'),
#  rdflib.term.Literal('see'),
#  rdflib.term.Literal('seek'),
#  rdflib.term.Literal('sell'),
#  rdflib.term.Literal('send'),
#  rdflib.term.Literal('serve'),
#  rdflib.term.Literal('set'),
#  rdflib.term.Literal('showcase'),
#  rdflib.term.Literal('sign'),
#  rdflib.term.Literal('snag'),
#  rdflib.term.Literal('speak'),
#  rdflib.term.Literal('spend'),
#  rdflib.term.Literal('sponsor'),
#  rdflib.term.Literal('spread'),
#  rdflib.term.Literal('start'),
#  rdflib.term.Literal('state'),
#  rdflib.term.Literal('store'),
#  rdflib.term.Literal('strive'),
#  rdflib.term.Literal('submit'),
#  rdflib.term.Literal('subsidize'),
#  rdflib.term.Literal('sue'),
#  rdflib.term.Literal('support'),
#  rdflib.term.Literal('take'),
#  rdflib.term.Literal('talk'),
#  rdflib.term.Literal('tell'),
#  rdflib.term.Literal('test'),
#  rdflib.term.Literal('think'),
#  rdflib.term.Literal('track'),
#  rdflib.term.Literal('turn'),
#  rdflib.term.Literal('underscore'),
#  rdflib.term.Literal('understand'),
#  rdflib.term.Literal('uninstall'),
#  rdflib.term.Literal('up'),
#  rdflib.term.Literal('update'),
#  rdflib.term.Literal('use'),
#  rdflib.term.Literal('utilize'),
#  rdflib.term.Literal('visit'),
#  rdflib.term.Literal('want'),
#  rdflib.term.Literal('watch'),
#  rdflib.term.Literal('wear'),
#  rdflib.term.Literal('welcome'),
#  rdflib.term.Literal('will'),
#  rdflib.term.Literal('win'),
#  rdflib.term.Literal('wish'),
#  rdflib.term.Literal('work')}

# %%
qres = g.query('SELECT ?s ?o WHERE { ?s ?p ?o . }', initBindings = {'p' : Literal('remove')})

for row in qres:
    print("%s -> %s" % row)
# Out:
# david.badura@enron.com -> category
# lorna.brennan@enron.com -> amount

# %%
msg_key_idx
# Out:
# {(rdflib.term.Literal("'hitschel@enron.com"),
#   rdflib.term.Literal('think'),
#   rdflib.term.Literal('itinerary')): [15205],
#  (rdflib.term.Literal("'s"),
#   rdflib.term.Literal('do'),
#   rdflib.term.Literal('show')): [15172],
#  (rdflib.term.Literal("'s"),
#   rdflib.term.Literal('schedule'),
#   rdflib.term.Literal('marketer')): [15084],
#  (rdflib.term.Literal('ALJ'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('consideration')): [15304],
#  (rdflib.term.Literal('ALJ'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('resolution')): [15304],
#  (rdflib.term.Literal('Administration'),
#   rdflib.term.Literal('project'),
#   rdflib.term.Literal('gas price')): [15385],
#  (rdflib.term.Literal('Administration'),
#   rdflib.term.Literal('project'),
#   rdflib.term.Literal('wellhead')): [15385],
#  (rdflib.term.Literal('Alliance'),
#   rdflib.term.Literal('flow'),
#   rdflib.term.Literal('amount')): [15342],
#  (rdflib.term.Literal('Alliance'),
#   rdflib.term.Literal('flow'),
#   rdflib.term.Literal('market')): [15342],
#  (rdflib.term.Literal('Alliance'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('delay date')): [15460],
#  (rdflib.term.Literal('Alliance'),
#   rdflib.term.Literal('increase'),
#   rdflib.term.Literal('gas')): [15355],
#  (rdflib.term.Literal('Allot'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('feel effect')): [15046],
#  (rdflib.term.Literal('America'),
#   rdflib.term.Literal('offer'),
#   rdflib.term.Literal('17th')): [15335],
#  (rdflib.term.Literal('America'),
#   rdflib.term.Literal('offer'),
#   rdflib.term.Literal('training class')): [15335],
#  (rdflib.term.Literal('Amoco'),
#   rdflib.term.Literal('change'),
#   rdflib.term.Literal('name')): [15434],
#  (rdflib.term.Literal('Analysis'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('basis differential')): [15013],
#  (rdflib.term.Literal('Apollo'),
#   rdflib.term.Literal('conduct'),
#   rdflib.term.Literal('ap')): [15024, 15346],
#  (rdflib.term.Literal('Apollo'),
#   rdflib.term.Literal('conduct'),
#   rdflib.term.Literal('implementation')): [15024, 15046, 15346],
#  (rdflib.term.Literal('Aquila'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('transport right')): [15428],
#  (rdflib.term.Literal('Armstrong'),
#   rdflib.term.Literal('coordinate'),
#   rdflib.term.Literal('trip')): [15446],
#  (rdflib.term.Literal('Award'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('program')): [15495],
#  (rdflib.term.Literal('BP'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('concern')): [15303],
#  (rdflib.term.Literal('Ballet'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('need')): [15268],
#  (rdflib.term.Literal('Bechtel'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('leader')): [15327],
#  (rdflib.term.Literal('Bechtel'),
#   rdflib.term.Literal('fold'),
#   rdflib.term.Literal('business')): [15327],
#  (rdflib.term.Literal('Bechtel'),
#   rdflib.term.Literal('fold'),
#   rdflib.term.Literal('intergen')): [15327],
#  (rdflib.term.Literal('Bechtel'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('deal')): [15327],
#  (rdflib.term.Literal('Bechtel'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('payment')): [15327],
#  (rdflib.term.Literal('Bechtel'),
#   rdflib.term.Literal('own'),
#   rdflib.term.Literal('%')): [15327],
#  (rdflib.term.Literal('Below'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('copy')): [15059],
#  (rdflib.term.Literal('Below'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('detail')): [15371],
#  (rdflib.term.Literal('Brunch'),
#   rdflib.term.Literal('start'),
#   rdflib.term.Literal('10:30am')): [15283],
#  (rdflib.term.Literal('Burlington'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('mmbtu')): [15456],
#  (rdflib.term.Literal('Burlington'),
#   rdflib.term.Literal('schedule'),
#   rdflib.term.Literal('conference call')): [15210],
#  (rdflib.term.Literal('Bus'),
#   rdflib.term.Literal('depart'),
#   rdflib.term.Literal('a.m.')): [15283],
#  (rdflib.term.Literal('Bus'),
#   rdflib.term.Literal('depart'),
#   rdflib.term.Literal('building')): [15283],
#  (rdflib.term.Literal('CPUC'),
#   rdflib.term.Literal('tell'),
#   rdflib.term.Literal('ferc')): [15407],
#  (rdflib.term.Literal('Cafe'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('grinch')): [15382],
#  (rdflib.term.Literal('Campaign'),
#   rdflib.term.Literal('draw'),
#   rdflib.term.Literal('close')): [15440],
#  (rdflib.term.Literal('Cedar'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('signature')): [15457],
#  (rdflib.term.Literal('Center'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('operation')): [15405],
#  (rdflib.term.Literal('Center'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('step')): [15057],
#  (rdflib.term.Literal('Centilli'),
#   rdflib.term.Literal('run'),
#   rdflib.term.Literal('economic')): [15151],
#  (rdflib.term.Literal('Central'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('training session')): [15077],
#  (rdflib.term.Literal('Centrica'),
#   rdflib.term.Literal('eye'),
#   rdflib.term.Literal('candidate')): [15329],
#  (rdflib.term.Literal('Centrica'),
#   rdflib.term.Literal('eye'),
#   rdflib.term.Literal('energy')): [15329],
#  (rdflib.term.Literal('Centrica'),
#   rdflib.term.Literal('tell'),
#   rdflib.term.Literal('newspaper')): [15329],
#  (rdflib.term.Literal('Chairman'),
#   rdflib.term.Literal('conduct'),
#   rdflib.term.Literal('session')): [15462],
#  (rdflib.term.Literal('Chairman'),
#   rdflib.term.Literal('speak'),
#   rdflib.term.Literal('lunch')): [15310],
#  (rdflib.term.Literal('Chevron'),
#   rdflib.term.Literal('retain'),
#   rdflib.term.Literal('share')): [15347],
#  (rdflib.term.Literal('ChevronTexaco'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('producer')): [15347],
#  (rdflib.term.Literal('ChevronTexaco'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('production')): [15347],
#  (rdflib.term.Literal('Chicago'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('market')): [15355],
#  (rdflib.term.Literal('Children'),
#   rdflib.term.Literal('develop'),
#   rdflib.term.Literal('skill')): [15268],
#  (rdflib.term.Literal('Cliff'),
#   rdflib.term.Literal('focus'),
#   rdflib.term.Literal('repositioning')): [15465],
#  (rdflib.term.Literal('Cliff'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('enron')): [15465],
#  (rdflib.term.Literal('Club'),
#   rdflib.term.Literal('collect'),
#   rdflib.term.Literal('month')): [15480],
#  (rdflib.term.Literal('Club'),
#   rdflib.term.Literal('collect'),
#   rdflib.term.Literal('t shirt')): [15480],
#  (rdflib.term.Literal('Clyde'),
#   rdflib.term.Literal('answer'),
#   rdflib.term.Literal('event')): [15450],
#  (rdflib.term.Literal('Clyde'),
#   rdflib.term.Literal('conduct'),
#   rdflib.term.Literal('session')): [15450],
#  (rdflib.term.Literal('Code'),
#   rdflib.term.Literal('prohibit'),
#   rdflib.term.Literal('sharing')): [15384],
#  (rdflib.term.Literal('Commission'),
#   rdflib.term.Literal('authorize'),
#   rdflib.term.Literal('gas')): [15281],
#  (rdflib.term.Literal('Commission'),
#   rdflib.term.Literal('grant'),
#   rdflib.term.Literal('determination')): [15281],
#  (rdflib.term.Literal('Commission'),
#   rdflib.term.Literal('launch'),
#   rdflib.term.Literal('offensive')): [15407],
#  (rdflib.term.Literal('Commission'),
#   rdflib.term.Literal('require'),
#   rdflib.term.Literal('transco')): [15281],
#  (rdflib.term.Literal('Company'),
#   rdflib.term.Literal('deliver'),
#   rdflib.term.Literal('response')): [15304],
#  (rdflib.term.Literal('Company'),
#   rdflib.term.Literal('object'),
#   rdflib.term.Literal('provision')): [15304],
#  (rdflib.term.Literal('Computers'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('property')): [15021, 15416],
#  (rdflib.term.Literal('Conduct'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('employee')): [15490],
#  (rdflib.term.Literal('Contract'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('7th')): [15463],
#  (rdflib.term.Literal('Cookies'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('sale')): [15364],
#  (rdflib.term.Literal('Coop'),
#   rdflib.term.Literal('owe'),
#   rdflib.term.Literal('tw')): [15479],
#  (rdflib.term.Literal('Coral'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('marketer')): [15327],
#  (rdflib.term.Literal('Coral'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('d')): [15327],
#  (rdflib.term.Literal('Coral'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('gas supply')): [15327],
#  (rdflib.term.Literal('Coral'),
#   rdflib.term.Literal('participate'),
#   rdflib.term.Literal('business partner')): [15327],
#  (rdflib.term.Literal('Coral'),
#   rdflib.term.Literal('participate'),
#   rdflib.term.Literal('part')): [15327],
#  (rdflib.term.Literal('Corman'),
#   rdflib.term.Literal('assume'),
#   rdflib.term.Literal('responsibility')): [15286],
#  (rdflib.term.Literal('Corp.'),
#   rdflib.term.Literal('sell'),
#   rdflib.term.Literal('% stake')): [15428],
#  (rdflib.term.Literal('Customers'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('maximum')): [15304],
#  (rdflib.term.Literal('Dan'),
#   rdflib.term.Literal('conduct'),
#   rdflib.term.Literal('session')): [15498],
#  (rdflib.term.Literal('Dashboard'),
#   rdflib.term.Literal('appear'),
#   rdflib.term.Literal('default')): [15074],
#  (rdflib.term.Literal('Dave'),
#   rdflib.term.Literal('say'),
#   rdflib.term.Literal('thank')): [15256],
#  (rdflib.term.Literal('Dec'),
#   rdflib.term.Literal('meet'),
#   rdflib.term.Literal('rep')): [15434],
#  (rdflib.term.Literal('Dec'),
#   rdflib.term.Literal('retain'),
#   rdflib.term.Literal('rate')): [15434],
#  (rdflib.term.Literal('December'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('retention cost')): [15271],
#  (rdflib.term.Literal('Difference'),
#   rdflib.term.Literal('mojave'),
#   rdflib.term.Literal('tw')): [15231],
#  (rdflib.term.Literal('Duke'),
#   rdflib.term.Literal('move'),
#   rdflib.term.Literal('mmbtu')): [15265],
#  (rdflib.term.Literal('Duke'),
#   rdflib.term.Literal('move'),
#   rdflib.term.Literal('rate')): [15265],
#  (rdflib.term.Literal('Duke'),
#   rdflib.term.Literal('move'),
#   rdflib.term.Literal('west')): [15265],
#  (rdflib.term.Literal('Dynegy'),
#   rdflib.term.Literal('echo'),
#   rdflib.term.Literal('concern')): [15303],
#  (rdflib.term.Literal('Dynegy'),
#   rdflib.term.Literal('reiterate'),
#   rdflib.term.Literal('suggestion')): [15303],
#  (rdflib.term.Literal('ENA'),
#   rdflib.term.Literal('meet'),
#   rdflib.term.Literal('owner')): [15397],
#  (rdflib.term.Literal('ENA'),
#   rdflib.term.Literal('meet'),
#   rdflib.term.Literal('region')): [15397],
#  (rdflib.term.Literal('ENA'),
#   rdflib.term.Literal('owe'),
#   rdflib.term.Literal('money')): [15125],
#  (rdflib.term.Literal('EP'),
#   rdflib.term.Literal('go'),
#   rdflib.term.Literal('end')): [15434],
#  (rdflib.term.Literal('EP'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('adjustment')): [15434],
#  (rdflib.term.Literal('EP'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('language')): [15434],
#  (rdflib.term.Literal('EPFS'),
#   rdflib.term.Literal('commit'),
#   rdflib.term.Literal('flow supply')): [15434],
#  (rdflib.term.Literal('EPFS'),
#   rdflib.term.Literal('pay'),
#   rdflib.term.Literal('cost')): [15434],
#  (rdflib.term.Literal('ETS'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('duck')): [15442],
#  (rdflib.term.Literal('Employees'),
#   rdflib.term.Literal('elect'),
#   rdflib.term.Literal('uhc')): [15409],
#  (rdflib.term.Literal('Employees'),
#   rdflib.term.Literal('participate'),
#   rdflib.term.Literal('benefit')): [15301, 15409],
#  (rdflib.term.Literal('Employees'),
#   rdflib.term.Literal('pay'),
#   rdflib.term.Literal('management')): [15046],
#  (rdflib.term.Literal('Employees'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('conduct research')): [15015],
#  (rdflib.term.Literal('Employees'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('web site')): [15015],
#  (rdflib.term.Literal('Energy'),
#   rdflib.term.Literal('expect'),
#   rdflib.term.Literal('close transaction')): [15437],
#  (rdflib.term.Literal('Energy'),
#   rdflib.term.Literal('own'),
#   rdflib.term.Literal('% stake')): [15329],
#  (rdflib.term.Literal('Engbrock'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('information')): [15309],
#  (rdflib.term.Literal('Engbrock'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('term')): [15309],
#  (rdflib.term.Literal('England'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('price')): [15271],
#  (rdflib.term.Literal('Enogex'),
#   rdflib.term.Literal('sell'),
#   rdflib.term.Literal('line')): [15311],
#  (rdflib.term.Literal('Enogex'),
#   rdflib.term.Literal('sell'),
#   rdflib.term.Literal('piedmont')): [15311],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('acquire'),
#   rdflib.term.Literal('plc')): [15316],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('agree'),
#   rdflib.term.Literal('cover half')): [15270],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('authorize'),
#   rdflib.term.Literal('process claim')): [15301],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('authorize'),
#   rdflib.term.Literal('uhc')): [15301],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('place')): [15411],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('process')): [15069],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('trade cow')): [15198],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('build'),
#   rdflib.term.Literal('orientation')): [15245, 15255],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('create'),
#   rdflib.term.Literal('business')): [15411],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('do'),
#   rdflib.term.Literal('business')): [15403],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('enlist'),
#   rdflib.term.Literal('cooperation')): [15403],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('day')): [15283],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('host'),
#   rdflib.term.Literal('kid')): [15480],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('business')): [15391],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('tion')): [15391],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('match'),
#   rdflib.term.Literal('contribution dollar')): [15374],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('match'),
#   rdflib.term.Literal('dollar')): [15374],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('phase'),
#   rdflib.term.Literal('reporti')): [15077],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('print'),
#   rdflib.term.Literal('newsletter')): [15299],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('rescue'),
#   rdflib.term.Literal('panda')): [15401],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('snag'),
#   rdflib.term.Literal('award')): [15341],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('start'),
#   rdflib.term.Literal('commodity market')): [15316],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('subsidize'),
#   rdflib.term.Literal('%')): [15480],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('subsidize'),
#   rdflib.term.Literal('half')): [15480],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('support'),
#   rdflib.term.Literal('work environment')): [15021, 15416],
#  (rdflib.term.Literal('Enron'),
#   rdflib.term.Literal('win'),
#   rdflib.term.Literal('award')): [15442],
#  (rdflib.term.Literal('Eprime'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('agreement')): [15456],
#  (rdflib.term.Literal('Explorer'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('session')): [15015],
#  (rdflib.term.Literal('FERC'),
#   rdflib.term.Literal('deny'),
#   rdflib.term.Literal('request')): [15281],
#  (rdflib.term.Literal('FERC'),
#   rdflib.term.Literal('depart'),
#   rdflib.term.Literal('policy')): [15336],
#  (rdflib.term.Literal('FERC'),
#   rdflib.term.Literal('require'),
#   rdflib.term.Literal('tw')): [15303],
#  (rdflib.term.Literal('FERC'),
#   rdflib.term.Literal('schedule'),
#   rdflib.term.Literal('conference')): [15265],
#  (rdflib.term.Literal('Federation'),
#   rdflib.term.Literal('recruit'),
#   rdflib.term.Literal('volunteer')): [15268],
#  (rdflib.term.Literal('Fitch'),
#   rdflib.term.Literal('cite'),
#   rdflib.term.Literal('need')): [15295],
#  (rdflib.term.Literal('Fitch'),
#   rdflib.term.Literal('state'),
#   rdflib.term.Literal('announcement')): [15295],
#  (rdflib.term.Literal('Foundation'),
#   rdflib.term.Literal('seek'),
#   rdflib.term.Literal('walker')): [15480],
#  (rdflib.term.Literal('Furniture'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('offer')): [15361],
#  (rdflib.term.Literal('GPG'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('gather information')): [15002],
#  (rdflib.term.Literal('Gala'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('volunteer')): [15366],
#  (rdflib.term.Literal('Gardens'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('community')): [15366],
#  (rdflib.term.Literal('Gary'),
#   rdflib.term.Literal('assume'),
#   rdflib.term.Literal('resource responsibility')): [15286],
#  (rdflib.term.Literal('Gary'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('president')): [15286, 15286],
#  (rdflib.term.Literal('Gary'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('year')): [15286],
#  (rdflib.term.Literal('Gas'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('supply contract')): [15475],
#  (rdflib.term.Literal('Gas'),
#   rdflib.term.Literal('institute'),
#   rdflib.term.Literal('balancing requirement')): [15475],
#  (rdflib.term.Literal('Gas'),
#   rdflib.term.Literal('play'),
#   rdflib.term.Literal('storage game')): [15475],
#  (rdflib.term.Literal('Generators'),
#   rdflib.term.Literal('post'),
#   rdflib.term.Literal('am')): [15438],
#  (rdflib.term.Literal('Gish'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('service')): [15460],
#  (rdflib.term.Literal('Glassberg'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('butterfly')): [15495],
#  (rdflib.term.Literal('Group'),
#   rdflib.term.Literal('buy'),
#   rdflib.term.Literal('property')): [15437],
#  (rdflib.term.Literal('Harris'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('extend invitation')): [15424],
#  (rdflib.term.Literal('Harry'),
#   rdflib.term.Literal('answer'),
#   rdflib.term.Literal('question')): [15322],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('base'),
#   rdflib.term.Literal('recommendation')): [15293],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('bachelor')): [15420],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('inform'),
#   rdflib.term.Literal('activity')): [15495],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('label'),
#   rdflib.term.Literal('power')): [15293],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('s'),
#   rdflib.term.Literal('value')): [15391],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('temperature')): [15375],
#  (rdflib.term.Literal('He'),
#   rdflib.term.Literal('start'),
#   rdflib.term.Literal('business')): [15391],
#  (rdflib.term.Literal('HealthCare'),
#   rdflib.term.Literal('reach'),
#   rdflib.term.Literal('agreement')): [15409],
#  (rdflib.term.Literal('Help'),
#   rdflib.term.Literal('put'),
#   rdflib.term.Literal('knapsack')): [15382],
#  (rdflib.term.Literal('Hermann'),
#   rdflib.term.Literal('cancel'),
#   rdflib.term.Literal('contract')): [15301],
#  (rdflib.term.Literal('Hirko'),
#   rdflib.term.Literal('accomplish'),
#   rdflib.term.Literal('thing')): [15391],
#  (rdflib.term.Literal('Horton'),
#   rdflib.term.Literal('open'),
#   rdflib.term.Literal('class')): [15269],
#  (rdflib.term.Literal('Horton'),
#   rdflib.term.Literal('open'),
#   rdflib.term.Literal('remark')): [15269],
#  (rdflib.term.Literal('Houston'),
#   rdflib.term.Literal('rank'),
#   rdflib.term.Literal('survey')): [15248],
#  (rdflib.term.Literal('Husband'),
#   rdflib.term.Literal('uninstall'),
#   rdflib.term.Literal('program')): [15119],
#  (rdflib.term.Literal('Hyatt'),
#   rdflib.term.Literal('attend'),
#   rdflib.term.Literal('weather derivative')): [15375],
#  (rdflib.term.Literal('I'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('contribute fund')): [15277],
#  (rdflib.term.Literal('ID'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('id')): [15063],
#  (rdflib.term.Literal('II'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('dth')): [15281],
#  (rdflib.term.Literal('II'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('ndow')): [15002],
#  (rdflib.term.Literal('ISC'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('organization')): [15009],
#  (rdflib.term.Literal('ISC'),
#   rdflib.term.Literal('launch'),
#   rdflib.term.Literal('order')): [15009],
#  (rdflib.term.Literal('ISC'),
#   rdflib.term.Literal('launch'),
#   rdflib.term.Literal('website')): [15009],
#  (rdflib.term.Literal('Ignacio'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('million')): [15132],
#  (rdflib.term.Literal('Imbalance'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('level')): [15162],
#  (rdflib.term.Literal('InterGen'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('developer')): [15327],
#  (rdflib.term.Literal('InterGen'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('majority')): [15327],
#  (rdflib.term.Literal('InterGen'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('% stake')): [15327],
#  (rdflib.term.Literal('InterGen'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('plan')): [15327],
#  (rdflib.term.Literal('Interruptions'),
#   rdflib.term.Literal('modify'),
#   rdflib.term.Literal('configuration')): [15054],
#  (rdflib.term.Literal('Interruptions'),
#   rdflib.term.Literal('modify'),
#   rdflib.term.Literal('hardware setting')): [15054],
#  (rdflib.term.Literal('Interruptions'),
#   rdflib.term.Literal('modify'),
#   rdflib.term.Literal('network setting')): [15054],
#  (rdflib.term.Literal('Invoice'),
#   rdflib.term.Literal('accommodate'),
#   rdflib.term.Literal('code')): [15464],
#  (rdflib.term.Literal('Jan'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('position')): [15377],
#  (rdflib.term.Literal('Jean'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('netscape')): [15049],
#  (rdflib.term.Literal('Jean'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('user')): [15049],
#  (rdflib.term.Literal('Jenkins'),
#   rdflib.term.Literal('present'),
#   rdflib.term.Literal('check')): [15387],
#  (rdflib.term.Literal('Jenkins'),
#   rdflib.term.Literal('present'),
#   rdflib.term.Literal('team')): [15387],
#  (rdflib.term.Literal('Joy'),
#   rdflib.term.Literal('promote'),
#   rdflib.term.Literal('need')): [15366],
#  (rdflib.term.Literal('Juan'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('widening')): [15271],
#  (rdflib.term.Literal('Ken'),
#   rdflib.term.Literal('assume'),
#   rdflib.term.Literal('role')): [15391],
#  (rdflib.term.Literal('Ken'),
#   rdflib.term.Literal('wear'),
#   rdflib.term.Literal('costume')): [15401],
#  (rdflib.term.Literal('Lay'),
#   rdflib.term.Literal('answer'),
#   rdflib.term.Literal('event')): [15462],
#  (rdflib.term.Literal('Leader'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('point')): [15017],
#  (rdflib.term.Literal('Leader'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('t')): [15017],
#  (rdflib.term.Literal('Legal'),
#   rdflib.term.Literal('check'),
#   rdflib.term.Literal('row')): [15397],
#  (rdflib.term.Literal('Lobby'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('audience')): [15366],
#  (rdflib.term.Literal('Lokay'),
#   rdflib.term.Literal('find'),
#   rdflib.term.Literal('name')): [15408],
#  (rdflib.term.Literal('Lokay'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('time')): [15252],
#  (rdflib.term.Literal('Lokay'),
#   rdflib.term.Literal('review'),
#   rdflib.term.Literal('index price')): [15008],
#  (rdflib.term.Literal('M.L.'),
#   rdflib.term.Literal('run'),
#   rdflib.term.Literal('reserve')): [15281],
#  (rdflib.term.Literal('MMBtu'),
#   rdflib.term.Literal('compete'),
#   rdflib.term.Literal('capacity')): [15271],
#  (rdflib.term.Literal('Maintenance'),
#   rdflib.term.Literal('perform'),
#   rdflib.term.Literal('battery')): [15054],
#  (rdflib.term.Literal('Maintenance'),
#   rdflib.term.Literal('perform'),
#   rdflib.term.Literal('maintenance')): [15054],
#  (rdflib.term.Literal('Management'),
#   rdflib.term.Literal('conduct'),
#   rdflib.term.Literal('audits')): [15490],
#  (rdflib.term.Literal('Marketing'),
#   rdflib.term.Literal('approve'),
#   rdflib.term.Literal('addition')): [15383],
#  (rdflib.term.Literal('Marketing'),
#   rdflib.term.Literal('approve'),
#   rdflib.term.Literal('point')): [15383],
#  (rdflib.term.Literal('Martin'),
#   rdflib.term.Literal('become'),
#   rdflib.term.Literal('president')): [15244],
#  (rdflib.term.Literal('Measurement'),
#   rdflib.term.Literal('analyze'),
#   rdflib.term.Literal('model')): [15485],
#  (rdflib.term.Literal('Merchants'),
#   rdflib.term.Literal('showcase'),
#   rdflib.term.Literal('row')): [15364, 15364, 15374, 15374],
#  (rdflib.term.Literal('Mexico'),
#   rdflib.term.Literal('force'),
#   rdflib.term.Literal('blow mainline')): [15265],
#  (rdflib.term.Literal('Mexico'),
#   rdflib.term.Literal('force'),
#   rdflib.term.Literal('operations')): [15265],
#  (rdflib.term.Literal('Michelle'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('evaluate ride')): [15287, 15287],
#  (rdflib.term.Literal('Mike'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('measure')): [15130],
#  (rdflib.term.Literal('Mike'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('spreadsheet')): [15159],
#  (rdflib.term.Literal('Mirant'),
#   rdflib.term.Literal('integrate'),
#   rdflib.term.Literal('profile')): [15157],
#  (rdflib.term.Literal('Mirant'),
#   rdflib.term.Literal('integrate'),
#   rdflib.term.Literal('weather risk')): [15157],
#  (rdflib.term.Literal('Moore'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('team')): [15377],
#  (rdflib.term.Literal('Myers'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('management team')): [15379],
#  (rdflib.term.Literal('NOVA'),
#   rdflib.term.Literal('change'),
#   rdflib.term.Literal('%')): [15392],
#  (rdflib.term.Literal('NW'),
#   rdflib.term.Literal('run'),
#   rdflib.term.Literal('time')): [15355],
#  (rdflib.term.Literal('Needles'),
#   rdflib.term.Literal('spread'),
#   rdflib.term.Literal('spread')): [15473],
#  (rdflib.term.Literal('Nelson'),
#   rdflib.term.Literal('host'),
#   rdflib.term.Literal('event')): [15487],
#  (rdflib.term.Literal('Northwest'),
#   rdflib.term.Literal('announce'),
#   rdflib.term.Literal('revision')): [15432],
#  (rdflib.term.Literal('November'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('warm')): [15271],
#  (rdflib.term.Literal("O'Neill"),
#   rdflib.term.Literal('coordinate'),
#   rdflib.term.Literal('plane schedule')): [15446],
#  (rdflib.term.Literal('Oak'),
#   rdflib.term.Literal('donate'),
#   rdflib.term.Literal('percentage')): [15374],
#  (rdflib.term.Literal('Oasis'),
#   rdflib.term.Literal('complete'),
#   rdflib.term.Literal('upgrade')): [15428],
#  (rdflib.term.Literal('October'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('chapter')): [15480],
#  (rdflib.term.Literal('Office'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('what say')): [15322],
#  (rdflib.term.Literal('Office'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('outline change')): [15379],
#  (rdflib.term.Literal('Option'),
#   rdflib.term.Literal('call'),
#   rdflib.term.Literal('capacity')): [15463],
#  (rdflib.term.Literal('Ours'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('company')): [15245, 15255],
#  (rdflib.term.Literal('Outlook'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('client')): [15048],
#  (rdflib.term.Literal('Outlook'),
#   rdflib.term.Literal('integrate'),
#   rdflib.term.Literal('system')): [15048],
#  (rdflib.term.Literal('PG&E'),
#   rdflib.term.Literal('overcome'),
#   rdflib.term.Literal('roadblock')): [15437],
#  (rdflib.term.Literal('PG&E'),
#   rdflib.term.Literal('pay'),
#   rdflib.term.Literal('price')): [15437],
#  (rdflib.term.Literal('PG&E'),
#   rdflib.term.Literal('purchase'),
#   rdflib.term.Literal('property')): [15437],
#  (rdflib.term.Literal('Paintings'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('lover')): [15374],
#  (rdflib.term.Literal('Paso'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('player')): [15437],
#  (rdflib.term.Literal('Paso'),
#   rdflib.term.Literal('declare'),
#   rdflib.term.Literal('situation')): [15392],
#  (rdflib.term.Literal('Paso'),
#   rdflib.term.Literal('encourage'),
#   rdflib.term.Literal('interest')): [15426],
#  (rdflib.term.Literal('Paso'),
#   rdflib.term.Literal('expect'),
#   rdflib.term.Literal('manage risk')): [15437],
#  (rdflib.term.Literal('Paso'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('finalize agreement')): [15437],
#  (rdflib.term.Literal('Payable'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('help desk')): [15384],
#  (rdflib.term.Literal('Payables'),
#   rdflib.term.Literal('input'),
#   rdflib.term.Literal('invoice')): [15004, 15285],
#  (rdflib.term.Literal('Payables'),
#   rdflib.term.Literal('input'),
#   rdflib.term.Literal('system')): [15004, 15285],
#  (rdflib.term.Literal('PerkCard'),
#   rdflib.term.Literal('offer'),
#   rdflib.term.Literal('discount')): [15268],
#  (rdflib.term.Literal('Pipeline'),
#   rdflib.term.Literal('come'),
#   rdflib.term.Literal('line')): [15385],
#  (rdflib.term.Literal('Pipeline'),
#   rdflib.term.Literal('extend'),
#   rdflib.term.Literal('delay')): [15460],
#  (rdflib.term.Literal('Pipeline'),
#   rdflib.term.Literal('institute'),
#   rdflib.term.Literal('ofo')): [15475],
#  (rdflib.term.Literal('Power'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('buy')): [15293],
#  (rdflib.term.Literal('Price'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('markets')): [15379],
#  (rdflib.term.Literal('Proceeds'),
#   rdflib.term.Literal('go'),
#   rdflib.term.Literal('line')): [15303],
#  (rdflib.term.Literal('Process'),
#   rdflib.term.Literal('lose'),
#   rdflib.term.Literal('mail message')): [15059],
#  (rdflib.term.Literal('Products'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('addition')): [15406],
#  (rdflib.term.Literal('Products'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('right')): [15406],
#  (rdflib.term.Literal('Program'),
#   rdflib.term.Literal('adopt'),
#   rdflib.term.Literal('agency')): [15332],
#  (rdflib.term.Literal('Project'),
#   rdflib.term.Literal('post'),
#   rdflib.term.Literal('am')): [15281],
#  (rdflib.term.Literal('Project'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('capacity')): [15438],
#  (rdflib.term.Literal('Reports'),
#   rdflib.term.Literal('accommodate'),
#   rdflib.term.Literal('code')): [15464],
#  (rdflib.term.Literal('Representatives'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('answer question')): [15394],
#  (rdflib.term.Literal('Research'),
#   rdflib.term.Literal('launch'),
#   rdflib.term.Literal('product')): [15015],
#  (rdflib.term.Literal('River'),
#   rdflib.term.Literal('cast'),
#   rdflib.term.Literal('expansion')): [15260],
#  (rdflib.term.Literal('River'),
#   rdflib.term.Literal('cast'),
#   rdflib.term.Literal('lot')): [15260],
#  (rdflib.term.Literal('River'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('season')): [15260],
#  (rdflib.term.Literal('River'),
#   rdflib.term.Literal('plan'),
#   rdflib.term.Literal('expansion')): [15438],
#  (rdflib.term.Literal('Road'),
#   rdflib.term.Literal('alleviate'),
#   rdflib.term.Literal('problem')): [15304],
#  (rdflib.term.Literal('SAP'),
#   rdflib.term.Literal('bring'),
#   rdflib.term.Literal('dynamic')): [15024, 15046, 15346],
#  (rdflib.term.Literal('School'),
#   rdflib.term.Literal('lead'),
#   rdflib.term.Literal('lesson')): [15401],
#  (rdflib.term.Literal('Select'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('contact')): [15019],
#  (rdflib.term.Literal('Sempra'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('candidate')): [15329],
#  (rdflib.term.Literal('Services'),
#   rdflib.term.Literal('chip'),
#   rdflib.term.Literal('obstacle')): [15401],
#  (rdflib.term.Literal('Services'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('system')): [15426],
#  (rdflib.term.Literal('Services'),
#   rdflib.term.Literal('will'),
#   rdflib.term.Literal('benefit child')): [15332],
#  (rdflib.term.Literal('Shell'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('one')): [15327],
#  (rdflib.term.Literal('Shell'),
#   rdflib.term.Literal('form'),
#   rdflib.term.Literal('intergen')): [15327],
#  (rdflib.term.Literal('Shelley'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('weekend')): [15209],
#  (rdflib.term.Literal('Skilling'),
#   rdflib.term.Literal('serve'),
#   rdflib.term.Literal('lifeline')): [15487],
#  (rdflib.term.Literal('Skinner'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('responsibility')): [15379],
#  (rdflib.term.Literal('Skinner'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('team')): [15379],
#  (rdflib.term.Literal('Smith'),
#   rdflib.term.Literal('accept'),
#   rdflib.term.Literal('ed')): [15286],
#  (rdflib.term.Literal('Smith'),
#   rdflib.term.Literal('accept'),
#   rdflib.term.Literal('position')): [15286],
#  (rdflib.term.Literal('SoCal'),
#   rdflib.term.Literal('lower'),
#   rdflib.term.Literal('tomorrow')): [15475],
#  (rdflib.term.Literal('SoCal'),
#   rdflib.term.Literal('lower'),
#   rdflib.term.Literal('window')): [15475],
#  (rdflib.term.Literal('SoCalGas'),
#   rdflib.term.Literal('file'),
#   rdflib.term.Literal('letter')): [15304],
#  (rdflib.term.Literal('Stephanie'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('office')): [15457],
#  (rdflib.term.Literal('Steve'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('derivative class')): [15273],
#  (rdflib.term.Literal('Steve'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('month')): [15273],
#  (rdflib.term.Literal('Systems'),
#   rdflib.term.Literal('ask'),
#   rdflib.term.Literal('%')): [15301],
#  (rdflib.term.Literal('TRAINING'),
#   rdflib.term.Literal('go'),
#   rdflib.term.Literal('page')): [15384],
#  (rdflib.term.Literal('TW'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('control meeting')): [15135],
#  (rdflib.term.Literal('TW'),
#   rdflib.term.Literal('open'),
#   rdflib.term.Literal('floor')): [15303],
#  (rdflib.term.Literal('TW'),
#   rdflib.term.Literal('open'),
#   rdflib.term.Literal('question')): [15303],
#  (rdflib.term.Literal('Taylor'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('group')): [15286],
#  (rdflib.term.Literal('Team'),
#   rdflib.term.Literal('work'),
#   rdflib.term.Literal('vendor')): [15045, 15396],
#  (rdflib.term.Literal('Tennessee'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('note')): [15428],
#  (rdflib.term.Literal('Tennessee'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('quarter')): [15428],
#  (rdflib.term.Literal('Texaco'),
#   rdflib.term.Literal('own'),
#   rdflib.term.Literal('%')): [15347],
#  (rdflib.term.Literal('Texans'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('mw')): [15386],
#  (rdflib.term.Literal('Things'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('debacle')): [15230],
#  (rdflib.term.Literal('Tickets'),
#   rdflib.term.Literal('remain'),
#   rdflib.term.Literal('p.m.')): [15366, 15495],
#  (rdflib.term.Literal('Tickets'),
#   rdflib.term.Literal('remain'),
#   rdflib.term.Literal('sale')): [15366, 15495],
#  (rdflib.term.Literal('TransCanada'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('brunt')): [15271],
#  (rdflib.term.Literal('Transco'),
#   rdflib.term.Literal('initiate'),
#   rdflib.term.Literal('domain proceeding')): [15281],
#  (rdflib.term.Literal('Transmission'),
#   rdflib.term.Literal('plan'),
#   rdflib.term.Literal('file application')): [15438],
#  (rdflib.term.Literal('Transportation'),
#   rdflib.term.Literal('sponsor'),
#   rdflib.term.Literal('program')): [15480],
#  (rdflib.term.Literal('Transwestern'),
#   rdflib.term.Literal('attempt'),
#   rdflib.term.Literal('answer question')): [15371],
#  (rdflib.term.Literal('Transwestern'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('workshop')): [15303],
#  (rdflib.term.Literal('Transwestern'),
#   rdflib.term.Literal('seek'),
#   rdflib.term.Literal('assistance')): [15371],
#  (rdflib.term.Literal('Traswestern'),
#   rdflib.term.Literal('clean'),
#   rdflib.term.Literal('line')): [15426],
#  (rdflib.term.Literal('Unit'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('exhibit')): [15394],
#  (rdflib.term.Literal('Varner'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('year')): [15420],
#  (rdflib.term.Literal('Varner'),
#   rdflib.term.Literal('lead'),
#   rdflib.term.Literal('workshop')): [15420],
#  (rdflib.term.Literal('Vector'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('service')): [15271],
#  (rdflib.term.Literal('Vernon'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('tw')): [15496],
#  (rdflib.term.Literal('Vernon'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('update')): [15496],
#  (rdflib.term.Literal('Virginia'),
#   rdflib.term.Literal('continue'),
#   rdflib.term.Literal('coordinate trip')): [15446],
#  (rdflib.term.Literal('Volume'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('production')): [15320],
#  (rdflib.term.Literal('Walk'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('event')): [15480, 15495],
#  (rdflib.term.Literal('Walk'),
#   rdflib.term.Literal('begin'),
#   rdflib.term.Literal('a.m.')): [15364],
#  (rdflib.term.Literal('Weather'),
#   rdflib.term.Literal('permit'),
#   rdflib.term.Literal('area')): [15479],
#  (rdflib.term.Literal('Westcoast'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('% tolerance')): [15392],
#  (rdflib.term.Literal('Western'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('process')): [15426],
#  (rdflib.term.Literal('Western'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('deliver gas')): [15426],
#  (rdflib.term.Literal('Williams'),
#   rdflib.term.Literal('cash'),
#   rdflib.term.Literal('imbalance')): [15143],
#  (rdflib.term.Literal('Williams'),
#   rdflib.term.Literal('declare'),
#   rdflib.term.Literal('force')): [15274],
#  (rdflib.term.Literal('Williams'),
#   rdflib.term.Literal('offer'),
#   rdflib.term.Literal('rate')): [15438],
#  (rdflib.term.Literal('Williams'),
#   rdflib.term.Literal('plan'),
#   rdflib.term.Literal('upgrade station')): [15260],
#  (rdflib.term.Literal('Williams'),
#   rdflib.term.Literal('plan'),
#   rdflib.term.Literal('way')): [15260],
#  (rdflib.term.Literal('WinInstall'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('computer')): [15011, 15030],
#  (rdflib.term.Literal('WinInstall'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('update')): [15011, 15030],
#  (rdflib.term.Literal('WinInstall'),
#   rdflib.term.Literal('run'),
#   rdflib.term.Literal('today')): [15030],
#  (rdflib.term.Literal('Windows'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('system')): [15002],
#  (rdflib.term.Literal('Winter'),
#   rdflib.term.Literal('arrive'),
#   rdflib.term.Literal('earnest')): [15271],
#  (rdflib.term.Literal('Winter'),
#   rdflib.term.Literal('bring'),
#   rdflib.term.Literal('price')): [15271],
#  (rdflib.term.Literal('Winter'),
#   rdflib.term.Literal('bring'),
#   rdflib.term.Literal('rockies')): [15271],
#  (rdflib.term.Literal('Winters'),
#   rdflib.term.Literal('initiate'),
#   rdflib.term.Literal('company')): [15293],
#  (rdflib.term.Literal('Winters'),
#   rdflib.term.Literal('initiate'),
#   rdflib.term.Literal('coverage')): [15293],
#  (rdflib.term.Literal('Work'),
#   rdflib.term.Literal('gear'),
#   rdflib.term.Literal('session')): [15268],
#  (rdflib.term.Literal('advantage'),
#   rdflib.term.Literal('increase'),
#   rdflib.term.Literal('capacity')): [15397],
#  (rdflib.term.Literal('agreement'),
#   rdflib.term.Literal('lock'),
#   rdflib.term.Literal('construction contract')): [15327],
#  (rdflib.term.Literal('all.america@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('business')): [15488],
#  (rdflib.term.Literal('all.america@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('member')): [15488],
#  (rdflib.term.Literal('all.america@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('time')): [15488],
#  (rdflib.term.Literal('all.america@enron.com'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('data ehronline')): [15461],
#  (rdflib.term.Literal('all.america@enron.com'),
#   rdflib.term.Literal('update'),
#   rdflib.term.Literal('datum')): [15351],
#  (rdflib.term.Literal('all.downtown@enron.com'),
#   rdflib.term.Literal('consider'),
#   rdflib.term.Literal('fact')): [15409],
#  (rdflib.term.Literal('all.downtown@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('problem')): [15268],
#  (rdflib.term.Literal('all.downtown@enron.com'),
#   rdflib.term.Literal('win'),
#   rdflib.term.Literal('9th')): [15268],
#  (rdflib.term.Literal('all.downtown@enron.com'),
#   rdflib.term.Literal('win'),
#   rdflib.term.Literal('spot')): [15268],
#  (rdflib.term.Literal('all.employees@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('letter')): [15403],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('access'),
#   rdflib.term.Literal('system')): [15384],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('appreciate'),
#   rdflib.term.Literal('work')): [15480],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('wa')): [15394],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('call'),
#   rdflib.term.Literal('service number')): [15301],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('check'),
#   rdflib.term.Literal('nomination statistic')): [15480],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('do'),
#   rdflib.term.Literal('holiday')): [15374],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('forget'),
#   rdflib.term.Literal('password')): [15384],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('comment')): [15344],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('futures')): [15026],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('opportunity')): [15382],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('power')): [15026],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('question')): [15394],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('what see')): [15344],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('contribution')): [15366, 15495],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('access')): [15384],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('attention')): [15301],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('purchase'),
#   rdflib.term.Literal('seat')): [15480],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('purchase'),
#   rdflib.term.Literal('ticket package')): [15374],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('communication')): [15301],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('decision')): [15301],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('discount')): [15382],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('understand'),
#   rdflib.term.Literal('situation')): [15301],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('visit'),
#   rdflib.term.Literal('table')): [15480],
#  (rdflib.term.Literal('all.houston@enron.com'),
#   rdflib.term.Literal('watch'),
#   rdflib.term.Literal('elevator')): [15344],
#  (rdflib.term.Literal('all.states@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('question')): [15077],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('comment')): [15498],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('location')): [15450, 15462],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('earn'),
#   rdflib.term.Literal('credit')): [15289],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('earn'),
#   rdflib.term.Literal('idea')): [15289],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('find'),
#   rdflib.term.Literal('issue')): [15316],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('account')): [15458],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('fund')): [15458],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('idea')): [15289],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('intelligence')): [15322],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('keep'),
#   rdflib.term.Literal('question')): [15450, 15462],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('make'),
#   rdflib.term.Literal('event')): [15328],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('pay'),
#   rdflib.term.Literal('penalty')): [15458],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('post'),
#   rdflib.term.Literal('question')): [15498],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('mail')): [15251],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('nomination form')): [15251],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('time')): [15445],
#  (rdflib.term.Literal('all.worldwide@enron.com'),
#   rdflib.term.Literal('talk'),
#   rdflib.term.Literal('account')): [15458],
#  (rdflib.term.Literal('all_enron_houston@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('chance')): [15487],
#  (rdflib.term.Literal('analysis'),
#   rdflib.term.Literal('hope'),
#   rdflib.term.Literal('give answer')): [15485],
#  (rdflib.term.Literal('andre.walters@enron.com'),
#   rdflib.term.Literal('access'),
#   rdflib.term.Literal('outlook')): [15066],
#  (rdflib.term.Literal('andre.walters@enron.com'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('action')): [15066],
#  (rdflib.term.Literal('andre.walters@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('store message')): [15066],
#  (rdflib.term.Literal('audrey.robertson@enron.com'),
#   rdflib.term.Literal('discuss'),
#   rdflib.term.Literal('request')): [15022],
#  (rdflib.term.Literal('audrey.robertson@enron.com'),
#   rdflib.term.Literal('forward'),
#   rdflib.term.Literal('box')): [15492],
#  (rdflib.term.Literal('audrey.robertson@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('reflect change')): [15040],
#  (rdflib.term.Literal('audrey.robertson@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('make request')): [15022],
#  (rdflib.term.Literal('audrey.robertson@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('meeting discussion')): [15075, 15339],
#  (rdflib.term.Literal('audrey.robertson@enron.com'),
#   rdflib.term.Literal('move'),
#   rdflib.term.Literal('something')): [15267],
#  (rdflib.term.Literal('audrey.robertson@enron.com'),
#   rdflib.term.Literal('submit'),
#   rdflib.term.Literal('room')): [15359],
#  (rdflib.term.Literal('bob.burleson@enron.com'),
#   rdflib.term.Literal('ammend'),
#   rdflib.term.Literal('agreement')): [15277],
#  (rdflib.term.Literal('bob.burleson@enron.com'),
#   rdflib.term.Literal('spend'),
#   rdflib.term.Literal('money')): [15277],
#  (rdflib.term.Literal('bob.burleson@enron.com'),
#   rdflib.term.Literal('spend'),
#   rdflib.term.Literal('put measurement')): [15277],
#  (rdflib.term.Literal('chris.smith@enron.com'),
#   rdflib.term.Literal('approach'),
#   rdflib.term.Literal('approach')): [15002],
#  (rdflib.term.Literal('chris.smith@enron.com'),
#   rdflib.term.Literal('approach'),
#   rdflib.term.Literal('project')): [15002],
# ...
#   rdflib.term.Literal('document')): [15109],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('question')): [15042, 15280, 15494],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('ticket')): [15172],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('use u')): [15451],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('leave'),
#   rdflib.term.Literal('hour')): [15205],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('receive statement')): [15093, 15196],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('log'),
#   rdflib.term.Literal('system')): [15064],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('look'),
#   rdflib.term.Literal('week')): [15147],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('look'),
#   rdflib.term.Literal('what')): [15200],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('mention'),
#   rdflib.term.Literal('meeting')): [15215],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('move'),
#   rdflib.term.Literal('production')): [15200],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('check')): [15186],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('message')): [15042, 15280, 15494],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('run'),
#   rdflib.term.Literal('report')): [15090],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('run'),
#   rdflib.term.Literal('side')): [15090],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('marketing report')): [15065],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('datum')): [15108],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('sue'),
#   rdflib.term.Literal('distance carrier')): [15190],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('sue'),
#   rdflib.term.Literal('everyone')): [15190],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('day')): [15091, 15105, 15152],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('take'),
#   rdflib.term.Literal('day vacation')): [15175],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('update'),
#   rdflib.term.Literal('accomplishment')): [15129],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('update'),
#   rdflib.term.Literal('name')): [15080],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('update'),
#   rdflib.term.Literal('trading')): [15080],
#  (rdflib.term.Literal('michelle.lokay@enron.com'),
#   rdflib.term.Literal('utilize'),
#   rdflib.term.Literal('system')): [15195],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('email')): [15408],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('pleasure')): [15421],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('buy'),
#   rdflib.term.Literal('house')): [15421],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('find'),
#   rdflib.term.Literal('name')): [15408],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('time')): [15252],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('email')): [15408],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('name')): [15408],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('information')): [15408],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('16th')): [15252],
#  (rdflib.term.Literal('mlokay@enron.com'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('tournament')): [15252],
#  (rdflib.term.Literal('nancy.bastida@enron.com'),
#   rdflib.term.Literal('fax'),
#   rdflib.term.Literal('envision')): [15052],
#  (rdflib.term.Literal('nancy.bastida@enron.com'),
#   rdflib.term.Literal('fax'),
#   rdflib.term.Literal('information')): [15052],
#  (rdflib.term.Literal('nancy.bastida@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('question')): [15052],
#  (rdflib.term.Literal('new.jun-sept@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('forefront')): [15245],
#  (rdflib.term.Literal('new.jun-sept@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('company')): [15245],
#  (rdflib.term.Literal('new.jun-sept@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('growth')): [15245],
#  (rdflib.term.Literal('new.jun-sept@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('time')): [15245],
#  (rdflib.term.Literal('new.jun-sept@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('day')): [15245],
#  (rdflib.term.Literal('new.jun-sept@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('job')): [15245],
#  (rdflib.term.Literal('new.jun-sept@enron.com'),
#   rdflib.term.Literal('understand'),
#   rdflib.term.Literal('breadth')): [15245],
#  (rdflib.term.Literal('new.may-june@enron.com'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('forefront')): [15255],
#  (rdflib.term.Literal('new.may-june@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('company')): [15255],
#  (rdflib.term.Literal('new.may-june@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('growth')): [15255],
#  (rdflib.term.Literal('new.may-june@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('time')): [15255],
#  (rdflib.term.Literal('new.may-june@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('day')): [15255],
#  (rdflib.term.Literal('new.may-june@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('job')): [15255],
#  (rdflib.term.Literal('new.may-june@enron.com'),
#   rdflib.term.Literal('understand'),
#   rdflib.term.Literal('breadth')): [15255],
#  (rdflib.term.Literal('non.employees@enron.com'),
#   rdflib.term.Literal('use'),
#   rdflib.term.Literal('navigator')): [15270],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('add'),
#   rdflib.term.Literal('element')): [15487],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('continue'),
#   rdflib.term.Literal('increase return')): [15465],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('encourage'),
#   rdflib.term.Literal('attend off')): [15487],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('est'),
#   rdflib.term.Literal('stamina')): [15487],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('hope'),
#   rdflib.term.Literal('reach goal')): [15487],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('introduce'),
#   rdflib.term.Literal('t')): [15411],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('invite'),
#   rdflib.term.Literal('attend day')): [15245, 15255],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('kick'),
#   rdflib.term.Literal('campaign')): [15487],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('post'),
#   rdflib.term.Literal('document')): [15411],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('schedule'),
#   rdflib.term.Literal('future')): [15411],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('schedule'),
#   rdflib.term.Literal('session')): [15411],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('sign'),
#   rdflib.term.Literal('agreement')): [15411],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('subsidize'),
#   rdflib.term.Literal('internet connection')): [15411],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('test'),
#   rdflib.term.Literal('curiosity')): [15487],
#  (rdflib.term.Literal('office.chairman@enron.com'),
#   rdflib.term.Literal('test'),
#   rdflib.term.Literal('version')): [15487],
#  (rdflib.term.Literal('operators'),
#   rdflib.term.Literal('operate'),
#   rdflib.term.Literal('pipeline')): [15342],
#  (rdflib.term.Literal('pcervin@br-inc.com'),
#   rdflib.term.Literal('send'),
#   rdflib.term.Literal('representative')): [15371],
#  (rdflib.term.Literal('pipeline'),
#   rdflib.term.Literal('limit'),
#   rdflib.term.Literal('volume')): [15392],
#  (rdflib.term.Literal('public.relations@enron.com'),
#   rdflib.term.Literal('receive'),
#   rdflib.term.Literal('entry')): [15316],
#  (rdflib.term.Literal('public.relations@enron.com'),
#   rdflib.term.Literal('up'),
#   rdflib.term.Literal('addition')): [15316],
#  (rdflib.term.Literal('public.relations@enron.com'),
#   rdflib.term.Literal('up'),
#   rdflib.term.Literal('t')): [15316],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('create'),
#   rdflib.term.Literal('requirement document')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('implement'),
#   rdflib.term.Literal('system requirement')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('rate schedule')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('require'),
#   rdflib.term.Literal('shipper')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('require'),
#   rdflib.term.Literal('take capacity')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('see'),
#   rdflib.term.Literal('problem')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('store'),
#   rdflib.term.Literal('information')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('store'),
#   rdflib.term.Literal('level')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('store'),
#   rdflib.term.Literal('rate system')): [15253],
#  (rdflib.term.Literal('ramona.betancourt@enron.com'),
#   rdflib.term.Literal('track'),
#   rdflib.term.Literal('contract')): [15253],
#  (rdflib.term.Literal('rate'),
#   rdflib.term.Literal('keep'),
#   rdflib.term.Literal('inventory')): [15271],
#  (rdflib.term.Literal('rate'),
#   rdflib.term.Literal('keep'),
#   rdflib.term.Literal('path')): [15271],
#  (rdflib.term.Literal('richard.abramowicz@enron.com'),
#   rdflib.term.Literal('set'),
#   rdflib.term.Literal('user')): [15065],
#  (rdflib.term.Literal('richard.hanagriff@enron.com'),
#   rdflib.term.Literal('print'),
#   rdflib.term.Literal('lists')): [15231],
#  (rdflib.term.Literal('rjuenke@br-inc.com'),
#   rdflib.term.Literal('come'),
#   rdflib.term.Literal('training')): [15185],
#  (rdflib.term.Literal('rockey.storie@enron.com'),
#   rdflib.term.Literal('want'),
#   rdflib.term.Literal('information')): [15275],
#  (rdflib.term.Literal('role'),
#   rdflib.term.Literal('identify'),
#   rdflib.term.Literal('solution')): [15470],
#  (rdflib.term.Literal('ruth.mann@enron.com'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('basis')): [15340],
#  (rdflib.term.Literal('ruth.mann@enron.com'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('session')): [15340],
#  (rdflib.term.Literal('ruth.mann@enron.com'),
#   rdflib.term.Literal('prepare'),
#   rdflib.term.Literal('video example')): [15340],
#  (rdflib.term.Literal('sharee.payne@compaq.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('time')): [15313],
#  (rdflib.term.Literal('sharris1@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('question')): [15062, 15427],
#  (rdflib.term.Literal('she'),
#   rdflib.term.Literal('act'),
#   rdflib.term.Literal('liaison')): [15377],
#  (rdflib.term.Literal('she'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('3')): [15230],
#  (rdflib.term.Literal('she'),
#   rdflib.term.Literal('be'),
#   rdflib.term.Literal('addition')): [15377],
#  (rdflib.term.Literal('she'),
#   rdflib.term.Literal('facilitate'),
#   rdflib.term.Literal('training')): [15377],
#  (rdflib.term.Literal('she'),
#   rdflib.term.Literal('hold'),
#   rdflib.term.Literal('position')): [15377],
#  (rdflib.term.Literal('shelley.corman@enron.com'),
#   rdflib.term.Literal('get'),
#   rdflib.term.Literal('count')): [15269],
#  (rdflib.term.Literal('shelley.corman@enron.com'),
#   rdflib.term.Literal('open'),
#   rdflib.term.Literal('class')): [15269],
#  (rdflib.term.Literal('spokesperson'),
#   rdflib.term.Literal('underscore'),
#   rdflib.term.Literal('seriousness')): [15295],
#  (rdflib.term.Literal('steven.harris@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('question')): [15247, 15291, 15380],
#  (rdflib.term.Literal('steven.harris@enron.com'),
#   rdflib.term.Literal('join'),
#   rdflib.term.Literal('adr')): [15424],
#  (rdflib.term.Literal('susan.scott@enron.com'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('thought')): [15336],
#  (rdflib.term.Literal('tbrother@utilicorp.com'),
#   rdflib.term.Literal('like'),
#   rdflib.term.Literal('change point')): [15297],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('complete'),
#   rdflib.term.Literal('surve')): [15470],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('do'),
#   rdflib.term.Literal('math')): [15296],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('feel'),
#   rdflib.term.Literal('fear')): [15296],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('feel'),
#   rdflib.term.Literal('job')): [15296, 15470],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('fill'),
#   rdflib.term.Literal('pulse')): [15296],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('fill'),
#   rdflib.term.Literal('survey')): [15296],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('right')): [15296],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('identify'),
#   rdflib.term.Literal('problem area')): [15470],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('remember'),
#   rdflib.term.Literal('pulse')): [15470],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('think'),
#   rdflib.term.Literal('experience')): [15470],
#  (rdflib.term.Literal('the.mailout@enron.com'),
#   rdflib.term.Literal('want'),
#   rdflib.term.Literal('participation number')): [15296],
#  (rdflib.term.Literal('the.pulse-ets@enron.com'),
#   rdflib.term.Literal('think'),
#   rdflib.term.Literal('experience')): [15497],
#  (rdflib.term.Literal('tk.lohman@enron.com'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('question')): [15037],
#  (rdflib.term.Literal('tk.lohman@enron.com'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('cost')): [15278],
#  (rdflib.term.Literal('tk.lohman@enron.com'),
#   rdflib.term.Literal('need'),
#   rdflib.term.Literal('user id')): [15037],
#  (rdflib.term.Literal('toby.kuehl@enron.com'),
#   rdflib.term.Literal('provide'),
#   rdflib.term.Literal('code')): [15263],
#  (rdflib.term.Literal('trader'),
#   rdflib.term.Literal('have'),
#   rdflib.term.Literal('suspicion')): [15460],
#  (rdflib.term.Literal('trader'),
#   rdflib.term.Literal('know'),
#   rdflib.term.Literal('own capacity')): [15460],
#  (rdflib.term.Literal('we'),
#   rdflib.term.Literal('book'),
#   rdflib.term.Literal('excess')): [15397],
#  (rdflib.term.Literal('we'),
#   rdflib.term.Literal('book'),
#   rdflib.term.Literal('gain')): [15397],
#  (rdflib.term.Literal('we'),
#   rdflib.term.Literal('meet'),
#   rdflib.term.Literal('demand requirement')): [15397]}

# %%
msg_key_idx_reverse
# Out:
# {15002: [(rdflib.term.Literal('GPG'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('gather information')),
#   (rdflib.term.Literal('Windows'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('system')),
#   (rdflib.term.Literal('chris.smith@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('messaging')),
#   (rdflib.term.Literal('chris.smith@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('assistance')),
#   (rdflib.term.Literal('chris.smith@enron.com'),
#    rdflib.term.Literal('approach'),
#    rdflib.term.Literal('project')),
#   (rdflib.term.Literal('chris.smith@enron.com'),
#    rdflib.term.Literal('approach'),
#    rdflib.term.Literal('approach')),
#   (rdflib.term.Literal('II'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('ndow')),
#   (rdflib.term.Literal('chris.smith@enron.com'),
#    rdflib.term.Literal('migrate'),
#    rdflib.term.Literal('datum')),
#   (rdflib.term.Literal('chris.smith@enron.com'),
#    rdflib.term.Literal('migrate'),
#    rdflib.term.Literal('server')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('document')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15004: [(rdflib.term.Literal('Payables'),
#    rdflib.term.Literal('input'),
#    rdflib.term.Literal('invoice')),
#   (rdflib.term.Literal('Payables'),
#    rdflib.term.Literal('input'),
#    rdflib.term.Literal('system')),
#   (rdflib.term.Literal('gas.operations@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15006: [(rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question')),
#   (rdflib.term.Literal('jean.mcfarland@enron.com'),
#    rdflib.term.Literal('apologize'),
#    rdflib.term.Literal('problem'))],
#  15007: [(rdflib.term.Literal('enron.mailout@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('confirmation')),
#   (rdflib.term.Literal('enron.mailout@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('recommend'),
#    rdflib.term.Literal('attend training'))],
#  15008: [(rdflib.term.Literal('Lokay'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('index price'))],
#  15009: [(rdflib.term.Literal('ISC'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('organization')),
#   (rdflib.term.Literal('ISC'),
#    rdflib.term.Literal('launch'),
#    rdflib.term.Literal('website')),
#   (rdflib.term.Literal('ISC'),
#    rdflib.term.Literal('launch'),
#    rdflib.term.Literal('order'))],
#  15011: [(rdflib.term.Literal('WinInstall'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('update')),
#   (rdflib.term.Literal('WinInstall'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('computer')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('disturb'),
#    rdflib.term.Literal('machine')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15013: [(rdflib.term.Literal('meiling.chen@enron.com'),
#    rdflib.term.Literal('replace'),
#    rdflib.term.Literal('basis differential')),
#   (rdflib.term.Literal('Analysis'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('basis differential'))],
#  15014: [(rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('change order')),
#   (rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('click'),
#    rdflib.term.Literal('category')),
#   (rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('click'),
#    rdflib.term.Literal('exit screen')),
#   (rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('problem'))],
#  15015: [(rdflib.term.Literal('Research'),
#    rdflib.term.Literal('launch'),
#    rdflib.term.Literal('product')),
#   (rdflib.term.Literal('Employees'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('web site')),
#   (rdflib.term.Literal('Employees'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('conduct research')),
#   (rdflib.term.Literal('Explorer'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('session'))],
#  15016: [(rdflib.term.Literal('jean.mcfarland@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('email')),
#   (rdflib.term.Literal('jean.mcfarland@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('information')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('attempt')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('assistance')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('instal'),
#    rdflib.term.Literal('desktop')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('require'),
#    rdflib.term.Literal('emergency assistance')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('message'))],
#  15017: [(rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('go'),
#    rdflib.term.Literal('begin phase')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('gather'),
#    rdflib.term.Literal('informati')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('gather'),
#    rdflib.term.Literal('hardware')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('group')),
#   (rdflib.term.Literal('Leader'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('t')),
#   (rdflib.term.Literal('Leader'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('point')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('email')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('information')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('minute')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('environment')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('encourage'),
#    rdflib.term.Literal('review folder')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('review da')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('need')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('review'),
#    rdflib.term.Literal('file')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('retain'),
#    rdflib.term.Literal('file')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('look'),
#    rdflib.term.Literal('effort')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('communication')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15018: [(rdflib.term.Literal('lindy.donoho@enron.com'),
#    rdflib.term.Literal('save'),
#    rdflib.term.Literal('reference'))],
#  15019: [(rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('run'),
#    rdflib.term.Literal('winstall')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('version')),
#   (rdflib.term.Literal('Select'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('contact')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('update')),
#   (rdflib.term.Literal('et&s.office@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15020: [(rdflib.term.Literal('donna.vaughn@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('file')),
#   (rdflib.term.Literal('donna.vaughn@enron.com'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('computer')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('problem')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('version')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('prefer'),
#    rdflib.term.Literal('copy'))],
#  15021: [(rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('notice')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('email system')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('store document')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('keep day')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('folder')),
#   (rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('support'),
#    rdflib.term.Literal('work environment')),
#   (rdflib.term.Literal('Computers'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('property'))],
#  15022: [(rdflib.term.Literal('audrey.robertson@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('make request')),
#   (rdflib.term.Literal('audrey.robertson@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('request')),
#   (rdflib.term.Literal('joe.witherspoon@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15024: [(rdflib.term.Literal('Apollo'),
#    rdflib.term.Literal('conduct'),
#    rdflib.term.Literal('ap')),
#   (rdflib.term.Literal('Apollo'),
#    rdflib.term.Literal('conduct'),
#    rdflib.term.Literal('implementation')),
#   (rdflib.term.Literal('SAP'),
#    rdflib.term.Literal('bring'),
#    rdflib.term.Literal('dynamic'))],
#  15026: [(rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('process')),
#   (rdflib.term.Literal('all.houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('power')),
#   (rdflib.term.Literal('all.houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('futures'))],
#  15027: [(rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('call'),
#    rdflib.term.Literal('helpdesk')),
#   (rdflib.term.Literal('dan.bunch@enron.com'),
#    rdflib.term.Literal('look'),
#    rdflib.term.Literal('have everyone')),
#   (rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15028: [(rdflib.term.Literal('jean.mcfarland@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('training')),
#   (rdflib.term.Literal('jean.mcfarland@enron.com'),
#    rdflib.term.Literal('test'),
#    rdflib.term.Literal('marketing application')),
#   (rdflib.term.Literal('jean.mcfarland@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('email')),
#   (rdflib.term.Literal('jean.mcfarland@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('migration')),
#   (rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15029: [(rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('save'),
#    rdflib.term.Literal('information')),
#   (rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('file')),
#   (rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('copy'),
#    rdflib.term.Literal('h')),
#   (rdflib.term.Literal('michael.bodnar@enron.com'),
#    rdflib.term.Literal('delete'),
#    rdflib.term.Literal('example'))],
#  15030: [(rdflib.term.Literal('WinInstall'),
#    rdflib.term.Literal('run'),
#    rdflib.term.Literal('today')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('reboot'),
#    rdflib.term.Literal('pc')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('donot'),
#    rdflib.term.Literal('reboot')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('donot'),
#    rdflib.term.Literal('p.m.')),
#   (rdflib.term.Literal('WinInstall'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('update')),
#   (rdflib.term.Literal('WinInstall'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('computer')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('disturb'),
#    rdflib.term.Literal('machine')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15034: [(rdflib.term.Literal('feedback@intcx.com'),
#    rdflib.term.Literal('continue'),
#    rdflib.term.Literal('investigate issue'))],
#  15036: [(rdflib.term.Literal('enron.worldwide@enron.com'),
#    rdflib.term.Literal('access'),
#    rdflib.term.Literal('site')),
#   (rdflib.term.Literal('enron.worldwide@enron.com'),
#    rdflib.term.Literal('go'),
#    rdflib.term.Literal('website')),
#   (rdflib.term.Literal('enron.worldwide@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15037: [(rdflib.term.Literal('tk.lohman@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('user id')),
#   (rdflib.term.Literal('tk.lohman@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15038: [(rdflib.term.Literal('ets.announcement@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('adjustment'))],
#  15040: [(rdflib.term.Literal('audrey.robertson@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('reflect change')),
#   (rdflib.term.Literal('lindy.donoho@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('change'))],
#  15042: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('provide feedback')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15043: [(rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15045: [(rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('talk'),
#    rdflib.term.Literal('vendor')),
#   (rdflib.term.Literal('Team'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('vendor')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('apologize'),
#    rdflib.term.Literal('inconvenience')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15046: [(rdflib.term.Literal('Apollo'),
#    rdflib.term.Literal('conduct'),
#    rdflib.term.Literal('implementation')),
#   (rdflib.term.Literal('SAP'),
#    rdflib.term.Literal('bring'),
#    rdflib.term.Literal('dynamic')),
#   (rdflib.term.Literal('enron.everyone_et&s_field_offices@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('difficulty')),
#   (rdflib.term.Literal('Employees'),
#    rdflib.term.Literal('pay'),
#    rdflib.term.Literal('management')),
#   (rdflib.term.Literal('Allot'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('feel effect'))],
#  15047: [(rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('netscape')),
#   (rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15048: [(rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('platform')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('support'),
#    rdflib.term.Literal('messaging')),
#   (rdflib.term.Literal('enron.customers@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('basis')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('include'),
#    rdflib.term.Literal('list')),
#   (rdflib.term.Literal('Outlook'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('client')),
#   (rdflib.term.Literal('Outlook'),
#    rdflib.term.Literal('integrate'),
#    rdflib.term.Literal('system')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('platform')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('finalize'),
#    rdflib.term.Literal('unit')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('finalize'),
#    rdflib.term.Literal('rollout schedule')),
#   (rdflib.term.Literal('enron.customers@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('question'))],
#  15049: [(rdflib.term.Literal('Jean'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('netscape')),
#   (rdflib.term.Literal('Jean'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('user')),
#   (rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('lose'),
#    rdflib.term.Literal('capability'))],
#  15050: [(rdflib.term.Literal('jeff.huo@enron.com'),
#    rdflib.term.Literal('migrate'),
#    rdflib.term.Literal('web page')),
#   (rdflib.term.Literal('jeff.huo@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15051: [(rdflib.term.Literal('jeffery.fawcett@enron.com'),
#    rdflib.term.Literal('appear'),
#    rdflib.term.Literal('have volume'))],
#  15052: [(rdflib.term.Literal('dennis.lee@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('document')),
#   (rdflib.term.Literal('dennis.lee@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('email')),
#   (rdflib.term.Literal('dennis.lee@enron.com'),
#    rdflib.term.Literal('do'),
#    rdflib.term.Literal('email')),
#   (rdflib.term.Literal('nancy.bastida@enron.com'),
#    rdflib.term.Literal('fax'),
#    rdflib.term.Literal('information')),
#   (rdflib.term.Literal('nancy.bastida@enron.com'),
#    rdflib.term.Literal('fax'),
#    rdflib.term.Literal('envision')),
#   (rdflib.term.Literal('nancy.bastida@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15054: [(rdflib.term.Literal('Interruptions'),
#    rdflib.term.Literal('modify'),
#    rdflib.term.Literal('network setting')),
#   (rdflib.term.Literal('Interruptions'),
#    rdflib.term.Literal('modify'),
#    rdflib.term.Literal('hardware setting')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('experience'),
#    rdflib.term.Literal('connection problem')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('experience'),
#    rdflib.term.Literal('timeframe')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('experience'),
#    rdflib.term.Literal('a.m.')),
#   (rdflib.term.Literal('Interruptions'),
#    rdflib.term.Literal('modify'),
#    rdflib.term.Literal('configuration')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('experience'),
#    rdflib.term.Literal('outage')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('experience'),
#    rdflib.term.Literal('timeframe')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('user')),
#   (rdflib.term.Literal('Maintenance'),
#    rdflib.term.Literal('perform'),
#    rdflib.term.Literal('maintenance')),
#   (rdflib.term.Literal('Maintenance'),
#    rdflib.term.Literal('perform'),
#    rdflib.term.Literal('battery')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('operate'),
#    rdflib.term.Literal('system')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('operate'),
#    rdflib.term.Literal('period')),
#   (rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('anticipate'),
#    rdflib.term.Literal('service disruption')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('issue'))],
#  15056: [(rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('e mail')),
#   (rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15057: [(rdflib.term.Literal('Center'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('step')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('service')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('post'),
#    rdflib.term.Literal('result')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('post'),
#    rdflib.term.Literal('page'))],
#  15059: [(rdflib.term.Literal('ets.center@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('provide information')),
#   (rdflib.term.Literal('Process'),
#    rdflib.term.Literal('lose'),
#    rdflib.term.Literal('mail message')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('lose'),
#    rdflib.term.Literal('mail message')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('notes')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('desktop')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('owner')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('access')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('conversion')),
#   (rdflib.term.Literal('enron.everyone_et&s_houston@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('brochure')),
#   (rdflib.term.Literal('Below'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('copy'))],
#  15062: [(rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('access')),
#   (rdflib.term.Literal('sharris1@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15063: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('contact'),
#    rdflib.term.Literal('helpdesk')),
#   (rdflib.term.Literal('ID'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('id'))],
#  15064: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('log'),
#    rdflib.term.Literal('system')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('contact'),
#    rdflib.term.Literal('helpdesk'))],
#  15065: [(rdflib.term.Literal('richard.abramowicz@enron.com'),
#    rdflib.term.Literal('set'),
#    rdflib.term.Literal('user')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('marketing report'))],
#  15066: [(rdflib.term.Literal('andre.walters@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('action')),
#   (rdflib.term.Literal('andre.walters@enron.com'),
#    rdflib.term.Literal('access'),
#    rdflib.term.Literal('outlook')),
#   (rdflib.term.Literal('andre.walters@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('store message'))],
#  15069: [(rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('process')),
#   (rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('user')),
#   (rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('notice'),
#    rdflib.term.Literal('change')),
#   (rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('familiarize'),
#    rdflib.term.Literal('look')),
#   (rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15072: [(rdflib.term.Literal('diane.becker@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15074: [(rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('manage'),
#    rdflib.term.Literal('business')),
#   (rdflib.term.Literal('martha.janousek@enron.com'),
#    rdflib.term.Literal('roll'),
#    rdflib.term.Literal('release')),
#   (rdflib.term.Literal('martha.janousek@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('feedback')),
#   (rdflib.term.Literal('martha.janousek@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('survey')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('customize'),
#    rdflib.term.Literal('category')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('identify'),
#    rdflib.term.Literal('condition')),
#   (rdflib.term.Literal('martha.janousek@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('initial')),
#   (rdflib.term.Literal('i'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('initial')),
#   (rdflib.term.Literal('Dashboard'),
#    rdflib.term.Literal('appear'),
#    rdflib.term.Literal('default')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('remove'),
#    rdflib.term.Literal('category')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('day')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('log'),
#    rdflib.term.Literal('pc')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('create'),
#    rdflib.term.Literal('link category')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('group'),
#    rdflib.term.Literal('link')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('edit'),
#    rdflib.term.Literal('list')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('jot'),
#    rdflib.term.Literal('note')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('create'),
#    rdflib.term.Literal('memo pad')),
#   (rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15075: [(rdflib.term.Literal('audrey.robertson@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('meeting discussion'))],
#  15077: [(rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('phase'),
#    rdflib.term.Literal('reporti')),
#   (rdflib.term.Literal('Central'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('training session')),
#   (rdflib.term.Literal('all.states@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15080: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('name')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('trading'))],
#  15084: [(rdflib.term.Literal("'s"),
#    rdflib.term.Literal('schedule'),
#    rdflib.term.Literal('marketer'))],
#  15090: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('run'),
#    rdflib.term.Literal('report')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('run'),
#    rdflib.term.Literal('side'))],
#  15091: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('day'))],
#  15093: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('receive statement'))],
#  15105: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('day'))],
#  15108: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('datum'))],
#  15109: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('document'))],
#  15119: [(rdflib.term.Literal('Husband'),
#    rdflib.term.Literal('uninstall'),
#    rdflib.term.Literal('program'))],
#  15125: [(rdflib.term.Literal('ENA'),
#    rdflib.term.Literal('owe'),
#    rdflib.term.Literal('money')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('capacity'))],
#  15129: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('update'),
#    rdflib.term.Literal('accomplishment'))],
#  15130: [(rdflib.term.Literal('Mike'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('measure'))],
#  15132: [(rdflib.term.Literal('Ignacio'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('million'))],
#  15135: [(rdflib.term.Literal('TW'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('control meeting'))],
#  15143: [(rdflib.term.Literal('Williams'),
#    rdflib.term.Literal('cash'),
#    rdflib.term.Literal('imbalance'))],
#  15147: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('look'),
#    rdflib.term.Literal('week'))],
#  15151: [(rdflib.term.Literal('Centilli'),
#    rdflib.term.Literal('run'),
#    rdflib.term.Literal('economic'))],
#  15152: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('day'))],
#  15157: [(rdflib.term.Literal('mark.mcconnell@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('summer')),
#   (rdflib.term.Literal('Mirant'),
#    rdflib.term.Literal('integrate'),
#    rdflib.term.Literal('weather risk')),
#   (rdflib.term.Literal('Mirant'),
#    rdflib.term.Literal('integrate'),
#    rdflib.term.Literal('profile')),
#   (rdflib.term.Literal('mark.mcconnell@enron.com'),
#    rdflib.term.Literal('utilize'),
#    rdflib.term.Literal('information'))],
#  15158: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('tomorrow'))],
#  15159: [(rdflib.term.Literal('Mike'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('spreadsheet'))],
#  15162: [(rdflib.term.Literal('Imbalance'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('level'))],
#  15168: [(rdflib.term.Literal('mansoor.abdmoulaie@enron.com'),
#    rdflib.term.Literal('pick'),
#    rdflib.term.Literal('day'))],
#  15172: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('ticket')),
#   (rdflib.term.Literal("'s"),
#    rdflib.term.Literal('do'),
#    rdflib.term.Literal('show'))],
#  15173: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('discontinue'),
#    rdflib.term.Literal('contribution'))],
#  15175: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('day vacation'))],
#  15185: [(rdflib.term.Literal('rjuenke@br-inc.com'),
#    rdflib.term.Literal('come'),
#    rdflib.term.Literal('training'))],
#  15186: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('check'))],
#  15190: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('sue'),
#    rdflib.term.Literal('everyone')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('sue'),
#    rdflib.term.Literal('distance carrier'))],
#  15195: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('utilize'),
#    rdflib.term.Literal('system'))],
#  15196: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('receive statement'))],
#  15198: [(rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('cow')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('cow')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('cow')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('care')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('cow')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('cow')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('borrow'),
#    rdflib.term.Literal('%')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('sell'),
#    rdflib.term.Literal('cow')),
#   (rdflib.term.Literal('jimboman@bigfoot.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('exemption')),
#   (rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('trade cow'))],
#  15200: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('look'),
#    rdflib.term.Literal('what')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('production'))],
#  15205: [(rdflib.term.Literal("'hitschel@enron.com"),
#    rdflib.term.Literal('think'),
#    rdflib.term.Literal('itinerary')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('leave'),
#    rdflib.term.Literal('hour'))],
#  15209: [(rdflib.term.Literal('Shelley'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('weekend'))],
#  15210: [(rdflib.term.Literal('Burlington'),
#    rdflib.term.Literal('schedule'),
#    rdflib.term.Literal('conference call')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('pressure scenario'))],
#  15215: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('mention'),
#    rdflib.term.Literal('meeting'))],
#  15230: [(rdflib.term.Literal('Things'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('debacle')),
#   (rdflib.term.Literal('she'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('3'))],
#  15231: [(rdflib.term.Literal('richard.hanagriff@enron.com'),
#    rdflib.term.Literal('print'),
#    rdflib.term.Literal('lists')),
#   (rdflib.term.Literal('Difference'),
#    rdflib.term.Literal('mojave'),
#    rdflib.term.Literal('tw'))],
#  15234: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('ticket'))],
#  15238: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('voice mail'))],
#  15240: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('box'))],
#  15243: [(rdflib.term.Literal('e.houston@enron.com'),
#    rdflib.term.Literal('bring'),
#    rdflib.term.Literal('lunch'))],
#  15244: [(rdflib.term.Literal('Martin'),
#    rdflib.term.Literal('become'),
#    rdflib.term.Literal('president'))],
#  15245: [(rdflib.term.Literal('new.jun-sept@enron.com'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('company')),
#   (rdflib.term.Literal('new.jun-sept@enron.com'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('time')),
#   (rdflib.term.Literal('new.jun-sept@enron.com'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('growth')),
#   (rdflib.term.Literal('new.jun-sept@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('forefront')),
#   (rdflib.term.Literal('Ours'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('company')),
#   (rdflib.term.Literal('new.jun-sept@enron.com'),
#    rdflib.term.Literal('understand'),
#    rdflib.term.Literal('breadth')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('invite'),
#    rdflib.term.Literal('attend day')),
#   (rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('build'),
#    rdflib.term.Literal('orientation')),
#   (rdflib.term.Literal('new.jun-sept@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('day')),
#   (rdflib.term.Literal('new.jun-sept@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('job'))],
#  15247: [(rdflib.term.Literal('steven.harris@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15248: [(rdflib.term.Literal('Houston'),
#    rdflib.term.Literal('rank'),
#    rdflib.term.Literal('survey'))],
#  15251: [(rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('nomination form')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('mail')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('appreciate'),
#    rdflib.term.Literal('participation'))],
#  15252: [(rdflib.term.Literal('Lokay'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('time')),
#   (rdflib.term.Literal('mlokay@enron.com'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('tournament')),
#   (rdflib.term.Literal('mlokay@enron.com'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('16th')),
#   (rdflib.term.Literal('mlokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('time'))],
#  15253: [(rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('problem')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('implement'),
#    rdflib.term.Literal('system requirement')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('track'),
#    rdflib.term.Literal('contract')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('require'),
#    rdflib.term.Literal('shipper')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('require'),
#    rdflib.term.Literal('take capacity')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('store'),
#    rdflib.term.Literal('information')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('store'),
#    rdflib.term.Literal('level')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('store'),
#    rdflib.term.Literal('rate system')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('rate schedule')),
#   (rdflib.term.Literal('ramona.betancourt@enron.com'),
#    rdflib.term.Literal('create'),
#    rdflib.term.Literal('requirement document'))],
#  15255: [(rdflib.term.Literal('new.may-june@enron.com'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('company')),
#   (rdflib.term.Literal('new.may-june@enron.com'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('time')),
#   (rdflib.term.Literal('new.may-june@enron.com'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('growth')),
#   (rdflib.term.Literal('new.may-june@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('forefront')),
#   (rdflib.term.Literal('Ours'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('company')),
#   (rdflib.term.Literal('new.may-june@enron.com'),
#    rdflib.term.Literal('understand'),
#    rdflib.term.Literal('breadth')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('invite'),
#    rdflib.term.Literal('attend day')),
#   (rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('build'),
#    rdflib.term.Literal('orientation')),
#   (rdflib.term.Literal('new.may-june@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('day')),
#   (rdflib.term.Literal('new.may-june@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('job'))],
#  15256: [(rdflib.term.Literal('Dave'),
#    rdflib.term.Literal('say'),
#    rdflib.term.Literal('thank'))],
#  15257: [(rdflib.term.Literal('lorraine.lindberg@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('meeting')),
#   (rdflib.term.Literal('lorraine.lindberg@enron.com'),
#    rdflib.term.Literal('meet'),
#    rdflib.term.Literal('office'))],
#  15259: [(rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('netscape')),
#   (rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15260: [(rdflib.term.Literal('jeffery.fawcett@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('expansion noti')),
#   (rdflib.term.Literal('River'),
#    rdflib.term.Literal('cast'),
#    rdflib.term.Literal('lot')),
#   (rdflib.term.Literal('River'),
#    rdflib.term.Literal('cast'),
#    rdflib.term.Literal('expansion')),
#   (rdflib.term.Literal('Williams'),
#    rdflib.term.Literal('plan'),
#    rdflib.term.Literal('way')),
#   (rdflib.term.Literal('company'),
#    rdflib.term.Literal('file'),
#    rdflib.term.Literal('application')),
#   (rdflib.term.Literal('Williams'),
#    rdflib.term.Literal('plan'),
#    rdflib.term.Literal('upgrade station')),
#   (rdflib.term.Literal('River'),
#    rdflib.term.Literal('hold'),
#    rdflib.term.Literal('season'))],
#  15263: [(rdflib.term.Literal('toby.kuehl@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('code')),
#   (rdflib.term.Literal('christine.stokes@enron.com'),
#    rdflib.term.Literal('communicate'),
#    rdflib.term.Literal('information'))],
#  15265: [(rdflib.term.Literal('Mexico'),
#    rdflib.term.Literal('force'),
#    rdflib.term.Literal('operations')),
#   (rdflib.term.Literal('Mexico'),
#    rdflib.term.Literal('force'),
#    rdflib.term.Literal('blow mainline')),
#   (rdflib.term.Literal('Duke'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('mmbtu')),
#   (rdflib.term.Literal('Duke'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('west')),
#   (rdflib.term.Literal('Duke'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('rate')),
#   (rdflib.term.Literal('FERC'),
#    rdflib.term.Literal('schedule'),
#    rdflib.term.Literal('conference'))],
#  15267: [(rdflib.term.Literal('audrey.robertson@enron.com'),
#    rdflib.term.Literal('move'),
#    rdflib.term.Literal('something')),
#   (rdflib.term.Literal('lindy.donoho@enron.com'),
#    rdflib.term.Literal('feel'),
#    rdflib.term.Literal('change'))],
#  15268: [(rdflib.term.Literal('all.downtown@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('problem')),
#   (rdflib.term.Literal('Ballet'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('need')),
#   (rdflib.term.Literal('Federation'),
#    rdflib.term.Literal('recruit'),
#    rdflib.term.Literal('volunteer')),
#   (rdflib.term.Literal('all.downtown@enron.com'),
#    rdflib.term.Literal('win'),
#    rdflib.term.Literal('spot')),
#   (rdflib.term.Literal('all.downtown@enron.com'),
#    rdflib.term.Literal('win'),
#    rdflib.term.Literal('9th')),
#   (rdflib.term.Literal('Work'),
#    rdflib.term.Literal('gear'),
#    rdflib.term.Literal('session')),
#   (rdflib.term.Literal('PerkCard'),
#    rdflib.term.Literal('offer'),
#    rdflib.term.Literal('discount')),
#   (rdflib.term.Literal('Children'),
#    rdflib.term.Literal('develop'),
#    rdflib.term.Literal('skill'))],
#  15269: [(rdflib.term.Literal('david.badura@enron.com'),
#    rdflib.term.Literal('hear'),
#    rdflib.term.Literal('class')),
#   (rdflib.term.Literal('Horton'),
#    rdflib.term.Literal('open'),
#    rdflib.term.Literal('class')),
#   (rdflib.term.Literal('Horton'),
#    rdflib.term.Literal('open'),
#    rdflib.term.Literal('remark')),
#   (rdflib.term.Literal('shelley.corman@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('count')),
#   (rdflib.term.Literal('shelley.corman@enron.com'),
#    rdflib.term.Literal('open'),
#    rdflib.term.Literal('class'))],
#  15270: [(rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('agree'),
#    rdflib.term.Literal('cover half')),
#   (rdflib.term.Literal('non.employees@enron.com'),
#    rdflib.term.Literal('use'),
#    rdflib.term.Literal('navigator'))],
#  15271: [(rdflib.term.Literal('rate'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('inventory')),
#   (rdflib.term.Literal('rate'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('path')),
#   (rdflib.term.Literal('November'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('warm')),
#   (rdflib.term.Literal('Winter'),
#    rdflib.term.Literal('bring'),
#    rdflib.term.Literal('rockies')),
#   (rdflib.term.Literal('Winter'),
#    rdflib.term.Literal('bring'),
#    rdflib.term.Literal('price')),
#   (rdflib.term.Literal('Juan'),
#    rdflib.term.Literal('hold'),
#    rdflib.term.Literal('widening')),
#   (rdflib.term.Literal('Winter'),
#    rdflib.term.Literal('arrive'),
#    rdflib.term.Literal('earnest')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('expect'),
#    rdflib.term.Literal('see basis')),
#   (rdflib.term.Literal('England'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('price')),
#   (rdflib.term.Literal('December'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('retention cost')),
#   (rdflib.term.Literal('MMBtu'),
#    rdflib.term.Literal('compete'),
#    rdflib.term.Literal('capacity')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('see'),
#    rdflib.term.Literal('spike')),
#   (rdflib.term.Literal('TransCanada'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('brunt')),
#   (rdflib.term.Literal('Vector'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('service'))],
#  15273: [(rdflib.term.Literal('Steve'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('derivative class')),
#   (rdflib.term.Literal('Steve'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('month'))],
#  15274: [(rdflib.term.Literal('Williams'),
#    rdflib.term.Literal('declare'),
#    rdflib.term.Literal('force'))],
#  15275: [(rdflib.term.Literal('rockey.storie@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('information'))],
#  15277: [(rdflib.term.Literal('I'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('contribute fund')),
#   (rdflib.term.Literal('bob.burleson@enron.com'),
#    rdflib.term.Literal('spend'),
#    rdflib.term.Literal('money')),
#   (rdflib.term.Literal('bob.burleson@enron.com'),
#    rdflib.term.Literal('spend'),
#    rdflib.term.Literal('put measurement')),
#   (rdflib.term.Literal('bob.burleson@enron.com'),
#    rdflib.term.Literal('ammend'),
#    rdflib.term.Literal('agreement'))],
#  15278: [(rdflib.term.Literal('tk.lohman@enron.com'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('cost'))],
#  15280: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('provide feedback')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15281: [(rdflib.term.Literal('Project'),
#    rdflib.term.Literal('post'),
#    rdflib.term.Literal('am')),
#   (rdflib.term.Literal('Commission'),
#    rdflib.term.Literal('authorize'),
#    rdflib.term.Literal('gas')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('dth')),
#   (rdflib.term.Literal('II'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('dth')),
#   (rdflib.term.Literal('FERC'),
#    rdflib.term.Literal('deny'),
#    rdflib.term.Literal('request')),
#   (rdflib.term.Literal('Commission'),
#    rdflib.term.Literal('require'),
#    rdflib.term.Literal('transco')),
#   (rdflib.term.Literal('Transco'),
#    rdflib.term.Literal('initiate'),
# ...
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('utilize service')),
#   (rdflib.term.Literal('Virginia'),
#    rdflib.term.Literal('continue'),
#    rdflib.term.Literal('coordinate trip')),
#   (rdflib.term.Literal('Armstrong'),
#    rdflib.term.Literal('coordinate'),
#    rdflib.term.Literal('trip')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('continue'),
#    rdflib.term.Literal('monitor usage')),
#   (rdflib.term.Literal('enron.operations@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15447: [(rdflib.term.Literal('dennis.lee@enron.com'),
#    rdflib.term.Literal('work'),
#    rdflib.term.Literal('change'))],
#  15450: [(rdflib.term.Literal('Clyde'),
#    rdflib.term.Literal('conduct'),
#    rdflib.term.Literal('session')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('location')),
#   (rdflib.term.Literal('Clyde'),
#    rdflib.term.Literal('answer'),
#    rdflib.term.Literal('event')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('answer question')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('anticipate'),
#    rdflib.term.Literal('session')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('question'))],
#  15451: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('use u'))],
#  15452: [(rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('send'),
#    rdflib.term.Literal('e mail')),
#   (rdflib.term.Literal('isc.groups@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15456: [(rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('assist'),
#    rdflib.term.Literal('operation')),
#   (rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('sell'),
#    rdflib.term.Literal('mmbtu')),
#   (rdflib.term.Literal('kevin.hyatt@enron.com'),
#    rdflib.term.Literal('sell'),
#    rdflib.term.Literal('day')),
#   (rdflib.term.Literal('Burlington'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('mmbtu')),
#   (rdflib.term.Literal('Eprime'),
#    rdflib.term.Literal('sign'),
#    rdflib.term.Literal('agreement'))],
#  15457: [(rdflib.term.Literal('Cedar'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('signature')),
#   (rdflib.term.Literal('christine.stokes@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('approval')),
#   (rdflib.term.Literal('christine.stokes@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('approval')),
#   (rdflib.term.Literal('christine.stokes@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('approval')),
#   (rdflib.term.Literal('Stephanie'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('office'))],
#  15458: [(rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('talk'),
#    rdflib.term.Literal('account')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('pay'),
#    rdflib.term.Literal('penalty')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('fund')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('account'))],
#  15459: [(rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('like'),
#    rdflib.term.Literal('change order')),
#   (rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('click'),
#    rdflib.term.Literal('category')),
#   (rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('click'),
#    rdflib.term.Literal('exit screen')),
#   (rdflib.term.Literal('kent.miller@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('problem'))],
#  15460: [(rdflib.term.Literal('Pipeline'),
#    rdflib.term.Literal('extend'),
#    rdflib.term.Literal('delay')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('increase'),
#    rdflib.term.Literal('flow')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('increase'),
#    rdflib.term.Literal('system')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('encounter'),
#    rdflib.term.Literal('moisture')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('encounter'),
#    rdflib.term.Literal('construction')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('remove'),
#    rdflib.term.Literal('amount')),
#   (rdflib.term.Literal('Alliance'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('delay date')),
#   (rdflib.term.Literal('Gish'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('service')),
#   (rdflib.term.Literal('trader'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('suspicion')),
#   (rdflib.term.Literal('trader'),
#    rdflib.term.Literal('know'),
#    rdflib.term.Literal('own capacity')),
#   (rdflib.term.Literal('lorna.brennan@enron.com'),
#    rdflib.term.Literal('sell'),
#    rdflib.term.Literal('mine')),
#   (rdflib.term.Literal('he'),
#    rdflib.term.Literal('take'),
#    rdflib.term.Literal('lot'))],
#  15461: [(rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('tool')),
#   (rdflib.term.Literal('all.america@enron.com'),
#    rdflib.term.Literal('provide'),
#    rdflib.term.Literal('data ehronline'))],
#  15462: [(rdflib.term.Literal('Chairman'),
#    rdflib.term.Literal('conduct'),
#    rdflib.term.Literal('session')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('location')),
#   (rdflib.term.Literal('Lay'),
#    rdflib.term.Literal('answer'),
#    rdflib.term.Literal('event')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('answer question')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('anticipate'),
#    rdflib.term.Literal('session')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('keep'),
#    rdflib.term.Literal('question'))],
#  15463: [(rdflib.term.Literal('Contract'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('7th')),
#   (rdflib.term.Literal('Option'),
#    rdflib.term.Literal('call'),
#    rdflib.term.Literal('capacity')),
#   (rdflib.term.Literal('christine.stokes@enron.com'),
#    rdflib.term.Literal('need'),
#    rdflib.term.Literal('request form'))],
#  15464: [(rdflib.term.Literal('Invoice'),
#    rdflib.term.Literal('accommodate'),
#    rdflib.term.Literal('code')),
#   (rdflib.term.Literal('Reports'),
#    rdflib.term.Literal('accommodate'),
#    rdflib.term.Literal('code')),
#   (rdflib.term.Literal('enron.everyone_et&s_field_offices@enron.com'),
#    rdflib.term.Literal('find'),
#    rdflib.term.Literal('information'))],
#  15465: [(rdflib.term.Literal('Cliff'),
#    rdflib.term.Literal('join'),
#    rdflib.term.Literal('enron')),
#   (rdflib.term.Literal('Cliff'),
#    rdflib.term.Literal('focus'),
#    rdflib.term.Literal('repositioning')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('continue'),
#    rdflib.term.Literal('increase return'))],
#  15470: [(rdflib.term.Literal('the.mailout@enron.com'),
#    rdflib.term.Literal('think'),
#    rdflib.term.Literal('experience')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('want'),
#    rdflib.term.Literal('check pulse')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('change'),
#    rdflib.term.Literal('name')),
#   (rdflib.term.Literal('diagnosis'),
#    rdflib.term.Literal('lp'),
#    rdflib.term.Literal('problem area')),
#   (rdflib.term.Literal('the.mailout@enron.com'),
#    rdflib.term.Literal('remember'),
#    rdflib.term.Literal('pulse')),
#   (rdflib.term.Literal('the.mailout@enron.com'),
#    rdflib.term.Literal('complete'),
#    rdflib.term.Literal('surve')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('respond'),
#    rdflib.term.Literal('comment')),
#   (rdflib.term.Literal('enron.announcements@enron.com'),
#    rdflib.term.Literal('ask'),
#    rdflib.term.Literal('help')),
#   (rdflib.term.Literal('role'),
#    rdflib.term.Literal('identify'),
#    rdflib.term.Literal('solution')),
#   (rdflib.term.Literal('the.mailout@enron.com'),
#    rdflib.term.Literal('identify'),
#    rdflib.term.Literal('problem area')),
#   (rdflib.term.Literal('the.mailout@enron.com'),
#    rdflib.term.Literal('feel'),
#    rdflib.term.Literal('job'))],
#  15473: [(rdflib.term.Literal('Needles'),
#    rdflib.term.Literal('spread'),
#    rdflib.term.Literal('spread'))],
#  15475: [(rdflib.term.Literal('Pipeline'),
#    rdflib.term.Literal('institute'),
#    rdflib.term.Literal('ofo')),
#   (rdflib.term.Literal('Gas'),
#    rdflib.term.Literal('institute'),
#    rdflib.term.Literal('balancing requirement')),
#   (rdflib.term.Literal('Gas'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('supply contract')),
#   (rdflib.term.Literal('Gas'),
#    rdflib.term.Literal('play'),
#    rdflib.term.Literal('storage game')),
#   (rdflib.term.Literal('SoCal'),
#    rdflib.term.Literal('lower'),
#    rdflib.term.Literal('window')),
#   (rdflib.term.Literal('SoCal'),
#    rdflib.term.Literal('lower'),
#    rdflib.term.Literal('tomorrow'))],
#  15477: [(rdflib.term.Literal('jeffery.fawcett@enron.com'),
#    rdflib.term.Literal('appear'),
#    rdflib.term.Literal('have volume'))],
#  15479: [(rdflib.term.Literal('Weather'),
#    rdflib.term.Literal('permit'),
#    rdflib.term.Literal('area')),
#   (rdflib.term.Literal('christine.stokes@enron.com'),
#    rdflib.term.Literal('mention'),
#    rdflib.term.Literal('meeting')),
#   (rdflib.term.Literal('Coop'),
#    rdflib.term.Literal('owe'),
#    rdflib.term.Literal('tw')),
#   (rdflib.term.Literal('christine.stokes@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('action plan'))],
#  15480: [(rdflib.term.Literal('all.houston@enron.com'),
#    rdflib.term.Literal('appreciate'),
#    rdflib.term.Literal('work')),
#   (rdflib.term.Literal('all.houston@enron.com'),
#    rdflib.term.Literal('check'),
#    rdflib.term.Literal('nomination statistic')),
#   (rdflib.term.Literal('all.houston@enron.com'),
#    rdflib.term.Literal('visit'),
#    rdflib.term.Literal('table')),
#   (rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('subsidize'),
#    rdflib.term.Literal('half')),
#   (rdflib.term.Literal('all.houston@enron.com'),
#    rdflib.term.Literal('purchase'),
#    rdflib.term.Literal('seat')),
#   (rdflib.term.Literal('Club'),
#    rdflib.term.Literal('collect'),
#    rdflib.term.Literal('t shirt')),
#   (rdflib.term.Literal('Club'),
#    rdflib.term.Literal('collect'),
#    rdflib.term.Literal('month')),
#   (rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('host'),
#    rdflib.term.Literal('kid')),
#   (rdflib.term.Literal('October'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('chapter')),
#   (rdflib.term.Literal('Foundation'),
#    rdflib.term.Literal('seek'),
#    rdflib.term.Literal('walker')),
#   (rdflib.term.Literal('Walk'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('event')),
#   (rdflib.term.Literal('Transportation'),
#    rdflib.term.Literal('sponsor'),
#    rdflib.term.Literal('program')),
#   (rdflib.term.Literal('Enron'),
#    rdflib.term.Literal('subsidize'),
#    rdflib.term.Literal('%'))],
#  15485: [(rdflib.term.Literal('Measurement'),
#    rdflib.term.Literal('analyze'),
#    rdflib.term.Literal('model')),
#   (rdflib.term.Literal('analysis'),
#    rdflib.term.Literal('hope'),
#    rdflib.term.Literal('give answer'))],
#  15487: [(rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('kick'),
#    rdflib.term.Literal('campaign')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('est'),
#    rdflib.term.Literal('stamina')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('test'),
#    rdflib.term.Literal('curiosity')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('test'),
#    rdflib.term.Literal('version')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('encourage'),
#    rdflib.term.Literal('attend off')),
#   (rdflib.term.Literal('all_enron_houston@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('chance')),
#   (rdflib.term.Literal('Skilling'),
#    rdflib.term.Literal('serve'),
#    rdflib.term.Literal('lifeline')),
#   (rdflib.term.Literal('Nelson'),
#    rdflib.term.Literal('host'),
#    rdflib.term.Literal('event')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('element')),
#   (rdflib.term.Literal('office.chairman@enron.com'),
#    rdflib.term.Literal('hope'),
#    rdflib.term.Literal('reach goal'))],
#  15488: [(rdflib.term.Literal('all.america@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('business')),
#   (rdflib.term.Literal('all.america@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('time')),
#   (rdflib.term.Literal('all.america@enron.com'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('member'))],
#  15490: [(rdflib.term.Literal('Conduct'),
#    rdflib.term.Literal('hold'),
#    rdflib.term.Literal('employee')),
#   (rdflib.term.Literal('Management'),
#    rdflib.term.Literal('conduct'),
#    rdflib.term.Literal('audits'))],
#  15492: [(rdflib.term.Literal('audrey.robertson@enron.com'),
#    rdflib.term.Literal('forward'),
#    rdflib.term.Literal('box'))],
#  15494: [(rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('receive'),
#    rdflib.term.Literal('message')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('begin'),
#    rdflib.term.Literal('provide feedback')),
#   (rdflib.term.Literal('michelle.lokay@enron.com'),
#    rdflib.term.Literal('have'),
#    rdflib.term.Literal('question'))],
#  15495: [(rdflib.term.Literal('all.houston@enron.com'),
#    rdflib.term.Literal('make'),
#    rdflib.term.Literal('contribution')),
#   (rdflib.term.Literal('Award'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('program')),
#   (rdflib.term.Literal('Tickets'),
#    rdflib.term.Literal('remain'),
#    rdflib.term.Literal('sale')),
#   (rdflib.term.Literal('Tickets'),
#    rdflib.term.Literal('remain'),
#    rdflib.term.Literal('p.m.')),
#   (rdflib.term.Literal('Glassberg'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('butterfly')),
#   (rdflib.term.Literal('He'),
#    rdflib.term.Literal('inform'),
#    rdflib.term.Literal('activity')),
#   (rdflib.term.Literal('Walk'),
#    rdflib.term.Literal('be'),
#    rdflib.term.Literal('event'))],
#  15496: [(rdflib.term.Literal('Vernon'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('tw')),
#   (rdflib.term.Literal('Vernon'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('update')),
#   (rdflib.term.Literal('meiling.chen@enron.com'),
#    rdflib.term.Literal('apply'),
#    rdflib.term.Literal('logic')),
#   (rdflib.term.Literal('meiling.chen@enron.com'),
#    rdflib.term.Literal('get'),
#    rdflib.term.Literal('price'))],
#  15497: [(rdflib.term.Literal('the.pulse-ets@enron.com'),
#    rdflib.term.Literal('think'),
#    rdflib.term.Literal('experience'))],
#  15498: [(rdflib.term.Literal('Dan'),
#    rdflib.term.Literal('conduct'),
#    rdflib.term.Literal('session')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('post'),
#    rdflib.term.Literal('question')),
#   (rdflib.term.Literal('all.worldwide@enron.com'),
#    rdflib.term.Literal('add'),
#    rdflib.term.Literal('comment'))],
#  15499: [(rdflib.term.Literal('lorraine.lindberg@enron.com'),
#    rdflib.term.Literal('discuss'),
#    rdflib.term.Literal('meeting')),
#   (rdflib.term.Literal('lorraine.lindberg@enron.com'),
#    rdflib.term.Literal('incorporate'),
#    rdflib.term.Literal('transport option')),
#   (rdflib.term.Literal('lorraine.lindberg@enron.com'),
#    rdflib.term.Literal('incorporate'),
#    rdflib.term.Literal('capacity'))]}

# %% [raw]
# def query_relationships(predicate, g, msg_key_idx, msg_key_idx_reverse):
#     doc = nlp(predicate)
#     p = Literal(doc[0].lemma_)
#     qres = g.query('SELECT ?s ?o WHERE { ?s ?p ?o . }', initBindings = {'p' : p})
#
#     for row in qres:
#         r = (row[0], p, row[1])
#         print("%s\t*%s*\t%s -- msg_keys: %s" % (row[0], p, row[1], msg_key_idx[r]))

# %%
query_relationships("removed", g, msg_key_idx, msg_key_idx_reverse)
# Out:
# david.badura@enron.com *remove* category -- msg_keys: [15074]
# lorna.brennan@enron.com *remove* amount -- msg_keys: [15460]

# %%
def create_graph_from_email_relationships(mbox):
    g = Graph('Sleepycat', identifier='enron_relationships') # needs python lib bsddb3
    g.open('enron_relationships.rdf', create = True)
    msg_key_idx = {}
    msg_key_idx_reverse = {}
    
    i = 0
    msg_count = len(msgs)
    for msg_key in msgs: # no limit now, do all messages
        i += 1
        if i % 10000 == 0:
            print("Message %d of %d" % (i, msg_count))
    
        # find relationships
        rels = extract_email_relationships(mbox, msg_key)
        
        # for each relationship
        for (s, p, o) in rels:
            
            r = (Literal(s), Literal(p), Literal(o))
            
            # add relationship to the graph
            g.add(r)
            
            # remember which message(s) had this relationship
            if r in msg_key_idx:
                msg_key_idx[r].append(msg_key)
            else:
                msg_key_idx[r] = [msg_key]
                
            # remember the relationships this message had
            if msg_key in msg_key_idx_reverse:
                msg_key_idx_reverse[msg_key].append(r)
            else:
                msg_key_idx_reverse[msg_key] = [r]
                
    return (g, msg_key_idx, msg_key_idx_reverse)

# %%
(g, msg_key_idx, msg_key_idx_reverse) = create_graph_from_email_relationships(mbox)
# Out:
# Message 10000 of 517401
# Message 20000 of 517401
# Message 30000 of 517401
# Message 40000 of 517401
# Message 50000 of 517401
# Message 60000 of 517401
# Message 70000 of 517401
# Message 80000 of 517401
# Message 90000 of 517401
# Message 100000 of 517401
# Message 110000 of 517401
# Message 120000 of 517401
# Message 130000 of 517401
# Message 140000 of 517401
# Message 150000 of 517401
# Message 160000 of 517401
# Message 170000 of 517401
# Message 180000 of 517401
# Message 190000 of 517401
# Message 200000 of 517401
# Message 210000 of 517401
# Message 220000 of 517401
# Message 230000 of 517401
# Message 240000 of 517401
# Message 250000 of 517401
# Message 260000 of 517401
# Message 270000 of 517401
# Message 280000 of 517401
# Message 290000 of 517401
# Message 300000 of 517401
# Message 310000 of 517401
# Message 320000 of 517401
# Message 330000 of 517401
# Message 340000 of 517401
# Message 350000 of 517401
# Message 360000 of 517401
# Message 370000 of 517401
# Message 380000 of 517401
# Message 390000 of 517401
# Message 400000 of 517401
# Message 410000 of 517401
# Message 420000 of 517401
# Message 430000 of 517401
# Message 440000 of 517401
# Message 450000 of 517401
# Message 460000 of 517401
# Message 470000 of 517401
# Message 480000 of 517401

# %%
g
# Out:
# <Graph identifier=enron_relationships (<class 'rdflib.graph.Graph'>)>

# %%
len(msg_key_idx)
# Out:
# 296379

# %%
len(msg_key_idx_reverse)
# Out:
# 249924

# %%
query_relationships("removed", g, msg_key_idx, msg_key_idx_reverse)
# Out:
# Enron *remove* position -- msg_keys: [351804]
# jbass1@houston.rr.com *remove* travel insurance -- msg_keys: [72]
# You *remove* church -- msg_keys: [132170, 132354, 132864, 133883]
# ken.powers@enron.com *remove* datum -- msg_keys: [326808]
# Doug *remove* downtime -- msg_keys: [470390]
# Snyder *remove* obstacle -- msg_keys: [492, 4811, 7297]
# Program *remove* obstacle -- msg_keys: [35513, 221463, 222311]
# oewdd@daum.net *remove* obstacle -- msg_keys: [442706]
# Anjam *remove* attempt -- msg_keys: [198674, 202452, 217934]
# jmctarnaghan@gmssr.com *remove* appearance -- msg_keys: [308456, 320105]
# Jason *remove* center -- msg_keys: [205343, 213375, 219731]
# dawn.mcdonald@enron.com *remove* access -- msg_keys: [50077, 51936, 53100]
# jennifer.reed@enron.com *remove* access -- msg_keys: [12500]
# Anjam *remove* reply -- msg_keys: [198674, 202452, 217934]
# darron.giron@enron.com *remove* m -- msg_keys: [248403, 249184, 250034, 251627]
# FERC *remove* rate authority -- msg_keys: [424172]
# plucci@enron.com *remove* end -- msg_keys: [131197, 131203, 131204, 131246, 131269, 131304, 131306, 131314, 131597]
# will.smith@enron.com *remove* view -- msg_keys: [369036]
# narsimha.misra@enron.com *remove* bid -- msg_keys: [246233]
# I *remove* trailer -- msg_keys: [398451, 401268]
# gerald.nemec@enron.com *remove* rep -- msg_keys: [181313]
# citibank.bill.manager.subscribers@mailman.enron.com *remove* card -- msg_keys: [458808]
# undisclosed.recipients@mailman.enron.com *remove* mailing -- msg_keys: [162361, 222373, 246816]
# elected4@mailman.enron.com *remove* mailing -- msg_keys: [223038]
# new_features@listserv2.dowjones.com *remove* mailing -- msg_keys: [354355, 484199]
# selected4@mailman.enron.com *remove* mailing -- msg_keys: [441569]
# zone21@server.uva.br *remove* mailing -- msg_keys: [442527]
# 556kahu@digitech.co.nz *remove* domain -- msg_keys: [35489]
# gerald.nemec@enron.com *remove* pricing information -- msg_keys: [184653, 188915]
# chris.meyer@enron.com *remove* narrative -- msg_keys: [42417]
# David *remove* schedule -- msg_keys: [98679]
# charlotte.hawkins@enron.com *remove* nom -- msg_keys: [506992, 509035, 512884]
# leslie.reeves@enron.com *remove* name -- msg_keys: [174901]
# Tana *remove* name -- msg_keys: [79602, 93641]
# clint.dean@enron.com *remove* name -- msg_keys: [33467]
# janet.butler@enron.com *remove* name -- msg_keys: [102231, 104636, 104852]
# davidflowers@txu.com *remove* name -- msg_keys: [42866]
# connie.sutton@enron.com *remove* name -- msg_keys: [86761, 92276]
# cheryl.dudley@enron.com *remove* name -- msg_keys: [80120, 84652, 86273, 91540, 94626, 95806, 505198, 505537, 506422, 507911, 508891, 509197, 513469, 513620, 514564, 515800, 515990, 515991, 515997, 516001]
# linda.bryan@enron.com *remove* name -- msg_keys: [82035, 92863]
# beth.miertschin@enron.com *remove* name -- msg_keys: [487120]
# james.derrick@enron.com *remove* name -- msg_keys: [374198]
# jverner@vernerbrumley.com *remove* name -- msg_keys: [148507, 150868, 187396, 190155]
# bob@alohablooms.com *remove* name -- msg_keys: [3260, 5753]
# asmesch@flash.net *remove* name -- msg_keys: [158082, 158722]
# net-athome@sigma-consultants.fr *remove* name -- msg_keys: [158620, 159912]
# sbconlinebilling@sbc.m0.net *remove* name -- msg_keys: [3395]
# rob@alohablooms.com *remove* name -- msg_keys: [5579]
# sally.beck@alumni.utexas.net *remove* name -- msg_keys: [179649]
# texasexes@avatartechnology.com *remove* name -- msg_keys: [248292, 250109]
# dgiron@alumni.utexas.net *remove* name -- msg_keys: [251053]
# Cindy *remove* name -- msg_keys: [98612]
# tracey.kozadinos@enron.com *remove* name -- msg_keys: [457699]
# sally.beck@enron.com *remove* name -- msg_keys: [172097, 173017, 175325, 178749]
# elizabeth.serralheiro@enron.com *remove* name -- msg_keys: [378966, 389544]
# joel.bennett@enron.com *remove* name -- msg_keys: [477937, 479935, 481700]
# sscott5@enron.com *remove* name -- msg_keys: [479107]
# richard.cross@enron.com *remove* name -- msg_keys: [478388, 479777, 482138]
# Hall *remove* name -- msg_keys: [169811]
# Shane *remove* tpa -- msg_keys: [181881]
# gerald.nemec@enron.com *remove* tpa -- msg_keys: [181881]
# jacob.krautsch@enron.com *remove* approval -- msg_keys: [23301, 24674, 26073, 28028]
# phil.polsky@enron.com *remove* today -- msg_keys: [42981]
# paul.racicot@enron.com *remove* chart -- msg_keys: [353993]
# Smith *remove* response -- msg_keys: [108697, 111718, 119468, 123273, 130665]
# FERC *remove* prohibition -- msg_keys: [102581, 103021, 104362, 148679, 151099]
# jean.ryall@enron.com *remove* recommendation -- msg_keys: [105647, 111706, 116553, 117944, 126396, 337598, 340749]
# truong.vu@enron.com *remove* day(s -- msg_keys: [50049, 50159, 50536, 50545, 50582, 51342, 51890, 52736]
# david.forster@enron.com *remove* couple -- msg_keys: [461208]
# chris.booth@enron.com *remove* fuel option -- msg_keys: [54124, 63660, 66342]
# roseann.engeldorf@enron.com *remove* bracket -- msg_keys: [54433, 64238, 65051]
# EES *remove* enforcement -- msg_keys: [397882]
# dan.hyvl@enron.com *remove* flag -- msg_keys: [282415, 283734]
# citibank.bill.manager.subscribers@mailman.enron.com *remove* account -- msg_keys: [458808]
# FERC *remove* trading -- msg_keys: [102581, 103021, 104362, 148679, 151099]
# Commission *remove* decision -- msg_keys: [302057, 312384, 318869]
# jonathan.hoff@enron.com *remove* portion -- msg_keys: [426284, 430516, 432793]
# PG&E *remove* portion -- msg_keys: [311304, 325024]
# HPL *remove* tower -- msg_keys: [186952, 189874]
# tana.jones@enron.com *remove* brewer -- msg_keys: [77341]
# dan.hyvl@enron.com *remove* line -- msg_keys: [282372, 284597, 290142]
# line *remove* line -- msg_keys: [22992, 26035]
# Grant *remove* line -- msg_keys: [282372, 284597]
# eric.moon@enron.com *remove* language -- msg_keys: [131423]
# dwight.beach@enron.com *remove* language -- msg_keys: [185692, 190992]
# Commission *remove* language -- msg_keys: [302057, 312384, 318869]
# savita.puthigai@enron.com *remove* language -- msg_keys: [451640, 462777]
# john.lavorato@enron.com *remove* sheet -- msg_keys: [467750]
# jeremy.wong@enron.com *remove* day -- msg_keys: [474199]
# truong.vu@enron.com *remove* day -- msg_keys: [50049, 50049, 50050, 50159, 50513, 50513, 50532, 50536, 50536, 50545, 50582, 50582, 51342, 51342, 51365, 51890, 52711, 52711, 52736, 52736, 251030, 251030]
# robert.cass@enron.com *remove* bayside -- msg_keys: [1238, 2240, 4904, 6062]
# truong.vu@enron.com *remove* holiday -- msg_keys: [50049, 50536, 50582, 51342, 52736]
# rob.gay@enron.com *remove* contingency -- msg_keys: [489726, 490228]
# kim.ward@enron.com *remove* number -- msg_keys: [288704]
# david.forster@enron.com *remove* entergy -- msg_keys: [463899]
# gfergus@brobeck.com *remove* court -- msg_keys: [397879, 400185, 403894]
# jonathan.hoff@enron.com *remove* amortization -- msg_keys: [425584, 430246, 432394]
# inside *remove* shelf -- msg_keys: [202994, 213200, 221083]
# Democrats *remove* urgency clause -- msg_keys: [107721, 110127, 119501, 122054, 123727]
# skean@enron.com *remove* electricity gird -- msg_keys: [108512, 110650, 117040, 123846, 128568, 306591, 321944]
# you *remove* fork -- msg_keys: [334288, 335125, 335632]
# Smith *remove* holmstead -- msg_keys: [108697, 111718, 119468, 123273, 130665]
# Police *remove* protester -- msg_keys: [108993, 113932, 119269, 122044, 125516]
# California *remove* barrier -- msg_keys: [109347, 111191, 120531, 126758, 128721, 311427, 325096]
# andy.zipper@enron.com *remove* ice -- msg_keys: [164142, 164421, 165953, 167729]
# We *remove* pound -- msg_keys: [26678, 27086, 27434]
# Titan *remove* building -- msg_keys: [55345, 64634]
# shackleton@worldnet.att.net *remove* picture -- msg_keys: [156898, 159529, 160608]
# He *remove* machine -- msg_keys: [305663, 318393]
# Commission *remove* month -- msg_keys: [19527]
# Schundler *remove* month -- msg_keys: [342965]
# Steve *remove* meter -- msg_keys: [508227, 508618, 515187]
# gary.hanks@enron.com *remove* meter -- msg_keys: [505314, 508741, 513759]
# truong.vu@enron.com *remove* good -- msg_keys: [50218, 50524, 51359]
# globalfin@home.com *remove* recap -- msg_keys: [404366, 404418, 404425, 404449, 404809, 404965, 404976, 405076, 405137, 405239, 405266, 405307, 405369, 405601, 405643, 405748]
# john.lavorato@enron.com *remove* dependency -- msg_keys: [467750]
# catherine.clark@enron.com *remove* information -- msg_keys: [53540, 63452, 69783]
# ray.alvarez@enron.com *remove* team -- msg_keys: [343097, 424179]
# conaribuaion.1345@mailman.enron.com *remove* self -- msg_keys: [162380]
# conaribuaion.1345@oak.fujicom.co.jp *remove* self -- msg_keys: [162601]
# gary.hanks@enron.com *remove* scada -- msg_keys: [505314, 508741, 513759]
# us *remove* email address -- msg_keys: [241466, 241495, 241500, 284778, 285043, 285106, 285143, 440157, 440314, 440317, 440368, 440437]
# noreply@postmastergeneral.com *remove* email address -- msg_keys: [516339]
# chad.gardner@enron.com *remove* debit -- msg_keys: [152060]
# frank.vickers@enron.com *remove* swing flexibility -- msg_keys: [154984, 260157]
# dan.hyvl@enron.com *remove* lining -- msg_keys: [282634, 284241]
# garrick.hill@enron.com *remove* column -- msg_keys: [399254, 403703]
# Allan *remove* whalley -- msg_keys: [370715, 371820, 372191]
# Visited *remove* incumbent -- msg_keys: [165977, 167893]
# Enron *remove* fastow -- msg_keys: [351804]
# ray.alvarez@enron.com *remove* fastow -- msg_keys: [343097, 424179]
# dan.hyvl@enron.com *remove* requirement -- msg_keys: [283225, 284282]
# Lee *remove* requirement -- msg_keys: [283225, 284282]
# California *remove* development -- msg_keys: [109347, 111191, 120531, 126758, 128721, 311427, 325096]
# He *remove* tub -- msg_keys: [305663, 318393]
# gerald.nemec@enron.com *remove* right reservation -- msg_keys: [181767]
# expert *remove* pad gas -- msg_keys: [182385]
# Mier *remove* trader -- msg_keys: [473235]
# Moss *remove* game -- msg_keys: [13653]
# gerald.nemec@enron.com *remove* affiliate assignment -- msg_keys: [184712, 189201]
# andy.rodriquez@enron.com *remove* word -- msg_keys: [337716]
# Brown *remove* acreage language -- msg_keys: [186645, 188719]
# Brown *remove* dedication language -- msg_keys: [186645, 188719]
# gerald.nemec@enron.com *remove* season reference -- msg_keys: [186925, 189019]
# tammy.botsford@morganstanley.com *remove* business day -- msg_keys: [376513]
# melba.lozano@enron.com *remove* document -- msg_keys: [379806, 386192]
# dan.hyvl@enron.com *remove* document -- msg_keys: [282372, 284597, 290142]
# Grant *remove* document -- msg_keys: [282372, 284597]
# General *remove* condition -- msg_keys: [339560]
# gerald.nemec@enron.com *remove* discussion -- msg_keys: [186480, 188540]
# steven.leppard@enron.com *remove* pricing example -- msg_keys: [205340, 219467]
# jay.webb@enron.com *remove* thinking -- msg_keys: [462684]
# debra.perlingiere@enron.com *remove* provision -- msg_keys: [193464, 195677]
# dale.rasmussen@enron.com *remove* provision -- msg_keys: [55750, 56837, 63742, 64862, 69301, 75885]
# steven.bunkin@gs.com *remove* provision -- msg_keys: [31132]
# sara.shackleton@enron.com *remove* wording -- msg_keys: [384480, 389904]
# carol.clair@enron.com *remove* definition -- msg_keys: [291180, 292994]
# lisa.druzbik@enron.com *remove* sentence -- msg_keys: [182216]
# louise.kitchen@enron.com *remove* sentence -- msg_keys: [459819]
# We *remove* code -- msg_keys: [151887, 151926, 152457, 152461, 152854, 152922]
# rbuy@ect.enron.com *remove* sealant -- msg_keys: [241001]
# General *remove* order -- msg_keys: [339560]
# marion.collins@enron.com *remove* order -- msg_keys: [39698]
# stacy.dickson@enron.com *remove* point concept -- msg_keys: [242352, 242523]
# judy.thorne@enron.com *remove* draft -- msg_keys: [182096, 192904]
# jgermain@kaztex.com *remove* draft -- msg_keys: [132593]
# edahnxpnkb@dlc.fi *remove* request -- msg_keys: [35244]
# scott.stoness@enron.com *remove* request -- msg_keys: [304841, 321448]
# rita.wynne@enron.com *remove* sale -- msg_keys: [506820, 509427, 515543]
# dwindham@uclink4.berkeley.edu *remove* sale -- msg_keys: [301467, 321684]
# plucci@enron.com *remove* email -- msg_keys: [131197, 131204, 131246, 131304, 131306, 131314, 131597]
# beckynoodl@aol.com *remove* email -- msg_keys: [247262, 247278]
# leanne@integrityrs.com *remove* email -- msg_keys: [345821, 345937]
# robert.superty@enron.com *remove* calcagno -- msg_keys: [260584]
# robert.superty@enron.com *remove* group -- msg_keys: [260584]
# FERC *remove* complaint -- msg_keys: [23291, 25814, 27482]
# shorton@enron.com *remove* cost -- msg_keys: [45163]
# us *remove* short -- msg_keys: [406950]
# rita.wynne@enron.com *remove* ena -- msg_keys: [506820, 509427, 515543]
# carol.clair@enron.com *remove* trigger -- msg_keys: [291180, 292994]
# redenvelope@gifts.redenvelopegifts.com *remove* list -- msg_keys: [23894, 24190, 24209, 24318, 24661, 24983, 25149]
# tana.jones@enron.com *remove* list -- msg_keys: [77341]
# louis.dicarlo@enron.com *remove* list -- msg_keys: [376697, 419095]
# veronica.espinoza@enron.com *remove* list -- msg_keys: [295267, 295697, 296097]
# Tana *remove* list -- msg_keys: [79602, 93641]
# clint.dean@enron.com *remove* list -- msg_keys: [33467]
# edahnxpnkb@dlc.fi *remove* list -- msg_keys: [35244]
# davidflowers@txu.com *remove* list -- msg_keys: [41418]
# us *remove* list -- msg_keys: [440291]
# Allan *remove* list -- msg_keys: [370715, 371820, 372191]
# frank.davis@enron.com *remove* list -- msg_keys: [76938, 81204]
# connie.sutton@enron.com *remove* list -- msg_keys: [86761, 92276]
# cheryl.dudley@enron.com *remove* list -- msg_keys: [80120, 84652, 94626, 95806]
# linda.bryan@enron.com *remove* list -- msg_keys: [82035, 92863]
# monika.causholli@enron.com *remove* list -- msg_keys: [470409]
# pete.davis@enron.com *remove* list -- msg_keys: [139964, 470434, 471148]
# marie.hejka@enron.com *remove* list -- msg_keys: [175512]
# beth.miertschin@enron.com *remove* list -- msg_keys: [487120]
# james.derrick@enron.com *remove* list -- msg_keys: [374198]
# jverner@vernerbrumley.com *remove* list -- msg_keys: [148507, 150868, 187396, 190155]
# Steve *remove* list -- msg_keys: [508227, 508618, 515187]
# bob@alohablooms.com *remove* list -- msg_keys: [3260, 5753]
# asmesch@flash.net *remove* list -- msg_keys: [158082, 158722]
# net-athome@sigma-consultants.fr *remove* list -- msg_keys: [158620, 159912]
# sbconlinebilling@sbc.m0.net *remove* list -- msg_keys: [3395]
# jacqueline.coleman@enron.com *remove* list -- msg_keys: [198063, 273844, 457732, 458274, 486785, 489111]
# rob@alohablooms.com *remove* list -- msg_keys: [5579]
# sally.beck@alumni.utexas.net *remove* list -- msg_keys: [179649]
# Anjam *remove* list -- msg_keys: [198674, 202452, 217934]
# danielle.marcinkowski@enron.com *remove* list -- msg_keys: [475005]
# aastavast@earthlink.net *remove* list -- msg_keys: [222441]
# abnjlc@earthlink.net *remove* list -- msg_keys: [222909]
# carbob@pacbell.net *remove* list -- msg_keys: [222956]
# Monica *remove* list -- msg_keys: [279521, 280392, 281160]
# p..o'neil@enron.com *remove* list -- msg_keys: [246940]
# texasexes@avatartechnology.com *remove* list -- msg_keys: [248292, 250109]
# dgiron@alumni.utexas.net *remove* list -- msg_keys: [251053]
# darlene.forsyth@enron.com *remove* list -- msg_keys: [267730, 268936, 270059]
# Gas *remove* list -- msg_keys: [376697, 419095]
# ksbaa@indiana.edu *remove* list -- msg_keys: [277161]
# Cindy *remove* list -- msg_keys: [98482]
# support3@clearstation.com *remove* list -- msg_keys: [294043]
# jennifer.rudolph@enron.com *remove* list -- msg_keys: [302485, 314641]
# orders@acteva.com *remove* list -- msg_keys: [308054, 310446, 320838, 323327]
# sally.beck@enron.com *remove* list -- msg_keys: [172097, 173017, 175325, 178749]
# new_features@listserv2.dowjones.com *remove* list -- msg_keys: [354355, 484199, 484454, 484486]
# elizabeth.serralheiro@enron.com *remove* list -- msg_keys: [378966, 389544]
# alewis@ect.enron.com *remove* list -- msg_keys: [404366, 404418, 404425, 404449, 404809, 404965, 404976, 405076, 405137, 405239, 405266, 405307, 405369, 405601, 405643, 405748]
# ac76@earthlink.net *remove* list -- msg_keys: [442633]
# joel.bennett@enron.com *remove* list -- msg_keys: [477937, 479935, 481700]
# jaroslaw.ferenc@enron.com *remove* list -- msg_keys: [451199, 452424]
# sscott5@enron.com *remove* list -- msg_keys: [479107]
# london@icelandair.is *remove* list -- msg_keys: [477256, 479576, 482675]
# richard.cross@enron.com *remove* list -- msg_keys: [478388, 479777, 482138]
# Hall *remove* list -- msg_keys: [169811]
# noreply@postmastergeneral.com *remove* list -- msg_keys: [516339]
# States *remove* list -- msg_keys: [341766]
# Brian *remove* list -- msg_keys: [279454, 280319, 281093]
# Stuart *remove* list -- msg_keys: [131937]
# Jessica *remove* list -- msg_keys: [98778]
# howard.sangwine@enron.com *remove* list -- msg_keys: [467491, 468595, 469604]
# amy.felling@enron.com *remove* list -- msg_keys: [287952]
# matt.sample@enform.com *remove* leisure -- msg_keys: [457343]
# jacob.krautsch@enron.com *remove* form -- msg_keys: [23301, 24674, 26073, 28028]
# gerald.nemec@enron.com *remove* form -- msg_keys: [183491, 189076]
# jfields@argentinc.com *remove* form -- msg_keys: [22569, 25477, 27798]
# amy.felling@enron.com *remove* kennedy -- msg_keys: [287952]
# Enron *remove* equipment -- msg_keys: [184817, 188917]
# HPL *remove* equipment -- msg_keys: [186952, 189874]
# alice.johnson@enron.com *remove* shipper -- msg_keys: [48661]
# robert.cass@enron.com *remove* product -- msg_keys: [1238, 2240, 4904, 6062]
# cguarino@dow.com *remove* section -- msg_keys: [84534, 91790]
# pete.davis@enron.com *remove* dispatch -- msg_keys: [99577]
# PinkRock *remove* cat urine -- msg_keys: [298582, 298582, 305589, 305589]
# Smith *remove* agenda -- msg_keys: [108697, 111718, 119468, 123273, 130665]
# We *remove* limit -- msg_keys: [26678, 27086, 27434]
# bill@katzlaw.com *remove* s -- msg_keys: [183117]
# Rate *remove* price effect -- msg_keys: [307295, 318284]
# enron.com@denverpost.publishmail.com *remove* distribution -- msg_keys: [270507]
# jerry.graves@enron.com *remove* distribution -- msg_keys: [325549]
# shirley.crenshaw@enron.com *remove* calendar -- msg_keys: [200639, 210483, 210491, 214737]
# kimberly.hillis@enron.com *remove* calendar -- msg_keys: [467172, 468648, 470043]
# FERC *remove* market prohibition -- msg_keys: [309595, 321582]
# jerry.graves@enron.com *remove* outage report -- msg_keys: [325549]
# We *remove* enron -- msg_keys: [462621]
# States *remove* hezbollah -- msg_keys: [341766]
# jeremy.wong@enron.com *remove* July -- msg_keys: [474199]
# joe.parks@enron.com *remove* ticket -- msg_keys: [41284]
# skean@enron.com *remove* t -- msg_keys: [108512, 110650, 117040, 123846, 128568, 306591, 321944]
# gfergus@brobeck.com *remove* case -- msg_keys: [397879, 400185, 403894]
# cooper.richey@enron.com *remove* c++ -- msg_keys: [358572]
# pete.davis@enron.com *remove* finals -- msg_keys: [362365, 363372]
# dan.hyvl@enron.com *remove* example -- msg_keys: [282976, 284400]
# lcampbel@enron.com *remove* mail address -- msg_keys: [24961]
# Reply *remove* subject -- msg_keys: [234724, 234733, 234739, 234752, 234754, 234759, 234767, 234768, 234769, 234773, 234774, 234775, 234779, 234872, 234888, 235530]
# joe.parks@enron.com *remove* pricing -- msg_keys: [41284]
# melba.lozano@enron.com *remove* footer -- msg_keys: [377512, 379806, 386192, 392123]
# dale.neuner@enron.com *remove* cad -- msg_keys: [379438, 392362]
# EES *remove* compliance proceeding -- msg_keys: [397889, 400929, 403786]
# robert.cass@enron.com *remove* point -- msg_keys: [1238, 2240, 4904, 6062]
# garrick.hill@enron.com *remove* debt value -- msg_keys: [399254, 403703]
# mark.taylor@enron.com *remove* cabinet -- msg_keys: [382524, 389297]
# Marshall *remove* system -- msg_keys: [98105]
# NGC *remove* system -- msg_keys: [423541]
# NGC *remove* voltage constraint -- msg_keys: [423541]
# shackleton@austin.rr.com *remove* address -- msg_keys: [158002]
# dm-kz1-help@dmx0.com *remove* address -- msg_keys: [511480]
# james.grace@enron.com *remove* reference -- msg_keys: [149266, 151359]
# n..gray@enron.com *remove* reference -- msg_keys: [444392, 445527, 462718]
# jonathan.hoff@enron.com *remove* reference -- msg_keys: [425584, 430246, 432394]
# I *remove* reference -- msg_keys: [290685, 292441]
# justin.boyd@enron.com *remove* reference -- msg_keys: [448893, 454342]
# jean.ryall@enron.com *remove* reference -- msg_keys: [105647, 111706, 116553, 117944, 126396, 337598, 340749]
# SettleSupplemental.xls *remove* reference -- msg_keys: [277528]
# susan.scott@enron.com *remove* reference -- msg_keys: [19394, 236667]
# rich.heidorn@ipgdirect.com *remove* reference -- msg_keys: [354424]
# gerald.nemec@enron.com *remove* presence -- msg_keys: [183102]
# susan.scott@enron.com *remove* item -- msg_keys: [478096, 480257, 482478]
# david.badura@enron.com *remove* category -- msg_keys: [15074, 17856]
# louise.kitchen@enron.com *remove* confirm provision -- msg_keys: [459740]
# bob.hillier@enron.com *remove* configuration -- msg_keys: [462745]
# Doug *remove* maintenance -- msg_keys: [470390]
# tom.victorio@enron.com *remove* retaileast -- msg_keys: [472888]
# a..bibi@enron.com *remove* paragraph -- msg_keys: [168558]
# Bear *remove* paragraph -- msg_keys: [379796, 388372]
# jmpa@dynegy.com *remove* paragraph -- msg_keys: [476748, 477301, 480947]
# greg.johnston@enron.com *remove* paragraph -- msg_keys: [398353, 401271]
# plucci@enron.com *remove* signature -- msg_keys: [131197, 131203, 131204, 131246, 131269, 131304, 131306, 131314, 131597]
# merger *remove* competition -- msg_keys: [463908]
# george.robinson@enron.com *remove* well -- msg_keys: [21973, 23578, 25382]
# dawn.mcdonald@enron.com *remove* directory -- msg_keys: [50077, 51936, 53100]
# matt.sample@enform.com *remove* show -- msg_keys: [457343]
# NGC *remove* installation -- msg_keys: [423541]
# sally.beck@alumni.utexas.net *remove* time -- msg_keys: [179649]
# texasexes@avatartechnology.com *remove* time -- msg_keys: [248292, 250109]
# darlene.forsyth@enron.com *remove* time -- msg_keys: [267730, 268936, 270059]
# sally.beck@enron.com *remove* time -- msg_keys: [172097, 173017, 178749]
# terry.porter@intcx.com *remove* time -- msg_keys: [469409]
# Enron *remove* termination -- msg_keys: [184817, 188917]
# lorna.brennan@enron.com *remove* amount -- msg_keys: [15460, 17087, 18764]
# judy.thorne@enron.com *remove* amendment -- msg_keys: [182096, 192904]
# Shane *remove* strike -- msg_keys: [181881]
# gerald.nemec@enron.com *remove* strike -- msg_keys: [181881]
# Schundler *remove* toll -- msg_keys: [342965]
# troy.denetsosie@enron.com *remove* bike -- msg_keys: [41539, 409692]
# lcampbel@enron.com *remove* record -- msg_keys: [24961]
# Commission *remove* restriction -- msg_keys: [19527]
# bob.hillier@enron.com *remove* storage -- msg_keys: [462745]
# kim.ward@enron.com *remove* phrase -- msg_keys: [288704]
# frank.davis@enron.com *remove* bryan -- msg_keys: [76938, 81204]
# alice.johnson@enron.com *remove* report -- msg_keys: [48661]
# them *remove* report -- msg_keys: [228144, 229091, 231086]
# gerald.nemec@enron.com *remove* report -- msg_keys: [184653, 188915]
# michelle.cash@enron.com *remove* anything -- msg_keys: [491157]
# ripley@stats.ox.ac.uk *remove* version -- msg_keys: [358825]
# valarie.sabo@enron.com *remove* mtm -- msg_keys: [471710, 473398, 473467]
# Dave *remove* corporation -- msg_keys: [76557]
# gerald.nemec@enron.com *remove* condition precedent -- msg_keys: [21285, 181751, 185052, 189343]
# sundar.chitradurga@enron.com *remove* book -- msg_keys: [293649]
# mark.powell@enron.com *remove* concept -- msg_keys: [21338]
# peter.keohane@enron.com *remove* concept -- msg_keys: [21441]
# jfields@argentinc.com *remove* watermark -- msg_keys: [21796, 22599, 25992]
# george.robinson@enron.com *remove* psh -- msg_keys: [21973, 23578, 25382]
# skean@enron.com *remove* roadblock -- msg_keys: [108512, 110650, 117040, 123846, 128568, 306591, 321944]
